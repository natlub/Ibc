# %%
# tweakreg defaults: 
# threshold = 4
# conv_width = 3.5
# use round = No --> roundlo = -1, roundhi = 1
# peakmin = //
# peakmax = //

# %%
import sys
sys.path.append("/Users/natalie/PycharmProjects/code/")
    
from Drizzle_func import *
import pandas
import matplotlib.pyplot as plt
# Out:
# The following task in the stsci.skypac package can be run with TEAL:
#                                     skymatch
# The following tasks in the drizzlepac package can be run with TEAL:
#     astrodrizzle       imagefindpars           mapreg              photeq
#      pixreplace           pixtopix            pixtosky        refimagefindpars
#      resetbits          runastrodriz          skytopix           tweakback
#       tweakreg           updatenpol

# %%
# tweak_run(path, n_up, threshold_ini, threshold_gap, conv_width_ini, conv_width_gap, 
# roundlo_val_ini, roundlo_gap, roundhi_val_ini, roundhi_gap, peakmax_val_ini, peakmax_gap):
test = tweak_run('/Users/natalie/anaconda2/envs/iraf27/iraf/sn/2000ds/2000ds_pre/tweak_555_2',10,5,1,3.5,0,-1,0,1,0,1000,0)
# Out:
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 11:10:15.908 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u3m71605r_c0m.fits
#
#     u3m71606r_c0m.fits
#
# ===  Source finding for image 'u3m71605r_c0m.fits':
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 1) started at: 11:10:16.218 (12/12/2017)
#
#      Found 855 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 2) started at: 11:10:16.734 (12/12/2017)
#
#      Found 676 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 3) started at: 11:10:17.133 (12/12/2017)
#
#      Found 706 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 4) started at: 11:10:17.544 (12/12/2017)
#
#      Found 801 objects.
#
# ===  Found a TOTAL of 3038 objects in image 'u3m71605r_c0m.fits'
#
#
#
# ===  Source finding for image 'u3m71606r_c0m.fits':
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 1) started at: 11:10:18.303 (12/12/2017)
#
#      Found 699 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 2) started at: 11:10:18.748 (12/12/2017)
#
#      Found 570 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 3) started at: 11:10:19.099 (12/12/2017)
#
#      Found 593 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 4) started at: 11:10:19.523 (12/12/2017)
#
#      Found 649 objects.
#
# ===  Found a TOTAL of 2511 objects in image 'u3m71606r_c0m.fits'
#
#
#
#  Catalog trimmed to 3038 objects
#
#
# ====================
# Aligning all input images to WCS defined by u3m71605r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u3m71606r_c0m.fits
#
# Matching sources from 'u3m71606r_c0m.fits' with sources from reference image 'u3m71605r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.767121225432 -0.544393952705
#
#     with significance of  578.83479155 and  37.0  matches
#
# Found 126 matches for u3m71606r_c0m.fits...
#
# Computed  rscale  fit for  u3m71606r_c0m.fits :
#
# XSH: 0.0177742  YSH: 0.00304694    ROT: 0.00058182    SCALE: 1.00001
#
# XRMS: 0.18625    YRMS: 0.203834
#
# RMS_RA: 6.96374e-06 (deg)   RMS_DEC: 3.15149e-07 (deg)
#
# Final solution based on  116  objects.
#
# wrote XY data to:  u3m71606r_c0m_catalog_fit.match
#
# Writing out shiftfile : 1shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 0.017774
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 11:10:20.496 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u3m71605r_c0m.fits
#
#     u3m71606r_c0m.fits
#
# ===  Source finding for image 'u3m71605r_c0m.fits':
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 1) started at: 11:10:20.743 (12/12/2017)
#
#      Found 821 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 2) started at: 11:10:21.132 (12/12/2017)
#
#      Found 674 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 3) started at: 11:10:21.516 (12/12/2017)
#
#      Found 701 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 4) started at: 11:10:21.983 (12/12/2017)
#
#      Found 783 objects.
#
# ===  Found a TOTAL of 2979 objects in image 'u3m71605r_c0m.fits'
#
#
#
# ===  Source finding for image 'u3m71606r_c0m.fits':
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 1) started at: 11:10:22.722 (12/12/2017)
#
#      Found 646 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 2) started at: 11:10:23.095 (12/12/2017)
#
#      Found 568 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 3) started at: 11:10:23.434 (12/12/2017)
#
#      Found 609 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 4) started at: 11:10:23.906 (12/12/2017)
#
#      Found 652 objects.
#
# ===  Found a TOTAL of 2475 objects in image 'u3m71606r_c0m.fits'
#
#
#
#  Catalog trimmed to 2979 objects
#
#
# ====================
# Aligning all input images to WCS defined by u3m71605r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u3m71606r_c0m.fits
#
# Matching sources from 'u3m71606r_c0m.fits' with sources from reference image 'u3m71605r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.83336228774 -0.546845433808
#
#     with significance of  522.179566816 and  30.0  matches
#
# Found 103 matches for u3m71606r_c0m.fits...
#
# Computed  rscale  fit for  u3m71606r_c0m.fits :
#
# XSH: 0.0301087  YSH: 0.032555    ROT: 2.2461e-05    SCALE: 1
#
# XRMS: 0.132074    YRMS: 0.171744
#
# RMS_RA: 5.40267e-06 (deg)   RMS_DEC: 4.77515e-07 (deg)
#
# Final solution based on  95  objects.
#
# wrote XY data to:  u3m71606r_c0m_catalog_fit.match
#
# Writing out shiftfile : 2shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 0.030109
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 11:10:24.826 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u3m71605r_c0m.fits
#
#     u3m71606r_c0m.fits
#
# ===  Source finding for image 'u3m71605r_c0m.fits':
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 1) started at: 11:10:25.117 (12/12/2017)
#
#      Found 791 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 2) started at: 11:10:25.585 (12/12/2017)
#
#      Found 676 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 3) started at: 11:10:25.97 (12/12/2017)
#
#      Found 699 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 4) started at: 11:10:26.371 (12/12/2017)
#
#      Found 773 objects.
#
# ===  Found a TOTAL of 2939 objects in image 'u3m71605r_c0m.fits'
#
#
#
# ===  Source finding for image 'u3m71606r_c0m.fits':
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 1) started at: 11:10:26.913 (12/12/2017)
#
#      Found 619 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 2) started at: 11:10:27.205 (12/12/2017)
#
#      Found 557 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 3) started at: 11:10:27.488 (12/12/2017)
#
#      Found 609 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 4) started at: 11:10:27.861 (12/12/2017)
#
#      Found 648 objects.
#
# ===  Found a TOTAL of 2433 objects in image 'u3m71606r_c0m.fits'
#
#
#
#  Catalog trimmed to 2939 objects
#
#
# ====================
# Aligning all input images to WCS defined by u3m71605r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u3m71606r_c0m.fits
#
# Matching sources from 'u3m71606r_c0m.fits' with sources from reference image 'u3m71605r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.796895297514 -0.619380504614
#
#     with significance of  510.37802891 and  28.0  matches
#
# Found 95 matches for u3m71606r_c0m.fits...
#
# Computed  rscale  fit for  u3m71606r_c0m.fits :
#
# XSH: 0.0391048  YSH: 0.0333478    ROT: 0.000359187    SCALE: 1.00002
#
# XRMS: 0.13279    YRMS: 0.159995
#
# RMS_RA: 5.21541e-06 (deg)   RMS_DEC: 3.61689e-07 (deg)
#
# Final solution based on  86  objects.
#
# wrote XY data to:  u3m71606r_c0m_catalog_fit.match
#
# Writing out shiftfile : 3shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 0.039105
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 11:10:28.799 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u3m71605r_c0m.fits
#
#     u3m71606r_c0m.fits
#
# ===  Source finding for image 'u3m71605r_c0m.fits':
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 1) started at: 11:10:29.023 (12/12/2017)
#
#      Found 737 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 2) started at: 11:10:29.409 (12/12/2017)
#
#      Found 671 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 3) started at: 11:10:30.0 (12/12/2017)
#
#      Found 705 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 4) started at: 11:10:30.505 (12/12/2017)
#
#      Found 778 objects.
#
# ===  Found a TOTAL of 2891 objects in image 'u3m71605r_c0m.fits'
#
#
#
# ===  Source finding for image 'u3m71606r_c0m.fits':
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 1) started at: 11:10:31.256 (12/12/2017)
#
#      Found 575 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 2) started at: 11:10:31.567 (12/12/2017)
#
#      Found 553 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 3) started at: 11:10:31.894 (12/12/2017)
#
#      Found 610 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 4) started at: 11:10:32.318 (12/12/2017)
#
#      Found 650 objects.
#
# ===  Found a TOTAL of 2388 objects in image 'u3m71606r_c0m.fits'
#
#
#
#  Catalog trimmed to 2891 objects
#
#
# ====================
# Aligning all input images to WCS defined by u3m71605r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u3m71606r_c0m.fits
#
# Matching sources from 'u3m71606r_c0m.fits' with sources from reference image 'u3m71605r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -1.03400434231 -0.702835511146
#
#     with significance of  481.234208714 and  24.0  matches
#
# Found 82 matches for u3m71606r_c0m.fits...
#
# Computed  rscale  fit for  u3m71606r_c0m.fits :
#
# XSH: 0.0135753  YSH: 0.00909101    ROT: 359.999    SCALE: 1.00001
#
# XRMS: 0.108175    YRMS: 0.146621
#
# RMS_RA: 4.52673e-06 (deg)   RMS_DEC: 4.46718e-07 (deg)
#
# Final solution based on  70  objects.
#
# wrote XY data to:  u3m71606r_c0m_catalog_fit.match
#
# Writing out shiftfile : 4shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 0.013575
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 11:10:33.397 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u3m71605r_c0m.fits
#
#     u3m71606r_c0m.fits
#
# ===  Source finding for image 'u3m71605r_c0m.fits':
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 1) started at: 11:10:33.723 (12/12/2017)
#
#      Found 682 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 2) started at: 11:10:34.040 (12/12/2017)
#
#      Found 675 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 3) started at: 11:10:34.417 (12/12/2017)
#
#      Found 724 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 4) started at: 11:10:34.912 (12/12/2017)
#
#      Found 785 objects.
#
# ===  Found a TOTAL of 2866 objects in image 'u3m71605r_c0m.fits'
#
#
#
# ===  Source finding for image 'u3m71606r_c0m.fits':
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 1) started at: 11:10:35.547 (12/12/2017)
#
#      Found 529 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 2) started at: 11:10:35.8 (12/12/2017)
#
#      Found 553 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 3) started at: 11:10:36.117 (12/12/2017)
#
#      Found 615 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 4) started at: 11:10:36.527 (12/12/2017)
#
#      Found 646 objects.
#
# ===  Found a TOTAL of 2343 objects in image 'u3m71606r_c0m.fits'
#
#
#
#  Catalog trimmed to 2866 objects
#
#
# ====================
# Aligning all input images to WCS defined by u3m71605r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u3m71606r_c0m.fits
#
# Matching sources from 'u3m71606r_c0m.fits' with sources from reference image 'u3m71605r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.999340476769 -0.749340476769
#
#     with significance of  441.169549526 and  20.0  matches
#
# Found 67 matches for u3m71606r_c0m.fits...
#
# Computed  rscale  fit for  u3m71606r_c0m.fits :
#
# XSH: 0.01522  YSH: 0.0211729    ROT: 9.78329e-05    SCALE: 1.00003
#
# XRMS: 0.108875    YRMS: 0.14227
#
# RMS_RA: 4.46551e-06 (deg)   RMS_DEC: 4.00116e-07 (deg)
#
# Final solution based on  58  objects.
#
# wrote XY data to:  u3m71606r_c0m_catalog_fit.match
#
# Writing out shiftfile : 5shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 0.015220
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 11:10:37.40 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u3m71605r_c0m.fits
#
#     u3m71606r_c0m.fits
#
# ===  Source finding for image 'u3m71605r_c0m.fits':
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 1) started at: 11:10:37.653 (12/12/2017)
#
#      Found 647 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 2) started at: 11:10:37.948 (12/12/2017)
#
#      Found 669 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 3) started at: 11:10:38.297 (12/12/2017)
#
#      Found 726 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 4) started at: 11:10:38.766 (12/12/2017)
#
#      Found 779 objects.
#
# ===  Found a TOTAL of 2821 objects in image 'u3m71605r_c0m.fits'
#
#
#
# ===  Source finding for image 'u3m71606r_c0m.fits':
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 1) started at: 11:10:39.439 (12/12/2017)
#
#      Found 491 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 2) started at: 11:10:39.700 (12/12/2017)
#
#      Found 558 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 3) started at: 11:10:40.03 (12/12/2017)
#
#      Found 621 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 4) started at: 11:10:40.425 (12/12/2017)
#
#      Found 643 objects.
#
# ===  Found a TOTAL of 2313 objects in image 'u3m71606r_c0m.fits'
#
#
#
#  Catalog trimmed to 2821 objects
#
#
# ====================
# Aligning all input images to WCS defined by u3m71605r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u3m71606r_c0m.fits
#
# Matching sources from 'u3m71606r_c0m.fits' with sources from reference image 'u3m71605r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -1.073686882 -0.724480532791
#
#     with significance of  421.984814506 and  19.0  matches
#
# Found 62 matches for u3m71606r_c0m.fits...
#
# Computed  rscale  fit for  u3m71606r_c0m.fits :
#
# XSH: 0.0053063  YSH: 0.0195344    ROT: 360    SCALE: 1.00003
#
# XRMS: 0.102293    YRMS: 0.134396
#
# RMS_RA: 4.20797e-06 (deg)   RMS_DEC: 3.8271e-07 (deg)
#
# Final solution based on  54  objects.
#
# wrote XY data to:  u3m71606r_c0m_catalog_fit.match
#
# Writing out shiftfile : 6shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 0.005306
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 11:10:41.30 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u3m71605r_c0m.fits
#
#     u3m71606r_c0m.fits
#
# ===  Source finding for image 'u3m71605r_c0m.fits':
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 1) started at: 11:10:41.541 (12/12/2017)
#
#      Found 619 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 2) started at: 11:10:41.874 (12/12/2017)
#
#      Found 661 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 3) started at: 11:10:42.211 (12/12/2017)
#
#      Found 732 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 4) started at: 11:10:42.652 (12/12/2017)
#
#      Found 785 objects.
#
# ===  Found a TOTAL of 2797 objects in image 'u3m71605r_c0m.fits'
#
#
#
# ===  Source finding for image 'u3m71606r_c0m.fits':
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 1) started at: 11:10:43.268 (12/12/2017)
#
#      Found 465 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 2) started at: 11:10:43.524 (12/12/2017)
#
#      Found 555 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 3) started at: 11:10:43.862 (12/12/2017)
#
#      Found 627 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 4) started at: 11:10:44.319 (12/12/2017)
#
#      Found 646 objects.
#
# ===  Found a TOTAL of 2293 objects in image 'u3m71606r_c0m.fits'
#
#
#
#  Catalog trimmed to 2797 objects
#
#
# ====================
# Aligning all input images to WCS defined by u3m71605r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u3m71606r_c0m.fits
#
# Matching sources from 'u3m71606r_c0m.fits' with sources from reference image 'u3m71605r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.92090910422 -0.162575770886
#
#     with significance of  407.047669049 and  19.0  matches
#
# Found 61 matches for u3m71606r_c0m.fits...
#
# Computed  rscale  fit for  u3m71606r_c0m.fits :
#
# XSH: 0.032664  YSH: 0.0510724    ROT: 360    SCALE: 1.00003
#
# XRMS: 0.129258    YRMS: 0.12692
#
# RMS_RA: 4.58453e-06 (deg)   RMS_DEC: 8.29154e-08 (deg)
#
# Final solution based on  54  objects.
#
# wrote XY data to:  u3m71606r_c0m_catalog_fit.match
#
# Writing out shiftfile : 7shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 0.032664
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 11:10:45.200 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u3m71605r_c0m.fits
#
#     u3m71606r_c0m.fits
#
# ===  Source finding for image 'u3m71605r_c0m.fits':
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 1) started at: 11:10:45.445 (12/12/2017)
#
#      Found 592 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 2) started at: 11:10:45.726 (12/12/2017)
#
#      Found 662 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 3) started at: 11:10:46.095 (12/12/2017)
#
#      Found 734 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 4) started at: 11:10:46.551 (12/12/2017)
#
#      Found 790 objects.
#
# ===  Found a TOTAL of 2778 objects in image 'u3m71605r_c0m.fits'
#
#
#
# ===  Source finding for image 'u3m71606r_c0m.fits':
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 1) started at: 11:10:47.255 (12/12/2017)
#
#      Found 437 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 2) started at: 11:10:47.504 (12/12/2017)
#
#      Found 560 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 3) started at: 11:10:47.871 (12/12/2017)
#
#      Found 630 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 4) started at: 11:10:48.304 (12/12/2017)
#
#      Found 650 objects.
#
# ===  Found a TOTAL of 2277 objects in image 'u3m71606r_c0m.fits'
#
#
#
#  Catalog trimmed to 2778 objects
#
#
# ====================
# Aligning all input images to WCS defined by u3m71605r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u3m71606r_c0m.fits
#
# Matching sources from 'u3m71606r_c0m.fits' with sources from reference image 'u3m71605r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.903253736988 -0.106643567497
#
#     with significance of  408.875548652 and  19.0  matches
#
# Found 61 matches for u3m71606r_c0m.fits...
#
# Computed  rscale  fit for  u3m71606r_c0m.fits :
#
# XSH: 0.0274346  YSH: 0.037633    ROT: 360    SCALE: 1.00002
#
# XRMS: 0.124798    YRMS: 0.140767
#
# RMS_RA: 4.7376e-06 (deg)   RMS_DEC: 2.50274e-07 (deg)
#
# Final solution based on  54  objects.
#
# wrote XY data to:  u3m71606r_c0m_catalog_fit.match
#
# Writing out shiftfile : 8shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 0.027435
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 11:10:49.188 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u3m71605r_c0m.fits
#
#     u3m71606r_c0m.fits
#
# ===  Source finding for image 'u3m71605r_c0m.fits':
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 1) started at: 11:10:49.477 (12/12/2017)
#
#      Found 563 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 2) started at: 11:10:49.794 (12/12/2017)
#
#      Found 661 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 3) started at: 11:10:50.214 (12/12/2017)
#
#      Found 720 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 4) started at: 11:10:50.697 (12/12/2017)
#
#      Found 787 objects.
#
# ===  Found a TOTAL of 2731 objects in image 'u3m71605r_c0m.fits'
#
#
#
# ===  Source finding for image 'u3m71606r_c0m.fits':
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 1) started at: 11:10:51.409 (12/12/2017)
#
#      Found 427 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 2) started at: 11:10:51.683 (12/12/2017)
#
#      Found 552 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 3) started at: 11:10:52.022 (12/12/2017)
#
#      Found 629 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 4) started at: 11:10:52.530 (12/12/2017)
#
#      Found 646 objects.
#
# ===  Found a TOTAL of 2254 objects in image 'u3m71606r_c0m.fits'
#
#
#
#  Catalog trimmed to 2731 objects
#
#
# ====================
# Aligning all input images to WCS defined by u3m71605r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u3m71606r_c0m.fits
#
# Matching sources from 'u3m71606r_c0m.fits' with sources from reference image 'u3m71605r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.87083265162 -0.568080358042
#
#     with significance of  391.49913793 and  17.0  matches
#
# Found 60 matches for u3m71606r_c0m.fits...
#
# Computed  rscale  fit for  u3m71606r_c0m.fits :
#
# XSH: 0.00438821  YSH: 0.00479817    ROT: 359.999    SCALE: 1.00001
#
# XRMS: 0.166659    YRMS: 0.177252
#
# RMS_RA: 6.14344e-06 (deg)   RMS_DEC: 2.33982e-07 (deg)
#
# Final solution based on  54  objects.
#
# wrote XY data to:  u3m71606r_c0m_catalog_fit.match
#
# Writing out shiftfile : 9shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 0.004388

# %%
# change to a jupyter table
dt=test.to_pandas()
dt.to_pickle('data.pickle')
good_table=pandas.read_pickle('data.pickle')

# %%
# all table
good_table
# Out:
#          shift                file     x_rms     y_rms  threshold  conv_width  \
# 0   1shift.txt  u3m71605r_c0m.fits  0.000000  0.000000          5         3.5
# 1   1shift.txt  u3m71606r_c0m.fits  0.186250  0.203834          5         3.5
# 2   2shift.txt  u3m71605r_c0m.fits  0.000000  0.000000          6         3.5
# 3   2shift.txt  u3m71606r_c0m.fits  0.132074  0.171744          6         3.5
# 4   3shift.txt  u3m71605r_c0m.fits  0.000000  0.000000          7         3.5
# 5   3shift.txt  u3m71606r_c0m.fits  0.132790  0.159995          7         3.5
# 6   4shift.txt  u3m71605r_c0m.fits  0.000000  0.000000          8         3.5
# 7   4shift.txt  u3m71606r_c0m.fits  0.108175  0.146621          8         3.5
# 8   5shift.txt  u3m71605r_c0m.fits  0.000000  0.000000          9         3.5
# 9   5shift.txt  u3m71606r_c0m.fits  0.108875  0.142270          9         3.5
# 10  6shift.txt  u3m71605r_c0m.fits  0.000000  0.000000         10         3.5
# 11  6shift.txt  u3m71606r_c0m.fits  0.102293  0.134396         10         3.5
# 12  7shift.txt  u3m71605r_c0m.fits  0.000000  0.000000         11         3.5
# 13  7shift.txt  u3m71606r_c0m.fits  0.129258  0.126920         11         3.5
# 14  8shift.txt  u3m71605r_c0m.fits  0.000000  0.000000         12         3.5
# 15  8shift.txt  u3m71606r_c0m.fits  0.124798  0.140767         12         3.5
# 16  9shift.txt  u3m71605r_c0m.fits  0.000000  0.000000         13         3.5
# 17  9shift.txt  u3m71606r_c0m.fits  0.166659  0.177252         13         3.5
#
#     roundlo  roundhi  peakmax
# 0        -1        1     1000
# 1        -1        1     1000
# 2        -1        1     1000
# 3        -1        1     1000
# 4        -1        1     1000
# 5        -1        1     1000
# 6        -1        1     1000
# 7        -1        1     1000
# 8        -1        1     1000
# 9        -1        1     1000
# 10       -1        1     1000
# 11       -1        1     1000
# 12       -1        1     1000
# 13       -1        1     1000
# 14       -1        1     1000
# 15       -1        1     1000
# 16       -1        1     1000
# 17       -1        1     1000

# %%
# filter by column
good_table['y_rms']
# Out:
# 0     0.000000
# 1     0.254965
# 2     0.000000
# 3     0.203834
# 4     0.000000
# 5     0.146621
# 6     0.000000
# 7     0.126920
# 8     0.000000
# 9     0.184182
# 10    0.000000
# 11    0.295041
# 12    0.000000
# 13    0.425022
# 14    0.000000
# 15    0.387422
# 16    0.000000
# 17    0.171391
# Name: y_rms, dtype: object

# %%
# filter by value in column
good_table[good_table['y_rms']=='failed']
# Out:
# Empty DataFrame
# Columns: [shift, file, x_rms, y_rms, threshold, conv_width, roundlo, roundhi, peakmax]
# Index: []

# %%
# see unique in column
good_table['shift'].unique()
# Out:
# array(['1shift.txt', '2shift.txt', '3shift.txt', '4shift.txt',
#        '5shift.txt', '6shift.txt', '7shift.txt', '8shift.txt', '9shift.txt'], dtype=object)

# %%
good_table.shape
# Out:
# (18, 9)

# %%
# take only unfailed sessions
good = good_table[good_table['y_rms'] != 'failed']

# %%
# ????????????????????????????????????????????????????
plt.figure(figsize = (7,7))
plt.plot(good['threshold'],good['x_rms'],'.g')
plt.plot(good['threshold'],good['y_rms'],'.b')
plt.title('x,y_rms(threshold)-g,b')
plt.show()

# %%
# plot figure for choosen sub-exp
plt.figure(figsize = (7,7))
plt.plot(good[good['file'] == 'u29r1r01t_c0m.fits']['threshold'],good[good['file'] == 'u29r1r01t_c0m.fits']['y_rms'],'.b')
plt.plot(good[good['file'] == 'u29r1r02t_c0m.fits']['threshold'],good[good['file'] == 'u29r1r02t_c0m.fits']['y_rms'],'.g')
plt.title('y_rms(threshold)-two filters')
plt.show()

# %%
# find min y_rms and min x_rms
min_x = good[good['x_rms'].values.astype(float) != 0.0]['x_rms'].min()
min_y = good[good['y_rms'].values.astype(float) != 0.0]['y_rms'].min()
print(min_x)
print(min_y)
# Out:
# 0.206961
# 0.186928

# %%
# sort all values =! 0 and take lowest 5 in y_rms
good[good['x_rms'].values.astype(float) != 0.0].sort_values('x_rms',ascending=True)[:5]
# Out:
#          shift                file     x_rms     y_rms  threshold  conv_width
# 21  6shift.txt  u6ea5402m_c0m.fits  0.056897  0.037645         51           3
# 17  5shift.txt  u6ea5402m_c0m.fits  0.069021  0.038714         41           3
# 9   3shift.txt  u6ea5402m_c0m.fits  0.074321  0.078460         21           3
# 5   2shift.txt  u6ea5402m_c0m.fits  0.088635  0.088857         11           3
# 13  4shift.txt  u6ea5402m_c0m.fits  0.152657  0.101558         31           3

# %%
# sort all values =! 0 and take lowest 5 in y_rms BY FILTER??????????????????????
good['file' == 'u29r1r02t_c0m.fits'][['y_rms'].values.astype(float) != 0.0]].sort_values('y_rms',ascending=True)[:5]
#plt.plot(good[good['file'] == 'u6ea5402m_c0m.fits']['threshold'],good[good['file'] == 'u6ea5402m_c0m.fits']['y_rms'],'.b')
# Out:
#   File "<ipython-input-14-aaeb809a2179>", line 2
#     good['file' == 'u29r1r02t_c0m.fits'][['y_rms'].values.astype(float) != 0.0]].sort_values('y_rms',ascending=True)[:5]
#                                                                                ^
# SyntaxError: invalid syntax

# %%
############################################################ thresh=10, conv_width?

# %%
# tweak_run(path, n_up, threshold_ini, threshold_gap, conv_width_ini, conv_width_gap, 
# roundlo_val_ini, roundlo_gap, roundhi_val_ini, roundhi_gap, peakmax_val_ini, peakmax_gap):
test = tweak_run('/Users/natalie/anaconda2/envs/iraf27/iraf/sn/2000ds/2000ds_pre/tweak_555_2',10,10,0,3.0,0.1,-1,0,1,0,1000,0)
# Out:
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 11:12:48.400 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u3m71605r_c0m.fits
#
#     u3m71606r_c0m.fits
#
# ===  Source finding for image 'u3m71605r_c0m.fits':
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 1) started at: 11:12:48.722 (12/12/2017)
#
#      Found 445 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 2) started at: 11:12:49.031 (12/12/2017)
#
#      Found 472 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 3) started at: 11:12:49.402 (12/12/2017)
#
#      Found 562 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 4) started at: 11:12:49.938 (12/12/2017)
#
#      Found 518 objects.
#
# ===  Found a TOTAL of 1997 objects in image 'u3m71605r_c0m.fits'
#
#
#
# ===  Source finding for image 'u3m71606r_c0m.fits':
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 1) started at: 11:12:50.610 (12/12/2017)
#
#      Found 332 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 2) started at: 11:12:50.928 (12/12/2017)
#
#      Found 398 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 3) started at: 11:12:51.352 (12/12/2017)
#
#      Found 488 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 4) started at: 11:12:51.799 (12/12/2017)
#
#      Found 467 objects.
#
# ===  Found a TOTAL of 1685 objects in image 'u3m71606r_c0m.fits'
#
#
#
#  Catalog trimmed to 1997 objects
#
#
# ====================
# Aligning all input images to WCS defined by u3m71605r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u3m71606r_c0m.fits
#
# Matching sources from 'u3m71606r_c0m.fits' with sources from reference image 'u3m71605r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.727281653239 0.0178163859763
#
#     with significance of  426.357830935 and  20.0  matches
#
# Found 64 matches for u3m71606r_c0m.fits...
#
# Computed  rscale  fit for  u3m71606r_c0m.fits :
#
# XSH: 0.0238546  YSH: 0.0427754    ROT: 359.999    SCALE: 1.00001
#
# XRMS: 0.141746    YRMS: 0.143311
#
# RMS_RA: 5.09795e-06 (deg)   RMS_DEC: 1.29477e-07 (deg)
#
# Final solution based on  57  objects.
#
# wrote XY data to:  u3m71606r_c0m_catalog_fit.match
#
# Writing out shiftfile : 1shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 0.023855
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 11:12:52.775 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u3m71605r_c0m.fits
#
#     u3m71606r_c0m.fits
#
# ===  Source finding for image 'u3m71605r_c0m.fits':
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 1) started at: 11:12:53.018 (12/12/2017)
#
#      Found 475 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 2) started at: 11:12:53.297 (12/12/2017)
#
#      Found 503 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 3) started at: 11:12:53.661 (12/12/2017)
#
#      Found 592 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 4) started at: 11:12:54.133 (12/12/2017)
#
#      Found 558 objects.
#
# ===  Found a TOTAL of 2128 objects in image 'u3m71605r_c0m.fits'
#
#
#
# ===  Source finding for image 'u3m71606r_c0m.fits':
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 1) started at: 11:12:54.750 (12/12/2017)
#
#      Found 347 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 2) started at: 11:12:55.002 (12/12/2017)
#
#      Found 421 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 3) started at: 11:12:55.385 (12/12/2017)
#
#      Found 509 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 4) started at: 11:12:55.789 (12/12/2017)
#
#      Found 501 objects.
#
# ===  Found a TOTAL of 1778 objects in image 'u3m71606r_c0m.fits'
#
#
#
#  Catalog trimmed to 2128 objects
#
#
# ====================
# Aligning all input images to WCS defined by u3m71605r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u3m71606r_c0m.fits
#
# Matching sources from 'u3m71606r_c0m.fits' with sources from reference image 'u3m71605r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.762575770886 -0.102575770886
#
#     with significance of  415.578426499 and  20.0  matches
#
# Found 62 matches for u3m71606r_c0m.fits...
#
# Computed  rscale  fit for  u3m71606r_c0m.fits :
#
# XSH: 0.0229279  YSH: 0.0436524    ROT: 360    SCALE: 1.00001
#
# XRMS: 0.143014    YRMS: 0.14294
#
# RMS_RA: 5.11535e-06 (deg)   RMS_DEC: 1.15196e-07 (deg)
#
# Final solution based on  57  objects.
#
# wrote XY data to:  u3m71606r_c0m_catalog_fit.match
#
# Writing out shiftfile : 2shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 0.022928
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 11:12:56.668 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u3m71605r_c0m.fits
#
#     u3m71606r_c0m.fits
#
# ===  Source finding for image 'u3m71605r_c0m.fits':
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 1) started at: 11:12:56.905 (12/12/2017)
#
#      Found 516 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 2) started at: 11:12:57.19 (12/12/2017)
#
#      Found 549 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 3) started at: 11:12:57.552 (12/12/2017)
#
#      Found 605 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 4) started at: 11:12:58.066 (12/12/2017)
#
#      Found 607 objects.
#
# ===  Found a TOTAL of 2277 objects in image 'u3m71605r_c0m.fits'
#
#
#
# ===  Source finding for image 'u3m71606r_c0m.fits':
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 1) started at: 11:12:58.673 (12/12/2017)
#
#      Found 383 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 2) started at: 11:12:58.920 (12/12/2017)
#
#      Found 447 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 3) started at: 11:12:59.254 (12/12/2017)
#
#      Found 536 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 4) started at: 11:12:59.627 (12/12/2017)
#
#      Found 533 objects.
#
# ===  Found a TOTAL of 1899 objects in image 'u3m71606r_c0m.fits'
#
#
#
#  Catalog trimmed to 2277 objects
#
#
# ====================
# Aligning all input images to WCS defined by u3m71605r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u3m71606r_c0m.fits
#
# Matching sources from 'u3m71606r_c0m.fits' with sources from reference image 'u3m71605r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.858802185981 -0.273896525603
#
#     with significance of  410.717692894 and  19.0  matches
#
# Found 63 matches for u3m71606r_c0m.fits...
#
# Computed  rscale  fit for  u3m71606r_c0m.fits :
#
# XSH: 0.0201928  YSH: 0.0482532    ROT: 360    SCALE: 1.00003
#
# XRMS: 0.146264    YRMS: 0.131517
#
# RMS_RA: 4.98104e-06 (deg)   RMS_DEC: 1.91973e-08 (deg)
#
# Final solution based on  57  objects.
#
# wrote XY data to:  u3m71606r_c0m_catalog_fit.match
#
# Writing out shiftfile : 3shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 0.020193
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 11:13:00.531 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u3m71605r_c0m.fits
#
#     u3m71606r_c0m.fits
#
# ===  Source finding for image 'u3m71605r_c0m.fits':
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 1) started at: 11:13:00.827 (12/12/2017)
#
#      Found 551 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 2) started at: 11:13:01.117 (12/12/2017)
#
#      Found 577 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 3) started at: 11:13:01.472 (12/12/2017)
#
#      Found 640 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 4) started at: 11:13:01.904 (12/12/2017)
#
#      Found 650 objects.
#
# ===  Found a TOTAL of 2418 objects in image 'u3m71605r_c0m.fits'
#
#
#
# ===  Source finding for image 'u3m71606r_c0m.fits':
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 1) started at: 11:13:02.499 (12/12/2017)
#
#      Found 429 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 2) started at: 11:13:02.754 (12/12/2017)
#
#      Found 488 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 3) started at: 11:13:03.162 (12/12/2017)
#
#      Found 558 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 4) started at: 11:13:03.591 (12/12/2017)
#
#      Found 573 objects.
#
# ===  Found a TOTAL of 2048 objects in image 'u3m71606r_c0m.fits'
#
#
#
#  Catalog trimmed to 2418 objects
#
#
# ====================
# Aligning all input images to WCS defined by u3m71605r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u3m71606r_c0m.fits
#
# Matching sources from 'u3m71606r_c0m.fits' with sources from reference image 'u3m71605r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.897760956072 -0.29590910422
#
#     with significance of  412.572390342 and  19.0  matches
#
# Found 64 matches for u3m71606r_c0m.fits...
#
# Computed  rscale  fit for  u3m71606r_c0m.fits :
#
# XSH: 0.0363402  YSH: 0.0501491    ROT: 359.999    SCALE: 1.00004
#
# XRMS: 0.130814    YRMS: 0.146748
#
# RMS_RA: 4.95224e-06 (deg)   RMS_DEC: 2.54825e-07 (deg)
#
# Final solution based on  58  objects.
#
# wrote XY data to:  u3m71606r_c0m_catalog_fit.match
#
# Writing out shiftfile : 4shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 0.036340
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 11:13:04.604 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u3m71605r_c0m.fits
#
#     u3m71606r_c0m.fits
#
# ===  Source finding for image 'u3m71605r_c0m.fits':
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 1) started at: 11:13:04.87 (12/12/2017)
#
#      Found 605 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 2) started at: 11:13:05.167 (12/12/2017)
#
#      Found 621 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 3) started at: 11:13:05.514 (12/12/2017)
#
#      Found 673 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 4) started at: 11:13:05.998 (12/12/2017)
#
#      Found 706 objects.
#
# ===  Found a TOTAL of 2605 objects in image 'u3m71605r_c0m.fits'
#
#
#
# ===  Source finding for image 'u3m71606r_c0m.fits':
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 1) started at: 11:13:06.609 (12/12/2017)
#
#      Found 466 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 2) started at: 11:13:06.860 (12/12/2017)
#
#      Found 524 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 3) started at: 11:13:07.17 (12/12/2017)
#
#      Found 580 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 4) started at: 11:13:07.540 (12/12/2017)
#
#      Found 603 objects.
#
# ===  Found a TOTAL of 2173 objects in image 'u3m71606r_c0m.fits'
#
#
#
#  Catalog trimmed to 2605 objects
#
#
# ====================
# Aligning all input images to WCS defined by u3m71605r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u3m71606r_c0m.fits
#
# Matching sources from 'u3m71606r_c0m.fits' with sources from reference image 'u3m71605r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.936934745245 -0.253174061485
#
#     with significance of  411.860723205 and  18.0  matches
#
# Found 67 matches for u3m71606r_c0m.fits...
#
# Computed  rscale  fit for  u3m71606r_c0m.fits :
#
# XSH: 0.0397938  YSH: 0.0450394    ROT: 360    SCALE: 1.00004
#
# XRMS: 0.130921    YRMS: 0.143948
#
# RMS_RA: 4.90642e-06 (deg)   RMS_DEC: 2.27755e-07 (deg)
#
# Final solution based on  61  objects.
#
# wrote XY data to:  u3m71606r_c0m_catalog_fit.match
#
# Writing out shiftfile : 5shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 0.039794
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 11:13:08.453 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u3m71605r_c0m.fits
#
#     u3m71606r_c0m.fits
#
# ===  Source finding for image 'u3m71605r_c0m.fits':
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 1) started at: 11:13:08.692 (12/12/2017)
#
#      Found 647 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 2) started at: 11:13:08.996 (12/12/2017)
#
#      Found 669 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 3) started at: 11:13:09.370 (12/12/2017)
#
#      Found 726 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 4) started at: 11:13:09.78 (12/12/2017)
#
#      Found 779 objects.
#
# ===  Found a TOTAL of 2821 objects in image 'u3m71605r_c0m.fits'
#
#
#
# ===  Source finding for image 'u3m71606r_c0m.fits':
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 1) started at: 11:13:10.399 (12/12/2017)
#
#      Found 491 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 2) started at: 11:13:10.652 (12/12/2017)
#
#      Found 558 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 3) started at: 11:13:11.011 (12/12/2017)
#
#      Found 621 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 4) started at: 11:13:11.408 (12/12/2017)
#
#      Found 643 objects.
#
# ===  Found a TOTAL of 2313 objects in image 'u3m71606r_c0m.fits'
#
#
#
#  Catalog trimmed to 2821 objects
#
#
# ====================
# Aligning all input images to WCS defined by u3m71605r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u3m71606r_c0m.fits
#
# Matching sources from 'u3m71606r_c0m.fits' with sources from reference image 'u3m71605r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -1.073686882 -0.724480532791
#
#     with significance of  421.984814506 and  19.0  matches
#
# Found 62 matches for u3m71606r_c0m.fits...
#
# Computed  rscale  fit for  u3m71606r_c0m.fits :
#
# XSH: 0.0053063  YSH: 0.0195344    ROT: 360    SCALE: 1.00003
#
# XRMS: 0.102293    YRMS: 0.134396
#
# RMS_RA: 4.20797e-06 (deg)   RMS_DEC: 3.8271e-07 (deg)
#
# Final solution based on  54  objects.
#
# wrote XY data to:  u3m71606r_c0m_catalog_fit.match
#
# Writing out shiftfile : 6shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 0.005306
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 11:13:12.249 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u3m71605r_c0m.fits
#
#     u3m71606r_c0m.fits
#
# ===  Source finding for image 'u3m71605r_c0m.fits':
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 1) started at: 11:13:12.49 (12/12/2017)
#
#      Found 214 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 2) started at: 11:13:12.745 (12/12/2017)
#
#      Found 237 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 3) started at: 11:13:13.110 (12/12/2017)
#
#      Found 321 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 4) started at: 11:13:13.625 (12/12/2017)
#
#      Found 315 objects.
#
# ===  Found a TOTAL of 1087 objects in image 'u3m71605r_c0m.fits'
#
#
#
# ===  Source finding for image 'u3m71606r_c0m.fits':
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 1) started at: 11:13:14.23 (12/12/2017)
#
#      Found 159 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 2) started at: 11:13:14.464 (12/12/2017)
#
#      Found 245 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 3) started at: 11:13:14.820 (12/12/2017)
#
#      Found 314 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 4) started at: 11:13:15.218 (12/12/2017)
#
#      Found 315 objects.
#
# ===  Found a TOTAL of 1033 objects in image 'u3m71606r_c0m.fits'
#
#
#
#  Catalog trimmed to 1087 objects
#
#
# ====================
# Aligning all input images to WCS defined by u3m71605r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u3m71606r_c0m.fits
#
# Matching sources from 'u3m71606r_c0m.fits' with sources from reference image 'u3m71605r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.652716615957 0.178269299536
#
#     with significance of  337.880896175 and  12.0  matches
#
# Found 38 matches for u3m71606r_c0m.fits...
#
# Computed  rscale  fit for  u3m71606r_c0m.fits :
#
# XSH: 0.0290736  YSH: 0.0494999    ROT: 0.000479857    SCALE: 1
#
# XRMS: 0.113038    YRMS: 0.131981
#
# RMS_RA: 4.36764e-06 (deg)   RMS_DEC: 2.68513e-07 (deg)
#
# Final solution based on  36  objects.
#
# wrote XY data to:  u3m71606r_c0m_catalog_fit.match
#
# Writing out shiftfile : 7shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 0.029074
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 11:13:16.068 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u3m71605r_c0m.fits
#
#     u3m71606r_c0m.fits
#
# ===  Source finding for image 'u3m71605r_c0m.fits':
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 1) started at: 11:13:16.331 (12/12/2017)
#
#      Found 228 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 2) started at: 11:13:16.586 (12/12/2017)
#
#      Found 256 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 3) started at: 11:13:17.030 (12/12/2017)
#
#      Found 338 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 4) started at: 11:13:17.489 (12/12/2017)
#
#      Found 329 objects.
#
# ===  Found a TOTAL of 1151 objects in image 'u3m71605r_c0m.fits'
#
#
#
# ===  Source finding for image 'u3m71606r_c0m.fits':
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 1) started at: 11:13:18.078 (12/12/2017)
#
#      Found 172 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 2) started at: 11:13:18.311 (12/12/2017)
#
#      Found 250 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 3) started at: 11:13:18.649 (12/12/2017)
#
#      Found 333 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 4) started at: 11:13:19.044 (12/12/2017)
#
#      Found 318 objects.
#
# ===  Found a TOTAL of 1073 objects in image 'u3m71606r_c0m.fits'
#
#
#
#  Catalog trimmed to 1151 objects
#
#
# ====================
# Aligning all input images to WCS defined by u3m71605r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u3m71606r_c0m.fits
#
# Matching sources from 'u3m71606r_c0m.fits' with sources from reference image 'u3m71605r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.637900446211 -0.0794588877695
#
#     with significance of  352.4464701 and  13.0  matches
#
# Found 43 matches for u3m71606r_c0m.fits...
#
# Computed  rscale  fit for  u3m71606r_c0m.fits :
#
# XSH: 0.030082  YSH: 0.0475092    ROT: 0.000227884    SCALE: 1.00001
#
# XRMS: 0.110243    YRMS: 0.128843
#
# RMS_RA: 4.2618e-06 (deg)   RMS_DEC: 2.63052e-07 (deg)
#
# Final solution based on  40  objects.
#
# wrote XY data to:  u3m71606r_c0m_catalog_fit.match
#
# Writing out shiftfile : 8shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 0.030082
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 11:13:19.995 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u3m71605r_c0m.fits
#
#     u3m71606r_c0m.fits
#
# ===  Source finding for image 'u3m71605r_c0m.fits':
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 1) started at: 11:13:20.24 (12/12/2017)
#
#      Found 241 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 2) started at: 11:13:20.514 (12/12/2017)
#
#      Found 278 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 3) started at: 11:13:20.877 (12/12/2017)
#
#      Found 355 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 4) started at: 11:13:21.331 (12/12/2017)
#
#      Found 341 objects.
#
# ===  Found a TOTAL of 1215 objects in image 'u3m71605r_c0m.fits'
#
#
#
# ===  Source finding for image 'u3m71606r_c0m.fits':
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 1) started at: 11:13:21.951 (12/12/2017)
#
#      Found 183 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 2) started at: 11:13:22.227 (12/12/2017)
#
#      Found 260 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 3) started at: 11:13:22.564 (12/12/2017)
#
#      Found 344 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 4) started at: 11:13:22.947 (12/12/2017)
#
#      Found 333 objects.
#
# ===  Found a TOTAL of 1120 objects in image 'u3m71606r_c0m.fits'
#
#
#
#  Catalog trimmed to 1215 objects
#
#
# ====================
# Aligning all input images to WCS defined by u3m71605r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u3m71606r_c0m.fits
#
# Matching sources from 'u3m71606r_c0m.fits' with sources from reference image 'u3m71605r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.475396283707 -0.0138578221685
#
#     with significance of  366.435461396 and  14.0  matches
#
# Found 46 matches for u3m71606r_c0m.fits...
#
# Computed  rscale  fit for  u3m71606r_c0m.fits :
#
# XSH: 0.0364737  YSH: 0.0415218    ROT: 0.000440886    SCALE: 1.00002
#
# XRMS: 0.116451    YRMS: 0.130275
#
# RMS_RA: 4.40234e-06 (deg)   RMS_DEC: 2.23472e-07 (deg)
#
# Final solution based on  43  objects.
#
# wrote XY data to:  u3m71606r_c0m_catalog_fit.match
#
# Writing out shiftfile : 9shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 0.036474

# %%
# change to a jupyter table
dt=test.to_pandas()
dt.to_pickle('data.pickle')
good_table=pandas.read_pickle('data.pickle')

# %%
# take only unfailed sessions
good_conv = good_table[good_table['y_rms'] != 'failed']

# %%
good_conv
# Out:
#          shift                file     x_rms     y_rms  threshold  conv_width  \
# 0   1shift.txt  u3m71605r_c0m.fits  0.000000  0.000000         10         3.0
# 1   1shift.txt  u3m71606r_c0m.fits  0.141746  0.143311         10         3.0
# 2   2shift.txt  u3m71605r_c0m.fits  0.000000  0.000000         10         3.1
# 3   2shift.txt  u3m71606r_c0m.fits  0.143014  0.142940         10         3.1
# 4   3shift.txt  u3m71605r_c0m.fits  0.000000  0.000000         10         3.2
# 5   3shift.txt  u3m71606r_c0m.fits  0.146264  0.131517         10         3.2
# 6   4shift.txt  u3m71605r_c0m.fits  0.000000  0.000000         10         3.3
# 7   4shift.txt  u3m71606r_c0m.fits  0.130814  0.146748         10         3.3
# 8   5shift.txt  u3m71605r_c0m.fits  0.000000  0.000000         10         3.4
# 9   5shift.txt  u3m71606r_c0m.fits  0.130921  0.143948         10         3.4
# 10  6shift.txt  u3m71605r_c0m.fits  0.000000  0.000000         10         3.5
# 11  6shift.txt  u3m71606r_c0m.fits  0.102293  0.134396         10         3.5
# 12  7shift.txt  u3m71605r_c0m.fits  0.000000  0.000000         10         3.6
# 13  7shift.txt  u3m71606r_c0m.fits  0.113038  0.131981         10         3.6
# 14  8shift.txt  u3m71605r_c0m.fits  0.000000  0.000000         10         3.7
# 15  8shift.txt  u3m71606r_c0m.fits  0.110243  0.128843         10         3.7
# 16  9shift.txt  u3m71605r_c0m.fits  0.000000  0.000000         10         3.8
# 17  9shift.txt  u3m71606r_c0m.fits  0.116451  0.130275         10         3.8
#
#     roundlo  roundhi  peakmax
# 0        -1        1     1000
# 1        -1        1     1000
# 2        -1        1     1000
# 3        -1        1     1000
# 4        -1        1     1000
# 5        -1        1     1000
# 6        -1        1     1000
# 7        -1        1     1000
# 8        -1        1     1000
# 9        -1        1     1000
# 10       -1        1     1000
# 11       -1        1     1000
# 12       -1        1     1000
# 13       -1        1     1000
# 14       -1        1     1000
# 15       -1        1     1000
# 16       -1        1     1000
# 17       -1        1     1000

# %%
# plot figure for all sub-exp
plt.figure(figsize = (7,7))
plt.plot(good_conv['conv_width'],good_conv['x_rms'],'.g')
plt.plot(good_conv['conv_width'],good_conv['y_rms'],'.b')
plt.title('x,y_rms(conv_width)-g,b')
plt.show()

# %%
# plot figure for choosen sub-exp
plt.figure(figsize = (7,7))
plt.plot(good_conv[good_conv['file'] == 'u6ea5402m_c0m.fits']['conv_width'],good_conv[good_conv['file'] == 'u6ea5402m_c0m.fits']['y_rms'],'.b')
plt.plot(good_conv[good_conv['file'] == 'u6ea5403m_c0m.fits']['conv_width'],good_conv[good_conv['file'] == 'u6ea5403m_c0m.fits']['y_rms'],'.g')
plt.title('y_rms(conv)-two filters')
plt.show()

# %%
#############################################thresh = 10, conv = 3.5, roundlo?

# %%
# tweak_run(path, n_up, threshold_ini, threshold_gap, conv_width_ini, conv_width_gap, 
# roundlo_val_ini, roundlo_gap, roundhi_val_ini, roundhi_gap, peakmax_val_ini, peakmax_gap):
test = tweak_run('/Users/natalie/anaconda2/envs/iraf27/iraf/sn/2000ds/2000ds_pre/tweak_555_2',10,10,0,3.5,0,-1.5,0.1,1,0,1000,0)
# Out:
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 11:17:03.318 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u3m71605r_c0m.fits
#
#     u3m71606r_c0m.fits
#
# ===  Source finding for image 'u3m71605r_c0m.fits':
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 1) started at: 11:17:03.618 (12/12/2017)
#
#      Found 674 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 2) started at: 11:17:03.940 (12/12/2017)
#
#      Found 698 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 3) started at: 11:17:04.372 (12/12/2017)
#
#      Found 765 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 4) started at: 11:17:04.799 (12/12/2017)
#
#      Found 808 objects.
#
# ===  Found a TOTAL of 2945 objects in image 'u3m71605r_c0m.fits'
#
#
#
# ===  Source finding for image 'u3m71606r_c0m.fits':
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 1) started at: 11:17:05.45 (12/12/2017)
#
#      Found 515 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 2) started at: 11:17:05.724 (12/12/2017)
#
#      Found 590 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 3) started at: 11:17:06.059 (12/12/2017)
#
#      Found 652 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 4) started at: 11:17:06.446 (12/12/2017)
#
#      Found 686 objects.
#
# ===  Found a TOTAL of 2443 objects in image 'u3m71606r_c0m.fits'
#
#
#
#  Catalog trimmed to 2945 objects
#
#
# ====================
# Aligning all input images to WCS defined by u3m71605r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u3m71606r_c0m.fits
#
# Matching sources from 'u3m71606r_c0m.fits' with sources from reference image 'u3m71605r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.962575770886 -0.123159712492
#
#     with significance of  434.396132579 and  21.0  matches
#
# Found 72 matches for u3m71606r_c0m.fits...
#
# Computed  rscale  fit for  u3m71606r_c0m.fits :
#
# XSH: 0.0371629  YSH: 0.0418466    ROT: 360    SCALE: 1.00005
#
# XRMS: 0.128809    YRMS: 0.144761
#
# RMS_RA: 4.88082e-06 (deg)   RMS_DEC: 2.53358e-07 (deg)
#
# Final solution based on  64  objects.
#
# wrote XY data to:  u3m71606r_c0m_catalog_fit.match
#
# Writing out shiftfile : 1shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 0.037163
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 11:17:07.476 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u3m71605r_c0m.fits
#
#     u3m71606r_c0m.fits
#
# ===  Source finding for image 'u3m71605r_c0m.fits':
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 1) started at: 11:17:07.719 (12/12/2017)
#
#      Found 674 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 2) started at: 11:17:08.016 (12/12/2017)
#
#      Found 695 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 3) started at: 11:17:08.384 (12/12/2017)
#
#      Found 759 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 4) started at: 11:17:08.841 (12/12/2017)
#
#      Found 804 objects.
#
# ===  Found a TOTAL of 2932 objects in image 'u3m71605r_c0m.fits'
#
#
#
# ===  Source finding for image 'u3m71606r_c0m.fits':
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 1) started at: 11:17:09.517 (12/12/2017)
#
#      Found 509 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 2) started at: 11:17:09.779 (12/12/2017)
#
#      Found 587 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 3) started at: 11:17:10.085 (12/12/2017)
#
#      Found 647 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 4) started at: 11:17:10.472 (12/12/2017)
#
#      Found 680 objects.
#
# ===  Found a TOTAL of 2423 objects in image 'u3m71606r_c0m.fits'
#
#
#
#  Catalog trimmed to 2932 objects
#
#
# ====================
# Aligning all input images to WCS defined by u3m71605r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u3m71606r_c0m.fits
#
# Matching sources from 'u3m71606r_c0m.fits' with sources from reference image 'u3m71605r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.940516947357 -0.139046359122
#
#     with significance of  434.396132579 and  21.0  matches
#
# Found 72 matches for u3m71606r_c0m.fits...
#
# Computed  rscale  fit for  u3m71606r_c0m.fits :
#
# XSH: 0.0371629  YSH: 0.0418466    ROT: 360    SCALE: 1.00005
#
# XRMS: 0.128809    YRMS: 0.144761
#
# RMS_RA: 4.88082e-06 (deg)   RMS_DEC: 2.53358e-07 (deg)
#
# Final solution based on  64  objects.
#
# wrote XY data to:  u3m71606r_c0m_catalog_fit.match
#
# Writing out shiftfile : 2shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 0.037163
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 11:17:11.361 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u3m71605r_c0m.fits
#
#     u3m71606r_c0m.fits
#
# ===  Source finding for image 'u3m71605r_c0m.fits':
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 1) started at: 11:17:11.609 (12/12/2017)
#
#      Found 669 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 2) started at: 11:17:11.90 (12/12/2017)
#
#      Found 690 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 3) started at: 11:17:12.308 (12/12/2017)
#
#      Found 753 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 4) started at: 11:17:12.760 (12/12/2017)
#
#      Found 801 objects.
#
# ===  Found a TOTAL of 2913 objects in image 'u3m71605r_c0m.fits'
#
#
#
# ===  Source finding for image 'u3m71606r_c0m.fits':
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 1) started at: 11:17:13.400 (12/12/2017)
#
#      Found 503 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 2) started at: 11:17:13.654 (12/12/2017)
#
#      Found 583 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 3) started at: 11:17:13.980 (12/12/2017)
#
#      Found 641 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 4) started at: 11:17:14.38 (12/12/2017)
#
#      Found 672 objects.
#
# ===  Found a TOTAL of 2399 objects in image 'u3m71606r_c0m.fits'
#
#
#
#  Catalog trimmed to 2913 objects
#
#
# ====================
# Aligning all input images to WCS defined by u3m71605r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u3m71606r_c0m.fits
#
# Matching sources from 'u3m71606r_c0m.fits' with sources from reference image 'u3m71605r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -1.00669341795 -0.70522282971
#
#     with significance of  421.984814506 and  19.0  matches
#
# Found 68 matches for u3m71606r_c0m.fits...
#
# Computed  rscale  fit for  u3m71606r_c0m.fits :
#
# XSH: 0.0223744  YSH: 0.0270492    ROT: 0.000266343    SCALE: 1.00004
#
# XRMS: 0.116081    YRMS: 0.13578
#
# RMS_RA: 4.48943e-06 (deg)   RMS_DEC: 2.78045e-07 (deg)
#
# Final solution based on  59  objects.
#
# wrote XY data to:  u3m71606r_c0m_catalog_fit.match
#
# Writing out shiftfile : 3shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 0.022374
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 11:17:15.300 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u3m71605r_c0m.fits
#
#     u3m71606r_c0m.fits
#
# ===  Source finding for image 'u3m71605r_c0m.fits':
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 1) started at: 11:17:15.560 (12/12/2017)
#
#      Found 660 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 2) started at: 11:17:15.910 (12/12/2017)
#
#      Found 686 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 3) started at: 11:17:16.320 (12/12/2017)
#
#      Found 747 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 4) started at: 11:17:16.829 (12/12/2017)
#
#      Found 794 objects.
#
# ===  Found a TOTAL of 2887 objects in image 'u3m71605r_c0m.fits'
#
#
#
# ===  Source finding for image 'u3m71606r_c0m.fits':
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 1) started at: 11:17:17.522 (12/12/2017)
#
#      Found 499 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 2) started at: 11:17:17.791 (12/12/2017)
#
#      Found 577 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 3) started at: 11:17:18.12 (12/12/2017)
#
#      Found 636 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 4) started at: 11:17:18.514 (12/12/2017)
#
#      Found 667 objects.
#
# ===  Found a TOTAL of 2379 objects in image 'u3m71606r_c0m.fits'
#
#
#
#  Catalog trimmed to 2887 objects
#
#
# ====================
# Aligning all input images to WCS defined by u3m71605r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u3m71606r_c0m.fits
#
# Matching sources from 'u3m71606r_c0m.fits' with sources from reference image 'u3m71605r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -1.02227726342 -0.686456367901
#
#     with significance of  421.984814506 and  19.0  matches
#
# Found 67 matches for u3m71606r_c0m.fits...
#
# Computed  rscale  fit for  u3m71606r_c0m.fits :
#
# XSH: 0.0223744  YSH: 0.0270492    ROT: 0.000266343    SCALE: 1.00004
#
# XRMS: 0.116081    YRMS: 0.13578
#
# RMS_RA: 4.48943e-06 (deg)   RMS_DEC: 2.78045e-07 (deg)
#
# Final solution based on  59  objects.
#
# wrote XY data to:  u3m71606r_c0m_catalog_fit.match
#
# Writing out shiftfile : 4shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 0.022374
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 11:17:19.393 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u3m71605r_c0m.fits
#
#     u3m71606r_c0m.fits
#
# ===  Source finding for image 'u3m71605r_c0m.fits':
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 1) started at: 11:17:19.632 (12/12/2017)
#
#      Found 654 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 2) started at: 11:17:19.982 (12/12/2017)
#
#      Found 681 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 3) started at: 11:17:20.325 (12/12/2017)
#
#      Found 737 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 4) started at: 11:17:20.775 (12/12/2017)
#
#      Found 789 objects.
#
# ===  Found a TOTAL of 2861 objects in image 'u3m71605r_c0m.fits'
#
#
#
# ===  Source finding for image 'u3m71606r_c0m.fits':
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 1) started at: 11:17:21.403 (12/12/2017)
#
#      Found 496 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 2) started at: 11:17:21.663 (12/12/2017)
#
#      Found 571 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 3) started at: 11:17:21.980 (12/12/2017)
#
#      Found 627 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 4) started at: 11:17:22.402 (12/12/2017)
#
#      Found 654 objects.
#
# ===  Found a TOTAL of 2348 objects in image 'u3m71606r_c0m.fits'
#
#
#
#  Catalog trimmed to 2861 objects
#
#
# ====================
# Aligning all input images to WCS defined by u3m71605r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u3m71606r_c0m.fits
#
# Matching sources from 'u3m71606r_c0m.fits' with sources from reference image 'u3m71605r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -1.00803031634 -0.727727286038
#
#     with significance of  421.984814506 and  19.0  matches
#
# Found 66 matches for u3m71606r_c0m.fits...
#
# Computed  rscale  fit for  u3m71606r_c0m.fits :
#
# XSH: 0.0219093  YSH: 0.021135    ROT: 7.08849e-05    SCALE: 1.00004
#
# XRMS: 0.116606    YRMS: 0.129338
#
# RMS_RA: 4.38923e-06 (deg)   RMS_DEC: 2.13395e-07 (deg)
#
# Final solution based on  58  objects.
#
# wrote XY data to:  u3m71606r_c0m_catalog_fit.match
#
# Writing out shiftfile : 5shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 0.021909
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 11:17:23.27 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u3m71605r_c0m.fits
#
#     u3m71606r_c0m.fits
#
# ===  Source finding for image 'u3m71605r_c0m.fits':
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 1) started at: 11:17:23.513 (12/12/2017)
#
#      Found 647 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 2) started at: 11:17:23.814 (12/12/2017)
#
#      Found 669 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 3) started at: 11:17:24.148 (12/12/2017)
#
#      Found 726 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 4) started at: 11:17:24.593 (12/12/2017)
#
#      Found 779 objects.
#
# ===  Found a TOTAL of 2821 objects in image 'u3m71605r_c0m.fits'
#
#
#
# ===  Source finding for image 'u3m71606r_c0m.fits':
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 1) started at: 11:17:25.296 (12/12/2017)
#
#      Found 491 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 2) started at: 11:17:25.554 (12/12/2017)
#
#      Found 558 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 3) started at: 11:17:25.891 (12/12/2017)
#
#      Found 621 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 4) started at: 11:17:26.272 (12/12/2017)
#
#      Found 643 objects.
#
# ===  Found a TOTAL of 2313 objects in image 'u3m71606r_c0m.fits'
#
#
#
#  Catalog trimmed to 2821 objects
#
#
# ====================
# Aligning all input images to WCS defined by u3m71605r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u3m71606r_c0m.fits
#
# Matching sources from 'u3m71606r_c0m.fits' with sources from reference image 'u3m71605r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -1.073686882 -0.724480532791
#
#     with significance of  421.984814506 and  19.0  matches
#
# Found 62 matches for u3m71606r_c0m.fits...
#
# Computed  rscale  fit for  u3m71606r_c0m.fits :
#
# XSH: 0.0053063  YSH: 0.0195344    ROT: 360    SCALE: 1.00003
#
# XRMS: 0.102293    YRMS: 0.134396
#
# RMS_RA: 4.20797e-06 (deg)   RMS_DEC: 3.8271e-07 (deg)
#
# Final solution based on  54  objects.
#
# wrote XY data to:  u3m71606r_c0m_catalog_fit.match
#
# Writing out shiftfile : 6shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 0.005306
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 11:17:27.141 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u3m71605r_c0m.fits
#
#     u3m71606r_c0m.fits
#
# ===  Source finding for image 'u3m71605r_c0m.fits':
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 1) started at: 11:17:27.39 (12/12/2017)
#
#      Found 636 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 2) started at: 11:17:27.695 (12/12/2017)
#
#      Found 663 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 3) started at: 11:17:28.087 (12/12/2017)
#
#      Found 717 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 4) started at: 11:17:28.529 (12/12/2017)
#
#      Found 765 objects.
#
# ===  Found a TOTAL of 2781 objects in image 'u3m71605r_c0m.fits'
#
#
#
# ===  Source finding for image 'u3m71606r_c0m.fits':
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 1) started at: 11:17:29.144 (12/12/2017)
#
#      Found 487 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 2) started at: 11:17:29.410 (12/12/2017)
#
#      Found 548 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 3) started at: 11:17:29.732 (12/12/2017)
#
#      Found 608 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 4) started at: 11:17:30.115 (12/12/2017)
#
#      Found 628 objects.
#
# ===  Found a TOTAL of 2271 objects in image 'u3m71606r_c0m.fits'
#
#
#
#  Catalog trimmed to 2781 objects
#
#
# ====================
# Aligning all input images to WCS defined by u3m71605r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u3m71606r_c0m.fits
#
# Matching sources from 'u3m71606r_c0m.fits' with sources from reference image 'u3m71605r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -1.0534848618 -0.714641886589
#
#     with significance of  421.984814506 and  19.0  matches
#
# Found 63 matches for u3m71606r_c0m.fits...
#
# Computed  rscale  fit for  u3m71606r_c0m.fits :
#
# XSH: 0.00820492  YSH: 0.0214147    ROT: 360    SCALE: 1.00004
#
# XRMS: 0.103689    YRMS: 0.133506
#
# RMS_RA: 4.21886e-06 (deg)   RMS_DEC: 3.62492e-07 (deg)
#
# Final solution based on  55  objects.
#
# wrote XY data to:  u3m71606r_c0m_catalog_fit.match
#
# Writing out shiftfile : 7shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 0.008205
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 11:17:31.074 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u3m71605r_c0m.fits
#
#     u3m71606r_c0m.fits
#
# ===  Source finding for image 'u3m71605r_c0m.fits':
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 1) started at: 11:17:31.321 (12/12/2017)
#
#      Found 623 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 2) started at: 11:17:31.628 (12/12/2017)
#
#      Found 655 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 3) started at: 11:17:31.993 (12/12/2017)
#
#      Found 706 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 4) started at: 11:17:32.44 (12/12/2017)
#
#      Found 753 objects.
#
# ===  Found a TOTAL of 2737 objects in image 'u3m71605r_c0m.fits'
#
#
#
# ===  Source finding for image 'u3m71606r_c0m.fits':
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 1) started at: 11:17:33.045 (12/12/2017)
#
#      Found 473 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 2) started at: 11:17:33.310 (12/12/2017)
#
#      Found 545 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 3) started at: 11:17:33.678 (12/12/2017)
#
#      Found 594 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 4) started at: 11:17:34.061 (12/12/2017)
#
#      Found 614 objects.
#
# ===  Found a TOTAL of 2226 objects in image 'u3m71606r_c0m.fits'
#
#
#
#  Catalog trimmed to 2737 objects
#
#
# ====================
# Aligning all input images to WCS defined by u3m71605r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u3m71606r_c0m.fits
#
# Matching sources from 'u3m71606r_c0m.fits' with sources from reference image 'u3m71605r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.997058529507 -0.669472322611
#
#     with significance of  421.984814506 and  19.0  matches
#
# Found 66 matches for u3m71606r_c0m.fits...
#
# Computed  rscale  fit for  u3m71606r_c0m.fits :
#
# XSH: 0.0223744  YSH: 0.0270492    ROT: 0.000266343    SCALE: 1.00004
#
# XRMS: 0.116081    YRMS: 0.13578
#
# RMS_RA: 4.48943e-06 (deg)   RMS_DEC: 2.78045e-07 (deg)
#
# Final solution based on  59  objects.
#
# wrote XY data to:  u3m71606r_c0m_catalog_fit.match
#
# Writing out shiftfile : 8shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 0.022374
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 11:17:34.923 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u3m71605r_c0m.fits
#
#     u3m71606r_c0m.fits
#
# ===  Source finding for image 'u3m71605r_c0m.fits':
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 1) started at: 11:17:35.163 (12/12/2017)
#
#      Found 609 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 2) started at: 11:17:35.456 (12/12/2017)
#
#      Found 638 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 3) started at: 11:17:35.797 (12/12/2017)
#
#      Found 692 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 4) started at: 11:17:36.291 (12/12/2017)
#
#      Found 737 objects.
#
# ===  Found a TOTAL of 2676 objects in image 'u3m71605r_c0m.fits'
#
#
#
# ===  Source finding for image 'u3m71606r_c0m.fits':
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 1) started at: 11:17:36.937 (12/12/2017)
#
#      Found 465 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 2) started at: 11:17:37.200 (12/12/2017)
#
#      Found 533 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 3) started at: 11:17:37.526 (12/12/2017)
#
#      Found 567 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 4) started at: 11:17:37.915 (12/12/2017)
#
#      Found 600 objects.
#
# ===  Found a TOTAL of 2165 objects in image 'u3m71606r_c0m.fits'
#
#
#
#  Catalog trimmed to 2676 objects
#
#
# ====================
# Aligning all input images to WCS defined by u3m71605r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u3m71606r_c0m.fits
#
# Matching sources from 'u3m71606r_c0m.fits' with sources from reference image 'u3m71605r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.998290056601 -0.685790056601
#
#     with significance of  421.984814506 and  19.0  matches
#
# Found 66 matches for u3m71606r_c0m.fits...
#
# Computed  rscale  fit for  u3m71606r_c0m.fits :
#
# XSH: 0.0223744  YSH: 0.0270492    ROT: 0.000266343    SCALE: 1.00004
#
# XRMS: 0.116081    YRMS: 0.13578
#
# RMS_RA: 4.48943e-06 (deg)   RMS_DEC: 2.78045e-07 (deg)
#
# Final solution based on  59  objects.
#
# wrote XY data to:  u3m71606r_c0m_catalog_fit.match
#
# Writing out shiftfile : 9shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 0.022374

# %%
# change to a jupyter table
dt=test.to_pandas()
dt.to_pickle('data.pickle')
good_table=pandas.read_pickle('data.pickle')

# %%
# take only unfailed sessions
good_roundlo = good_table[good_table['y_rms'] != 'failed']

# %%
good_roundlo
# Out:
#          shift                file     x_rms     y_rms  threshold  conv_width  \
# 0   1shift.txt  u3m71605r_c0m.fits  0.000000  0.000000         10         3.5
# 1   1shift.txt  u3m71606r_c0m.fits  0.128809  0.144761         10         3.5
# 2   2shift.txt  u3m71605r_c0m.fits  0.000000  0.000000         10         3.5
# 3   2shift.txt  u3m71606r_c0m.fits  0.128809  0.144761         10         3.5
# 4   3shift.txt  u3m71605r_c0m.fits  0.000000  0.000000         10         3.5
# 5   3shift.txt  u3m71606r_c0m.fits  0.116081  0.135780         10         3.5
# 6   4shift.txt  u3m71605r_c0m.fits  0.000000  0.000000         10         3.5
# 7   4shift.txt  u3m71606r_c0m.fits  0.116081  0.135780         10         3.5
# 8   5shift.txt  u3m71605r_c0m.fits  0.000000  0.000000         10         3.5
# 9   5shift.txt  u3m71606r_c0m.fits  0.116606  0.129338         10         3.5
# 10  6shift.txt  u3m71605r_c0m.fits  0.000000  0.000000         10         3.5
# 11  6shift.txt  u3m71606r_c0m.fits  0.102293  0.134396         10         3.5
# 12  7shift.txt  u3m71605r_c0m.fits  0.000000  0.000000         10         3.5
# 13  7shift.txt  u3m71606r_c0m.fits  0.103689  0.133506         10         3.5
# 14  8shift.txt  u3m71605r_c0m.fits  0.000000  0.000000         10         3.5
# 15  8shift.txt  u3m71606r_c0m.fits  0.116081  0.135780         10         3.5
# 16  9shift.txt  u3m71605r_c0m.fits  0.000000  0.000000         10         3.5
# 17  9shift.txt  u3m71606r_c0m.fits  0.116081  0.135780         10         3.5
#
#     roundlo  roundhi  peakmax
# 0      -1.5        1     1000
# 1      -1.5        1     1000
# 2      -1.4        1     1000
# 3      -1.4        1     1000
# 4      -1.3        1     1000
# 5      -1.3        1     1000
# 6      -1.2        1     1000
# 7      -1.2        1     1000
# 8      -1.1        1     1000
# 9      -1.1        1     1000
# 10     -1.0        1     1000
# 11     -1.0        1     1000
# 12     -0.9        1     1000
# 13     -0.9        1     1000
# 14     -0.8        1     1000
# 15     -0.8        1     1000
# 16     -0.7        1     1000
# 17     -0.7        1     1000

# %%
# plot figure for all sub-exp
plt.figure(figsize = (7,7))
plt.plot(good_roundlo['roundlo'],good_roundlo['x_rms'],'.g')
plt.plot(good_roundlo['roundlo'],good_roundlo['y_rms'],'.b')
plt.title('x,y_rms(roundlo)-g,b')
plt.show()

# %%
# plot figure for choosen sub-exp
plt.figure(figsize = (7,7))
plt.plot(good_round[good_round['file'] == 'u6ea5402m_c0m.fits']['roundlo'],good_round[good_round['file'] == 'u6ea5402m_c0m.fits']['y_rms'],'.b')
plt.plot(good_round[good_round['file'] == 'u6ea5403m_c0m.fits']['roundlo'],good_round[good_round['file'] == 'u6ea5403m_c0m.fits']['y_rms'],'.g')
plt.title('y_rms(roundlo)-two filters')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-1b5e9d62f47a> in <module>()
#       1 # plot figure for choosen sub-exp
#       2 plt.figure(figsize = (7,7))
# ----> 3 plt.plot(good_round[good_round['file'] == 'u6ea5402m_c0m.fits']['roundlo'],good_round[good_round['file'] == 'u6ea5402m_c0m.fits']['y_rms'],'.b')
#       4 plt.plot(good_round[good_round['file'] == 'u6ea5403m_c0m.fits']['roundlo'],good_round[good_round['file'] == 'u6ea5403m_c0m.fits']['y_rms'],'.g')
#       5 plt.title('y_rms(roundlo)-two filters')
#
# NameError: name 'good_round' is not defined

# %%
#############################################thresh = 10, conv = 3.5, roundlo = -1, roundhi?

# %%
# tweak_run(path, n_up, threshold_ini, threshold_gap, conv_width_ini, conv_width_gap, 
# roundlo_val_ini, roundlo_gap, roundhi_val_ini, roundhi_gap, peakmax_val_ini, peakmax_gap):
test = tweak_run('/Users/natalie/anaconda2/envs/iraf27/iraf/sn/2000ds/2000ds_pre/tweak_555_2',10,10,0,3.5,0,-1.0,0,1,0.1,1000,0)
# Out:
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 11:28:48.143 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u3m71605r_c0m.fits
#
#     u3m71606r_c0m.fits
#
# ===  Source finding for image 'u3m71605r_c0m.fits':
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 1) started at: 11:28:48.457 (12/12/2017)
#
#      Found 647 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 2) started at: 11:28:48.786 (12/12/2017)
#
#      Found 669 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 3) started at: 11:28:49.178 (12/12/2017)
#
#      Found 726 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 4) started at: 11:28:49.65 (12/12/2017)
#
#      Found 779 objects.
#
# ===  Found a TOTAL of 2821 objects in image 'u3m71605r_c0m.fits'
#
#
#
# ===  Source finding for image 'u3m71606r_c0m.fits':
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 1) started at: 11:28:50.4 (12/12/2017)
#
#      Found 491 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 2) started at: 11:28:50.761 (12/12/2017)
#
#      Found 558 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 3) started at: 11:28:51.180 (12/12/2017)
#
#      Found 621 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 4) started at: 11:28:51.70 (12/12/2017)
#
#      Found 643 objects.
#
# ===  Found a TOTAL of 2313 objects in image 'u3m71606r_c0m.fits'
#
#
#
#  Catalog trimmed to 2821 objects
#
#
# ====================
# Aligning all input images to WCS defined by u3m71605r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u3m71606r_c0m.fits
#
# Matching sources from 'u3m71606r_c0m.fits' with sources from reference image 'u3m71605r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -1.073686882 -0.724480532791
#
#     with significance of  421.984814506 and  19.0  matches
#
# Found 62 matches for u3m71606r_c0m.fits...
#
# Computed  rscale  fit for  u3m71606r_c0m.fits :
#
# XSH: 0.0053063  YSH: 0.0195344    ROT: 360    SCALE: 1.00003
#
# XRMS: 0.102293    YRMS: 0.134396
#
# RMS_RA: 4.20797e-06 (deg)   RMS_DEC: 3.8271e-07 (deg)
#
# Final solution based on  54  objects.
#
# wrote XY data to:  u3m71606r_c0m_catalog_fit.match
#
# Writing out shiftfile : 1shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 0.005306
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 11:28:52.770 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u3m71605r_c0m.fits
#
#     u3m71606r_c0m.fits
#
# ===  Source finding for image 'u3m71605r_c0m.fits':
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 1) started at: 11:28:53.026 (12/12/2017)
#
#      Found 650 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 2) started at: 11:28:53.341 (12/12/2017)
#
#      Found 673 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 3) started at: 11:28:53.750 (12/12/2017)
#
#      Found 736 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 4) started at: 11:28:54.247 (12/12/2017)
#
#      Found 785 objects.
#
# ===  Found a TOTAL of 2844 objects in image 'u3m71605r_c0m.fits'
#
#
#
# ===  Source finding for image 'u3m71606r_c0m.fits':
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 1) started at: 11:28:54.94 (12/12/2017)
#
#      Found 498 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 2) started at: 11:28:55.216 (12/12/2017)
#
#      Found 569 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 3) started at: 11:28:55.543 (12/12/2017)
#
#      Found 638 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 4) started at: 11:28:55.937 (12/12/2017)
#
#      Found 657 objects.
#
# ===  Found a TOTAL of 2362 objects in image 'u3m71606r_c0m.fits'
#
#
#
#  Catalog trimmed to 2844 objects
#
#
# ====================
# Aligning all input images to WCS defined by u3m71605r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u3m71606r_c0m.fits
#
# Matching sources from 'u3m71606r_c0m.fits' with sources from reference image 'u3m71605r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -1.08471317547 -0.725934549512
#
#     with significance of  423.886942474 and  19.0  matches
#
# Found 63 matches for u3m71606r_c0m.fits...
#
# Computed  rscale  fit for  u3m71606r_c0m.fits :
#
# XSH: 0.0053063  YSH: 0.0195344    ROT: 360    SCALE: 1.00003
#
# XRMS: 0.102293    YRMS: 0.134396
#
# RMS_RA: 4.20797e-06 (deg)   RMS_DEC: 3.8271e-07 (deg)
#
# Final solution based on  54  objects.
#
# wrote XY data to:  u3m71606r_c0m_catalog_fit.match
#
# Writing out shiftfile : 2shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 0.005306
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 11:28:56.94 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u3m71605r_c0m.fits
#
#     u3m71606r_c0m.fits
#
# ===  Source finding for image 'u3m71605r_c0m.fits':
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 1) started at: 11:28:57.221 (12/12/2017)
#
#      Found 656 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 2) started at: 11:28:57.528 (12/12/2017)
#
#      Found 682 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 3) started at: 11:28:57.958 (12/12/2017)
#
#      Found 747 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 4) started at: 11:28:58.4 (12/12/2017)
#
#      Found 798 objects.
#
# ===  Found a TOTAL of 2883 objects in image 'u3m71605r_c0m.fits'
#
#
#
# ===  Source finding for image 'u3m71606r_c0m.fits':
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 1) started at: 11:28:59.109 (12/12/2017)
#
#      Found 504 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 2) started at: 11:28:59.375 (12/12/2017)
#
#      Found 577 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 3) started at: 11:28:59.696 (12/12/2017)
#
#      Found 642 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 4) started at: 11:29:00.138 (12/12/2017)
#
#      Found 669 objects.
#
# ===  Found a TOTAL of 2392 objects in image 'u3m71606r_c0m.fits'
#
#
#
#  Catalog trimmed to 2883 objects
#
#
# ====================
# Aligning all input images to WCS defined by u3m71605r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u3m71606r_c0m.fits
#
# Matching sources from 'u3m71606r_c0m.fits' with sources from reference image 'u3m71605r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -1.09590910422 -0.673686881998
#
#     with significance of  423.886942474 and  19.0  matches
#
# Found 65 matches for u3m71606r_c0m.fits...
#
# Computed  rscale  fit for  u3m71606r_c0m.fits :
#
# XSH: 0.00820492  YSH: 0.0214147    ROT: 360    SCALE: 1.00004
#
# XRMS: 0.103689    YRMS: 0.133506
#
# RMS_RA: 4.21886e-06 (deg)   RMS_DEC: 3.62492e-07 (deg)
#
# Final solution based on  55  objects.
#
# wrote XY data to:  u3m71606r_c0m_catalog_fit.match
#
# Writing out shiftfile : 3shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 0.008205
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 11:29:01.229 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u3m71605r_c0m.fits
#
#     u3m71606r_c0m.fits
#
# ===  Source finding for image 'u3m71605r_c0m.fits':
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 1) started at: 11:29:01.47 (12/12/2017)
#
#      Found 667 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 2) started at: 11:29:01.785 (12/12/2017)
#
#      Found 688 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 3) started at: 11:29:02.260 (12/12/2017)
#
#      Found 756 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 4) started at: 11:29:02.672 (12/12/2017)
#
#      Found 804 objects.
#
# ===  Found a TOTAL of 2915 objects in image 'u3m71605r_c0m.fits'
#
#
#
# ===  Source finding for image 'u3m71606r_c0m.fits':
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 1) started at: 11:29:03.315 (12/12/2017)
#
#      Found 507 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 2) started at: 11:29:03.578 (12/12/2017)
#
#      Found 579 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 3) started at: 11:29:03.911 (12/12/2017)
#
#      Found 651 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 4) started at: 11:29:04.421 (12/12/2017)
#
#      Found 680 objects.
#
# ===  Found a TOTAL of 2417 objects in image 'u3m71606r_c0m.fits'
#
#
#
#  Catalog trimmed to 2915 objects
#
#
# ====================
# Aligning all input images to WCS defined by u3m71605r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u3m71606r_c0m.fits
#
# Matching sources from 'u3m71606r_c0m.fits' with sources from reference image 'u3m71605r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -1.12199606074 -0.694459828857
#
#     with significance of  443.034366613 and  19.0  matches
#
# Found 65 matches for u3m71606r_c0m.fits...
#
# Computed  rscale  fit for  u3m71606r_c0m.fits :
#
# XSH: 0.0053063  YSH: 0.0195344    ROT: 360    SCALE: 1.00003
#
# XRMS: 0.102293    YRMS: 0.134396
#
# RMS_RA: 4.20797e-06 (deg)   RMS_DEC: 3.8271e-07 (deg)
#
# Final solution based on  54  objects.
#
# wrote XY data to:  u3m71606r_c0m_catalog_fit.match
#
# Writing out shiftfile : 4shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 0.005306
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 11:29:05.418 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u3m71605r_c0m.fits
#
#     u3m71606r_c0m.fits
#
# ===  Source finding for image 'u3m71605r_c0m.fits':
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 1) started at: 11:29:05.675 (12/12/2017)
#
#      Found 671 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 2) started at: 11:29:05.983 (12/12/2017)
#
#      Found 690 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 3) started at: 11:29:06.352 (12/12/2017)
#
#      Found 762 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 4) started at: 11:29:06.780 (12/12/2017)
#
#      Found 811 objects.
#
# ===  Found a TOTAL of 2934 objects in image 'u3m71605r_c0m.fits'
#
#
#
# ===  Source finding for image 'u3m71606r_c0m.fits':
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 1) started at: 11:29:07.531 (12/12/2017)
#
#      Found 512 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 2) started at: 11:29:07.793 (12/12/2017)
#
#      Found 588 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 3) started at: 11:29:08.111 (12/12/2017)
#
#      Found 663 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 4) started at: 11:29:08.522 (12/12/2017)
#
#      Found 689 objects.
#
# ===  Found a TOTAL of 2452 objects in image 'u3m71606r_c0m.fits'
#
#
#
#  Catalog trimmed to 2934 objects
#
#
# ====================
# Aligning all input images to WCS defined by u3m71605r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u3m71606r_c0m.fits
#
# Matching sources from 'u3m71606r_c0m.fits' with sources from reference image 'u3m71605r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -1.13988073543 -0.70725662195
#
#     with significance of  443.034366613 and  19.0  matches
#
# Found 64 matches for u3m71606r_c0m.fits...
#
# Computed  rscale  fit for  u3m71606r_c0m.fits :
#
# XSH: -0.0205588  YSH: 0.0170218    ROT: 360    SCALE: 1.00002
#
# XRMS: 0.15379    YRMS: 0.138164
#
# RMS_RA: 5.2353e-06 (deg)   RMS_DEC: 2.13125e-08 (deg)
#
# Final solution based on  54  objects.
#
# wrote XY data to:  u3m71606r_c0m_catalog_fit.match
#
# Writing out shiftfile : 5shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.020559
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 11:29:09.432 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u3m71605r_c0m.fits
#
#     u3m71606r_c0m.fits
#
# ===  Source finding for image 'u3m71605r_c0m.fits':
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 1) started at: 11:29:09.708 (12/12/2017)
#
#      Found 674 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 2) started at: 11:29:10.008 (12/12/2017)
#
#      Found 697 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 3) started at: 11:29:10.420 (12/12/2017)
#
#      Found 768 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 4) started at: 11:29:10.974 (12/12/2017)
#
#      Found 815 objects.
#
# ===  Found a TOTAL of 2954 objects in image 'u3m71605r_c0m.fits'
#
#
#
# ===  Source finding for image 'u3m71606r_c0m.fits':
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 1) started at: 11:29:11.581 (12/12/2017)
#
#      Found 514 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 2) started at: 11:29:11.882 (12/12/2017)
#
#      Found 593 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 3) started at: 11:29:12.21 (12/12/2017)
#
#      Found 667 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 4) started at: 11:29:12.607 (12/12/2017)
#
#      Found 692 objects.
#
# ===  Found a TOTAL of 2466 objects in image 'u3m71606r_c0m.fits'
#
#
#
#  Catalog trimmed to 2954 objects
#
#
# ====================
# Aligning all input images to WCS defined by u3m71605r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u3m71606r_c0m.fits
#
# Matching sources from 'u3m71606r_c0m.fits' with sources from reference image 'u3m71605r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -1.12341493173 -0.710827519138
#
#     with significance of  443.034366613 and  19.0  matches
#
# Found 65 matches for u3m71606r_c0m.fits...
#
# Computed  rscale  fit for  u3m71606r_c0m.fits :
#
# XSH: -0.0205588  YSH: 0.0170218    ROT: 360    SCALE: 1.00002
#
# XRMS: 0.15379    YRMS: 0.138164
#
# RMS_RA: 5.2353e-06 (deg)   RMS_DEC: 2.13125e-08 (deg)
#
# Final solution based on  54  objects.
#
# wrote XY data to:  u3m71606r_c0m_catalog_fit.match
#
# Writing out shiftfile : 6shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.020559
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 11:29:13.55 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u3m71605r_c0m.fits
#
#     u3m71606r_c0m.fits
#
# ===  Source finding for image 'u3m71605r_c0m.fits':
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 1) started at: 11:29:13.849 (12/12/2017)
#
#      Found 676 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 2) started at: 11:29:14.160 (12/12/2017)
#
#      Found 707 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 3) started at: 11:29:14.5 (12/12/2017)
#
#      Found 773 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 4) started at: 11:29:15.035 (12/12/2017)
#
#      Found 821 objects.
#
# ===  Found a TOTAL of 2977 objects in image 'u3m71605r_c0m.fits'
#
#
#
# ===  Source finding for image 'u3m71606r_c0m.fits':
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 1) started at: 11:29:15.714 (12/12/2017)
#
#      Found 518 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 2) started at: 11:29:16.023 (12/12/2017)
#
#      Found 598 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 3) started at: 11:29:16.350 (12/12/2017)
#
#      Found 673 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 4) started at: 11:29:16.743 (12/12/2017)
#
#      Found 695 objects.
#
# ===  Found a TOTAL of 2484 objects in image 'u3m71606r_c0m.fits'
#
#
#
#  Catalog trimmed to 2977 objects
#
#
# ====================
# Aligning all input images to WCS defined by u3m71605r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u3m71606r_c0m.fits
#
# Matching sources from 'u3m71606r_c0m.fits' with sources from reference image 'u3m71605r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -1.10050680537 -0.707403357093
#
#     with significance of  443.034366613 and  19.0  matches
#
# Found 67 matches for u3m71606r_c0m.fits...
#
# Computed  rscale  fit for  u3m71606r_c0m.fits :
#
# XSH: -0.0172255  YSH: 0.0230174    ROT: 360    SCALE: 1.00003
#
# XRMS: 0.152263    YRMS: 0.138637
#
# RMS_RA: 5.21481e-06 (deg)   RMS_DEC: 3.87014e-09 (deg)
#
# Final solution based on  56  objects.
#
# wrote XY data to:  u3m71606r_c0m_catalog_fit.match
#
# Writing out shiftfile : 7shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.017225
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 11:29:17.706 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u3m71605r_c0m.fits
#
#     u3m71606r_c0m.fits
#
# ===  Source finding for image 'u3m71605r_c0m.fits':
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 1) started at: 11:29:18.028 (12/12/2017)
#
#      Found 678 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 2) started at: 11:29:18.450 (12/12/2017)
#
#      Found 710 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 3) started at: 11:29:18.860 (12/12/2017)
#
#      Found 776 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 4) started at: 11:29:19.31 (12/12/2017)
#
#      Found 824 objects.
#
# ===  Found a TOTAL of 2988 objects in image 'u3m71605r_c0m.fits'
#
#
#
# ===  Source finding for image 'u3m71606r_c0m.fits':
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 1) started at: 11:29:19.97 (12/12/2017)
#
#      Found 520 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 2) started at: 11:29:20.263 (12/12/2017)
#
#      Found 598 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 3) started at: 11:29:20.585 (12/12/2017)
#
#      Found 679 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 4) started at: 11:29:21.001 (12/12/2017)
#
#      Found 704 objects.
#
# ===  Found a TOTAL of 2501 objects in image 'u3m71606r_c0m.fits'
#
#
#
#  Catalog trimmed to 2988 objects
#
#
# ====================
# Aligning all input images to WCS defined by u3m71605r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u3m71606r_c0m.fits
#
# Matching sources from 'u3m71606r_c0m.fits' with sources from reference image 'u3m71605r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -1.1102267776 -0.694119395047
#
#     with significance of  452.593755693 and  19.0  matches
#
# Found 67 matches for u3m71606r_c0m.fits...
#
# Computed  rscale  fit for  u3m71606r_c0m.fits :
#
# XSH: -0.0172255  YSH: 0.0230174    ROT: 360    SCALE: 1.00003
#
# XRMS: 0.152263    YRMS: 0.138637
#
# RMS_RA: 5.21481e-06 (deg)   RMS_DEC: 3.87014e-09 (deg)
#
# Final solution based on  56  objects.
#
# wrote XY data to:  u3m71606r_c0m_catalog_fit.match
#
# Writing out shiftfile : 8shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.017225
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 11:29:21.998 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u3m71605r_c0m.fits
#
#     u3m71606r_c0m.fits
#
# ===  Source finding for image 'u3m71605r_c0m.fits':
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 1) started at: 11:29:22.286 (12/12/2017)
#
#      Found 685 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 2) started at: 11:29:22.582 (12/12/2017)
#
#      Found 715 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 3) started at: 11:29:22.940 (12/12/2017)
#
#      Found 780 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 4) started at: 11:29:23.419 (12/12/2017)
#
#      Found 827 objects.
#
# ===  Found a TOTAL of 3007 objects in image 'u3m71605r_c0m.fits'
#
#
#
# ===  Source finding for image 'u3m71606r_c0m.fits':
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 1) started at: 11:29:24.11 (12/12/2017)
#
#      Found 522 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 2) started at: 11:29:24.440 (12/12/2017)
#
#      Found 599 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 3) started at: 11:29:24.778 (12/12/2017)
#
#      Found 682 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 4) started at: 11:29:25.179 (12/12/2017)
#
#      Found 709 objects.
#
# ===  Found a TOTAL of 2512 objects in image 'u3m71606r_c0m.fits'
#
#
#
#  Catalog trimmed to 3007 objects
#
#
# ====================
# Aligning all input images to WCS defined by u3m71605r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u3m71606r_c0m.fits
#
# Matching sources from 'u3m71606r_c0m.fits' with sources from reference image 'u3m71605r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -1.1102267776 -0.694119395047
#
#     with significance of  452.593755693 and  19.0  matches
#
# Found 67 matches for u3m71606r_c0m.fits...
#
# Computed  rscale  fit for  u3m71606r_c0m.fits :
#
# XSH: -0.0172255  YSH: 0.0230174    ROT: 360    SCALE: 1.00003
#
# XRMS: 0.152263    YRMS: 0.138637
#
# RMS_RA: 5.21481e-06 (deg)   RMS_DEC: 3.87014e-09 (deg)
#
# Final solution based on  56  objects.
#
# wrote XY data to:  u3m71606r_c0m_catalog_fit.match
#
# Writing out shiftfile : 9shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.017225

# %%
# change to a jupyter table
dt=test.to_pandas()
dt.to_pickle('data.pickle')
good_table=pandas.read_pickle('data.pickle')

# %%
# take only unfailed sessions
good_roundhi = good_table[good_table['y_rms'] != 'failed']

# %%
good_roundhi
# Out:
#          shift                file     x_rms     y_rms  threshold  conv_width  \
# 0   1shift.txt  u3m71605r_c0m.fits  0.000000  0.000000         10         3.5
# 1   1shift.txt  u3m71606r_c0m.fits  0.125315  0.144362         10         3.5
# 2   2shift.txt  u3m71605r_c0m.fits  0.000000  0.000000         10         3.5
# 3   2shift.txt  u3m71606r_c0m.fits  0.127129  0.145862         10         3.5
# 4   3shift.txt  u3m71605r_c0m.fits  0.000000  0.000000         10         3.5
# 5   3shift.txt  u3m71606r_c0m.fits  0.128668  0.146306         10         3.5
# 6   4shift.txt  u3m71605r_c0m.fits  0.000000  0.000000         10         3.5
# 7   4shift.txt  u3m71606r_c0m.fits  0.128668  0.146306         10         3.5
# 8   5shift.txt  u3m71605r_c0m.fits  0.000000  0.000000         10         3.5
# 9   5shift.txt  u3m71606r_c0m.fits  0.128668  0.146306         10         3.5
# 10  6shift.txt  u3m71605r_c0m.fits  0.000000  0.000000         10         3.5
# 11  6shift.txt  u3m71606r_c0m.fits  0.102293  0.134396         10         3.5
# 12  7shift.txt  u3m71605r_c0m.fits  0.000000  0.000000         10         3.5
# 13  7shift.txt  u3m71606r_c0m.fits  0.102293  0.134396         10         3.5
# 14  8shift.txt  u3m71605r_c0m.fits  0.000000  0.000000         10         3.5
# 15  8shift.txt  u3m71606r_c0m.fits  0.103689  0.133506         10         3.5
# 16  9shift.txt  u3m71605r_c0m.fits  0.000000  0.000000         10         3.5
# 17  9shift.txt  u3m71606r_c0m.fits  0.102293  0.134396         10         3.5
#
#     roundlo  roundhi  peakmax
# 0      -1.0      0.5     1000
# 1      -1.0      0.5     1000
# 2      -1.0      0.6     1000
# 3      -1.0      0.6     1000
# 4      -1.0      0.7     1000
# 5      -1.0      0.7     1000
# 6      -1.0      0.8     1000
# 7      -1.0      0.8     1000
# 8      -1.0      0.9     1000
# 9      -1.0      0.9     1000
# 10     -1.0      1.0     1000
# 11     -1.0      1.0     1000
# 12     -1.0      1.1     1000
# 13     -1.0      1.1     1000
# 14     -1.0      1.2     1000
# 15     -1.0      1.2     1000
# 16     -1.0      1.3     1000
# 17     -1.0      1.3     1000

# %%
# plot figure for all sub-exp 
plt.figure(figsize = (7,7))
plt.plot(good_roundhi['roundhi'],good_roundhi['x_rms'],'.g')
plt.plot(good_roundhi['roundhi'],good_roundhi['y_rms'],'.b')
plt.title('x,y_rms(roundhi)-g,b')
plt.show()

# %%
# plot figure for choosen sub-exp
plt.figure(figsize = (7,7))
plt.plot(good_round[good_round['file'] == 'u6ea5402m_c0m.fits']['roundhi'],good_round[good_round['file'] == 'u6ea5402m_c0m.fits']['y_rms'],'.b')
plt.plot(good_round[good_round['file'] == 'u6ea5403m_c0m.fits']['roundhi'],good_round[good_round['file'] == 'u6ea5403m_c0m.fits']['y_rms'],'.g')
plt.title('y_rms(roundhi)-two filters')
plt.show()

# %%
#############################################thresh = 10, conv = 3.5 roundnlo = -1.0, rounfhi = 1, peakmax?

# %%
# tweak_run(path, n_up, threshold_ini, threshold_gap, conv_width_ini, conv_width_gap, 
# roundlo_val_ini, roundlo_gap, roundhi_val_ini, roundhi_gap, peakmax_val_ini, peakmax_gap):
test = tweak_run('/Users/natalie/anaconda2/envs/iraf27/iraf/sn/2000ds/2000ds_pre/tweak_555_2',10,10,0,3.5,0,-1.0,0,1,0.1,500,500)
# Out:
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 11:30:36.748 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u3m71605r_c0m.fits
#
#     u3m71606r_c0m.fits
#
# ===  Source finding for image 'u3m71605r_c0m.fits':
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 1) started at: 11:30:37.06 (12/12/2017)
#
#      Found 607 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 2) started at: 11:30:37.442 (12/12/2017)
#
#      Found 640 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 3) started at: 11:30:37.827 (12/12/2017)
#
#      Found 687 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 4) started at: 11:30:38.245 (12/12/2017)
#
#      Found 741 objects.
#
# ===  Found a TOTAL of 2675 objects in image 'u3m71605r_c0m.fits'
#
#
#
# ===  Source finding for image 'u3m71606r_c0m.fits':
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 1) started at: 11:30:39.008 (12/12/2017)
#
#      Found 467 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 2) started at: 11:30:39.287 (12/12/2017)
#
#      Found 542 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 3) started at: 11:30:39.641 (12/12/2017)
#
#      Found 587 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 4) started at: 11:30:40.108 (12/12/2017)
#
#      Found 606 objects.
#
# ===  Found a TOTAL of 2202 objects in image 'u3m71606r_c0m.fits'
#
#
#
#  Catalog trimmed to 2675 objects
#
#
# ====================
# Aligning all input images to WCS defined by u3m71605r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u3m71606r_c0m.fits
#
# Matching sources from 'u3m71606r_c0m.fits' with sources from reference image 'u3m71605r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -1.01948633999 -0.726803413163
#
#     with significance of  421.984814506 and  19.0  matches
#
# Found 64 matches for u3m71606r_c0m.fits...
#
# Computed  rscale  fit for  u3m71606r_c0m.fits :
#
# XSH: 0.0172016  YSH: 0.0214574    ROT: 5.50361e-05    SCALE: 1.00004
#
# XRMS: 0.112091    YRMS: 0.130926
#
# RMS_RA: 4.33192e-06 (deg)   RMS_DEC: 2.66734e-07 (deg)
#
# Final solution based on  57  objects.
#
# wrote XY data to:  u3m71606r_c0m_catalog_fit.match
#
# Writing out shiftfile : 1shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 0.017202
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 11:30:41.021 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u3m71605r_c0m.fits
#
#     u3m71606r_c0m.fits
#
# ===  Source finding for image 'u3m71605r_c0m.fits':
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 1) started at: 11:30:41.279 (12/12/2017)
#
#      Found 650 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 2) started at: 11:30:41.586 (12/12/2017)
#
#      Found 673 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 3) started at: 11:30:41.951 (12/12/2017)
#
#      Found 736 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 4) started at: 11:30:42.359 (12/12/2017)
#
#      Found 785 objects.
#
# ===  Found a TOTAL of 2844 objects in image 'u3m71605r_c0m.fits'
#
#
#
# ===  Source finding for image 'u3m71606r_c0m.fits':
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 1) started at: 11:30:43.081 (12/12/2017)
#
#      Found 498 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 2) started at: 11:30:43.346 (12/12/2017)
#
#      Found 569 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 3) started at: 11:30:43.682 (12/12/2017)
#
#      Found 638 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 4) started at: 11:30:44.078 (12/12/2017)
#
#      Found 657 objects.
#
# ===  Found a TOTAL of 2362 objects in image 'u3m71606r_c0m.fits'
#
#
#
#  Catalog trimmed to 2844 objects
#
#
# ====================
# Aligning all input images to WCS defined by u3m71605r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u3m71606r_c0m.fits
#
# Matching sources from 'u3m71606r_c0m.fits' with sources from reference image 'u3m71605r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -1.08471317547 -0.725934549512
#
#     with significance of  423.886942474 and  19.0  matches
#
# Found 63 matches for u3m71606r_c0m.fits...
#
# Computed  rscale  fit for  u3m71606r_c0m.fits :
#
# XSH: 0.0053063  YSH: 0.0195344    ROT: 360    SCALE: 1.00003
#
# XRMS: 0.102293    YRMS: 0.134396
#
# RMS_RA: 4.20797e-06 (deg)   RMS_DEC: 3.8271e-07 (deg)
#
# Final solution based on  54  objects.
#
# wrote XY data to:  u3m71606r_c0m_catalog_fit.match
#
# Writing out shiftfile : 2shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 0.005306
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 11:30:44.983 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u3m71605r_c0m.fits
#
#     u3m71606r_c0m.fits
#
# ===  Source finding for image 'u3m71605r_c0m.fits':
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 1) started at: 11:30:45.238 (12/12/2017)
#
#      Found 672 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 2) started at: 11:30:45.591 (12/12/2017)
#
#      Found 700 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 3) started at: 11:30:45.954 (12/12/2017)
#
#      Found 762 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 4) started at: 11:30:46.413 (12/12/2017)
#
#      Found 809 objects.
#
# ===  Found a TOTAL of 2943 objects in image 'u3m71605r_c0m.fits'
#
#
#
# ===  Source finding for image 'u3m71606r_c0m.fits':
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 1) started at: 11:30:47.059 (12/12/2017)
#
#      Found 520 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 2) started at: 11:30:47.333 (12/12/2017)
#
#      Found 589 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 3) started at: 11:30:47.668 (12/12/2017)
#
#      Found 651 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 4) started at: 11:30:48.126 (12/12/2017)
#
#      Found 680 objects.
#
# ===  Found a TOTAL of 2440 objects in image 'u3m71606r_c0m.fits'
#
#
#
#  Catalog trimmed to 2943 objects
#
#
# ====================
# Aligning all input images to WCS defined by u3m71605r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u3m71606r_c0m.fits
#
# Matching sources from 'u3m71606r_c0m.fits' with sources from reference image 'u3m71605r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -1.11257577089 -0.705432913744
#
#     with significance of  435.364687032 and  19.0  matches
#
# Found 64 matches for u3m71606r_c0m.fits...
#
# Computed  rscale  fit for  u3m71606r_c0m.fits :
#
# XSH: 0.0053063  YSH: 0.0195344    ROT: 360    SCALE: 1.00003
#
# XRMS: 0.102293    YRMS: 0.134396
#
# RMS_RA: 4.20797e-06 (deg)   RMS_DEC: 3.8271e-07 (deg)
#
# Final solution based on  54  objects.
#
# wrote XY data to:  u3m71606r_c0m_catalog_fit.match
#
# Writing out shiftfile : 3shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 0.005306
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 11:30:49.01 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u3m71605r_c0m.fits
#
#     u3m71606r_c0m.fits
#
# ===  Source finding for image 'u3m71605r_c0m.fits':
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 1) started at: 11:30:49.268 (12/12/2017)
#
#      Found 691 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 2) started at: 11:30:49.578 (12/12/2017)
#
#      Found 710 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 3) started at: 11:30:49.935 (12/12/2017)
#
#      Found 775 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 4) started at: 11:30:50.401 (12/12/2017)
#
#      Found 820 objects.
#
# ===  Found a TOTAL of 2996 objects in image 'u3m71605r_c0m.fits'
#
#
#
# ===  Source finding for image 'u3m71606r_c0m.fits':
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 1) started at: 11:30:51.076 (12/12/2017)
#
#      Found 531 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 2) started at: 11:30:51.342 (12/12/2017)
#
#      Found 595 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 3) started at: 11:30:51.675 (12/12/2017)
#
#      Found 664 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 4) started at: 11:30:52.046 (12/12/2017)
#
#      Found 697 objects.
#
# ===  Found a TOTAL of 2487 objects in image 'u3m71606r_c0m.fits'
#
#
#
#  Catalog trimmed to 2996 objects
#
#
# ====================
# Aligning all input images to WCS defined by u3m71605r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u3m71606r_c0m.fits
#
# Matching sources from 'u3m71606r_c0m.fits' with sources from reference image 'u3m71605r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -1.11429990882 -0.707403357093
#
#     with significance of  446.863748448 and  19.0  matches
#
# Found 65 matches for u3m71606r_c0m.fits...
#
# Computed  rscale  fit for  u3m71606r_c0m.fits :
#
# XSH: 0.0053063  YSH: 0.0195344    ROT: 360    SCALE: 1.00003
#
# XRMS: 0.102293    YRMS: 0.134396
#
# RMS_RA: 4.20797e-06 (deg)   RMS_DEC: 3.8271e-07 (deg)
#
# Final solution based on  54  objects.
#
# wrote XY data to:  u3m71606r_c0m_catalog_fit.match
#
# Writing out shiftfile : 4shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 0.005306
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 11:30:52.957 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u3m71605r_c0m.fits
#
#     u3m71606r_c0m.fits
#
# ===  Source finding for image 'u3m71605r_c0m.fits':
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 1) started at: 11:30:53.253 (12/12/2017)
#
#      Found 704 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 2) started at: 11:30:53.572 (12/12/2017)
#
#      Found 713 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 3) started at: 11:30:53.94 (12/12/2017)
#
#      Found 784 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 4) started at: 11:30:54.406 (12/12/2017)
#
#      Found 831 objects.
#
# ===  Found a TOTAL of 3032 objects in image 'u3m71605r_c0m.fits'
#
#
#
# ===  Source finding for image 'u3m71606r_c0m.fits':
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 1) started at: 11:30:55.034 (12/12/2017)
#
#      Found 540 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 2) started at: 11:30:55.292 (12/12/2017)
#
#      Found 605 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 3) started at: 11:30:55.644 (12/12/2017)
#
#      Found 680 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 4) started at: 11:30:56.085 (12/12/2017)
#
#      Found 708 objects.
#
# ===  Found a TOTAL of 2533 objects in image 'u3m71606r_c0m.fits'
#
#
#
#  Catalog trimmed to 3032 objects
#
#
# ====================
# Aligning all input images to WCS defined by u3m71605r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u3m71606r_c0m.fits
#
# Matching sources from 'u3m71606r_c0m.fits' with sources from reference image 'u3m71605r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -1.13149468981 -0.719332527643
#
#     with significance of  446.863748448 and  19.0  matches
#
# Found 64 matches for u3m71606r_c0m.fits...
#
# Computed  rscale  fit for  u3m71606r_c0m.fits :
#
# XSH: -0.0205588  YSH: 0.0170218    ROT: 360    SCALE: 1.00002
#
# XRMS: 0.15379    YRMS: 0.138164
#
# RMS_RA: 5.2353e-06 (deg)   RMS_DEC: 2.13125e-08 (deg)
#
# Final solution based on  54  objects.
#
# wrote XY data to:  u3m71606r_c0m_catalog_fit.match
#
# Writing out shiftfile : 5shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.020559
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 11:30:56.975 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u3m71605r_c0m.fits
#
#     u3m71606r_c0m.fits
#
# ===  Source finding for image 'u3m71605r_c0m.fits':
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 1) started at: 11:30:57.214 (12/12/2017)
#
#      Found 716 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 2) started at: 11:30:57.533 (12/12/2017)
#
#      Found 721 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 3) started at: 11:30:57.895 (12/12/2017)
#
#      Found 791 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 4) started at: 11:30:58.393 (12/12/2017)
#
#      Found 838 objects.
#
# ===  Found a TOTAL of 3066 objects in image 'u3m71605r_c0m.fits'
#
#
#
# ===  Source finding for image 'u3m71606r_c0m.fits':
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 1) started at: 11:30:59.009 (12/12/2017)
#
#      Found 545 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 2) started at: 11:30:59.298 (12/12/2017)
#
#      Found 610 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 3) started at: 11:30:59.630 (12/12/2017)
#
#      Found 685 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 4) started at: 11:31:00.034 (12/12/2017)
#
#      Found 712 objects.
#
# ===  Found a TOTAL of 2552 objects in image 'u3m71606r_c0m.fits'
#
#
#
#  Catalog trimmed to 3066 objects
#
#
# ====================
# Aligning all input images to WCS defined by u3m71605r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u3m71606r_c0m.fits
#
# Matching sources from 'u3m71606r_c0m.fits' with sources from reference image 'u3m71605r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -1.11389156036 -0.758628402465
#
#     with significance of  446.863748448 and  19.0  matches
#
# Found 63 matches for u3m71606r_c0m.fits...
#
# Computed  rscale  fit for  u3m71606r_c0m.fits :
#
# XSH: -0.0239524  YSH: 0.0101375    ROT: 360    SCALE: 1.00002
#
# XRMS: 0.155067    YRMS: 0.137098
#
# RMS_RA: 5.24096e-06 (deg)   RMS_DEC: 4.21541e-08 (deg)
#
# Final solution based on  52  objects.
#
# wrote XY data to:  u3m71606r_c0m_catalog_fit.match
#
# Writing out shiftfile : 6shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.023952
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 11:31:00.899 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u3m71605r_c0m.fits
#
#     u3m71606r_c0m.fits
#
# ===  Source finding for image 'u3m71605r_c0m.fits':
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 1) started at: 11:31:01.201 (12/12/2017)
#
#      Found 720 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 2) started at: 11:31:01.518 (12/12/2017)
#
#      Found 733 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 3) started at: 11:31:01.881 (12/12/2017)
#
#      Found 796 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 4) started at: 11:31:02.390 (12/12/2017)
#
#      Found 847 objects.
#
# ===  Found a TOTAL of 3096 objects in image 'u3m71605r_c0m.fits'
#
#
#
# ===  Source finding for image 'u3m71606r_c0m.fits':
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 1) started at: 11:31:03.029 (12/12/2017)
#
#      Found 550 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 2) started at: 11:31:03.307 (12/12/2017)
#
#      Found 619 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 3) started at: 11:31:03.707 (12/12/2017)
#
#      Found 695 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 4) started at: 11:31:04.113 (12/12/2017)
#
#      Found 715 objects.
#
# ===  Found a TOTAL of 2579 objects in image 'u3m71606r_c0m.fits'
#
#
#
#  Catalog trimmed to 3096 objects
#
#
# ====================
# Aligning all input images to WCS defined by u3m71605r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u3m71606r_c0m.fits
#
# Matching sources from 'u3m71606r_c0m.fits' with sources from reference image 'u3m71605r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -1.09244590076 -0.754783563094
#
#     with significance of  446.863748448 and  19.0  matches
#
# Found 66 matches for u3m71606r_c0m.fits...
#
# Computed  rscale  fit for  u3m71606r_c0m.fits :
#
# XSH: -0.0183829  YSH: 0.0192431    ROT: 360    SCALE: 1.00002
#
# XRMS: 0.153298    YRMS: 0.137477
#
# RMS_RA: 5.21435e-06 (deg)   RMS_DEC: 2.35288e-08 (deg)
#
# Final solution based on  55  objects.
#
# wrote XY data to:  u3m71606r_c0m_catalog_fit.match
#
# Writing out shiftfile : 7shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.018383
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 11:31:05.009 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u3m71605r_c0m.fits
#
#     u3m71606r_c0m.fits
#
# ===  Source finding for image 'u3m71605r_c0m.fits':
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 1) started at: 11:31:05.264 (12/12/2017)
#
#      Found 727 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 2) started at: 11:31:05.572 (12/12/2017)
#
#      Found 738 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 3) started at: 11:31:05.948 (12/12/2017)
#
#      Found 805 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 4) started at: 11:31:06.466 (12/12/2017)
#
#      Found 852 objects.
#
# ===  Found a TOTAL of 3122 objects in image 'u3m71605r_c0m.fits'
#
#
#
# ===  Source finding for image 'u3m71606r_c0m.fits':
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 1) started at: 11:31:07.101 (12/12/2017)
#
#      Found 556 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 2) started at: 11:31:07.379 (12/12/2017)
#
#      Found 621 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 3) started at: 11:31:07.703 (12/12/2017)
#
#      Found 702 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 4) started at: 11:31:08.11 (12/12/2017)
#
#      Found 730 objects.
#
# ===  Found a TOTAL of 2609 objects in image 'u3m71606r_c0m.fits'
#
#
#
#  Catalog trimmed to 3122 objects
#
#
# ====================
# Aligning all input images to WCS defined by u3m71605r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u3m71606r_c0m.fits
#
# Matching sources from 'u3m71606r_c0m.fits' with sources from reference image 'u3m71605r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -1.08757577089 -0.731325770886
#
#     with significance of  441.117763591 and  19.0  matches
#
# Found 67 matches for u3m71606r_c0m.fits...
#
# Computed  rscale  fit for  u3m71606r_c0m.fits :
#
# XSH: -0.0172255  YSH: 0.0230174    ROT: 360    SCALE: 1.00003
#
# XRMS: 0.152263    YRMS: 0.138637
#
# RMS_RA: 5.21481e-06 (deg)   RMS_DEC: 3.87014e-09 (deg)
#
# Final solution based on  56  objects.
#
# wrote XY data to:  u3m71606r_c0m_catalog_fit.match
#
# Writing out shiftfile : 8shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.017225
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 11:31:09.094 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u3m71605r_c0m.fits
#
#     u3m71606r_c0m.fits
#
# ===  Source finding for image 'u3m71605r_c0m.fits':
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 1) started at: 11:31:09.338 (12/12/2017)
#
#      Found 735 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 2) started at: 11:31:09.651 (12/12/2017)
#
#      Found 745 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 3) started at: 11:31:10.043 (12/12/2017)
#
#      Found 812 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 4) started at: 11:31:10.470 (12/12/2017)
#
#      Found 857 objects.
#
# ===  Found a TOTAL of 3149 objects in image 'u3m71605r_c0m.fits'
#
#
#
# ===  Source finding for image 'u3m71606r_c0m.fits':
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 1) started at: 11:31:11.154 (12/12/2017)
#
#      Found 559 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 2) started at: 11:31:11.468 (12/12/2017)
#
#      Found 624 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 3) started at: 11:31:11.788 (12/12/2017)
#
#      Found 709 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 4) started at: 11:31:12.20 (12/12/2017)
#
#      Found 736 objects.
#
# ===  Found a TOTAL of 2628 objects in image 'u3m71606r_c0m.fits'
#
#
#
#  Catalog trimmed to 3149 objects
#
#
# ====================
# Aligning all input images to WCS defined by u3m71605r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u3m71606r_c0m.fits
#
# Matching sources from 'u3m71606r_c0m.fits' with sources from reference image 'u3m71605r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -1.08757577089 -0.731325770886
#
#     with significance of  441.117763591 and  19.0  matches
#
# Found 67 matches for u3m71606r_c0m.fits...
#
# Computed  rscale  fit for  u3m71606r_c0m.fits :
#
# XSH: -0.0172255  YSH: 0.0230174    ROT: 360    SCALE: 1.00003
#
# XRMS: 0.152263    YRMS: 0.138637
#
# RMS_RA: 5.21481e-06 (deg)   RMS_DEC: 3.87014e-09 (deg)
#
# Final solution based on  56  objects.
#
# wrote XY data to:  u3m71606r_c0m_catalog_fit.match
#
# Writing out shiftfile : 9shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.017225

# %%
# change to a jupyter table
dt=test.to_pandas()
dt.to_pickle('data.pickle')
good_table=pandas.read_pickle('data.pickle')

# %%
# take only unfailed sessions
good_peakmax = good_table[good_table['y_rms'] != 'failed']

# %%
good_peakmax
# Out:
#          shift                file     x_rms     y_rms  threshold  conv_width  \
# 0   1shift.txt  u3m71605r_c0m.fits  0.000000  0.000000         10         3.5
# 1   1shift.txt  u3m71606r_c0m.fits  0.112091  0.130926         10         3.5
# 2   2shift.txt  u3m71605r_c0m.fits  0.000000  0.000000         10         3.5
# 3   2shift.txt  u3m71606r_c0m.fits  0.102293  0.134396         10         3.5
# 4   3shift.txt  u3m71605r_c0m.fits  0.000000  0.000000         10         3.5
# 5   3shift.txt  u3m71606r_c0m.fits  0.102293  0.134396         10         3.5
# 6   4shift.txt  u3m71605r_c0m.fits  0.000000  0.000000         10         3.5
# 7   4shift.txt  u3m71606r_c0m.fits  0.102293  0.134396         10         3.5
# 8   5shift.txt  u3m71605r_c0m.fits  0.000000  0.000000         10         3.5
# 9   5shift.txt  u3m71606r_c0m.fits  0.153790  0.138164         10         3.5
# 10  6shift.txt  u3m71605r_c0m.fits  0.000000  0.000000         10         3.5
# 11  6shift.txt  u3m71606r_c0m.fits  0.155067  0.137098         10         3.5
# 12  7shift.txt  u3m71605r_c0m.fits  0.000000  0.000000         10         3.5
# 13  7shift.txt  u3m71606r_c0m.fits  0.153298  0.137477         10         3.5
# 14  8shift.txt  u3m71605r_c0m.fits  0.000000  0.000000         10         3.5
# 15  8shift.txt  u3m71606r_c0m.fits  0.152263  0.138637         10         3.5
# 16  9shift.txt  u3m71605r_c0m.fits  0.000000  0.000000         10         3.5
# 17  9shift.txt  u3m71606r_c0m.fits  0.152263  0.138637         10         3.5
#
#     roundlo  roundhi  peakmax
# 0      -1.0      1.0      500
# 1      -1.0      1.0      500
# 2      -1.0      1.1     1000
# 3      -1.0      1.1     1000
# 4      -1.0      1.2     1500
# 5      -1.0      1.2     1500
# 6      -1.0      1.3     2000
# 7      -1.0      1.3     2000
# 8      -1.0      1.4     2500
# 9      -1.0      1.4     2500
# 10     -1.0      1.5     3000
# 11     -1.0      1.5     3000
# 12     -1.0      1.6     3500
# 13     -1.0      1.6     3500
# 14     -1.0      1.7     4000
# 15     -1.0      1.7     4000
# 16     -1.0      1.8     4500
# 17     -1.0      1.8     4500

# %%
# plot figure for all sub-exp ??????????????????????????????????????????
plt.figure(figsize = (7,7))
plt.plot(good_peakmax['peakmax'],good_peakmax['x_rms'],'.g')
plt.plot(good_peakmax['peakmax'],good_peakmax['y_rms'],'.b')
plt.title('x,y_rms(peakmax)-g,b')
plt.show()

# %%
################################## tweakreg run for good parameters without headers, see figures- 
# thresh = 10, conv = 3.5 roundnlo = -0.1, rounfhi = 1.0, peakmax = 1000

# %%
import os
from drizzlepac import tweakreg
os.chdir('/Users/natalie/anaconda2/envs/iraf27/iraf/sn/2000ds/2000ds_pre/tweak_814_1')
tweakreg.TweakReg('*c0m.fits', exclusions='WFPC2_exclude.txt', updatehdr=False, shiftfile=True, outshifts='shift_final', residplot='both', see2dplot='Yes', use_sharp_round='Yes', threshold=7, conv_width=3.5, roundlo=-0.1, roundhi=1.0, peakmax=4500)
# Out:
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 23:54:43.46 (06/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u2tv1801t_c0m.fits
#
#     u2tv1802t_c0m.fits
#
# ===  Source finding for image 'u2tv1801t_c0m.fits':
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 1) started at: 23:54:43.899 (06/12/2017)
#
#      Found 160 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 2) started at: 23:54:44.289 (06/12/2017)
#
#      Found 90 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 3) started at: 23:54:44.517 (06/12/2017)
#
#      Found 125 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 4) started at: 23:54:44.82 (06/12/2017)
#
#      Found 150 objects.
#
# ===  Found a TOTAL of 525 objects in image 'u2tv1801t_c0m.fits'
#
#
#
# ===  Source finding for image 'u2tv1802t_c0m.fits':
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 1) started at: 23:54:45.293 (06/12/2017)
#
#      Found 157 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 2) started at: 23:54:45.681 (06/12/2017)
#
#      Found 74 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 3) started at: 23:54:45.93 (06/12/2017)
#
#      Found 80 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 4) started at: 23:54:46.212 (06/12/2017)
#
#      Found 153 objects.
#
# ===  Found a TOTAL of 464 objects in image 'u2tv1802t_c0m.fits'
#
#
#
#  Catalog trimmed to 525 objects
#
#
# ====================
# Aligning all input images to WCS defined by u2tv1801t_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u2tv1802t_c0m.fits
#
# Matching sources from 'u2tv1802t_c0m.fits' with sources from reference image 'u2tv1801t_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.847995822128 -0.975655396597
#
#     with significance of  317.022492687 and  12.0  matches
#
# Found 30 matches for u2tv1802t_c0m.fits...
#
# Computed  rscale  fit for  u2tv1802t_c0m.fits :
#
# XSH: 0.0121239  YSH: -0.0124761    ROT: 359.999    SCALE: 1.00001
#
# XRMS: 0.116002    YRMS: 0.1232
#
# RMS_RA: 4.25878e-06 (deg)   RMS_DEC: 2.49732e-07 (deg)
#
# Final solution based on  27  objects.
#
# wrote XY data to:  u2tv1802t_c0m_catalog_fit.match
#
# Total # points:  27
#
# # of points after clipping:  27
#
# Total # points:  27
#
# # of points after clipping:  27
#
# Press ENTER for next image,
#       'n' to continue without updating header or
#       'q' to quit immediately...
#
# Writing out shiftfile : shift_final
#
# Trailer file written to:  tweakreg.log

# %%
################################## tweakreg run for headers update -  
# thresh = 7, conv = 3.5 roundnlo = -0.1, rounfhi = 1.0, peakmax = 4500

# %%
# final parameters to see plots
import os
from drizzlepac import tweakreg
os.chdir('/Users/natalie/anaconda2/envs/iraf27/iraf/sn/2000ds/2000ds_pre/tweak_555_2')
tweakreg.TweakReg('*c0m.fits', exclusions='WFPC2_exclude.txt', updatehdr=False, shiftfile=True, outshifts='shift_final', residplot='both', see2dplot='Yes', use_sharp_round='Yes', threshold=10, conv_width=3.5, roundlo=-0.1, roundhi=1.0, peakmax=1000)
# Out:
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 11:33:33.900 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u3m71605r_c0m.fits
#
#     u3m71606r_c0m.fits
#
# ===  Source finding for image 'u3m71605r_c0m.fits':
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 1) started at: 11:33:34.249 (12/12/2017)
#
#      Found 306 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 2) started at: 11:33:34.58 (12/12/2017)
#
#      Found 318 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 3) started at: 11:33:35.029 (12/12/2017)
#
#      Found 325 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 4) started at: 11:33:35.476 (12/12/2017)
#
#      Found 335 objects.
#
# ===  Found a TOTAL of 1284 objects in image 'u3m71605r_c0m.fits'
#
#
#
# ===  Source finding for image 'u3m71606r_c0m.fits':
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 1) started at: 11:33:36.12 (12/12/2017)
#
#      Found 212 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 2) started at: 11:33:36.400 (12/12/2017)
#
#      Found 262 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 3) started at: 11:33:36.745 (12/12/2017)
#
#      Found 261 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 4) started at: 11:33:37.145 (12/12/2017)
#
#      Found 298 objects.
#
# ===  Found a TOTAL of 1033 objects in image 'u3m71606r_c0m.fits'
#
#
#
#  Catalog trimmed to 1284 objects
#
#
# ====================
# Aligning all input images to WCS defined by u3m71605r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u3m71606r_c0m.fits
#
# Matching sources from 'u3m71606r_c0m.fits' with sources from reference image 'u3m71605r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.151764960076 -0.935548743859
#
#     with significance of  279.04046113 and  9.0  matches
#
# Found 26 matches for u3m71606r_c0m.fits...
#
# Computed  rscale  fit for  u3m71606r_c0m.fits :
#
# XSH: 0.055619  YSH: 0.0393857    ROT: 0.000475847    SCALE: 1.00005
#
# XRMS: 0.130669    YRMS: 0.0986879
#
# RMS_RA: 4.12879e-06 (deg)   RMS_DEC: 1.92795e-07 (deg)
#
# Final solution based on  24  objects.
#
# wrote XY data to:  u3m71606r_c0m_catalog_fit.match
#
# Total # points:  24
#
# # of points after clipping:  24
#
# Total # points:  24
#
# # of points after clipping:  24
#
# Press ENTER for next image,
#       'n' to continue without updating header or
#       'q' to quit immediately...
#
# Writing out shiftfile : shift_final
#
# Trailer file written to:  tweakreg.log

# %%
# final run with hdr update
import os
from drizzlepac import tweakreg
os.chdir('/Users/natalie/anaconda2/envs/iraf27/iraf/sn/2000ds/2000ds_pre/tweak_555_2')
tweakreg.TweakReg('*c0m.fits', exclusions='WFPC2_exclude.txt', updatehdr=True, shiftfile=True, outshifts='shift_final', residplot='both', see2dplot='Yes', use_sharp_round='Yes', threshold=10, conv_width=3.5, roundlo=-0.1, roundhi=1.0, peakmax=1000)
# Out:
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 11:34:43.156 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u3m71605r_c0m.fits
#
#     u3m71606r_c0m.fits
#
# ===  Source finding for image 'u3m71605r_c0m.fits':
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 1) started at: 11:34:43.63 (12/12/2017)
#
#      Found 306 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 2) started at: 11:34:44.046 (12/12/2017)
#
#      Found 318 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 3) started at: 11:34:44.433 (12/12/2017)
#
#      Found 325 objects.
#
#   #  Source finding for 'u3m71605r_c0m.fits', EXT=('SCI', 4) started at: 11:34:44.85 (12/12/2017)
#
#      Found 335 objects.
#
# ===  Found a TOTAL of 1284 objects in image 'u3m71605r_c0m.fits'
#
#
#
# ===  Source finding for image 'u3m71606r_c0m.fits':
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 1) started at: 11:34:45.644 (12/12/2017)
#
#      Found 212 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 2) started at: 11:34:45.962 (12/12/2017)
#
#      Found 262 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 3) started at: 11:34:46.343 (12/12/2017)
#
#      Found 261 objects.
#
#   #  Source finding for 'u3m71606r_c0m.fits', EXT=('SCI', 4) started at: 11:34:46.832 (12/12/2017)
#
#      Found 298 objects.
#
# ===  Found a TOTAL of 1033 objects in image 'u3m71606r_c0m.fits'
#
#
#
#  Catalog trimmed to 1284 objects
#
#
# ====================
# Aligning all input images to WCS defined by u3m71605r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u3m71606r_c0m.fits
#
# Matching sources from 'u3m71606r_c0m.fits' with sources from reference image 'u3m71605r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.151764960076 -0.935548743859
#
#     with significance of  279.04046113 and  9.0  matches
#
# Found 26 matches for u3m71606r_c0m.fits...
#
# Computed  rscale  fit for  u3m71606r_c0m.fits :
#
# XSH: 0.055619  YSH: 0.0393857    ROT: 0.000475847    SCALE: 1.00005
#
# XRMS: 0.130669    YRMS: 0.0986879
#
# RMS_RA: 4.12879e-06 (deg)   RMS_DEC: 1.92795e-07 (deg)
#
# Final solution based on  24  objects.
#
# wrote XY data to:  u3m71606r_c0m_catalog_fit.match
#
# Total # points:  24
#
# # of points after clipping:  24
#
# Total # points:  24
#
# # of points after clipping:  24
#
# Press ENTER for next image,
#       'n' to continue without updating header or
#       'q' to quit immediately...
#
#
# ....Updating header for u3m71606r_c0m.fits...
#
#
# Processing u3m71606r_c0m.fits['SCI',1]
#
# Updating header for u3m71606r_c0m.fits[1]
#
# WCSNAME  :  TWEAK
#
#
# Processing u3m71606r_c0m.fits['SCI',2]
#
# Updating header for u3m71606r_c0m.fits[2]
#
# WCSNAME  :  TWEAK
#
#
# Processing u3m71606r_c0m.fits['SCI',3]
#
# Updating header for u3m71606r_c0m.fits[3]
#
# WCSNAME  :  TWEAK
#
#
# Processing u3m71606r_c0m.fits['SCI',4]
#
# Updating header for u3m71606r_c0m.fits[4]
#
# WCSNAME  :  TWEAK
#
# Writing out shiftfile : shift_final
#
# Trailer file written to:  tweakreg.log

# %%
# tweaked checks
from astropy.io import fits
tw=fits.open('/Users/natalie/anaconda2/envs/iraf27/iraf/sn/2000ds/2000ds_pre/tweak_555_2/u3m71606r_c0m.fits')

# %%
tw[1].header
# Out:
# XTENSION= 'IMAGE   '           / Image extension
# BITPIX  =                  -32 / Bits per pixel
# NAXIS   =                    2 / Number of axes
# NAXIS1  =                  800 / Axis length
# NAXIS2  =                  800 / Axis length
# PCOUNT  =                    0 / No 'random' parameters
# GCOUNT  =                    1 / Only one group
# ORIGIN  = 'NOAO-IRAF FITS Image Kernel July 2003' / FITS file originator
# EXTNAME = 'SCI     '           / Extension name
# EXTVER  =                    1 / Extension version
# INHERIT =                    T / Inherits global header
# DATE    = '2008-12-25T18:24:13' / Date FITS file was generated
# IRAF-TLM= '18:24:16 (25/12/2008)' / Time of last modification
# ROOTNAME= 'u3m71606r                         ' / rootname of the observation set
# EXPNAME = 'u3m71606r                ' / exposure identifier
# DATAMIN =            -272.9274 / the minimum value of the data
# DATAMAX =             37264.34 / the maximum value of the data
# BUNIT   = 'COUNTS            ' / brightness units
#
#               / World Coordinate System and Related Parameters
#
# WCSAXES =                    2 / number of World Coordinate System axes
# CRPIX1  =                425.0 / x-coordinate of reference pixel
# CRPIX2  =                425.0 / y-coordinate of reference pixel
# CRVAL1  =      137.90643653122 / first axis value at reference pixel
# CRVAL2  =      60.037282849675 / second axis value at reference pixel
# CTYPE1  = 'RA---TAN-SIP'       / the coordinate type for the first axis
# CTYPE2  = 'DEC--TAN-SIP'       / the coordinate type for the second axis
# CD1_1   =  9.3476230101978E-06 / partial of first axis coordinate w.r.t. x
# CD1_2   =  8.5273886591487E-06 / partial of first axis coordinate w.r.t. y
# CD2_1   = 8.51732223017419E-06 / partial of second axis coordinate w.r.t. x
# CD2_2   = -9.3377429951788E-06 / partial of second axis coordinate w.r.t. y
# VAFACTOR=   9.999157363177E-01 / velocity aberration plate scale factor
#
#               / PODPS PARAMETERS
#
# DETECTOR=                    1 / CCD number of the detector: PC 1, WFC 2-4
#
#               / OSS PARAMETERS
#
# FILLCNT =                    0 / number of segments containing fill
# ERRCNT  =                    0 / number of segments containing errors
#
#               / IMAGE PARAMETERS
#
# MIR_REVR=                    T / is the image mirror reversed?
# ORIENTAT=     137.597130574039 / position angle of image y axis (deg. e of n)
# FPKTTIME=         50953.220805 / time of the first packet (Modified Julian Date)
# LPKTTIME=         50953.220972 / time of the last packet (Modified Julian Date)
# DEZERO  =             315.8505 / Mean bias level from EED extended register
# BIASEVEN=             315.8798 / Bias level from even-numbered columns
# BIASODD =             315.8213 / Bias level from odd-numbered columns
# GOODMIN =            -1.668748 / minimum value of good pixels
# GOODMAX =             2543.136 / maximum value of good pixels
# DATAMEAN=             21.50565 / mean value of the good pixels
#
#               / DATA QUALITY FILE SUMMARY
#
# GPIXELS =               552449 / number of good pixels (DQF=0)
# SOFTERRS=                    0 / number of soft error pixels (DQF=1)
# CALIBDEF=                82477 / number of calibration defect pixels (DQF=2)
# STATICD =                    0 / number of static defect pixels (DQF=4)
# ATODSAT =                    1 / number of AtoD saturated pixels (DQF=8)
# DATALOST=                    0 / number of data lost pixels (DQF=16)
# BADPIXEL=                    0 / number of generic bad pixels (DQF=32)
# OVERLAP =                    0 / number of image overlap pixels (DQF=64)
#
#               / PHOTOMETRY KEYWORDS
#
# PHOTMODE= 'WFPC2,1,A2D7,F555W,,CAL'
# PHOTFLAM=         3.482944E-18 / Inverse Sensitivity
# PHOTZPT =                -21.1 / Zero point
# PHOTPLAM=             5442.928 / Pivot wavelength
# PHOTBW  =              522.241 / RMS bandwidth of the filter
# ZP_CORR =          0.004038811 / Delta magnitude correction for contamination
#
#               / IMAGE STATISTICS
#
# MEDIAN  =             16.04841 / middle data value when good qual pixels sorted
# MEDSHADO=             6.370959 / median pixel value in shadow of pyramid edge
# HISTWIDE=             12.25385 / width of the histogram
# SKEWNESS=           0.09758715 / skewness of the histogram
# MEANC10 =             196.2104 / mean of a 10x10 region at center of chip
# MEANC25 =             212.0892 / mean of a 25x25 region at center of chip
# MEANC50 =              198.666 / mean of a 50x50 region at center of chip
# MEANC100=             123.7704 / mean of a 100x100 region at center of chip
# MEANC200=             71.67891 / mean of a 200x200 region at center of chip
# MEANC300=              50.9226 / mean of a 300x300 region at center of chip
# BACKGRND=             14.38495 / estimated background level
# BIASEVNU=             0.000000 / BIASEVEN value prior to WF4T correction
# BIASODDU=             0.000000 / BIASODD value prior to WF4T correction
# CTE_1E2 =  0.05108707398176193 / expected delta mag from CTE,100 electron pt src
# CTE_1E3 =   0.0201050229370594 / expected delta mag from CTE,1000 electron pt sr
# CTE_1E4 = 0.009607640095055103 / expected delta mag from CTE,1e+4 electron pt sr
# OCRVAL1 =       137.9064344702 / first axis value at reference pixel
# OCRVAL2 =       60.03722429285 / second axis value at reference pixel
# OCRPIX2 =                424.5 / y-coordinate of reference pixel
# OCRPIX1 =                420.0 / x-coordinate of reference pixel
# ONAXIS2 =                  800 / Axis length
# ONAXIS1 =                  800 / Axis length
# OCD2_2  = -9.343109999999999E-06 / partial of second axis coordinate w.r.t. y
# OCD2_1  = 8.518440000000001E-06 / partial of second axis coordinate w.r.t. x
# OORIENTA=    137.6566393240637 / position angle of image y axis (deg. e of n)
# OCTYPE1 = 'RA---TAN'           / the coordinate type for the first axis
# OCD1_1  = 9.347419999999999E-06 / partial of first axis coordinate w.r.t. x
# OCD1_2  =          8.51451E-06 / partial of first axis coordinate w.r.t. y
# OCTYPE2 = 'DEC--TAN'           / the coordinate type for the second axis
# WCSCDATE= '18:24:30 (25/12/2008)' / Time WCS keywords were copied.
# A_0_2   = -1.7707000097288E-06
# B_0_2   = -3.3403597862258E-06
# A_1_1   =  -1.905799990709E-06
# B_1_1   = -2.0743586191652E-06
# A_2_0   = -3.7332999909267E-06
# B_2_0   = -1.9870178679283E-06
# A_0_3   = -7.5851998293519E-11
# B_0_3   = -3.6467375723897E-08
# A_1_2   = -3.5839999412701E-08
# B_1_2   = 4.57159135685641E-10
# A_2_1   = 4.55110005237457E-10
# B_2_1   = -3.6163953295162E-08
# A_3_0   = -3.6067998365751E-08
# B_3_0   = -1.6839174375705E-10
# A_ORDER =                    3
# B_ORDER =                    3
# IDCSCALE=             0.045532
# IDCV2REF=    2.578121720480491
# IDCV3REF=   -30.26950453156165
# IDCTHETA=    224.8480072021484
# OCX10   =                  0.0
# OCX11   =             0.045532
# OCY10   =  0.04553017896056175
# OCY11   = 5.075451992452145E-05
# D2IMERR2=  0.01497428864240646 / Maximum error of NPOL correction for axis 2
# D2IMDIS2= 'Lookup  '           / Detector to image correction type
# D2IM2   = 'EXTVER: 1' / Version number of WCSDVARR extension containing d2im loo
# D2IM2   = 'NAXES: 2' / Number of independent variables in d2im function
# D2IM2   = 'AXIS.1: 1' / Axis number of the jth independent variable in a d2im fu
# D2IM2   = 'AXIS.2: 2' / Axis number of the jth independent variable in a d2im fu
# D2IMEXT = 'u3m71606r_c0m_d2im.fits'
# RADESYS = 'FK5     '
# WCSNAMEO= 'OPUS    '
# WCSAXESO=                    2
# CRPIX1O =                425.0
# CRPIX2O =                425.0
# CDELT1O =                  1.0
# CDELT2O =                  1.0
# CUNIT1O = 'deg     '
# CUNIT2O = 'deg     '
# CTYPE1O = 'RA---TAN-SIP'
# CTYPE2O = 'DEC--TAN-SIP'
# CRVAL1O =      137.90644264104
# CRVAL2O =      60.037282964306
# LONPOLEO=                180.0
# LATPOLEO=      60.037282964306
# RADESYSO= 'FK5     '
# EQUINOXO=               2000.0
# CD1_1O  = 9.34882777186059E-06
# CD1_2O  =  8.5286291163834E-06
# CD2_1O  = 8.51856140826609E-06
# CD2_2O  = -9.3389463202698E-06
# IDCXREF =                425.0
# IDCYREF =                425.0
# IDCTAB  = 'uref$ta81040lu_idc.fits'
# WCSNAME = 'TWEAK   '
# WCSNAMEA= 'IDC_ta81040lu'
# WCSAXESA=                    2
# CRPIX1A =                425.0
# CRPIX2A =                425.0
# CDELT1A =                  1.0
# CDELT2A =                  1.0
# CUNIT1A = 'deg     '
# CUNIT2A = 'deg     '
# CTYPE1A = 'RA---TAN-SIP'
# CTYPE2A = 'DEC--TAN-SIP'
# CRVAL1A =      137.90643897506
# CRVAL2A =      60.037283011654
# LONPOLEA=                180.0
# LATPOLEA=      60.037283011654
# RADESYSA= 'FK5     '
# EQUINOXA=               2000.0
# CD1_1A  = 9.34803997679850E-06
# CD1_2A  =  8.5279104626694E-06
# CD2_1A  = 8.51784363133329E-06
# CD2_2A  = -9.3381593507398E-06
# CDELT1  =                  1.0
# CDELT2  =                  1.0
# CUNIT1  = 'deg     '
# CUNIT2  = 'deg     '
# LONPOLE =                180.0
# LATPOLE =      60.037282849675
# CRDER1  =    4.12879305145E-06
# CRDER2  =  1.9279488583379E-07
# EQUINOX =               2000.0
# WCSNAMEB= 'TWEAK   '
# WCSAXESB=                    2
# CRPIX1B =                425.0
# CRPIX2B =                425.0
# CDELT1B =                  1.0
# CDELT2B =                  1.0
# CUNIT1B = 'deg     '
# CUNIT2B = 'deg     '
# CTYPE1B = 'RA---TAN-SIP'
# CTYPE2B = 'DEC--TAN-SIP'
# CRVAL1B =      137.90643653122
# CRVAL2B =      60.037282849675
# LONPOLEB=                180.0
# LATPOLEB=      60.037282849675
# CRDER1B =    4.12879305145E-06
# CRDER2B =  1.9279488583379E-07
# RADESYSB= 'FK5     '
# EQUINOXB=               2000.0
# CD1_1B  =  9.3476230101978E-06
# CD1_2B  =  8.5273886591487E-06
# CD2_1B  = 8.51732223017419E-06
# CD2_2B  = -9.3377429951788E-06
# FITNAMEB= 'TWEAK   '
# NMATCHB =                   24
# RMS_RAB = 4.12879305144997E-06
# RMS_DECB= 1.92794885833791E-07

# %%
tw[1].header['WCSNAME']
# Out:
# 'TWEAK'
