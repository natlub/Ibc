# %%
# tweakreg defaults: 
# threshold = 4
# conv_width = 3.5
# use round = No --> roundlo = -1, roundhi = 1
# peakmin = //
# peakmax = //

# %%
from Drizzle_func import *
import drizzlepac
from drizzlepac import tweakreg
import os
from astropy import table
import matplotlib.pyplot as plt
import fnmatch
import pandas
import matplotlib.pyplot as plt
# Out:
# The following task in the stsci.skypac package can be run with TEAL:
#                                     skymatch
# The following tasks in the drizzlepac package can be run with TEAL:
#     astrodrizzle       imagefindpars           mapreg              photeq
#      pixreplace           pixtopix            pixtosky        refimagefindpars
#      resetbits          runastrodriz          skytopix           tweakback
#       tweakreg           updatenpol

# %%
# tweak_run(path, n_up, threshold_ini, threshold_gap, conv_width_ini, conv_width_gap, 
# roundlo_val_ini, roundlo_gap, roundhi_val_ini, roundhi_gap, peakmax_val_ini, peakmax_gap):
test = tweak_run('/Users/natalie/anaconda2/envs/iraf27/iraf/sn/2000ds/2000ds_pre/tweak_814_1',10,7,3,3.5,0,-1,0,1,0,1000,0)
# Out:
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 23:19:43.001 (06/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u2tv1801t_c0m.fits
#
#     u2tv1802t_c0m.fits
#
# ===  Source finding for image 'u2tv1801t_c0m.fits':
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 1) started at: 23:19:43.338 (06/12/2017)
#
#      Found 429 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 2) started at: 23:19:43.823 (06/12/2017)
#
#      Found 204 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 3) started at: 23:19:44.069 (06/12/2017)
#
#      Found 244 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 4) started at: 23:19:44.5 (06/12/2017)
#
#      Found 361 objects.
#
# ===  Found a TOTAL of 1238 objects in image 'u2tv1801t_c0m.fits'
#
#
#
# ===  Source finding for image 'u2tv1802t_c0m.fits':
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 1) started at: 23:19:45.089 (06/12/2017)
#
#      Found 407 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 2) started at: 23:19:45.597 (06/12/2017)
#
#      Found 183 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 3) started at: 23:19:45.917 (06/12/2017)
#
#      Found 194 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 4) started at: 23:19:46.212 (06/12/2017)
#
#      Found 353 objects.
#
# ===  Found a TOTAL of 1137 objects in image 'u2tv1802t_c0m.fits'
#
#
#
#  Catalog trimmed to 1238 objects
#
#
# ====================
# Aligning all input images to WCS defined by u2tv1801t_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u2tv1802t_c0m.fits
#
# Matching sources from 'u2tv1802t_c0m.fits' with sources from reference image 'u2tv1801t_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.760661523365 -1.13238927206
#
#     with significance of  546.420043223 and  30.0  matches
#
# Found 77 matches for u2tv1802t_c0m.fits...
#
# Computed  rscale  fit for  u2tv1802t_c0m.fits :
#
# XSH: -0.0222707  YSH: -0.100597    ROT: 0.00104008    SCALE: 1
#
# XRMS: 0.206961    YRMS: 0.186928
#
# RMS_RA: 6.92919e-06 (deg)   RMS_DEC: 6.93428e-07 (deg)
#
# Final solution based on  67  objects.
#
# wrote XY data to:  u2tv1802t_c0m_catalog_fit.match
#
# Writing out shiftfile : 1shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.022271
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 23:19:47.067 (06/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u2tv1801t_c0m.fits
#
#     u2tv1802t_c0m.fits
#
# ===  Source finding for image 'u2tv1801t_c0m.fits':
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 1) started at: 23:19:47.325 (06/12/2017)
#
#      Found 437 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 2) started at: 23:19:47.752 (06/12/2017)
#
#      Found 200 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 3) started at: 23:19:47.9 (06/12/2017)
#
#      Found 243 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 4) started at: 23:19:48.291 (06/12/2017)
#
#      Found 309 objects.
#
# ===  Found a TOTAL of 1189 objects in image 'u2tv1801t_c0m.fits'
#
#
#
# ===  Source finding for image 'u2tv1802t_c0m.fits':
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 1) started at: 23:19:48.827 (06/12/2017)
#
#      Found 454 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 2) started at: 23:19:49.254 (06/12/2017)
#
#      Found 192 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 3) started at: 23:19:49.527 (06/12/2017)
#
#      Found 195 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 4) started at: 23:19:49.81 (06/12/2017)
#
#      Found 303 objects.
#
# ===  Found a TOTAL of 1144 objects in image 'u2tv1802t_c0m.fits'
#
#
#
#  Catalog trimmed to 1189 objects
#
#
# ====================
# Aligning all input images to WCS defined by u2tv1801t_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u2tv1802t_c0m.fits
#
# Matching sources from 'u2tv1802t_c0m.fits' with sources from reference image 'u2tv1801t_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.795648642122 -1.102526949
#
#     with significance of  511.94075178 and  28.0  matches
#
# Found 69 matches for u2tv1802t_c0m.fits...
#
# Computed  rscale  fit for  u2tv1802t_c0m.fits :
#
# XSH: -0.105461  YSH: -0.236552    ROT: 359.995    SCALE: 0.999952
#
# XRMS: 0.302566    YRMS: 0.31737
#
# RMS_RA: 1.10274e-05 (deg)   RMS_DEC: 6.81307e-07 (deg)
#
# Final solution based on  62  objects.
#
# wrote XY data to:  u2tv1802t_c0m_catalog_fit.match
#
# Writing out shiftfile : 2shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.105461
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 23:19:50.765 (06/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u2tv1801t_c0m.fits
#
#     u2tv1802t_c0m.fits
#
# ===  Source finding for image 'u2tv1801t_c0m.fits':
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 1) started at: 23:19:51.170 (06/12/2017)
#
#      Found 440 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 2) started at: 23:19:51.652 (06/12/2017)
#
#      Found 191 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 3) started at: 23:19:51.946 (06/12/2017)
#
#      Found 259 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 4) started at: 23:19:52.245 (06/12/2017)
#
#      Found 303 objects.
#
# ===  Found a TOTAL of 1193 objects in image 'u2tv1801t_c0m.fits'
#
#
#
# ===  Source finding for image 'u2tv1802t_c0m.fits':
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 1) started at: 23:19:52.730 (06/12/2017)
#
#      Found 446 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 2) started at: 23:19:53.136 (06/12/2017)
#
#      Found 179 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 3) started at: 23:19:53.364 (06/12/2017)
#
#      Found 221 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 4) started at: 23:19:53.685 (06/12/2017)
#
#      Found 294 objects.
#
# ===  Found a TOTAL of 1140 objects in image 'u2tv1802t_c0m.fits'
#
#
#
#  Catalog trimmed to 1193 objects
#
#
# ====================
# Aligning all input images to WCS defined by u2tv1801t_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u2tv1802t_c0m.fits
#
# Matching sources from 'u2tv1802t_c0m.fits' with sources from reference image 'u2tv1801t_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.790357636831 -0.959669806143
#
#     with significance of  461.087844125 and  24.0  matches
#
# Found 61 matches for u2tv1802t_c0m.fits...
#
# Computed  rscale  fit for  u2tv1802t_c0m.fits :
#
# XSH: -0.289644  YSH: -0.270657    ROT: 359.99    SCALE: 0.9999
#
# XRMS: 0.462856    YRMS: 0.455657
#
# RMS_RA: 1.6262e-05 (deg)   RMS_DEC: 1.26729e-06 (deg)
#
# Final solution based on  57  objects.
#
# wrote XY data to:  u2tv1802t_c0m_catalog_fit.match
#
# Writing out shiftfile : 3shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.289644
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 23:19:54.429 (06/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u2tv1801t_c0m.fits
#
#     u2tv1802t_c0m.fits
#
# ===  Source finding for image 'u2tv1801t_c0m.fits':
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 1) started at: 23:19:54.685 (06/12/2017)
#
#      Found 403 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 2) started at: 23:19:55.044 (06/12/2017)
#
#      Found 203 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 3) started at: 23:19:55.280 (06/12/2017)
#
#      Found 261 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 4) started at: 23:19:55.605 (06/12/2017)
#
#      Found 310 objects.
#
# ===  Found a TOTAL of 1177 objects in image 'u2tv1801t_c0m.fits'
#
#
#
# ===  Source finding for image 'u2tv1802t_c0m.fits':
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 1) started at: 23:19:56.154 (06/12/2017)
#
#      Found 432 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 2) started at: 23:19:56.591 (06/12/2017)
#
#      Found 184 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 3) started at: 23:19:56.835 (06/12/2017)
#
#      Found 239 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 4) started at: 23:19:57.161 (06/12/2017)
#
#      Found 295 objects.
#
# ===  Found a TOTAL of 1150 objects in image 'u2tv1802t_c0m.fits'
#
#
#
#  Catalog trimmed to 1177 objects
#
#
# ====================
# Aligning all input images to WCS defined by u2tv1801t_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u2tv1802t_c0m.fits
#
# Matching sources from 'u2tv1802t_c0m.fits' with sources from reference image 'u2tv1801t_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -1.03040219266 -0.802332017226
#
#     with significance of  392.77856357 and  18.0  matches
#
# Found 48 matches for u2tv1802t_c0m.fits...
#
# Computed  rscale  fit for  u2tv1802t_c0m.fits :
#
# XSH: -0.400712  YSH: -0.401824    ROT: 359.994    SCALE: 0.999878
#
# XRMS: 0.71971    YRMS: 0.577636
#
# RMS_RA: 2.26229e-05 (deg)   RMS_DEC: 2.95735e-06 (deg)
#
# Final solution based on  48  objects.
#
# wrote XY data to:  u2tv1802t_c0m_catalog_fit.match
#
# Writing out shiftfile : 4shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.400712
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 23:19:58.086 (06/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u2tv1801t_c0m.fits
#
#     u2tv1802t_c0m.fits
#
# ===  Source finding for image 'u2tv1801t_c0m.fits':
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 1) started at: 23:19:58.429 (06/12/2017)
#
#      Found 363 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 2) started at: 23:19:58.784 (06/12/2017)
#
#      Found 207 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 3) started at: 23:19:59.088 (06/12/2017)
#
#      Found 276 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 4) started at: 23:19:59.441 (06/12/2017)
#
#      Found 334 objects.
#
# ===  Found a TOTAL of 1180 objects in image 'u2tv1801t_c0m.fits'
#
#
#
# ===  Source finding for image 'u2tv1802t_c0m.fits':
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 1) started at: 23:20:00.057 (06/12/2017)
#
#      Found 408 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 2) started at: 23:20:00.49 (06/12/2017)
#
#      Found 176 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 3) started at: 23:20:00.759 (06/12/2017)
#
#      Found 248 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 4) started at: 23:20:01.126 (06/12/2017)
#
#      Found 305 objects.
#
# ===  Found a TOTAL of 1137 objects in image 'u2tv1802t_c0m.fits'
#
#
#
#  Catalog trimmed to 1180 objects
#
#
# ====================
# Aligning all input images to WCS defined by u2tv1801t_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u2tv1802t_c0m.fits
#
# Matching sources from 'u2tv1802t_c0m.fits' with sources from reference image 'u2tv1801t_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.990093086566 -0.87580737228
#
#     with significance of  359.3886256 and  13.0  matches
#
# Found 38 matches for u2tv1802t_c0m.fits...
#
# Computed  rscale  fit for  u2tv1802t_c0m.fits :
#
# XSH: -0.284011  YSH: -0.334336    ROT: 359.993    SCALE: 0.999877
#
# XRMS: 0.605392    YRMS: 0.460895
#
# RMS_RA: 1.8521e-05 (deg)   RMS_DEC: 2.67602e-06 (deg)
#
# Final solution based on  37  objects.
#
# wrote XY data to:  u2tv1802t_c0m_catalog_fit.match
#
# Writing out shiftfile : 5shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.284011
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 23:20:02.050 (06/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u2tv1801t_c0m.fits
#
#     u2tv1802t_c0m.fits
#
# ===  Source finding for image 'u2tv1801t_c0m.fits':
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 1) started at: 23:20:02.338 (06/12/2017)
#
#      Found 358 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 2) started at: 23:20:02.679 (06/12/2017)
#
#      Found 212 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 3) started at: 23:20:02.943 (06/12/2017)
#
#      Found 303 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 4) started at: 23:20:03.33 (06/12/2017)
#
#      Found 325 objects.
#
# ===  Found a TOTAL of 1198 objects in image 'u2tv1801t_c0m.fits'
#
#
#
# ===  Source finding for image 'u2tv1802t_c0m.fits':
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 1) started at: 23:20:03.923 (06/12/2017)
#
#      Found 400 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 2) started at: 23:20:04.346 (06/12/2017)
#
#      Found 181 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 3) started at: 23:20:04.663 (06/12/2017)
#
#      Found 262 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 4) started at: 23:20:05.072 (06/12/2017)
#
#      Found 322 objects.
#
# ===  Found a TOTAL of 1165 objects in image 'u2tv1802t_c0m.fits'
#
#
#
#  Catalog trimmed to 1198 objects
#
#
# ====================
# Aligning all input images to WCS defined by u2tv1801t_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u2tv1802t_c0m.fits
#
# Matching sources from 'u2tv1802t_c0m.fits' with sources from reference image 'u2tv1801t_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -1.01787086434 -0.978188324661
#
#     with significance of  317.678383834 and  11.0  matches
#
# Found 35 matches for u2tv1802t_c0m.fits...
#
# Computed  rscale  fit for  u2tv1802t_c0m.fits :
#
# XSH: -0.426076  YSH: -0.619459    ROT: 359.997    SCALE: 0.999771
#
# XRMS: 0.681196    YRMS: 0.678721
#
# RMS_RA: 2.40983e-05 (deg)   RMS_DEC: 1.80386e-06 (deg)
#
# Final solution based on  35  objects.
#
# wrote XY data to:  u2tv1802t_c0m_catalog_fit.match
#
# Writing out shiftfile : 6shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.426076
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 23:20:06.046 (06/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u2tv1801t_c0m.fits
#
#     u2tv1802t_c0m.fits
#
# ===  Source finding for image 'u2tv1801t_c0m.fits':
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 1) started at: 23:20:06.354 (06/12/2017)
#
#      Found 330 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 2) started at: 23:20:06.649 (06/12/2017)
#
#      Found 221 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 3) started at: 23:20:06.919 (06/12/2017)
#
#      Found 309 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 4) started at: 23:20:07.280 (06/12/2017)
#
#      Found 366 objects.
#
# ===  Found a TOTAL of 1226 objects in image 'u2tv1801t_c0m.fits'
#
#
#
# ===  Source finding for image 'u2tv1802t_c0m.fits':
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 1) started at: 23:20:07.974 (06/12/2017)
#
#      Found 374 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 2) started at: 23:20:08.282 (06/12/2017)
#
#      Found 180 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 3) started at: 23:20:08.554 (06/12/2017)
#
#      Found 273 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 4) started at: 23:20:08.918 (06/12/2017)
#
#      Found 357 objects.
#
# ===  Found a TOTAL of 1184 objects in image 'u2tv1802t_c0m.fits'
#
#
#
#  Catalog trimmed to 1226 objects
#
#
# ====================
# Aligning all input images to WCS defined by u2tv1801t_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u2tv1802t_c0m.fits
#
# Matching sources from 'u2tv1802t_c0m.fits' with sources from reference image 'u2tv1801t_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -1.06631909936 -0.98422954712
#
#     with significance of  300.958468896 and  9.0  matches
#
# Found 30 matches for u2tv1802t_c0m.fits...
#
# Computed  rscale  fit for  u2tv1802t_c0m.fits :
#
# XSH: -0.471535  YSH: -0.673838    ROT: 359.992    SCALE: 0.999698
#
# XRMS: 0.695665    YRMS: 0.705979
#
# RMS_RA: 2.48715e-05 (deg)   RMS_DEC: 1.74536e-06 (deg)
#
# Final solution based on  30  objects.
#
# wrote XY data to:  u2tv1802t_c0m_catalog_fit.match
#
# Writing out shiftfile : 7shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.471535
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 23:20:09.822 (06/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u2tv1801t_c0m.fits
#
#     u2tv1802t_c0m.fits
#
# ===  Source finding for image 'u2tv1801t_c0m.fits':
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 1) started at: 23:20:10.129 (06/12/2017)
#
#      Found 322 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 2) started at: 23:20:10.476 (06/12/2017)
#
#      Found 215 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 3) started at: 23:20:10.77 (06/12/2017)
#
#      Found 322 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 4) started at: 23:20:11.121 (06/12/2017)
#
#      Found 368 objects.
#
# ===  Found a TOTAL of 1227 objects in image 'u2tv1801t_c0m.fits'
#
#
#
# ===  Source finding for image 'u2tv1802t_c0m.fits':
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 1) started at: 23:20:11.783 (06/12/2017)
#
#      Found 337 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 2) started at: 23:20:12.063 (06/12/2017)
#
#      Found 195 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 3) started at: 23:20:12.343 (06/12/2017)
#
#      Found 281 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 4) started at: 23:20:12.722 (06/12/2017)
#
#      Found 373 objects.
#
# ===  Found a TOTAL of 1186 objects in image 'u2tv1802t_c0m.fits'
#
#
#
#  Catalog trimmed to 1227 objects
#
#
# ====================
# Aligning all input images to WCS defined by u2tv1801t_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u2tv1802t_c0m.fits
#
# Matching sources from 'u2tv1802t_c0m.fits' with sources from reference image 'u2tv1801t_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.148177250464 -0.807091979146
#
#     with significance of  340.839348577 and  10.0  matches
#
# Found 30 matches for u2tv1802t_c0m.fits...
#
# Computed  rscale  fit for  u2tv1802t_c0m.fits :
#
# XSH: -0.0179165  YSH: -0.209379    ROT: 0.0056151    SCALE: 0.999909
#
# XRMS: 0.540209    YRMS: 0.381293
#
# RMS_RA: 1.59168e-05 (deg)   RMS_DEC: 2.61392e-06 (deg)
#
# Final solution based on  29  objects.
#
# wrote XY data to:  u2tv1802t_c0m_catalog_fit.match
#
# Writing out shiftfile : 8shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.017917
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 23:20:13.721 (06/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u2tv1801t_c0m.fits
#
#     u2tv1802t_c0m.fits
#
# ===  Source finding for image 'u2tv1801t_c0m.fits':
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 1) started at: 23:20:14.022 (06/12/2017)
#
#      Found 276 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 2) started at: 23:20:14.27 (06/12/2017)
#
#      Found 214 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 3) started at: 23:20:14.554 (06/12/2017)
#
#      Found 321 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 4) started at: 23:20:14.916 (06/12/2017)
#
#      Found 361 objects.
#
# ===  Found a TOTAL of 1172 objects in image 'u2tv1801t_c0m.fits'
#
#
#
# ===  Source finding for image 'u2tv1802t_c0m.fits':
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 1) started at: 23:20:15.587 (06/12/2017)
#
#      Found 314 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 2) started at: 23:20:15.848 (06/12/2017)
#
#      Found 207 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 3) started at: 23:20:16.12 (06/12/2017)
#
#      Found 296 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 4) started at: 23:20:16.584 (06/12/2017)
#
#      Found 374 objects.
#
# ===  Found a TOTAL of 1191 objects in image 'u2tv1802t_c0m.fits'
#
#
#
#  Catalog trimmed to 1172 objects
#
#
# ====================
# Aligning all input images to WCS defined by u2tv1801t_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u2tv1802t_c0m.fits
#
# Matching sources from 'u2tv1802t_c0m.fits' with sources from reference image 'u2tv1801t_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.987712134185 -0.929378800852
#
#     with significance of  284.379022734 and  9.0  matches
#
# Found 30 matches for u2tv1802t_c0m.fits...
#
# Computed  rscale  fit for  u2tv1802t_c0m.fits :
#
# XSH: -0.553781  YSH: -0.620844    ROT: 0.00302228    SCALE: 0.999796
#
# XRMS: 0.745688    YRMS: 0.779104
#
# RMS_RA: 2.7115e-05 (deg)   RMS_DEC: 1.70226e-06 (deg)
#
# Final solution based on  30  objects.
#
# wrote XY data to:  u2tv1802t_c0m_catalog_fit.match
#
# Writing out shiftfile : 9shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.553781

# %%
# change to a jupyter table
dt=test.to_pandas()
dt.to_pickle('data.pickle')
good_table=pandas.read_pickle('data.pickle')

# %%
# all table
good_table
# Out:
#          shift                file     x_rms     y_rms  threshold  conv_width  \
# 0   1shift.txt  u2tv1801t_c0m.fits  0.000000  0.000000          7         3.5
# 1   1shift.txt  u2tv1802t_c0m.fits  0.206961  0.186928          7         3.5
# 2   2shift.txt  u2tv1801t_c0m.fits  0.000000  0.000000         10         3.5
# 3   2shift.txt  u2tv1802t_c0m.fits  0.302566  0.317370         10         3.5
# 4   3shift.txt  u2tv1801t_c0m.fits  0.000000  0.000000         13         3.5
# 5   3shift.txt  u2tv1802t_c0m.fits  0.462856  0.455657         13         3.5
# 6   4shift.txt  u2tv1801t_c0m.fits  0.000000  0.000000         16         3.5
# 7   4shift.txt  u2tv1802t_c0m.fits  0.719710  0.577636         16         3.5
# 8   5shift.txt  u2tv1801t_c0m.fits  0.000000  0.000000         19         3.5
# 9   5shift.txt  u2tv1802t_c0m.fits  0.605392  0.460895         19         3.5
# 10  6shift.txt  u2tv1801t_c0m.fits  0.000000  0.000000         22         3.5
# 11  6shift.txt  u2tv1802t_c0m.fits  0.681196  0.678721         22         3.5
# 12  7shift.txt  u2tv1801t_c0m.fits  0.000000  0.000000         25         3.5
# 13  7shift.txt  u2tv1802t_c0m.fits  0.695665  0.705979         25         3.5
# 14  8shift.txt  u2tv1801t_c0m.fits  0.000000  0.000000         28         3.5
# 15  8shift.txt  u2tv1802t_c0m.fits  0.540209  0.381293         28         3.5
# 16  9shift.txt  u2tv1801t_c0m.fits  0.000000  0.000000         31         3.5
# 17  9shift.txt  u2tv1802t_c0m.fits  0.745688  0.779104         31         3.5
#
#     roundlo  roundhi  peakmax
# 0        -1        1     1000
# 1        -1        1     1000
# 2        -1        1     1000
# 3        -1        1     1000
# 4        -1        1     1000
# 5        -1        1     1000
# 6        -1        1     1000
# 7        -1        1     1000
# 8        -1        1     1000
# 9        -1        1     1000
# 10       -1        1     1000
# 11       -1        1     1000
# 12       -1        1     1000
# 13       -1        1     1000
# 14       -1        1     1000
# 15       -1        1     1000
# 16       -1        1     1000
# 17       -1        1     1000

# %%
# filter by column
good_table['y_rms']
# Out:
# 0     0.000000
# 1     0.186928
# 2     0.000000
# 3     0.317370
# 4     0.000000
# 5     0.455657
# 6     0.000000
# 7     0.577636
# 8     0.000000
# 9     0.460895
# 10    0.000000
# 11    0.678721
# 12    0.000000
# 13    0.705979
# 14    0.000000
# 15    0.381293
# 16    0.000000
# 17    0.779104
# Name: y_rms, dtype: object

# %%
# filter by value in column
good_table[good_table['y_rms']=='failed']
# Out:
# Empty DataFrame
# Columns: [shift, file, x_rms, y_rms, threshold, conv_width, roundlo, roundhi, peakmax]
# Index: []

# %%
# see unique in column
good_table['shift'].unique()
# Out:
# array(['1shift.txt', '2shift.txt', '3shift.txt', '4shift.txt',
#        '5shift.txt', '6shift.txt', '7shift.txt', '8shift.txt', '9shift.txt'], dtype=object)

# %%
good_table.shape
# Out:
# (18, 9)

# %%
# take only unfailed sessions
good = good_table[good_table['y_rms'] != 'failed']

# %%
# ????????????????????????????????????????????????????
plt.figure(figsize = (7,7))
plt.plot(good['threshold'],good['x_rms'],'.g')
plt.plot(good['threshold'],good['y_rms'],'.b')
plt.title('x,y_rms(threshold)-g,b')
plt.show()

# %%
# plot figure for choosen sub-exp
plt.figure(figsize = (7,7))
plt.plot(good[good['file'] == 'u29r1r01t_c0m.fits']['threshold'],good[good['file'] == 'u29r1r01t_c0m.fits']['y_rms'],'.b')
plt.plot(good[good['file'] == 'u29r1r02t_c0m.fits']['threshold'],good[good['file'] == 'u29r1r02t_c0m.fits']['y_rms'],'.g')
plt.title('y_rms(threshold)-two filters')
plt.show()

# %%
# find min y_rms and min x_rms
min_x = good[good['x_rms'].values.astype(float) != 0.0]['x_rms'].min()
min_y = good[good['y_rms'].values.astype(float) != 0.0]['y_rms'].min()
print(min_x)
print(min_y)
# Out:
# 0.206961
# 0.186928

# %%
# sort all values =! 0 and take lowest 5 in y_rms
good[good['x_rms'].values.astype(float) != 0.0].sort_values('x_rms',ascending=True)[:5]
# Out:
#          shift                file     x_rms     y_rms  threshold  conv_width
# 21  6shift.txt  u6ea5402m_c0m.fits  0.056897  0.037645         51           3
# 17  5shift.txt  u6ea5402m_c0m.fits  0.069021  0.038714         41           3
# 9   3shift.txt  u6ea5402m_c0m.fits  0.074321  0.078460         21           3
# 5   2shift.txt  u6ea5402m_c0m.fits  0.088635  0.088857         11           3
# 13  4shift.txt  u6ea5402m_c0m.fits  0.152657  0.101558         31           3

# %%
# sort all values =! 0 and take lowest 5 in y_rms BY FILTER??????????????????????
good['file' == 'u29r1r02t_c0m.fits'][['y_rms'].values.astype(float) != 0.0]].sort_values('y_rms',ascending=True)[:5]
#plt.plot(good[good['file'] == 'u6ea5402m_c0m.fits']['threshold'],good[good['file'] == 'u6ea5402m_c0m.fits']['y_rms'],'.b')
# Out:
#   File "<ipython-input-14-aaeb809a2179>", line 2
#     good['file' == 'u29r1r02t_c0m.fits'][['y_rms'].values.astype(float) != 0.0]].sort_values('y_rms',ascending=True)[:5]
#                                                                                ^
# SyntaxError: invalid syntax

# %%
############################################################ thresh=7, conv_width?

# %%
# tweak_run(path, n_up, threshold_ini, threshold_gap, conv_width_ini, conv_width_gap, 
# roundlo_val_ini, roundlo_gap, roundhi_val_ini, roundhi_gap, peakmax_val_ini, peakmax_gap):
test = tweak_run('/Users/natalie/anaconda2/envs/iraf27/iraf/sn/2000ds/2000ds_pre/tweak_814_1',15,7,0,2.0,0.3,-1,0,1,0,1000,0)
# Out:
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 23:25:04.825 (06/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u2tv1801t_c0m.fits
#
#     u2tv1802t_c0m.fits
#
# ===  Source finding for image 'u2tv1801t_c0m.fits':
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 1) started at: 23:25:05.157 (06/12/2017)
#
#      Found 392 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 2) started at: 23:25:05.602 (06/12/2017)
#
#      Found 148 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 3) started at: 23:25:05.870 (06/12/2017)
#
#      Found 189 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 4) started at: 23:25:06.215 (06/12/2017)
#
#      Found 237 objects.
#
# ===  Found a TOTAL of 966 objects in image 'u2tv1801t_c0m.fits'
#
#
#
# ===  Source finding for image 'u2tv1802t_c0m.fits':
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 1) started at: 23:25:06.905 (06/12/2017)
#
#      Found 428 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 2) started at: 23:25:07.346 (06/12/2017)
#
#      Found 135 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 3) started at: 23:25:07.600 (06/12/2017)
#
#      Found 159 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 4) started at: 23:25:07.893 (06/12/2017)
#
#      Found 231 objects.
#
# ===  Found a TOTAL of 953 objects in image 'u2tv1802t_c0m.fits'
#
#
#
#  Catalog trimmed to 966 objects
#
#
# ====================
# Aligning all input images to WCS defined by u2tv1801t_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u2tv1802t_c0m.fits
#
# Matching sources from 'u2tv1802t_c0m.fits' with sources from reference image 'u2tv1801t_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.277455723929 -1.05694290342
#
#     with significance of  506.821344262 and  27.0  matches
#
# Found 83 matches for u2tv1802t_c0m.fits...
#
# Computed  rscale  fit for  u2tv1802t_c0m.fits :
#
# XSH: -0.00865553  YSH: -0.227186    ROT: 359.999    SCALE: 0.999935
#
# XRMS: 0.384692    YRMS: 0.419129
#
# RMS_RA: 1.43383e-05 (deg)   RMS_DEC: 7.48508e-07 (deg)
#
# Final solution based on  76  objects.
#
# wrote XY data to:  u2tv1802t_c0m_catalog_fit.match
#
# Writing out shiftfile : 1shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.008656
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 23:25:08.725 (06/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u2tv1801t_c0m.fits
#
#     u2tv1802t_c0m.fits
#
# ===  Source finding for image 'u2tv1801t_c0m.fits':
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 1) started at: 23:25:08.974 (06/12/2017)
#
#      Found 390 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 2) started at: 23:25:09.414 (06/12/2017)
#
#      Found 136 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 3) started at: 23:25:09.637 (06/12/2017)
#
#      Found 154 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 4) started at: 23:25:09.926 (06/12/2017)
#
#      Found 230 objects.
#
# ===  Found a TOTAL of 910 objects in image 'u2tv1801t_c0m.fits'
#
#
#
# ===  Source finding for image 'u2tv1802t_c0m.fits':
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 1) started at: 23:25:10.423 (06/12/2017)
#
#      Found 387 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 2) started at: 23:25:10.804 (06/12/2017)
#
#      Found 126 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 3) started at: 23:25:11.025 (06/12/2017)
#
#      Found 161 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 4) started at: 23:25:11.299 (06/12/2017)
#
#      Found 215 objects.
#
# ===  Found a TOTAL of 889 objects in image 'u2tv1802t_c0m.fits'
#
#
#
#  Catalog trimmed to 910 objects
#
#
# ====================
# Aligning all input images to WCS defined by u2tv1801t_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u2tv1802t_c0m.fits
#
# Matching sources from 'u2tv1802t_c0m.fits' with sources from reference image 'u2tv1801t_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.702982152807 -1.021417907
#
#     with significance of  501.701936745 and  26.0  matches
#
# Found 74 matches for u2tv1802t_c0m.fits...
#
# Computed  rscale  fit for  u2tv1802t_c0m.fits :
#
# XSH: -0.047342  YSH: -0.185958    ROT: 359.999    SCALE: 0.999961
#
# XRMS: 0.324762    YRMS: 0.353574
#
# RMS_RA: 1.20993e-05 (deg)   RMS_DEC: 6.3386e-07 (deg)
#
# Final solution based on  67  objects.
#
# wrote XY data to:  u2tv1802t_c0m_catalog_fit.match
#
# Writing out shiftfile : 2shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.047342
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 23:25:12.022 (06/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u2tv1801t_c0m.fits
#
#     u2tv1802t_c0m.fits
#
# ===  Source finding for image 'u2tv1801t_c0m.fits':
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 1) started at: 23:25:12.340 (06/12/2017)
#
#      Found 371 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 2) started at: 23:25:12.730 (06/12/2017)
#
#      Found 135 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 3) started at: 23:25:12.948 (06/12/2017)
#
#      Found 158 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 4) started at: 23:25:13.245 (06/12/2017)
#
#      Found 232 objects.
#
# ===  Found a TOTAL of 896 objects in image 'u2tv1801t_c0m.fits'
#
#
#
# ===  Source finding for image 'u2tv1802t_c0m.fits':
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 1) started at: 23:25:13.708 (06/12/2017)
#
#      Found 365 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 2) started at: 23:25:14.080 (06/12/2017)
#
#      Found 129 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 3) started at: 23:25:14.294 (06/12/2017)
#
#      Found 168 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 4) started at: 23:25:14.549 (06/12/2017)
#
#      Found 233 objects.
#
# ===  Found a TOTAL of 895 objects in image 'u2tv1802t_c0m.fits'
#
#
#
#  Catalog trimmed to 896 objects
#
#
# ====================
# Aligning all input images to WCS defined by u2tv1801t_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u2tv1802t_c0m.fits
#
# Matching sources from 'u2tv1802t_c0m.fits' with sources from reference image 'u2tv1801t_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.673128800852 -0.979378800852
#
#     with significance of  506.130401781 and  30.0  matches
#
# Found 75 matches for u2tv1802t_c0m.fits...
#
# Computed  rscale  fit for  u2tv1802t_c0m.fits :
#
# XSH: -0.0352012  YSH: -0.125431    ROT: 4.96664e-05    SCALE: 0.999989
#
# XRMS: 0.243883    YRMS: 0.257517
#
# RMS_RA: 8.92321e-06 (deg)   RMS_DEC: 5.36347e-07 (deg)
#
# Final solution based on  67  objects.
#
# wrote XY data to:  u2tv1802t_c0m_catalog_fit.match
#
# Writing out shiftfile : 3shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.035201
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 23:25:15.260 (06/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u2tv1801t_c0m.fits
#
#     u2tv1802t_c0m.fits
#
# ===  Source finding for image 'u2tv1801t_c0m.fits':
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 1) started at: 23:25:15.514 (06/12/2017)
#
#      Found 360 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 2) started at: 23:25:15.957 (06/12/2017)
#
#      Found 166 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 3) started at: 23:25:16.231 (06/12/2017)
#
#      Found 176 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 4) started at: 23:25:16.504 (06/12/2017)
#
#      Found 261 objects.
#
# ===  Found a TOTAL of 963 objects in image 'u2tv1801t_c0m.fits'
#
#
#
# ===  Source finding for image 'u2tv1802t_c0m.fits':
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 1) started at: 23:25:17.031 (06/12/2017)
#
#      Found 391 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 2) started at: 23:25:17.442 (06/12/2017)
#
#      Found 135 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 3) started at: 23:25:17.679 (06/12/2017)
#
#      Found 163 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 4) started at: 23:25:17.930 (06/12/2017)
#
#      Found 258 objects.
#
# ===  Found a TOTAL of 947 objects in image 'u2tv1802t_c0m.fits'
#
#
#
#  Catalog trimmed to 963 objects
#
#
# ====================
# Aligning all input images to WCS defined by u2tv1801t_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u2tv1802t_c0m.fits
#
# Matching sources from 'u2tv1802t_c0m.fits' with sources from reference image 'u2tv1801t_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.818576331716 -0.861786208259
#
#     with significance of  505.023036957 and  31.0  matches
#
# Found 76 matches for u2tv1802t_c0m.fits...
#
# Computed  rscale  fit for  u2tv1802t_c0m.fits :
#
# XSH: -0.030682  YSH: -0.063512    ROT: 359.999    SCALE: 1.00002
#
# XRMS: 0.207899    YRMS: 0.231
#
# RMS_RA: 7.84022e-06 (deg)   RMS_DEC: 3.70658e-07 (deg)
#
# Final solution based on  69  objects.
#
# wrote XY data to:  u2tv1802t_c0m_catalog_fit.match
#
# Writing out shiftfile : 4shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.030682
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 23:25:18.677 (06/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u2tv1801t_c0m.fits
#
#     u2tv1802t_c0m.fits
#
# ===  Source finding for image 'u2tv1801t_c0m.fits':
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 1) started at: 23:25:18.936 (06/12/2017)
#
#      Found 374 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 2) started at: 23:25:19.376 (06/12/2017)
#
#      Found 181 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 3) started at: 23:25:19.601 (06/12/2017)
#
#      Found 216 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 4) started at: 23:25:19.90 (06/12/2017)
#
#      Found 307 objects.
#
# ===  Found a TOTAL of 1078 objects in image 'u2tv1801t_c0m.fits'
#
#
#
# ===  Source finding for image 'u2tv1802t_c0m.fits':
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 1) started at: 23:25:20.355 (06/12/2017)
#
#      Found 394 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 2) started at: 23:25:20.726 (06/12/2017)
#
#      Found 151 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 3) started at: 23:25:20.971 (06/12/2017)
#
#      Found 184 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 4) started at: 23:25:21.205 (06/12/2017)
#
#      Found 297 objects.
#
# ===  Found a TOTAL of 1026 objects in image 'u2tv1802t_c0m.fits'
#
#
#
#  Catalog trimmed to 1078 objects
#
#
# ====================
# Aligning all input images to WCS defined by u2tv1801t_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u2tv1802t_c0m.fits
#
# Matching sources from 'u2tv1802t_c0m.fits' with sources from reference image 'u2tv1801t_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.589598926638 -0.922932259971
#
#     with significance of  515.845407438 and  31.0  matches
#
# Found 82 matches for u2tv1802t_c0m.fits...
#
# Computed  rscale  fit for  u2tv1802t_c0m.fits :
#
# XSH: -0.00446634  YSH: -0.0703133    ROT: 359.999    SCALE: 1.00001
#
# XRMS: 0.192639    YRMS: 0.202674
#
# RMS_RA: 7.03335e-06 (deg)   RMS_DEC: 4.2919e-07 (deg)
#
# Final solution based on  74  objects.
#
# wrote XY data to:  u2tv1802t_c0m_catalog_fit.match
#
# Writing out shiftfile : 5shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.004466
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 23:25:21.966 (06/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u2tv1801t_c0m.fits
#
#     u2tv1802t_c0m.fits
#
# ===  Source finding for image 'u2tv1801t_c0m.fits':
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 1) started at: 23:25:22.289 (06/12/2017)
#
#      Found 429 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 2) started at: 23:25:22.666 (06/12/2017)
#
#      Found 204 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 3) started at: 23:25:22.892 (06/12/2017)
#
#      Found 244 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 4) started at: 23:25:23.143 (06/12/2017)
#
#      Found 361 objects.
#
# ===  Found a TOTAL of 1238 objects in image 'u2tv1801t_c0m.fits'
#
#
#
# ===  Source finding for image 'u2tv1802t_c0m.fits':
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 1) started at: 23:25:23.681 (06/12/2017)
#
#      Found 407 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 2) started at: 23:25:24.060 (06/12/2017)
#
#      Found 183 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 3) started at: 23:25:24.286 (06/12/2017)
#
#      Found 194 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 4) started at: 23:25:24.554 (06/12/2017)
#
#      Found 353 objects.
#
# ===  Found a TOTAL of 1137 objects in image 'u2tv1802t_c0m.fits'
#
#
#
#  Catalog trimmed to 1238 objects
#
#
# ====================
# Aligning all input images to WCS defined by u2tv1801t_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u2tv1802t_c0m.fits
#
# Matching sources from 'u2tv1802t_c0m.fits' with sources from reference image 'u2tv1801t_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.760661523365 -1.13238927206
#
#     with significance of  546.420043223 and  30.0  matches
#
# Found 77 matches for u2tv1802t_c0m.fits...
#
# Computed  rscale  fit for  u2tv1802t_c0m.fits :
#
# XSH: -0.0222707  YSH: -0.100597    ROT: 0.00104008    SCALE: 1
#
# XRMS: 0.206961    YRMS: 0.186928
#
# RMS_RA: 6.92919e-06 (deg)   RMS_DEC: 6.93428e-07 (deg)
#
# Final solution based on  67  objects.
#
# wrote XY data to:  u2tv1802t_c0m_catalog_fit.match
#
# Writing out shiftfile : 6shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.022271
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 23:25:25.271 (06/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u2tv1801t_c0m.fits
#
#     u2tv1802t_c0m.fits
#
# ===  Source finding for image 'u2tv1801t_c0m.fits':
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 1) started at: 23:25:25.5 (06/12/2017)
#
#      Found 325 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 2) started at: 23:25:25.987 (06/12/2017)
#
#      Found 139 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 3) started at: 23:25:26.267 (06/12/2017)
#
#      Found 173 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 4) started at: 23:25:26. (06/12/2017)
#
#      Found 244 objects.
#
# ===  Found a TOTAL of 881 objects in image 'u2tv1801t_c0m.fits'
#
#
#
# ===  Source finding for image 'u2tv1802t_c0m.fits':
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 1) started at: 23:25:27.073 (06/12/2017)
#
#      Found 391 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 2) started at: 23:25:27.469 (06/12/2017)
#
#      Found 118 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 3) started at: 23:25:27.720 (06/12/2017)
#
#      Found 159 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 4) started at: 23:25:28.025 (06/12/2017)
#
#      Found 215 objects.
#
# ===  Found a TOTAL of 883 objects in image 'u2tv1802t_c0m.fits'
#
#
#
#  Catalog trimmed to 881 objects
#
#
# ====================
# Aligning all input images to WCS defined by u2tv1801t_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u2tv1802t_c0m.fits
#
# Matching sources from 'u2tv1802t_c0m.fits' with sources from reference image 'u2tv1801t_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.772025859675 -0.983790565558
#
#     with significance of  500.568529234 and  29.0  matches
#
# Found 78 matches for u2tv1802t_c0m.fits...
#
# Computed  rscale  fit for  u2tv1802t_c0m.fits :
#
# XSH: -0.0423324  YSH: -0.154305    ROT: 359.999    SCALE: 0.99996
#
# XRMS: 0.238195    YRMS: 0.260669
#
# RMS_RA: 8.90146e-06 (deg)   RMS_DEC: 4.54786e-07 (deg)
#
# Final solution based on  69  objects.
#
# wrote XY data to:  u2tv1802t_c0m_catalog_fit.match
#
# Writing out shiftfile : 7shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.042332
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 23:25:28.787 (06/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u2tv1801t_c0m.fits
#
#     u2tv1802t_c0m.fits
#
# ===  Source finding for image 'u2tv1801t_c0m.fits':
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 1) started at: 23:25:29.047 (06/12/2017)
#
#      Found 369 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 2) started at: 23:25:29.499 (06/12/2017)
#
#      Found 156 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 3) started at: 23:25:29.750 (06/12/2017)
#
#      Found 177 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 4) started at: 23:25:30.024 (06/12/2017)
#
#      Found 253 objects.
#
# ===  Found a TOTAL of 955 objects in image 'u2tv1801t_c0m.fits'
#
#
#
# ===  Source finding for image 'u2tv1802t_c0m.fits':
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 1) started at: 23:25:30.565 (06/12/2017)
#
#      Found 404 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 2) started at: 23:25:30.96 (06/12/2017)
#
#      Found 138 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 3) started at: 23:25:31.217 (06/12/2017)
#
#      Found 178 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 4) started at: 23:25:31.507 (06/12/2017)
#
#      Found 251 objects.
#
# ===  Found a TOTAL of 971 objects in image 'u2tv1802t_c0m.fits'
#
#
#
#  Catalog trimmed to 955 objects
#
#
# ====================
# Aligning all input images to WCS defined by u2tv1801t_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u2tv1802t_c0m.fits
#
# Matching sources from 'u2tv1802t_c0m.fits' with sources from reference image 'u2tv1801t_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.880304726778 -0.94379679027
#
#     with significance of  521.546786013 and  33.0  matches
#
# Found 80 matches for u2tv1802t_c0m.fits...
#
# Computed  rscale  fit for  u2tv1802t_c0m.fits :
#
# XSH: -0.0421633  YSH: -0.116866    ROT: 0.00101776    SCALE: 0.999988
#
# XRMS: 0.211398    YRMS: 0.223347
#
# RMS_RA: 7.73731e-06 (deg)   RMS_DEC: 4.63916e-07 (deg)
#
# Final solution based on  69  objects.
#
# wrote XY data to:  u2tv1802t_c0m_catalog_fit.match
#
# Writing out shiftfile : 8shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.042163
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 23:25:32.265 (06/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u2tv1801t_c0m.fits
#
#     u2tv1802t_c0m.fits
#
# ===  Source finding for image 'u2tv1801t_c0m.fits':
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 1) started at: 23:25:32.52 (06/12/2017)
#
#      Found 401 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 2) started at: 23:25:33.042 (06/12/2017)
#
#      Found 179 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 3) started at: 23:25:33.304 (06/12/2017)
#
#      Found 196 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 4) started at: 23:25:33.623 (06/12/2017)
#
#      Found 294 objects.
#
# ===  Found a TOTAL of 1070 objects in image 'u2tv1801t_c0m.fits'
#
#
#
# ===  Source finding for image 'u2tv1802t_c0m.fits':
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 1) started at: 23:25:34.108 (06/12/2017)
#
#      Found 399 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 2) started at: 23:25:34.494 (06/12/2017)
#
#      Found 168 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 3) started at: 23:25:34.750 (06/12/2017)
#
#      Found 195 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 4) started at: 23:25:35.056 (06/12/2017)
#
#      Found 299 objects.
#
# ===  Found a TOTAL of 1061 objects in image 'u2tv1802t_c0m.fits'
#
#
#
#  Catalog trimmed to 1070 objects
#
#
# ====================
# Aligning all input images to WCS defined by u2tv1801t_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u2tv1802t_c0m.fits
#
# Matching sources from 'u2tv1802t_c0m.fits' with sources from reference image 'u2tv1801t_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.697235943709 -1.04485499133
#
#     with significance of  560.738900279 and  38.0  matches
#
# Found 100 matches for u2tv1802t_c0m.fits...
#
# Computed  rscale  fit for  u2tv1802t_c0m.fits :
#
# XSH: -0.0260655  YSH: -0.145632    ROT: 0.000349306    SCALE: 0.999973
#
# XRMS: 0.230393    YRMS: 0.270953
#
# RMS_RA: 8.99292e-06 (deg)   RMS_DEC: 2.97979e-07 (deg)
#
# Final solution based on  87  objects.
#
# wrote XY data to:  u2tv1802t_c0m_catalog_fit.match
#
# Writing out shiftfile : 9shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.026065
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 23:25:35.86 (06/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u2tv1801t_c0m.fits
#
#     u2tv1802t_c0m.fits
#
# ===  Source finding for image 'u2tv1801t_c0m.fits':
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 1) started at: 23:25:36.158 (06/12/2017)
#      Found 337 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 2) started at: 23:25:36.613 (06/12/2017)
#
#      Found 134 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 3) started at: 23:25:36.900 (06/12/2017)
#
#      Found 167 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 4) started at: 23:25:37.398 (06/12/2017)
#
#      Found 223 objects.
#
# ===  Found a TOTAL of 861 objects in image 'u2tv1801t_c0m.fits'
#
#
#
# ===  Source finding for image 'u2tv1802t_c0m.fits':
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 1) started at: 23:25:38.063 (06/12/2017)
#
#      Found 373 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 2) started at: 23:25:38.63 (06/12/2017)
#
#      Found 131 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 3) started at: 23:25:38.927 (06/12/2017)
#
#      Found 175 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 4) started at: 23:25:39.297 (06/12/2017)
#
#      Found 228 objects.
#
# ===  Found a TOTAL of 907 objects in image 'u2tv1802t_c0m.fits'
#
#
#
#  Catalog trimmed to 861 objects
#
#
# ====================
# Aligning all input images to WCS defined by u2tv1801t_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u2tv1802t_c0m.fits
#
# Matching sources from 'u2tv1802t_c0m.fits' with sources from reference image 'u2tv1801t_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.848128800852 -0.891878800852
#
#     with significance of  465.417402436 and  25.0  matches
#
# Found 68 matches for u2tv1802t_c0m.fits...
#
# Computed  rscale  fit for  u2tv1802t_c0m.fits :
#
# XSH: -0.0220256  YSH: -0.14591    ROT: 359.999    SCALE: 0.999971
#
# XRMS: 0.220398    YRMS: 0.270073
#
# RMS_RA: 8.82408e-06 (deg)   RMS_DEC: 2.03048e-07 (deg)
#
# Final solution based on  59  objects.
#
# wrote XY data to:  u2tv1802t_c0m_catalog_fit.match
#
# Writing out shiftfile : 10shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.022026
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 23:25:40.189 (06/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u2tv1801t_c0m.fits
#
#     u2tv1802t_c0m.fits
#
# ===  Source finding for image 'u2tv1801t_c0m.fits':
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 1) started at: 23:25:40.550 (06/12/2017)
#
#      Found 168 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 2) started at: 23:25:40.874 (06/12/2017)
#
#      Found 48 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 3) started at: 23:25:41.135 (06/12/2017)
#
#      Found 59 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 4) started at: 23:25:41.44 (06/12/2017)
#
#      Found 81 objects.
#
# ===  Found a TOTAL of 356 objects in image 'u2tv1801t_c0m.fits'
#
#
#
# ===  Source finding for image 'u2tv1802t_c0m.fits':
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 1) started at: 23:25:42.001 (06/12/2017)
#
#      Found 169 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 2) started at: 23:25:42.405 (06/12/2017)
#
#      Found 40 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 3) started at: 23:25:42.733 (06/12/2017)
#
#      Found 81 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 4) started at: 23:25:43.026 (06/12/2017)
#
#      Found 67 objects.
#
# ===  Found a TOTAL of 357 objects in image 'u2tv1802t_c0m.fits'
#
#
#
#  Catalog trimmed to 356 objects
#
#
# ====================
# Aligning all input images to WCS defined by u2tv1801t_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u2tv1802t_c0m.fits
#
# Matching sources from 'u2tv1802t_c0m.fits' with sources from reference image 'u2tv1801t_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -8.25872662694 -2.86742227911
#
#     with significance of  215.015115748 and  6.0  matches
#
# ##############################################################################
# #                                                                            #
# # WARNING:                                                                   #
# # Not enough matches (< 15) found for input image: u2tv1802t_c0m.fits        #
# #                                                                            #
# ##############################################################################
#
#
# Unable to match the following images:
#
# -------------------------------------
#
# u2tv1802t_c0m.fits
#
#
# Writing out shiftfile : 11shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# nan
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 23:25:43.731 (06/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u2tv1801t_c0m.fits
#
#     u2tv1802t_c0m.fits
#
# ===  Source finding for image 'u2tv1801t_c0m.fits':
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 1) started at: 23:25:44.077 (06/12/2017)
#
#      Found 172 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 2) started at: 23:25:44.518 (06/12/2017)
#
#      Found 50 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 3) started at: 23:25:44.806 (06/12/2017)
#
#      Found 60 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 4) started at: 23:25:45.155 (06/12/2017)
#
#      Found 87 objects.
#
# ===  Found a TOTAL of 369 objects in image 'u2tv1801t_c0m.fits'
#
#
#
# ===  Source finding for image 'u2tv1802t_c0m.fits':
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 1) started at: 23:25:45.681 (06/12/2017)
#
#      Found 172 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 2) started at: 23:25:46.011 (06/12/2017)
#
#      Found 33 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 3) started at: 23:25:46.244 (06/12/2017)
#
#      Found 78 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 4) started at: 23:25:46.522 (06/12/2017)
#
#      Found 82 objects.
#
# ===  Found a TOTAL of 365 objects in image 'u2tv1802t_c0m.fits'
#
#
#
#  Catalog trimmed to 369 objects
#
#
# ====================
# Aligning all input images to WCS defined by u2tv1801t_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u2tv1802t_c0m.fits
#
# Matching sources from 'u2tv1802t_c0m.fits' with sources from reference image 'u2tv1801t_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.408924255397 -0.954378800852
#
#     with significance of  235.537258199 and  6.0  matches
#
# Found 17 matches for u2tv1802t_c0m.fits...
#
# Computed  rscale  fit for  u2tv1802t_c0m.fits :
#
# XSH: -0.00343975  YSH: -0.288751    ROT: 359.992    SCALE: 0.99994
#
# XRMS: 0.26426    YRMS: 0.270028
#
# RMS_RA: 9.4855e-06 (deg)   RMS_DEC: 6.49057e-07 (deg)
#
# Final solution based on  16  objects.
#
# wrote XY data to:  u2tv1802t_c0m_catalog_fit.match
#
# Writing out shiftfile : 12shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.003440
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 23:25:47.255 (06/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u2tv1801t_c0m.fits
#
#     u2tv1802t_c0m.fits
#
# ===  Source finding for image 'u2tv1801t_c0m.fits':
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 1) started at: 23:25:47.485 (06/12/2017)
#      Found 194 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 2) started at: 23:25:47.822 (06/12/2017)
#
#      Found 52 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 3) started at: 23:25:48.03 (06/12/2017)
#
#      Found 55 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 4) started at: 23:25:48.297 (06/12/2017)
#
#      Found 95 objects.
#
# ===  Found a TOTAL of 396 objects in image 'u2tv1801t_c0m.fits'
#
#
#
# ===  Source finding for image 'u2tv1802t_c0m.fits':
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 1) started at: 23:25:48.799 (06/12/2017)
#
#      Found 184 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 2) started at: 23:25:49.128 (06/12/2017)
#
#      Found 38 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 3) started at: 23:25:49.340 (06/12/2017)
#
#      Found 80 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 4) started at: 23:25:49.569 (06/12/2017)
#
#      Found 90 objects.
#
# ===  Found a TOTAL of 392 objects in image 'u2tv1802t_c0m.fits'
#
#
#
#  Catalog trimmed to 396 objects
#
#
# ====================
# Aligning all input images to WCS defined by u2tv1801t_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u2tv1802t_c0m.fits
#
# Matching sources from 'u2tv1802t_c0m.fits' with sources from reference image 'u2tv1801t_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.295842215486 -0.978769044754
#
#     with significance of  267.023674713 and  9.0  matches
#
# Found 20 matches for u2tv1802t_c0m.fits...
#
# Computed  rscale  fit for  u2tv1802t_c0m.fits :
#
# XSH: -0.016833  YSH: -0.171238    ROT: 359.999    SCALE: 1.00001
#
# XRMS: 0.275887    YRMS: 0.265865
#
# RMS_RA: 9.57638e-06 (deg)   RMS_DEC: 7.98574e-07 (deg)
#
# Final solution based on  20  objects.
#
# wrote XY data to:  u2tv1802t_c0m_catalog_fit.match
#
# Writing out shiftfile : 13shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.016833
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 23:25:50.225 (06/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u2tv1801t_c0m.fits
#
#     u2tv1802t_c0m.fits
#
# ===  Source finding for image 'u2tv1801t_c0m.fits':
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 1) started at: 23:25:50.464 (06/12/2017)
#
#      Found 156 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 2) started at: 23:25:50.739 (06/12/2017)
#
#      Found 48 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 3) started at: 23:25:50.96 (06/12/2017)
#
#      Found 62 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 4) started at: 23:25:51.199 (06/12/2017)
#
#      Found 74 objects.
#
# ===  Found a TOTAL of 340 objects in image 'u2tv1801t_c0m.fits'
#
#
#
# ===  Source finding for image 'u2tv1802t_c0m.fits':
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 1) started at: 23:25:51.689 (06/12/2017)
#
#      Found 165 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 2) started at: 23:25:51.996 (06/12/2017)
#
#      Found 34 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 3) started at: 23:25:52.206 (06/12/2017)
#
#      Found 62 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 4) started at: 23:25:52.448 (06/12/2017)
#
#      Found 64 objects.
#
# ===  Found a TOTAL of 325 objects in image 'u2tv1802t_c0m.fits'
#
#
#
#  Catalog trimmed to 340 objects
#
#
# ====================
# Aligning all input images to WCS defined by u2tv1801t_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u2tv1802t_c0m.fits
#
# Matching sources from 'u2tv1802t_c0m.fits' with sources from reference image 'u2tv1801t_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.176601023074 0.0456211991482
#
#     with significance of  180.60493586 and  4.0  matches
#
# ##############################################################################
# #                                                                            #
# # WARNING:                                                                   #
# # Not enough matches (< 15) found for input image: u2tv1802t_c0m.fits        #
# #                                                                            #
# ##############################################################################
#
#
# Unable to match the following images:
#
# -------------------------------------
#
# u2tv1802t_c0m.fits
#
#
# Writing out shiftfile : 14shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# nan

# %%
# change to a jupyter table
dt=test.to_pandas()
dt.to_pickle('data.pickle')
good_table=pandas.read_pickle('data.pickle')

# %%
# take only unfailed sessions
good_conv = good_table[good_table['y_rms'] != 'failed']

# %%
good_conv
# Out:
#           shift                file     x_rms     y_rms  threshold  \
# 0    1shift.txt  u2tv1801t_c0m.fits  0.000000  0.000000          7
# 1    1shift.txt  u2tv1802t_c0m.fits  0.384692  0.419129          7
# 2    2shift.txt  u2tv1801t_c0m.fits  0.000000  0.000000          7
# 3    2shift.txt  u2tv1802t_c0m.fits  0.324762  0.353574          7
# 4    3shift.txt  u2tv1801t_c0m.fits  0.000000  0.000000          7
# 5    3shift.txt  u2tv1802t_c0m.fits  0.243883  0.257517          7
# 6    4shift.txt  u2tv1801t_c0m.fits  0.000000  0.000000          7
# 7    4shift.txt  u2tv1802t_c0m.fits  0.207899  0.231000          7
# 8    5shift.txt  u2tv1801t_c0m.fits  0.000000  0.000000          7
# 9    5shift.txt  u2tv1802t_c0m.fits  0.192639  0.202674          7
# 10   6shift.txt  u2tv1801t_c0m.fits  0.000000  0.000000          7
# 11   6shift.txt  u2tv1802t_c0m.fits  0.206961  0.186928          7
# 12   7shift.txt  u2tv1801t_c0m.fits  0.000000  0.000000          7
# 13   7shift.txt  u2tv1802t_c0m.fits  0.238195  0.260669          7
# 14   8shift.txt  u2tv1801t_c0m.fits  0.000000  0.000000          7
# 15   8shift.txt  u2tv1802t_c0m.fits  0.211398  0.223347          7
# 16   9shift.txt  u2tv1801t_c0m.fits  0.000000  0.000000          7
# 17   9shift.txt  u2tv1802t_c0m.fits  0.230393  0.270953          7
# 18  10shift.txt  u2tv1801t_c0m.fits  0.000000  0.000000          7
# 19  10shift.txt  u2tv1802t_c0m.fits  0.220398  0.270073          7
# 20  11shift.txt  u2tv1801t_c0m.fits  0.000000  0.000000          7
# 22  12shift.txt  u2tv1801t_c0m.fits  0.000000  0.000000          7
# 23  12shift.txt  u2tv1802t_c0m.fits  0.264260  0.270028          7
# 24  13shift.txt  u2tv1801t_c0m.fits  0.000000  0.000000          7
# 25  13shift.txt  u2tv1802t_c0m.fits  0.275887  0.265865          7
# 26  14shift.txt  u2tv1801t_c0m.fits  0.000000  0.000000          7
#
#     conv_width  roundlo  roundhi  peakmax
# 0          2.0       -1        1     1000
# 1          2.0       -1        1     1000
# 2          2.3       -1        1     1000
# 3          2.3       -1        1     1000
# 4          2.6       -1        1     1000
# 5          2.6       -1        1     1000
# 6          2.9       -1        1     1000
# 7          2.9       -1        1     1000
# 8          3.2       -1        1     1000
# 9          3.2       -1        1     1000
# 10         3.5       -1        1     1000
# 11         3.5       -1        1     1000
# 12         3.8       -1        1     1000
# 13         3.8       -1        1     1000
# 14         4.1       -1        1     1000
# 15         4.1       -1        1     1000
# 16         4.4       -1        1     1000
# 17         4.4       -1        1     1000
# 18         4.7       -1        1     1000
# 19         4.7       -1        1     1000
# 20         5.0       -1        1     1000
# 22         5.3       -1        1     1000
# 23         5.3       -1        1     1000
# 24         5.6       -1        1     1000
# 25         5.6       -1        1     1000
# 26         5.9       -1        1     1000

# %%
# plot figure for all sub-exp
plt.figure(figsize = (7,7))
plt.plot(good_conv['conv_width'],good_conv['x_rms'],'.g')
plt.plot(good_conv['conv_width'],good_conv['y_rms'],'.b')
plt.title('x,y_rms(conv_width)-g,b')
plt.show()

# %%
# plot figure for choosen sub-exp
plt.figure(figsize = (7,7))
plt.plot(good_conv[good_conv['file'] == 'u6ea5402m_c0m.fits']['conv_width'],good_conv[good_conv['file'] == 'u6ea5402m_c0m.fits']['y_rms'],'.b')
plt.plot(good_conv[good_conv['file'] == 'u6ea5403m_c0m.fits']['conv_width'],good_conv[good_conv['file'] == 'u6ea5403m_c0m.fits']['y_rms'],'.g')
plt.title('y_rms(conv)-two filters')
plt.show()

# %%
#############################################thresh = 7, conv = 3.5, roundlo?

# %%
# tweak_run(path, n_up, threshold_ini, threshold_gap, conv_width_ini, conv_width_gap, 
# roundlo_val_ini, roundlo_gap, roundhi_val_ini, roundhi_gap, peakmax_val_ini, peakmax_gap):
test = tweak_run('/Users/natalie/anaconda2/envs/iraf27/iraf/sn/2000ds/2000ds_pre/tweak_814_1',10,7,0,3.5,0,-0.5,0.1,1,0,1000,0)
# Out:
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 23:33:15.192 (06/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u2tv1801t_c0m.fits
#
#     u2tv1802t_c0m.fits
#
# ===  Source finding for image 'u2tv1801t_c0m.fits':
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 1) started at: 23:33:15.537 (06/12/2017)
#
#      Found 313 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 2) started at: 23:33:15.986 (06/12/2017)
#
#      Found 174 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 3) started at: 23:33:16.247 (06/12/2017)
#
#      Found 209 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 4) started at: 23:33:16.597 (06/12/2017)
#
#      Found 297 objects.
#
# ===  Found a TOTAL of 993 objects in image 'u2tv1801t_c0m.fits'
#
#
#
# ===  Source finding for image 'u2tv1802t_c0m.fits':
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 1) started at: 23:33:17.195 (06/12/2017)
#
#      Found 299 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 2) started at: 23:33:17.786 (06/12/2017)
#
#      Found 152 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 3) started at: 23:33:18.062 (06/12/2017)
#
#      Found 165 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 4) started at: 23:33:18.407 (06/12/2017)
#
#      Found 290 objects.
#
# ===  Found a TOTAL of 906 objects in image 'u2tv1802t_c0m.fits'
#
#
#
#  Catalog trimmed to 993 objects
#
#
# ====================
# Aligning all input images to WCS defined by u2tv1801t_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u2tv1802t_c0m.fits
#
# Matching sources from 'u2tv1802t_c0m.fits' with sources from reference image 'u2tv1801t_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.764984861458 -1.04528789176
#
#     with significance of  503.62660488 and  27.0  matches
#
# Found 72 matches for u2tv1802t_c0m.fits...
#
# Computed  rscale  fit for  u2tv1802t_c0m.fits :
#
# XSH: 0.00175467  YSH: -0.0659009    ROT: 0.00114529    SCALE: 1.00001
#
# XRMS: 0.174253    YRMS: 0.170048
#
# RMS_RA: 6.09178e-06 (deg)   RMS_DEC: 4.88373e-07 (deg)
#
# Final solution based on  63  objects.
#
# wrote XY data to:  u2tv1802t_c0m_catalog_fit.match
#
# Writing out shiftfile : 1shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 0.001755
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 23:33:19.653 (06/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u2tv1801t_c0m.fits
#
#     u2tv1802t_c0m.fits
#
# ===  Source finding for image 'u2tv1801t_c0m.fits':
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 1) started at: 23:33:19.920 (06/12/2017)
#
#      Found 280 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 2) started at: 23:33:20.316 (06/12/2017)
#
#      Found 156 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 3) started at: 23:33:20.530 (06/12/2017)
#
#      Found 199 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 4) started at: 23:33:20.750 (06/12/2017)
#
#      Found 270 objects.
#
# ===  Found a TOTAL of 905 objects in image 'u2tv1801t_c0m.fits'
#
#
#
# ===  Source finding for image 'u2tv1802t_c0m.fits':
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 1) started at: 23:33:21.224 (06/12/2017)
#
#      Found 267 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 2) started at: 23:33:21.627 (06/12/2017)
#
#      Found 141 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 3) started at: 23:33:21.84 (06/12/2017)
#
#      Found 150 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 4) started at: 23:33:22.071 (06/12/2017)
#
#      Found 261 objects.
#
# ===  Found a TOTAL of 819 objects in image 'u2tv1802t_c0m.fits'
#
#
#
#  Catalog trimmed to 905 objects
#
#
# ====================
# Aligning all input images to WCS defined by u2tv1801t_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u2tv1802t_c0m.fits
#
# Matching sources from 'u2tv1802t_c0m.fits' with sources from reference image 'u2tv1801t_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.746831631041 -1.03928446123
#
#     with significance of  466.999226742 and  25.0  matches
#
# Found 66 matches for u2tv1802t_c0m.fits...
#
# Computed  rscale  fit for  u2tv1802t_c0m.fits :
#
# XSH: 0.00504386  YSH: -0.062837    ROT: 0.00106762    SCALE: 1.00001
#
# XRMS: 0.173394    YRMS: 0.177978
#
# RMS_RA: 6.24017e-06 (deg)   RMS_DEC: 4.19851e-07 (deg)
#
# Final solution based on  59  objects.
#
# wrote XY data to:  u2tv1802t_c0m_catalog_fit.match
#
# Writing out shiftfile : 2shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 0.005044
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 23:33:22.774 (06/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u2tv1801t_c0m.fits
#
#     u2tv1802t_c0m.fits
#
# ===  Source finding for image 'u2tv1801t_c0m.fits':
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 1) started at: 23:33:22.985 (06/12/2017)
#
#      Found 231 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 2) started at: 23:33:23.336 (06/12/2017)
#
#      Found 132 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 3) started at: 23:33:23.555 (06/12/2017)
#
#      Found 179 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 4) started at: 23:33:23.787 (06/12/2017)
#
#      Found 240 objects.
#
# ===  Found a TOTAL of 782 objects in image 'u2tv1801t_c0m.fits'
#
#
#
# ===  Source finding for image 'u2tv1802t_c0m.fits':
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 1) started at: 23:33:24.230 (06/12/2017)
#
#      Found 230 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 2) started at: 23:33:24.671 (06/12/2017)
#
#      Found 124 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 3) started at: 23:33:24.883 (06/12/2017)
#
#      Found 132 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 4) started at: 23:33:25.206 (06/12/2017)
#
#      Found 227 objects.
#
# ===  Found a TOTAL of 713 objects in image 'u2tv1802t_c0m.fits'
#
#
#
#  Catalog trimmed to 782 objects
#
#
# ====================
# Aligning all input images to WCS defined by u2tv1801t_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u2tv1802t_c0m.fits
#
# Matching sources from 'u2tv1802t_c0m.fits' with sources from reference image 'u2tv1801t_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.687712134185 -0.987712134185
#
#     with significance of  448.337508735 and  24.0  matches
#
# Found 62 matches for u2tv1802t_c0m.fits...
#
# Computed  rscale  fit for  u2tv1802t_c0m.fits :
#
# XSH: -0.0111781  YSH: -0.0365794    ROT: 0.000663598    SCALE: 1.00003
#
# XRMS: 0.17588    YRMS: 0.186282
#
# RMS_RA: 6.4467e-06 (deg)   RMS_DEC: 3.82502e-07 (deg)
#
# Final solution based on  57  objects.
#
# wrote XY data to:  u2tv1802t_c0m_catalog_fit.match
#
# Writing out shiftfile : 3shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.011178
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 23:33:25.874 (06/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u2tv1801t_c0m.fits
#
#     u2tv1802t_c0m.fits
#
# ===  Source finding for image 'u2tv1801t_c0m.fits':
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 1) started at: 23:33:26.079 (06/12/2017)
#
#      Found 188 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 2) started at: 23:33:26.449 (06/12/2017)
#
#      Found 112 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 3) started at: 23:33:26.6 (06/12/2017)
#
#      Found 150 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 4) started at: 23:33:26.86 (06/12/2017)
#
#      Found 195 objects.
#
# ===  Found a TOTAL of 645 objects in image 'u2tv1801t_c0m.fits'
#
#
#
# ===  Source finding for image 'u2tv1802t_c0m.fits':
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 1) started at: 23:33:27.269 (06/12/2017)
#
#      Found 193 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 2) started at: 23:33:27.676 (06/12/2017)
#
#      Found 97 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 3) started at: 23:33:27.862 (06/12/2017)
#
#      Found 110 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 4) started at: 23:33:28.0 (06/12/2017)
#
#      Found 190 objects.
#
# ===  Found a TOTAL of 590 objects in image 'u2tv1802t_c0m.fits'
#
#
#
#  Catalog trimmed to 645 objects
#
#
# ====================
# Aligning all input images to WCS defined by u2tv1801t_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u2tv1802t_c0m.fits
#
# Matching sources from 'u2tv1802t_c0m.fits' with sources from reference image 'u2tv1801t_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.4392272857 -0.878621225094
#
#     with significance of  398.196454865 and  19.0  matches
#
# Found 52 matches for u2tv1802t_c0m.fits...
#
# Computed  rscale  fit for  u2tv1802t_c0m.fits :
#
# XSH: 0.0252867  YSH: 0.000330084    ROT: 0.000113096    SCALE: 1.00004
#
# XRMS: 0.150941    YRMS: 0.17506
#
# RMS_RA: 5.84174e-06 (deg)   RMS_DEC: 2.13713e-07 (deg)
#
# Final solution based on  47  objects.
#
# wrote XY data to:  u2tv1802t_c0m_catalog_fit.match
#
# Writing out shiftfile : 4shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 0.025287
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 23:33:28.728 (06/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u2tv1801t_c0m.fits
#
#     u2tv1802t_c0m.fits
#
# ===  Source finding for image 'u2tv1801t_c0m.fits':
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 1) started at: 23:33:28.951 (06/12/2017)
#
#      Found 158 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 2) started at: 23:33:29.355 (06/12/2017)
#
#      Found 87 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 3) started at: 23:33:29.553 (06/12/2017)
#
#      Found 123 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 4) started at: 23:33:29.800 (06/12/2017)
#
#      Found 146 objects.
#
# ===  Found a TOTAL of 514 objects in image 'u2tv1801t_c0m.fits'
#
#
#
# ===  Source finding for image 'u2tv1802t_c0m.fits':
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 1) started at: 23:33:30.181 (06/12/2017)
#
#      Found 152 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 2) started at: 23:33:30.605 (06/12/2017)
#
#      Found 70 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 3) started at: 23:33:30.799 (06/12/2017)
#
#      Found 79 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 4) started at: 23:33:31.007 (06/12/2017)
#
#      Found 150 objects.
#
# ===  Found a TOTAL of 451 objects in image 'u2tv1802t_c0m.fits'
#
#
#
#  Catalog trimmed to 514 objects
#
#
# ====================
# Aligning all input images to WCS defined by u2tv1801t_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u2tv1802t_c0m.fits
#
# Matching sources from 'u2tv1802t_c0m.fits' with sources from reference image 'u2tv1801t_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.845683148678 -0.976117931287
#
#     with significance of  307.964707182 and  11.0  matches
#
# Found 29 matches for u2tv1802t_c0m.fits...
#
# Computed  rscale  fit for  u2tv1802t_c0m.fits :
#
# XSH: 0.00843292  YSH: -0.0126417    ROT: 359.999    SCALE: 1.00001
#
# XRMS: 0.117607    YRMS: 0.125786
#
# RMS_RA: 4.33566e-06 (deg)   RMS_DEC: 2.46535e-07 (deg)
#
# Final solution based on  26  objects.
#
# wrote XY data to:  u2tv1802t_c0m_catalog_fit.match
#
# Writing out shiftfile : 5shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 0.008433
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 23:33:31.630 (06/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u2tv1801t_c0m.fits
#
#     u2tv1802t_c0m.fits
#
# ===  Source finding for image 'u2tv1801t_c0m.fits':
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 1) started at: 23:33:31.862 (06/12/2017)
#
#      Found 118 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 2) started at: 23:33:32.195 (06/12/2017)
#
#      Found 68 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 3) started at: 23:33:32.391 (06/12/2017)
#
#      Found 93 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 4) started at: 23:33:32.602 (06/12/2017)
#
#      Found 106 objects.
#
# ===  Found a TOTAL of 385 objects in image 'u2tv1801t_c0m.fits'
#
#
#
# ===  Source finding for image 'u2tv1802t_c0m.fits':
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 1) started at: 23:33:33.108 (06/12/2017)
#
#      Found 111 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 2) started at: 23:33:33.50 (06/12/2017)
#
#      Found 53 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 3) started at: 23:33:33.700 (06/12/2017)
#
#      Found 55 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 4) started at: 23:33:33.910 (06/12/2017)
#
#      Found 101 objects.
#
# ===  Found a TOTAL of 320 objects in image 'u2tv1802t_c0m.fits'
#
#
#
#  Catalog trimmed to 385 objects
#
#
# ====================
# Aligning all input images to WCS defined by u2tv1801t_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u2tv1802t_c0m.fits
#
# Matching sources from 'u2tv1802t_c0m.fits' with sources from reference image 'u2tv1801t_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.404378800852 -0.854378800852
#
#     with significance of  240.959619981 and  7.0  matches
#
# ##############################################################################
# #                                                                            #
# # WARNING:                                                                   #
# # Not enough matches (< 15) found for input image: u2tv1802t_c0m.fits        #
# #                                                                            #
# ##############################################################################
#
#
# Unable to match the following images:
#
# -------------------------------------
#
# u2tv1802t_c0m.fits
#
#
# Writing out shiftfile : 6shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# nan
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 23:33:34.522 (06/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u2tv1801t_c0m.fits
#
#     u2tv1802t_c0m.fits
#
# ===  Source finding for image 'u2tv1801t_c0m.fits':
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 1) started at: 23:33:34.740 (06/12/2017)
#
#      Found 86 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 2) started at: 23:33:35.07 (06/12/2017)
#
#      Found 49 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 3) started at: 23:33:35.282 (06/12/2017)
#
#      Found 65 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 4) started at: 23:33:35.500 (06/12/2017)
#
#      Found 73 objects.
#
# ===  Found a TOTAL of 273 objects in image 'u2tv1801t_c0m.fits'
#
#
#
# ===  Source finding for image 'u2tv1802t_c0m.fits':
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 1) started at: 23:33:35.898 (06/12/2017)
#
#      Found 81 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 2) started at: 23:33:36.225 (06/12/2017)
#
#      Found 36 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 3) started at: 23:33:36.473 (06/12/2017)
#
#      Found 41 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 4) started at: 23:33:36.697 (06/12/2017)
#
#      Found 77 objects.
#
# ===  Found a TOTAL of 235 objects in image 'u2tv1802t_c0m.fits'
#
#
#
#  Catalog trimmed to 273 objects
#
#
# ====================
# Aligning all input images to WCS defined by u2tv1801t_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u2tv1802t_c0m.fits
#
# Matching sources from 'u2tv1802t_c0m.fits' with sources from reference image 'u2tv1801t_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  16.4741926277 -19.2400930866
#
#     with significance of  136.239495008 and  2.0  matches
#
# ##############################################################################
# #                                                                            #
# # WARNING:                                                                   #
# # Not enough matches (< 15) found for input image: u2tv1802t_c0m.fits        #
# #                                                                            #
# ##############################################################################
#
#
# Unable to match the following images:
#
# -------------------------------------
#
# u2tv1802t_c0m.fits
#
#
# Writing out shiftfile : 7shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# nan
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 23:33:37.168 (06/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u2tv1801t_c0m.fits
#
#     u2tv1802t_c0m.fits
#
# ===  Source finding for image 'u2tv1801t_c0m.fits':
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 1) started at: 23:33:37.383 (06/12/2017)
#
#      Found 54 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 2) started at: 23:33:37.739 (06/12/2017)
#
#      Found 25 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 3) started at: 23:33:37.959 (06/12/2017)
#
#      Found 40 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 4) started at: 23:33:38.177 (06/12/2017)
#
#      Found 41 objects.
#
# ===  Found a TOTAL of 160 objects in image 'u2tv1801t_c0m.fits'
#
#
#
# ===  Source finding for image 'u2tv1802t_c0m.fits':
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 1) started at: 23:33:38.588 (06/12/2017)
#
#      Found 53 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 2) started at: 23:33:39.007 (06/12/2017)
#
#      Found 21 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 3) started at: 23:33:39.210 (06/12/2017)
#
#      Found 22 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 4) started at: 23:33:39.430 (06/12/2017)
#
#      Found 43 objects.
#
# ===  Found a TOTAL of 139 objects in image 'u2tv1802t_c0m.fits'
#
#
#
#  Catalog trimmed to 160 objects
#
#
# ====================
# Aligning all input images to WCS defined by u2tv1801t_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u2tv1802t_c0m.fits
#
# Matching sources from 'u2tv1802t_c0m.fits' with sources from reference image 'u2tv1801t_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.204378800852 -1.70437880085
#
#     with significance of  122.865780427 and  2.0  matches
#
# ##############################################################################
# #                                                                            #
# # WARNING:                                                                   #
# # Not enough matches (< 15) found for input image: u2tv1802t_c0m.fits        #
# #                                                                            #
# ##############################################################################
#
#
# Unable to match the following images:
#
# -------------------------------------
#
# u2tv1802t_c0m.fits
#
#
# Writing out shiftfile : 8shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# nan
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 23:33:39.871 (06/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u2tv1801t_c0m.fits
#
#     u2tv1802t_c0m.fits
#
# ===  Source finding for image 'u2tv1801t_c0m.fits':
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 1) started at: 23:33:40.082 (06/12/2017)
#
#      Found 39 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 2) started at: 23:33:40.4 (06/12/2017)
#
#      Found 12 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 3) started at: 23:33:40.701 (06/12/2017)
#
#      Found 20 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 4) started at: 23:33:40.946 (06/12/2017)
#
#      Found 26 objects.
#
# ===  Found a TOTAL of 97 objects in image 'u2tv1801t_c0m.fits'
#
#
#
# ===  Source finding for image 'u2tv1802t_c0m.fits':
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 1) started at: 23:33:41.347 (06/12/2017)
#
#      Found 26 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 2) started at: 23:33:41.713 (06/12/2017)
#
#      Found 12 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 3) started at: 23:33:41.956 (06/12/2017)
#
#      Found 12 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 4) started at: 23:33:42.183 (06/12/2017)
#
#      Found 18 objects.
#
# ===  Found a TOTAL of 68 objects in image 'u2tv1802t_c0m.fits'
#
#
#
#  Catalog trimmed to 97 objects
#
#
# ====================
# Aligning all input images to WCS defined by u2tv1801t_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u2tv1802t_c0m.fits
#
# Matching sources from 'u2tv1802t_c0m.fits' with sources from reference image 'u2tv1801t_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  0.0456211991482 -21.9543788009
#
#     with significance of  43.6806593357 and  1.0  matches
#
# ##############################################################################
# #                                                                            #
# # WARNING:                                                                   #
# # Not enough matches (< 15) found for input image: u2tv1802t_c0m.fits        #
# #                                                                            #
# ##############################################################################
# Unable to match the following images:
#
# -------------------------------------
#
# u2tv1802t_c0m.fits
#
#
# Writing out shiftfile : 9shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# nan

# %%
# change to a jupyter table
dt=test.to_pandas()
dt.to_pickle('data.pickle')
good_table=pandas.read_pickle('data.pickle')

# %%
# take only unfailed sessions
good_roundlo = good_table[good_table['y_rms'] != 'failed']

# %%
good_roundlo
# Out:
#          shift                file     x_rms     y_rms  threshold  conv_width  \
# 0   1shift.txt  u2tv1801t_c0m.fits  0.000000  0.000000          7         3.5
# 1   1shift.txt  u2tv1802t_c0m.fits  0.174253  0.170048          7         3.5
# 2   2shift.txt  u2tv1801t_c0m.fits  0.000000  0.000000          7         3.5
# 3   2shift.txt  u2tv1802t_c0m.fits  0.173394  0.177978          7         3.5
# 4   3shift.txt  u2tv1801t_c0m.fits  0.000000  0.000000          7         3.5
# 5   3shift.txt  u2tv1802t_c0m.fits  0.175880  0.186282          7         3.5
# 6   4shift.txt  u2tv1801t_c0m.fits  0.000000  0.000000          7         3.5
# 7   4shift.txt  u2tv1802t_c0m.fits  0.150941  0.175060          7         3.5
# 8   5shift.txt  u2tv1801t_c0m.fits  0.000000  0.000000          7         3.5
# 9   5shift.txt  u2tv1802t_c0m.fits  0.117607  0.125786          7         3.5
# 10  6shift.txt  u2tv1801t_c0m.fits  0.000000  0.000000          7         3.5
# 12  7shift.txt  u2tv1801t_c0m.fits  0.000000  0.000000          7         3.5
# 14  8shift.txt  u2tv1801t_c0m.fits  0.000000  0.000000          7         3.5
# 16  9shift.txt  u2tv1801t_c0m.fits  0.000000  0.000000          7         3.5
#
#     roundlo  roundhi  peakmax
# 0      -0.5        1     1000
# 1      -0.5        1     1000
# 2      -0.4        1     1000
# 3      -0.4        1     1000
# 4      -0.3        1     1000
# 5      -0.3        1     1000
# 6      -0.2        1     1000
# 7      -0.2        1     1000
# 8      -0.1        1     1000
# 9      -0.1        1     1000
# 10      0.0        1     1000
# 12      0.1        1     1000
# 14      0.2        1     1000
# 16      0.3        1     1000

# %%
# plot figure for all sub-exp ??????????????????????????????????????????
plt.figure(figsize = (7,7))
plt.plot(good_roundlo['roundlo'],good_roundlo['x_rms'],'.g')
plt.plot(good_roundlo['roundlo'],good_roundlo['y_rms'],'.b')
plt.title('x,y_rms(roundlo)-g,b')
plt.show()

# %%
# plot figure for choosen sub-exp
plt.figure(figsize = (7,7))
plt.plot(good_round[good_round['file'] == 'u6ea5402m_c0m.fits']['roundlo'],good_round[good_round['file'] == 'u6ea5402m_c0m.fits']['y_rms'],'.b')
plt.plot(good_round[good_round['file'] == 'u6ea5403m_c0m.fits']['roundlo'],good_round[good_round['file'] == 'u6ea5403m_c0m.fits']['y_rms'],'.g')
plt.title('y_rms(roundlo)-two filters')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-1b5e9d62f47a> in <module>()
#       1 # plot figure for choosen sub-exp
#       2 plt.figure(figsize = (7,7))
# ----> 3 plt.plot(good_round[good_round['file'] == 'u6ea5402m_c0m.fits']['roundlo'],good_round[good_round['file'] == 'u6ea5402m_c0m.fits']['y_rms'],'.b')
#       4 plt.plot(good_round[good_round['file'] == 'u6ea5403m_c0m.fits']['roundlo'],good_round[good_round['file'] == 'u6ea5403m_c0m.fits']['y_rms'],'.g')
#       5 plt.title('y_rms(roundlo)-two filters')
#
# NameError: name 'good_round' is not defined

# %%
#############################################thresh = 7, conv = 3.5, roundlo = -0.1, roundhi?

# %%
# tweak_run(path, n_up, threshold_ini, threshold_gap, conv_width_ini, conv_width_gap, 
# roundlo_val_ini, roundlo_gap, roundhi_val_ini, roundhi_gap, peakmax_val_ini, peakmax_gap):
test = tweak_run('/Users/natalie/anaconda2/envs/iraf27/iraf/sn/2000ds/2000ds_pre/tweak_814_1',10,7,0,3.5,0,-0.1,0,0.5,0.1,1000,0)
# Out:
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 23:42:46.312 (06/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u2tv1801t_c0m.fits
#
#     u2tv1802t_c0m.fits
#
# ===  Source finding for image 'u2tv1801t_c0m.fits':
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 1) started at: 23:42:46.796 (06/12/2017)
#
#      Found 83 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 2) started at: 23:42:47.234 (06/12/2017)
#
#      Found 65 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 3) started at: 23:42:47.474 (06/12/2017)
#
#      Found 88 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 4) started at: 23:42:47.890 (06/12/2017)
#
#      Found 99 objects.
#
# ===  Found a TOTAL of 335 objects in image 'u2tv1801t_c0m.fits'
#
#
#
# ===  Source finding for image 'u2tv1802t_c0m.fits':
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 1) started at: 23:42:48.544 (06/12/2017)
#
#      Found 92 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 2) started at: 23:42:49.006 (06/12/2017)
#
#      Found 53 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 3) started at: 23:42:49.309 (06/12/2017)
#
#      Found 62 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 4) started at: 23:42:49.60 (06/12/2017)
#
#      Found 109 objects.
#
# ===  Found a TOTAL of 316 objects in image 'u2tv1802t_c0m.fits'
#
#
#
#  Catalog trimmed to 335 objects
#
#
# ====================
# Aligning all input images to WCS defined by u2tv1801t_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u2tv1802t_c0m.fits
#
# Matching sources from 'u2tv1802t_c0m.fits' with sources from reference image 'u2tv1801t_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.516878800852 -0.735628800852
#
#     with significance of  296.363413274 and  10.0  matches
#
# Found 28 matches for u2tv1802t_c0m.fits...
#
# Computed  rscale  fit for  u2tv1802t_c0m.fits :
#
# XSH: 0.0190406  YSH: 0.0286397    ROT: 360    SCALE: 1.00002
#
# XRMS: 0.121205    YRMS: 0.156792
#
# RMS_RA: 5.02095e-06 (deg)   RMS_DEC: 4.93146e-08 (deg)
#
# Final solution based on  28  objects.
#
# wrote XY data to:  u2tv1802t_c0m_catalog_fit.match
#
# Writing out shiftfile : 1shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 0.019041
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 23:42:50.548 (06/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u2tv1801t_c0m.fits
#
#     u2tv1802t_c0m.fits
#
# ===  Source finding for image 'u2tv1801t_c0m.fits':
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 1) started at: 23:42:50.880 (06/12/2017)
#
#      Found 100 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 2) started at: 23:42:51.364 (06/12/2017)
#
#      Found 75 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 3) started at: 23:42:51.669 (06/12/2017)
#
#      Found 94 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 4) started at: 23:42:52.065 (06/12/2017)
#
#      Found 110 objects.
#
# ===  Found a TOTAL of 379 objects in image 'u2tv1801t_c0m.fits'
#
#
#
# ===  Source finding for image 'u2tv1802t_c0m.fits':
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 1) started at: 23:42:52.648 (06/12/2017)
#
#      Found 109 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 2) started at: 23:42:53.062 (06/12/2017)
#
#      Found 54 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 3) started at: 23:42:53.339 (06/12/2017)
#
#      Found 66 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 4) started at: 23:42:53.680 (06/12/2017)
#
#      Found 121 objects.
#
# ===  Found a TOTAL of 350 objects in image 'u2tv1802t_c0m.fits'
#
#
#
#  Catalog trimmed to 379 objects
#
#
# ====================
# Aligning all input images to WCS defined by u2tv1801t_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u2tv1802t_c0m.fits
#
# Matching sources from 'u2tv1802t_c0m.fits' with sources from reference image 'u2tv1801t_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.554378800852 -0.782950229423
#
#     with significance of  310.347587392 and  11.0  matches
#
# Found 31 matches for u2tv1802t_c0m.fits...
#
# Computed  rscale  fit for  u2tv1802t_c0m.fits :
#
# XSH: 0.0196666  YSH: 0.0281001    ROT: 360    SCALE: 1.00002
#
# XRMS: 0.119226    YRMS: 0.154192
#
# RMS_RA: 4.93815e-06 (deg)   RMS_DEC: 4.88167e-08 (deg)
#
# Final solution based on  29  objects.
#
# wrote XY data to:  u2tv1802t_c0m_catalog_fit.match
#
# Writing out shiftfile : 2shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 0.019667
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 23:42:54.381 (06/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u2tv1801t_c0m.fits
#
#     u2tv1802t_c0m.fits
#
# ===  Source finding for image 'u2tv1801t_c0m.fits':
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 1) started at: 23:42:54.602 (06/12/2017)
#
#      Found 108 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 2) started at: 23:42:54.992 (06/12/2017)
#
#      Found 78 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 3) started at: 23:42:55.215 (06/12/2017)
#
#      Found 104 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 4) started at: 23:42:55.45 (06/12/2017)
#
#      Found 120 objects.
#
# ===  Found a TOTAL of 410 objects in image 'u2tv1801t_c0m.fits'
#
#
#
# ===  Source finding for image 'u2tv1802t_c0m.fits':
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 1) started at: 23:42:56.008 (06/12/2017)
#
#      Found 119 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 2) started at: 23:42:56.369 (06/12/2017)
#
#      Found 58 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 3) started at: 23:42:56.56 (06/12/2017)
#
#      Found 71 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 4) started at: 23:42:56.820 (06/12/2017)
#
#      Found 133 objects.
#
# ===  Found a TOTAL of 381 objects in image 'u2tv1802t_c0m.fits'
#
#
#
#  Catalog trimmed to 410 objects
#
#
# ====================
# Aligning all input images to WCS defined by u2tv1801t_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u2tv1802t_c0m.fits
#
# Matching sources from 'u2tv1802t_c0m.fits' with sources from reference image 'u2tv1801t_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.467892314365 -0.846270692744
#
#     with significance of  315.21073537 and  11.0  matches
#
# Found 31 matches for u2tv1802t_c0m.fits...
#
# Computed  rscale  fit for  u2tv1802t_c0m.fits :
#
# XSH: 0.0196666  YSH: 0.0281001    ROT: 360    SCALE: 1.00002
#
# XRMS: 0.119226    YRMS: 0.154192
#
# RMS_RA: 4.93815e-06 (deg)   RMS_DEC: 4.88167e-08 (deg)
#
# Final solution based on  29  objects.
#
# wrote XY data to:  u2tv1802t_c0m_catalog_fit.match
#
# Writing out shiftfile : 3shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 0.019667
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 23:42:57.474 (06/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u2tv1801t_c0m.fits
#
#     u2tv1802t_c0m.fits
#
# ===  Source finding for image 'u2tv1801t_c0m.fits':
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 1) started at: 23:42:57.67 (06/12/2017)
#
#      Found 123 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 2) started at: 23:42:58.008 (06/12/2017)
#
#      Found 82 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 3) started at: 23:42:58.195 (06/12/2017)
#
#      Found 111 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 4) started at: 23:42:58.414 (06/12/2017)
#
#      Found 126 objects.
#
# ===  Found a TOTAL of 442 objects in image 'u2tv1801t_c0m.fits'
#
#
#
# ===  Source finding for image 'u2tv1802t_c0m.fits':
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 1) started at: 23:42:58.897 (06/12/2017)
#
#      Found 133 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 2) started at: 23:42:59.248 (06/12/2017)
#
#      Found 62 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 3) started at: 23:42:59.461 (06/12/2017)
#
#      Found 75 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 4) started at: 23:42:59.732 (06/12/2017)
#
#      Found 139 objects.
#
# ===  Found a TOTAL of 409 objects in image 'u2tv1802t_c0m.fits'
#
#
#
#  Catalog trimmed to 442 objects
#
#
# ====================
# Aligning all input images to WCS defined by u2tv1801t_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u2tv1802t_c0m.fits
#
# Matching sources from 'u2tv1802t_c0m.fits' with sources from reference image 'u2tv1801t_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.559641958747 -0.849115642957
#
#     with significance of  317.678383834 and  11.0  matches
#
# Found 31 matches for u2tv1802t_c0m.fits...
#
# Computed  rscale  fit for  u2tv1802t_c0m.fits :
#
# XSH: 0.0196666  YSH: 0.0281001    ROT: 360    SCALE: 1.00002
#
# XRMS: 0.119226    YRMS: 0.154192
#
# RMS_RA: 4.93815e-06 (deg)   RMS_DEC: 4.88167e-08 (deg)
#
# Final solution based on  29  objects.
#
# wrote XY data to:  u2tv1802t_c0m_catalog_fit.match
#
# Writing out shiftfile : 4shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 0.019667
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 23:43:00.572 (06/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u2tv1801t_c0m.fits
#
#     u2tv1802t_c0m.fits
#
# ===  Source finding for image 'u2tv1801t_c0m.fits':
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 1) started at: 23:43:00.812 (06/12/2017)
#
#      Found 143 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 2) started at: 23:43:01.182 (06/12/2017)
#
#      Found 85 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 3) started at: 23:43:01.421 (06/12/2017)
#
#      Found 117 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 4) started at: 23:43:01.649 (06/12/2017)
#
#      Found 137 objects.
#
# ===  Found a TOTAL of 482 objects in image 'u2tv1801t_c0m.fits'
#
#
#
# ===  Source finding for image 'u2tv1802t_c0m.fits':
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 1) started at: 23:43:02.195 (06/12/2017)
#
#      Found 143 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 2) started at: 23:43:02.610 (06/12/2017)
#
#      Found 65 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 3) started at: 23:43:02.856 (06/12/2017)
#
#      Found 78 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 4) started at: 23:43:03.10 (06/12/2017)
#
#      Found 144 objects.
#
# ===  Found a TOTAL of 430 objects in image 'u2tv1802t_c0m.fits'
#
#
#
#  Catalog trimmed to 482 objects
#
#
# ====================
# Aligning all input images to WCS defined by u2tv1801t_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u2tv1802t_c0m.fits
#
# Matching sources from 'u2tv1802t_c0m.fits' with sources from reference image 'u2tv1801t_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.692474038947 -0.859140705614
#
#     with significance of  303.33762425 and  11.0  matches
#
# Found 31 matches for u2tv1802t_c0m.fits...
#
# Computed  rscale  fit for  u2tv1802t_c0m.fits :
#
# XSH: 0.0196666  YSH: 0.0281001    ROT: 360    SCALE: 1.00002
#
# XRMS: 0.119226    YRMS: 0.154192
#
# RMS_RA: 4.93815e-06 (deg)   RMS_DEC: 4.88167e-08 (deg)
#
# Final solution based on  29  objects.
#
# wrote XY data to:  u2tv1802t_c0m_catalog_fit.match
#
# Writing out shiftfile : 5shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 0.019667
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 23:43:03.753 (06/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u2tv1801t_c0m.fits
#
#     u2tv1802t_c0m.fits
#
# ===  Source finding for image 'u2tv1801t_c0m.fits':
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 1) started at: 23:43:03.975 (06/12/2017)
#
#      Found 158 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 2) started at: 23:43:04.343 (06/12/2017)
#
#      Found 87 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 3) started at: 23:43:04.554 (06/12/2017)
#
#      Found 123 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 4) started at: 23:43:04.854 (06/12/2017)
#
#      Found 146 objects.
#
# ===  Found a TOTAL of 514 objects in image 'u2tv1801t_c0m.fits'
#
#
#
# ===  Source finding for image 'u2tv1802t_c0m.fits':
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 1) started at: 23:43:05.489 (06/12/2017)
#
#      Found 152 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 2) started at: 23:43:05.852 (06/12/2017)
#
#      Found 70 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 3) started at: 23:43:06.065 (06/12/2017)
#
#      Found 79 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 4) started at: 23:43:06.288 (06/12/2017)
#
#      Found 150 objects.
#
# ===  Found a TOTAL of 451 objects in image 'u2tv1802t_c0m.fits'
#
#
#
#  Catalog trimmed to 514 objects
#
#
# ====================
# Aligning all input images to WCS defined by u2tv1801t_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u2tv1802t_c0m.fits
#
# Matching sources from 'u2tv1802t_c0m.fits' with sources from reference image 'u2tv1801t_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.845683148678 -0.976117931287
#
#     with significance of  307.964707182 and  11.0  matches
#
# Found 29 matches for u2tv1802t_c0m.fits...
#
# Computed  rscale  fit for  u2tv1802t_c0m.fits :
#
# XSH: 0.00843292  YSH: -0.0126417    ROT: 359.999    SCALE: 1.00001
#
# XRMS: 0.117607    YRMS: 0.125786
#
# RMS_RA: 4.33566e-06 (deg)   RMS_DEC: 2.46535e-07 (deg)
#
# Final solution based on  26  objects.
#
# wrote XY data to:  u2tv1802t_c0m_catalog_fit.match
#
# Writing out shiftfile : 6shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 0.008433
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 23:43:06.992 (06/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
# Finding shifts for:
#
#     u2tv1801t_c0m.fits
#
#     u2tv1802t_c0m.fits
#
# ===  Source finding for image 'u2tv1801t_c0m.fits':
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 1) started at: 23:43:07.22 (06/12/2017)
#
#      Found 170 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 2) started at: 23:43:07.665 (06/12/2017)
#
#      Found 88 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 3) started at: 23:43:07.870 (06/12/2017)
#
#      Found 124 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 4) started at: 23:43:08.112 (06/12/2017)
#
#      Found 150 objects.
#
# ===  Found a TOTAL of 532 objects in image 'u2tv1801t_c0m.fits'
#
#
#
# ===  Source finding for image 'u2tv1802t_c0m.fits':
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 1) started at: 23:43:08.617 (06/12/2017)
#
#      Found 173 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 2) started at: 23:43:08.972 (06/12/2017)
#
#      Found 73 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 3) started at: 23:43:09.176 (06/12/2017)
#
#      Found 84 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 4) started at: 23:43:09.4 (06/12/2017)
#
#      Found 154 objects.
#
# ===  Found a TOTAL of 484 objects in image 'u2tv1802t_c0m.fits'
#
#
#
#  Catalog trimmed to 532 objects
#
#
# ====================
# Aligning all input images to WCS defined by u2tv1801t_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u2tv1802t_c0m.fits
#
# Matching sources from 'u2tv1802t_c0m.fits' with sources from reference image 'u2tv1801t_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.856339585166 -0.89555527144
#
#     with significance of  320.163295389 and  11.0  matches
#
# Found 33 matches for u2tv1802t_c0m.fits...
#
# Computed  rscale  fit for  u2tv1802t_c0m.fits :
#
# XSH: -0.0741546  YSH: -0.408411    ROT: 359.991    SCALE: 0.999842
#
# XRMS: 0.331604    YRMS: 0.616015
#
# RMS_RA: 1.75432e-05 (deg)   RMS_DEC: 1.27538e-06 (deg)
#
# Final solution based on  33  objects.
#
# wrote XY data to:  u2tv1802t_c0m_catalog_fit.match
#
# Writing out shiftfile : 7shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.074155
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 23:43:10.050 (06/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u2tv1801t_c0m.fits
#
#     u2tv1802t_c0m.fits
#
# ===  Source finding for image 'u2tv1801t_c0m.fits':
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 1) started at: 23:43:10.335 (06/12/2017)
#
#      Found 183 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 2) started at: 23:43:10.981 (06/12/2017)
#
#      Found 93 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 3) started at: 23:43:11.217 (06/12/2017)
#
#      Found 129 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 4) started at: 23:43:11.469 (06/12/2017)
#
#      Found 156 objects.
#
# ===  Found a TOTAL of 561 objects in image 'u2tv1801t_c0m.fits'
#
#
#
# ===  Source finding for image 'u2tv1802t_c0m.fits':
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 1) started at: 23:43:11.871 (06/12/2017)
#
#      Found 178 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 2) started at: 23:43:12.226 (06/12/2017)
#
#      Found 76 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 3) started at: 23:43:12.42 (06/12/2017)
#
#      Found 88 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 4) started at: 23:43:12.647 (06/12/2017)
#
#      Found 157 objects.
#
# ===  Found a TOTAL of 499 objects in image 'u2tv1802t_c0m.fits'
#
#
#
#  Catalog trimmed to 561 objects
#
#
# ====================
# Aligning all input images to WCS defined by u2tv1801t_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u2tv1802t_c0m.fits
#
# Matching sources from 'u2tv1802t_c0m.fits' with sources from reference image 'u2tv1801t_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.918664515138 -0.811521657995
#
#     with significance of  335.242449579 and  11.0  matches
#
# Found 34 matches for u2tv1802t_c0m.fits...
#
# Computed  rscale  fit for  u2tv1802t_c0m.fits :
#
# XSH: -0.0715757  YSH: -0.377128    ROT: 359.992    SCALE: 0.99985
#
# XRMS: 0.326135    YRMS: 0.621142
#
# RMS_RA: 1.75649e-05 (deg)   RMS_DEC: 1.36961e-06 (deg)
#
# Final solution based on  34  objects.
#
# wrote XY data to:  u2tv1802t_c0m_catalog_fit.match
#
# Writing out shiftfile : 8shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.071576
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 23:43:13.298 (06/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u2tv1801t_c0m.fits
#
#     u2tv1802t_c0m.fits
#
# ===  Source finding for image 'u2tv1801t_c0m.fits':
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 1) started at: 23:43:13.50 (06/12/2017)
#
#      Found 194 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 2) started at: 23:43:13.902 (06/12/2017)
#
#      Found 94 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 3) started at: 23:43:14.102 (06/12/2017)
#
#      Found 133 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 4) started at: 23:43:14.32 (06/12/2017)
#
#      Found 159 objects.
#
# ===  Found a TOTAL of 580 objects in image 'u2tv1801t_c0m.fits'
#
#
#
# ===  Source finding for image 'u2tv1802t_c0m.fits':
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 1) started at: 23:43:14.780 (06/12/2017)
#
#      Found 185 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 2) started at: 23:43:15.136 (06/12/2017)
#
#      Found 79 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 3) started at: 23:43:15.350 (06/12/2017)
#
#      Found 91 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 4) started at: 23:43:15.580 (06/12/2017)
#
#      Found 161 objects.
#
# ===  Found a TOTAL of 516 objects in image 'u2tv1802t_c0m.fits'
#
#
#
#  Catalog trimmed to 580 objects
#
#
# ====================
# Aligning all input images to WCS defined by u2tv1801t_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u2tv1802t_c0m.fits
#
# Matching sources from 'u2tv1802t_c0m.fits' with sources from reference image 'u2tv1801t_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.645287891761 -0.772560619034
#
#     with significance of  342.692281792 and  12.0  matches
#
# Found 34 matches for u2tv1802t_c0m.fits...
#
# Computed  rscale  fit for  u2tv1802t_c0m.fits :
#
# XSH: 0.036026  YSH: -0.0414584    ROT: 360    SCALE: 0.999995
#
# XRMS: 0.122329    YRMS: 0.271767
#
# RMS_RA: 7.37762e-06 (deg)   RMS_DEC: 8.06155e-07 (deg)
#
# Final solution based on  31  objects.
#
# wrote XY data to:  u2tv1802t_c0m_catalog_fit.match
#
# Writing out shiftfile : 9shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 0.036026

# %%
# change to a jupyter table
dt=test.to_pandas()
dt.to_pickle('data.pickle')
good_table=pandas.read_pickle('data.pickle')

# %%
# take only unfailed sessions
good_roundhi = good_table[good_table['y_rms'] != 'failed']

# %%
good_roundhi
# Out:
#          shift                file     x_rms     y_rms  threshold  conv_width  \
# 0   1shift.txt  u2tv1801t_c0m.fits  0.000000  0.000000          7         3.5
# 1   1shift.txt  u2tv1802t_c0m.fits  0.121205  0.156792          7         3.5
# 2   2shift.txt  u2tv1801t_c0m.fits  0.000000  0.000000          7         3.5
# 3   2shift.txt  u2tv1802t_c0m.fits  0.119226  0.154192          7         3.5
# 4   3shift.txt  u2tv1801t_c0m.fits  0.000000  0.000000          7         3.5
# 5   3shift.txt  u2tv1802t_c0m.fits  0.119226  0.154192          7         3.5
# 6   4shift.txt  u2tv1801t_c0m.fits  0.000000  0.000000          7         3.5
# 7   4shift.txt  u2tv1802t_c0m.fits  0.119226  0.154192          7         3.5
# 8   5shift.txt  u2tv1801t_c0m.fits  0.000000  0.000000          7         3.5
# 9   5shift.txt  u2tv1802t_c0m.fits  0.119226  0.154192          7         3.5
# 10  6shift.txt  u2tv1801t_c0m.fits  0.000000  0.000000          7         3.5
# 11  6shift.txt  u2tv1802t_c0m.fits  0.117607  0.125786          7         3.5
# 12  7shift.txt  u2tv1801t_c0m.fits  0.000000  0.000000          7         3.5
# 13  7shift.txt  u2tv1802t_c0m.fits  0.331604  0.616015          7         3.5
# 14  8shift.txt  u2tv1801t_c0m.fits  0.000000  0.000000          7         3.5
# 15  8shift.txt  u2tv1802t_c0m.fits  0.326135  0.621142          7         3.5
# 16  9shift.txt  u2tv1801t_c0m.fits  0.000000  0.000000          7         3.5
# 17  9shift.txt  u2tv1802t_c0m.fits  0.122329  0.271767          7         3.5
#
#     roundlo  roundhi  peakmax
# 0      -0.1      0.5     1000
# 1      -0.1      0.5     1000
# 2      -0.1      0.6     1000
# 3      -0.1      0.6     1000
# 4      -0.1      0.7     1000
# 5      -0.1      0.7     1000
# 6      -0.1      0.8     1000
# 7      -0.1      0.8     1000
# 8      -0.1      0.9     1000
# 9      -0.1      0.9     1000
# 10     -0.1      1.0     1000
# 11     -0.1      1.0     1000
# 12     -0.1      1.1     1000
# 13     -0.1      1.1     1000
# 14     -0.1      1.2     1000
# 15     -0.1      1.2     1000
# 16     -0.1      1.3     1000
# 17     -0.1      1.3     1000

# %%
# plot figure for all sub-exp ??????????????????????????????????????????
plt.figure(figsize = (7,7))
plt.plot(good_roundhi['roundhi'],good_roundhi['x_rms'],'.g')
plt.plot(good_roundhi['roundhi'],good_roundhi['y_rms'],'.b')
plt.title('x,y_rms(roundhi)-g,b')
plt.show()

# %%
# plot figure for choosen sub-exp
plt.figure(figsize = (7,7))
plt.plot(good_round[good_round['file'] == 'u6ea5402m_c0m.fits']['roundhi'],good_round[good_round['file'] == 'u6ea5402m_c0m.fits']['y_rms'],'.b')
plt.plot(good_round[good_round['file'] == 'u6ea5403m_c0m.fits']['roundhi'],good_round[good_round['file'] == 'u6ea5403m_c0m.fits']['y_rms'],'.g')
plt.title('y_rms(roundhi)-two filters')
plt.show()

# %%
#############################################thresh = 7, conv = 3.5 roundnlo = -0.1, rounfhi = 1, peakmax?

# %%
# tweak_run(path, n_up, threshold_ini, threshold_gap, conv_width_ini, conv_width_gap, 
# roundlo_val_ini, roundlo_gap, roundhi_val_ini, roundhi_gap, peakmax_val_ini, peakmax_gap):
test = tweak_run('/Users/natalie/anaconda2/envs/iraf27/iraf/sn/2000ds/2000ds_pre/tweak_814_1',10,7,0,3.5,0,-0.1,0,1.0,0,2500,500)
# Out:
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 23:51:34.976 (06/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u2tv1801t_c0m.fits
#
#     u2tv1802t_c0m.fits
#
# ===  Source finding for image 'u2tv1801t_c0m.fits':
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 1) started at: 23:51:35.289 (06/12/2017)
#
#      Found 159 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 2) started at: 23:51:35.687 (06/12/2017)
#
#      Found 88 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 3) started at: 23:51:35.981 (06/12/2017)
#
#      Found 125 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 4) started at: 23:51:36.287 (06/12/2017)
#
#      Found 149 objects.
#
# ===  Found a TOTAL of 521 objects in image 'u2tv1801t_c0m.fits'
#
#
#
# ===  Source finding for image 'u2tv1802t_c0m.fits':
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 1) started at: 23:51:36.767 (06/12/2017)
#
#      Found 154 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 2) started at: 23:51:37.157 (06/12/2017)
#
#      Found 71 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 3) started at: 23:51:37.42 (06/12/2017)
#
#      Found 79 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 4) started at: 23:51:37 (06/12/2017)
#
#      Found 153 objects.
#
# ===  Found a TOTAL of 457 objects in image 'u2tv1802t_c0m.fits'
#
#
#
#  Catalog trimmed to 521 objects
#
#
# ====================
# Aligning all input images to WCS defined by u2tv1801t_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u2tv1802t_c0m.fits
#
# Matching sources from 'u2tv1802t_c0m.fits' with sources from reference image 'u2tv1801t_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.845683148678 -0.976117931287
#
#     with significance of  307.964707182 and  11.0  matches
#
# Found 29 matches for u2tv1802t_c0m.fits...
#
# Computed  rscale  fit for  u2tv1802t_c0m.fits :
#
# XSH: 0.00843292  YSH: -0.0126417    ROT: 359.999    SCALE: 1.00001
#
# XRMS: 0.117607    YRMS: 0.125786
#
# RMS_RA: 4.33566e-06 (deg)   RMS_DEC: 2.46535e-07 (deg)
#
# Final solution based on  26  objects.
#
# wrote XY data to:  u2tv1802t_c0m_catalog_fit.match
#
# Writing out shiftfile : 1shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 0.008433
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 23:51:38.491 (06/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u2tv1801t_c0m.fits
#
#     u2tv1802t_c0m.fits
#
# ===  Source finding for image 'u2tv1801t_c0m.fits':
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 1) started at: 23:51:38.743 (06/12/2017)
#
#      Found 159 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 2) started at: 23:51:39.164 (06/12/2017)
#
#      Found 88 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 3) started at: 23:51:39.401 (06/12/2017)
#
#      Found 125 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 4) started at: 23:51:39.644 (06/12/2017)
#
#      Found 149 objects.
#
# ===  Found a TOTAL of 521 objects in image 'u2tv1801t_c0m.fits'
#
#
#
# ===  Source finding for image 'u2tv1802t_c0m.fits':
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 1) started at: 23:51:40.124 (06/12/2017)
#
#      Found 155 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 2) started at: 23:51:40.497 (06/12/2017)
#
#      Found 71 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 3) started at: 23:51:40.721 (06/12/2017)
#
#      Found 80 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 4) started at: 23:51:40.977 (06/12/2017)
#
#      Found 153 objects.
#
# ===  Found a TOTAL of 459 objects in image 'u2tv1802t_c0m.fits'
#
#
#
#  Catalog trimmed to 521 objects
#
#
# ====================
# Aligning all input images to WCS defined by u2tv1801t_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u2tv1802t_c0m.fits
#
# Matching sources from 'u2tv1802t_c0m.fits' with sources from reference image 'u2tv1801t_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.845683148678 -0.976117931287
#
#     with significance of  307.964707182 and  11.0  matches
#
# Found 29 matches for u2tv1802t_c0m.fits...
#
# Computed  rscale  fit for  u2tv1802t_c0m.fits :
#
# XSH: 0.00843292  YSH: -0.0126417    ROT: 359.999    SCALE: 1.00001
#
# XRMS: 0.117607    YRMS: 0.125786
#
# RMS_RA: 4.33566e-06 (deg)   RMS_DEC: 2.46535e-07 (deg)
#
# Final solution based on  26  objects.
#
# wrote XY data to:  u2tv1802t_c0m_catalog_fit.match
#
# Writing out shiftfile : 2shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 0.008433
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 23:51:41.681 (06/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u2tv1801t_c0m.fits
#
#     u2tv1802t_c0m.fits
#
# ===  Source finding for image 'u2tv1801t_c0m.fits':
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 1) started at: 23:51:41.921 (06/12/2017)
#
#      Found 159 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 2) started at: 23:51:42.344 (06/12/2017)
#
#      Found 89 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 3) started at: 23:51:42.563 (06/12/2017)
#
#      Found 125 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 4) started at: 23:51:42.856 (06/12/2017)
#
#      Found 149 objects.
#
# ===  Found a TOTAL of 522 objects in image 'u2tv1801t_c0m.fits'
#
#
#
# ===  Source finding for image 'u2tv1802t_c0m.fits':
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 1) started at: 23:51:43.302 (06/12/2017)
#
#      Found 156 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 2) started at: 23:51:43.657 (06/12/2017)
#
#      Found 71 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 3) started at: 23:51:43.874 (06/12/2017)
#
#      Found 80 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 4) started at: 23:51:44.109 (06/12/2017)
#
#      Found 153 objects.
#
# ===  Found a TOTAL of 460 objects in image 'u2tv1802t_c0m.fits'
#
#
#
#  Catalog trimmed to 522 objects
#
#
# ====================
# Aligning all input images to WCS defined by u2tv1801t_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u2tv1802t_c0m.fits
#
# Matching sources from 'u2tv1802t_c0m.fits' with sources from reference image 'u2tv1801t_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.845683148678 -0.976117931287
#
#     with significance of  307.964707182 and  11.0  matches
#
# Found 29 matches for u2tv1802t_c0m.fits...
#
# Computed  rscale  fit for  u2tv1802t_c0m.fits :
#
# XSH: 0.00843292  YSH: -0.0126417    ROT: 359.999    SCALE: 1.00001
#
# XRMS: 0.117607    YRMS: 0.125786
#
# RMS_RA: 4.33566e-06 (deg)   RMS_DEC: 2.46535e-07 (deg)
#
# Final solution based on  26  objects.
#
# wrote XY data to:  u2tv1802t_c0m_catalog_fit.match
#
# Writing out shiftfile : 3shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 0.008433
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 23:51:44.823 (06/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u2tv1801t_c0m.fits
#
#     u2tv1802t_c0m.fits
#
# ===  Source finding for image 'u2tv1801t_c0m.fits':
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 1) started at: 23:51:45.09 (06/12/2017)
#
#      Found 160 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 2) started at: 23:51:45.494 (06/12/2017)
#
#      Found 90 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 3) started at: 23:51:45.709 (06/12/2017)
#
#      Found 125 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 4) started at: 23:51:45.951 (06/12/2017)
#
#      Found 150 objects.
#
# ===  Found a TOTAL of 525 objects in image 'u2tv1801t_c0m.fits'
#
#
#
# ===  Source finding for image 'u2tv1802t_c0m.fits':
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 1) started at: 23:51:46.443 (06/12/2017)
#
#      Found 157 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 2) started at: 23:51:46.816 (06/12/2017)
#
#      Found 74 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 3) started at: 23:51:47.036 (06/12/2017)
#
#      Found 80 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 4) started at: 23:51:47.294 (06/12/2017)
#
#      Found 153 objects.
#
# ===  Found a TOTAL of 464 objects in image 'u2tv1802t_c0m.fits'
#
#
#
#  Catalog trimmed to 525 objects
#
#
# ====================
# Aligning all input images to WCS defined by u2tv1801t_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u2tv1802t_c0m.fits
#
# Matching sources from 'u2tv1802t_c0m.fits' with sources from reference image 'u2tv1801t_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.847995822128 -0.975655396597
#
#     with significance of  317.022492687 and  12.0  matches
#
# Found 30 matches for u2tv1802t_c0m.fits...
#
# Computed  rscale  fit for  u2tv1802t_c0m.fits :
#
# XSH: 0.0121239  YSH: -0.0124761    ROT: 359.999    SCALE: 1.00001
#
# XRMS: 0.116002    YRMS: 0.1232
#
# RMS_RA: 4.25878e-06 (deg)   RMS_DEC: 2.49732e-07 (deg)
#
# Final solution based on  27  objects.
#
# wrote XY data to:  u2tv1802t_c0m_catalog_fit.match
#
# Writing out shiftfile : 4shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 0.012124
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 23:51:47.976 (06/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u2tv1801t_c0m.fits
#
#     u2tv1802t_c0m.fits
#
# ===  Source finding for image 'u2tv1801t_c0m.fits':
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 1) started at: 23:51:48.219 (06/12/2017)
#
#      Found 160 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 2) started at: 23:51:48.638 (06/12/2017)
#
#      Found 90 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 3) started at: 23:51:48.862 (06/12/2017)
#
#      Found 126 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 4) started at: 23:51:49.158 (06/12/2017)
#
#      Found 150 objects.
#
# ===  Found a TOTAL of 526 objects in image 'u2tv1801t_c0m.fits'
#
#
#
# ===  Source finding for image 'u2tv1802t_c0m.fits':
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 1) started at: 23:51:49.591 (06/12/2017)
#
#      Found 157 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 2) started at: 23:51:49.962 (06/12/2017)
#
#      Found 74 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 3) started at: 23:51:50.177 (06/12/2017)
#
#      Found 80 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 4) started at: 23:51:50.421 (06/12/2017)
#
#      Found 154 objects.
#
# ===  Found a TOTAL of 465 objects in image 'u2tv1802t_c0m.fits'
#
#
#
#  Catalog trimmed to 526 objects
#
#
# ====================
# Aligning all input images to WCS defined by u2tv1801t_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u2tv1802t_c0m.fits
#
# Matching sources from 'u2tv1802t_c0m.fits' with sources from reference image 'u2tv1801t_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.847995822128 -0.975655396597
#
#     with significance of  317.022492687 and  12.0  matches
#
# Found 30 matches for u2tv1802t_c0m.fits...
#
# Computed  rscale  fit for  u2tv1802t_c0m.fits :
#
# XSH: 0.0121239  YSH: -0.0124761    ROT: 359.999    SCALE: 1.00001
#
# XRMS: 0.116002    YRMS: 0.1232
#
# RMS_RA: 4.25878e-06 (deg)   RMS_DEC: 2.49732e-07 (deg)
#
# Final solution based on  27  objects.
#
# wrote XY data to:  u2tv1802t_c0m_catalog_fit.match
#
# Writing out shiftfile : 5shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 0.012124
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 23:51:51.153 (06/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u2tv1801t_c0m.fits
#
#     u2tv1802t_c0m.fits
#
# ===  Source finding for image 'u2tv1801t_c0m.fits':
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 1) started at: 23:51:51.391 (06/12/2017)
#
#      Found 160 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 2) started at: 23:51:51.750 (06/12/2017)
#
#      Found 90 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 3) started at: 23:51:52.018 (06/12/2017)
#
#      Found 126 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 4) started at: 23:51:52.252 (06/12/2017)
#
#      Found 151 objects.
#
# ===  Found a TOTAL of 527 objects in image 'u2tv1801t_c0m.fits'
#
#
#
# ===  Source finding for image 'u2tv1802t_c0m.fits':
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 1) started at: 23:51:52.741 (06/12/2017)
#
#      Found 157 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 2) started at: 23:51:53.108 (06/12/2017)
#
#      Found 74 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 3) started at: 23:51:53.319 (06/12/2017)
#
#      Found 80 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 4) started at: 23:51:53.555 (06/12/2017)
#
#      Found 154 objects.
#
# ===  Found a TOTAL of 465 objects in image 'u2tv1802t_c0m.fits'
#
#
#
#  Catalog trimmed to 527 objects
#
#
# ====================
# Aligning all input images to WCS defined by u2tv1801t_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u2tv1802t_c0m.fits
#
# Matching sources from 'u2tv1802t_c0m.fits' with sources from reference image 'u2tv1801t_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.847995822128 -0.975655396597
#
#     with significance of  317.022492687 and  12.0  matches
#
# Found 30 matches for u2tv1802t_c0m.fits...
#
# Computed  rscale  fit for  u2tv1802t_c0m.fits :
#
# XSH: 0.0121239  YSH: -0.0124761    ROT: 359.999    SCALE: 1.00001
#
# XRMS: 0.116002    YRMS: 0.1232
#
# RMS_RA: 4.25878e-06 (deg)   RMS_DEC: 2.49732e-07 (deg)
#
# Final solution based on  27  objects.
#
# wrote XY data to:  u2tv1802t_c0m_catalog_fit.match
#
# Writing out shiftfile : 6shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 0.012124
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 23:51:54.254 (06/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u2tv1801t_c0m.fits
#
#     u2tv1802t_c0m.fits
#
# ===  Source finding for image 'u2tv1801t_c0m.fits':
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 1) started at: 23:51:54.516 (06/12/2017)
#
#      Found 160 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 2) started at: 23:51:54.933 (06/12/2017)
#
#      Found 90 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 3) started at: 23:51:55.159 (06/12/2017)
#
#      Found 126 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 4) started at: 23:51:55.460 (06/12/2017)
#
#      Found 151 objects.
#
# ===  Found a TOTAL of 527 objects in image 'u2tv1801t_c0m.fits'
#
#
#
# ===  Source finding for image 'u2tv1802t_c0m.fits':
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 1) started at: 23:51:55.923 (06/12/2017)
#
#      Found 158 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 2) started at: 23:51:56.287 (06/12/2017)
#
#      Found 74 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 3) started at: 23:51:56.513 (06/12/2017)
#
#      Found 80 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 4) started at: 23:51:56.75 (06/12/2017)
#
#      Found 154 objects.
#
# ===  Found a TOTAL of 466 objects in image 'u2tv1802t_c0m.fits'
#
#
#
#  Catalog trimmed to 527 objects
#
#
# ====================
# Aligning all input images to WCS defined by u2tv1801t_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u2tv1802t_c0m.fits
#
# Matching sources from 'u2tv1802t_c0m.fits' with sources from reference image 'u2tv1801t_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.847995822128 -0.975655396597
#
#     with significance of  317.022492687 and  12.0  matches
#
# Found 30 matches for u2tv1802t_c0m.fits...
#
# Computed  rscale  fit for  u2tv1802t_c0m.fits :
#
# XSH: 0.0121239  YSH: -0.0124761    ROT: 359.999    SCALE: 1.00001
#
# XRMS: 0.116002    YRMS: 0.1232
#
# RMS_RA: 4.25878e-06 (deg)   RMS_DEC: 2.49732e-07 (deg)
#
# Final solution based on  27  objects.
#
# wrote XY data to:  u2tv1802t_c0m_catalog_fit.match
#
# Writing out shiftfile : 7shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 0.012124
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 23:51:57.474 (06/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u2tv1801t_c0m.fits
#
#     u2tv1802t_c0m.fits
#
# ===  Source finding for image 'u2tv1801t_c0m.fits':
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 1) started at: 23:51:57.733 (06/12/2017)
#
#      Found 160 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 2) started at: 23:51:58.0 (06/12/2017)
#
#      Found 90 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 3) started at: 23:51:58.368 (06/12/2017)
#
#      Found 126 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 4) started at: 23:51:58.609 (06/12/2017)
#
#      Found 151 objects.
#
# ===  Found a TOTAL of 527 objects in image 'u2tv1801t_c0m.fits'
#
#
#
# ===  Source finding for image 'u2tv1802t_c0m.fits':
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 1) started at: 23:51:59.113 (06/12/2017)
#
#      Found 158 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 2) started at: 23:51:59.475 (06/12/2017)
#
#      Found 74 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 3) started at: 23:51:59.703 (06/12/2017)
#
#      Found 80 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 4) started at: 23:51:59.957 (06/12/2017)
#
#      Found 154 objects.
#
# ===  Found a TOTAL of 466 objects in image 'u2tv1802t_c0m.fits'
#
#
#
#  Catalog trimmed to 527 objects
#
#
# ====================
# Aligning all input images to WCS defined by u2tv1801t_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u2tv1802t_c0m.fits
#
# Matching sources from 'u2tv1802t_c0m.fits' with sources from reference image 'u2tv1801t_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.847995822128 -0.975655396597
#
#     with significance of  317.022492687 and  12.0  matches
#
# Found 30 matches for u2tv1802t_c0m.fits...
#
# Computed  rscale  fit for  u2tv1802t_c0m.fits :
#
# XSH: 0.0121239  YSH: -0.0124761    ROT: 359.999    SCALE: 1.00001
#
# XRMS: 0.116002    YRMS: 0.1232
#
# RMS_RA: 4.25878e-06 (deg)   RMS_DEC: 2.49732e-07 (deg)
#
# Final solution based on  27  objects.
#
# wrote XY data to:  u2tv1802t_c0m_catalog_fit.match
#
# Writing out shiftfile : 8shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 0.012124
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 23:52:00.675 (06/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u2tv1801t_c0m.fits
#
#     u2tv1802t_c0m.fits
#
# ===  Source finding for image 'u2tv1801t_c0m.fits':
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 1) started at: 23:52:00.914 (06/12/2017)
#
#      Found 160 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 2) started at: 23:52:01.32 (06/12/2017)
#
#      Found 90 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 3) started at: 23:52:01.543 (06/12/2017)
#
#      Found 126 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 4) started at: 23:52:01.825 (06/12/2017)
#
#      Found 151 objects.
#
# ===  Found a TOTAL of 527 objects in image 'u2tv1801t_c0m.fits'
#
#
#
# ===  Source finding for image 'u2tv1802t_c0m.fits':
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 1) started at: 23:52:02.284 (06/12/2017)
#
#      Found 158 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 2) started at: 23:52:02.648 (06/12/2017)
#
#      Found 74 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 3) started at: 23:52:02.869 (06/12/2017)
#
#      Found 80 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 4) started at: 23:52:03.114 (06/12/2017)
#
#      Found 154 objects.
#
# ===  Found a TOTAL of 466 objects in image 'u2tv1802t_c0m.fits'
#
#
#
#  Catalog trimmed to 527 objects
#
#
# ====================
# Aligning all input images to WCS defined by u2tv1801t_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u2tv1802t_c0m.fits
#
# Matching sources from 'u2tv1802t_c0m.fits' with sources from reference image 'u2tv1801t_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.847995822128 -0.975655396597
#
#     with significance of  317.022492687 and  12.0  matches
#
# Found 30 matches for u2tv1802t_c0m.fits...
#
# Computed  rscale  fit for  u2tv1802t_c0m.fits :
#
# XSH: 0.0121239  YSH: -0.0124761    ROT: 359.999    SCALE: 1.00001
#
# XRMS: 0.116002    YRMS: 0.1232
#
# RMS_RA: 4.25878e-06 (deg)   RMS_DEC: 2.49732e-07 (deg)
#
# Final solution based on  27  objects.
#
# wrote XY data to:  u2tv1802t_c0m_catalog_fit.match
#
# Writing out shiftfile : 9shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 0.012124

# %%
# change to a jupyter table
dt=test.to_pandas()
dt.to_pickle('data.pickle')
good_table=pandas.read_pickle('data.pickle')

# %%
# take only unfailed sessions
good_peakmax = good_table[good_table['y_rms'] != 'failed']

# %%
good_peakmax
# Out:
#          shift                file     x_rms     y_rms  threshold  conv_width  \
# 0   1shift.txt  u2tv1801t_c0m.fits  0.000000  0.000000          7         3.5
# 1   1shift.txt  u2tv1802t_c0m.fits  0.117607  0.125786          7         3.5
# 2   2shift.txt  u2tv1801t_c0m.fits  0.000000  0.000000          7         3.5
# 3   2shift.txt  u2tv1802t_c0m.fits  0.117607  0.125786          7         3.5
# 4   3shift.txt  u2tv1801t_c0m.fits  0.000000  0.000000          7         3.5
# 5   3shift.txt  u2tv1802t_c0m.fits  0.117607  0.125786          7         3.5
# 6   4shift.txt  u2tv1801t_c0m.fits  0.000000  0.000000          7         3.5
# 7   4shift.txt  u2tv1802t_c0m.fits  0.116002  0.123200          7         3.5
# 8   5shift.txt  u2tv1801t_c0m.fits  0.000000  0.000000          7         3.5
# 9   5shift.txt  u2tv1802t_c0m.fits  0.116002  0.123200          7         3.5
# 10  6shift.txt  u2tv1801t_c0m.fits  0.000000  0.000000          7         3.5
# 11  6shift.txt  u2tv1802t_c0m.fits  0.116002  0.123200          7         3.5
# 12  7shift.txt  u2tv1801t_c0m.fits  0.000000  0.000000          7         3.5
# 13  7shift.txt  u2tv1802t_c0m.fits  0.116002  0.123200          7         3.5
# 14  8shift.txt  u2tv1801t_c0m.fits  0.000000  0.000000          7         3.5
# 15  8shift.txt  u2tv1802t_c0m.fits  0.116002  0.123200          7         3.5
# 16  9shift.txt  u2tv1801t_c0m.fits  0.000000  0.000000          7         3.5
# 17  9shift.txt  u2tv1802t_c0m.fits  0.116002  0.123200          7         3.5
#
#     roundlo  roundhi  peakmax
# 0      -0.1      1.0     2500
# 1      -0.1      1.0     2500
# 2      -0.1      1.0     3000
# 3      -0.1      1.0     3000
# 4      -0.1      1.0     3500
# 5      -0.1      1.0     3500
# 6      -0.1      1.0     4000
# 7      -0.1      1.0     4000
# 8      -0.1      1.0     4500
# 9      -0.1      1.0     4500
# 10     -0.1      1.0     5000
# 11     -0.1      1.0     5000
# 12     -0.1      1.0     5500
# 13     -0.1      1.0     5500
# 14     -0.1      1.0     6000
# 15     -0.1      1.0     6000
# 16     -0.1      1.0     6500
# 17     -0.1      1.0     6500

# %%
# plot figure for all sub-exp ??????????????????????????????????????????
plt.figure(figsize = (7,7))
plt.plot(good_peakmax['peakmax'],good_peakmax['x_rms'],'.g')
plt.plot(good_peakmax['peakmax'],good_peakmax['y_rms'],'.b')
plt.title('x,y_rms(peakmax)-g,b')
plt.show()

# %%
################################## tweakreg run for good parameters without headers, see figures- 
# thresh = 7, conv = 3.5 roundnlo = -0.1, rounfhi = 1.0, peakmax = 4500

# %%
import os
from drizzlepac import tweakreg
os.chdir('/Users/natalie/anaconda2/envs/iraf27/iraf/sn/2000ds/2000ds_pre/tweak_814_1')
tweakreg.TweakReg('*c0m.fits', exclusions='WFPC2_exclude.txt', updatehdr=False, shiftfile=True, outshifts='shift_final', residplot='both', see2dplot='Yes', use_sharp_round='Yes', threshold=7, conv_width=3.5, roundlo=-0.1, roundhi=1.0, peakmax=4500)
# Out:
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 23:54:43.46 (06/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u2tv1801t_c0m.fits
#
#     u2tv1802t_c0m.fits
#
# ===  Source finding for image 'u2tv1801t_c0m.fits':
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 1) started at: 23:54:43.899 (06/12/2017)
#
#      Found 160 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 2) started at: 23:54:44.289 (06/12/2017)
#
#      Found 90 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 3) started at: 23:54:44.517 (06/12/2017)
#
#      Found 125 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 4) started at: 23:54:44.82 (06/12/2017)
#
#      Found 150 objects.
#
# ===  Found a TOTAL of 525 objects in image 'u2tv1801t_c0m.fits'
#
#
#
# ===  Source finding for image 'u2tv1802t_c0m.fits':
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 1) started at: 23:54:45.293 (06/12/2017)
#
#      Found 157 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 2) started at: 23:54:45.681 (06/12/2017)
#
#      Found 74 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 3) started at: 23:54:45.93 (06/12/2017)
#
#      Found 80 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 4) started at: 23:54:46.212 (06/12/2017)
#
#      Found 153 objects.
#
# ===  Found a TOTAL of 464 objects in image 'u2tv1802t_c0m.fits'
#
#
#
#  Catalog trimmed to 525 objects
#
#
# ====================
# Aligning all input images to WCS defined by u2tv1801t_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u2tv1802t_c0m.fits
#
# Matching sources from 'u2tv1802t_c0m.fits' with sources from reference image 'u2tv1801t_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.847995822128 -0.975655396597
#
#     with significance of  317.022492687 and  12.0  matches
#
# Found 30 matches for u2tv1802t_c0m.fits...
#
# Computed  rscale  fit for  u2tv1802t_c0m.fits :
#
# XSH: 0.0121239  YSH: -0.0124761    ROT: 359.999    SCALE: 1.00001
#
# XRMS: 0.116002    YRMS: 0.1232
#
# RMS_RA: 4.25878e-06 (deg)   RMS_DEC: 2.49732e-07 (deg)
#
# Final solution based on  27  objects.
#
# wrote XY data to:  u2tv1802t_c0m_catalog_fit.match
#
# Total # points:  27
#
# # of points after clipping:  27
#
# Total # points:  27
#
# # of points after clipping:  27
#
# Press ENTER for next image,
#       'n' to continue without updating header or
#       'q' to quit immediately...
#
# Writing out shiftfile : shift_final
#
# Trailer file written to:  tweakreg.log

# %%
################################## tweakreg run for headers update -  
# thresh = 7, conv = 3.5 roundnlo = -0.1, rounfhi = 1.0, peakmax = 4500

# %%
import os
from drizzlepac import tweakreg
os.chdir('/Users/natalie/anaconda2/envs/iraf27/iraf/sn/2000ds/2000ds_pre/tweak_814_1')
tweakreg.TweakReg('*c0m.fits', exclusions='WFPC2_exclude.txt', updatehdr=True, shiftfile=True, outshifts='shift_final', residplot='both', see2dplot='Yes', use_sharp_round='Yes', threshold=7, conv_width=3.5, roundlo=-0.1, roundhi=1.0, peakmax=4500)
# Out:
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 23:56:25.819 (06/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u2tv1801t_c0m.fits
#
#     u2tv1802t_c0m.fits
#
# ===  Source finding for image 'u2tv1801t_c0m.fits':
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 1) started at: 23:56:26.235 (06/12/2017)
#
#      Found 160 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 2) started at: 23:56:26.701 (06/12/2017)
#
#      Found 90 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 3) started at: 23:56:26.929 (06/12/2017)
#
#      Found 126 objects.
#
#   #  Source finding for 'u2tv1801t_c0m.fits', EXT=('SCI', 4) started at: 23:56:27.21 (06/12/2017)
#
#      Found 150 objects.
#
# ===  Found a TOTAL of 526 objects in image 'u2tv1801t_c0m.fits'
#
#
#
# ===  Source finding for image 'u2tv1802t_c0m.fits':
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 1) started at: 23:56:27.757 (06/12/2017)
#
#      Found 157 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 2) started at: 23:56:28.142 (06/12/2017)
#
#      Found 74 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 3) started at: 23:56:28.374 (06/12/2017)
#
#      Found 80 objects.
#
#   #  Source finding for 'u2tv1802t_c0m.fits', EXT=('SCI', 4) started at: 23:56:28.632 (06/12/2017)
#
#      Found 154 objects.
#
# ===  Found a TOTAL of 465 objects in image 'u2tv1802t_c0m.fits'
#
#
#
#  Catalog trimmed to 526 objects
#
#
# ====================
# Aligning all input images to WCS defined by u2tv1801t_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u2tv1802t_c0m.fits
#
# Matching sources from 'u2tv1802t_c0m.fits' with sources from reference image 'u2tv1801t_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.847995822128 -0.975655396597
#
#     with significance of  317.022492687 and  12.0  matches
#
# Found 30 matches for u2tv1802t_c0m.fits...
#
# Computed  rscale  fit for  u2tv1802t_c0m.fits :
#
# XSH: 0.0121239  YSH: -0.0124761    ROT: 359.999    SCALE: 1.00001
#
# XRMS: 0.116002    YRMS: 0.1232
#
# RMS_RA: 4.25878e-06 (deg)   RMS_DEC: 2.49732e-07 (deg)
#
# Final solution based on  27  objects.
#
# wrote XY data to:  u2tv1802t_c0m_catalog_fit.match
#
# Total # points:  27
#
# # of points after clipping:  27
#
# Total # points:  27
#
# # of points after clipping:  27
#
# Press ENTER for next image,
#       'n' to continue without updating header or
#       'q' to quit immediately...
#
#
# ....Updating header for u2tv1802t_c0m.fits...
#
#
# Processing u2tv1802t_c0m.fits['SCI',1]
#
# Updating header for u2tv1802t_c0m.fits[1]
#
# WCSNAME  :  TWEAK
#
#
# Processing u2tv1802t_c0m.fits['SCI',2]
#
# Updating header for u2tv1802t_c0m.fits[2]
#
# WCSNAME  :  TWEAK
#
#
# Processing u2tv1802t_c0m.fits['SCI',3]
#
# Updating header for u2tv1802t_c0m.fits[3]
#
# WCSNAME  :  TWEAK
#
#
# Processing u2tv1802t_c0m.fits['SCI',4]
#
# Updating header for u2tv1802t_c0m.fits[4]
#
# WCSNAME  :  TWEAK
#
# Writing out shiftfile : shift_final
#
# Trailer file written to:  tweakreg.log

# %%
# tweaked checks
from astropy.io import fits
tw=fits.open('/Users/natalie/anaconda2/envs/iraf27/iraf/sn/2000ds/2000ds_pre/tweak_814_1/u2tv1802t_c0m.fits')

# %%
tw[1].header
# Out:
# XTENSION= 'IMAGE   '           / Image extension
# BITPIX  =                  -32 / Bits per pixel
# NAXIS   =                    2 / Number of axes
# NAXIS1  =                  800 / Axis length
# NAXIS2  =                  800 / Axis length
# PCOUNT  =                    0 / No 'random' parameters
# GCOUNT  =                    1 / Only one group
# ORIGIN  = 'NOAO-IRAF FITS Image Kernel July 2003' / FITS file originator
# EXTNAME = 'SCI     '           / Extension name
# EXTVER  =                    1 / Extension version
# INHERIT =                    T / Inherits global header
# DATE    = '2008-10-30T17:13:30' / Date FITS file was generated
# IRAF-TLM= '17:13:27 (30/10/2008)' / Time of last modification
# ROOTNAME= 'u2tv1802t                         ' / rootname of the observation set
# EXPNAME = 'u2tv1802t                ' / exposure identifier
# DATAMIN =            -12479.47 / the minimum value of the data
# DATAMAX =             52693.49 / the maximum value of the data
# BUNIT   = 'COUNTS            ' / brightness units
#
#               / World Coordinate System and Related Parameters
#
# WCSAXES =                    2 / number of World Coordinate System axes
# CRPIX1  =                425.0 / x-coordinate of reference pixel
# CRPIX2  =                425.0 / y-coordinate of reference pixel
# CRVAL1  =      137.89370526931 / first axis value at reference pixel
# CRVAL2  =      60.045086060968 / second axis value at reference pixel
# CTYPE1  = 'RA---TAN-SIP'       / the coordinate type for the first axis
# CTYPE2  = 'DEC--TAN-SIP'       / the coordinate type for the second axis
# CD1_1   =  -7.551781783184E-06 / partial of first axis coordinate w.r.t. x
# CD1_2   = -1.0162374504793E-05 / partial of first axis coordinate w.r.t. y
# CD2_1   = -1.0152717012145E-05 / partial of second axis coordinate w.r.t. x
# CD2_2   =  7.5408935575332E-06 / partial of second axis coordinate w.r.t. y
# VAFACTOR=   1.000073890441E+00 / velocity aberration plate scale factor
#
#               / PODPS PARAMETERS
#
# DETECTOR=                    1 / CCD number of the detector: PC 1, WFC 2-4
#
#               / OSS PARAMETERS
#
# FILLCNT =                    0 / number of segments containing fill
# ERRCNT  =                    0 / number of segments containing errors
#
#               / IMAGE PARAMETERS
#
# MIR_REVR=                    T / is the image mirror reversed?
# ORIENTAT=    -53.4230881064094 / position angle of image y axis (deg. e of n)
# FPKTTIME=         50055.937506 / time of the first packet (Modified Julian Date)
# LPKTTIME=         50055.937673 / time of the last packet (Modified Julian Date)
# DEZERO  =             313.8783 / Mean bias level from EED extended register
# BIASEVEN=             313.8854 / Bias level from even-numbered columns
# BIASODD =             313.8712 / Bias level from odd-numbered columns
# GOODMIN =             -5.40698 / minimum value of good pixels
# GOODMAX =             1570.322 / maximum value of good pixels
# DATAMEAN=             1.859888 / mean value of the good pixels
#
#               / DATA QUALITY FILE SUMMARY
#
# GPIXELS =               557278 / number of good pixels (DQF=0)
# SOFTERRS=                    0 / number of soft error pixels (DQF=1)
# CALIBDEF=                82721 / number of calibration defect pixels (DQF=2)
# STATICD =                    0 / number of static defect pixels (DQF=4)
# ATODSAT =                    1 / number of AtoD saturated pixels (DQF=8)
# DATALOST=                    0 / number of data lost pixels (DQF=16)
# BADPIXEL=                    0 / number of generic bad pixels (DQF=32)
# OVERLAP =                    0 / number of image overlap pixels (DQF=64)
#
#               / PHOTOMETRY KEYWORDS
#
# PHOTMODE= 'WFPC2,1,A2D7,F814W,,CAL'
# PHOTFLAM=         2.507987E-18 / Inverse Sensitivity
# PHOTZPT =                -21.1 / Zero point
# PHOTPLAM=             7995.937 / Pivot wavelength
# PHOTBW  =             646.1154 / RMS bandwidth of the filter
# ZP_CORR =         -0.001087189 / Delta magnitude correction for contamination
#
#               / IMAGE STATISTICS
#
# MEDIAN  =             1.609093 / middle data value when good qual pixels sorted
# MEDSHADO=            -2.979621 / median pixel value in shadow of pyramid edge
# HISTWIDE=             1.865185 / width of the histogram
# SKEWNESS=           0.01467894 / skewness of the histogram
# MEANC10 =             1.562933 / mean of a 10x10 region at center of chip
# MEANC25 =             1.491655 / mean of a 25x25 region at center of chip
# MEANC50 =              1.52484 / mean of a 50x50 region at center of chip
# MEANC100=             1.568731 / mean of a 100x100 region at center of chip
# MEANC200=             1.531756 / mean of a 200x200 region at center of chip
# MEANC300=             1.582383 / mean of a 300x300 region at center of chip
# BACKGRND=            0.7382593 / estimated background level
# BIASEVNU=             0.000000 / BIASEVEN value prior to WF4T correction
# BIASODDU=             0.000000 / BIASODD value prior to WF4T correction
# CTE_1E2 =   0.1014450788497925 / expected delta mag from CTE,100 electron pt src
# CTE_1E3 =  0.04049043357372284 / expected delta mag from CTE,1000 electron pt sr
# CTE_1E4 =  0.01965644955635071 / expected delta mag from CTE,1e+4 electron pt sr
# OCRVAL1 =            137.89375 / first axis value at reference pixel
# OCRVAL2 =       60.04508333333 / second axis value at reference pixel
# OCRPIX2 =                424.5 / y-coordinate of reference pixel
# OCRPIX1 =                420.0 / x-coordinate of reference pixel
# ONAXIS2 =                  800 / Axis length
# ONAXIS1 =                  800 / Axis length
# OCD2_2  =          7.50696E-06 / partial of second axis coordinate w.r.t. y
# OCD2_1  =         -1.01793E-05 / partial of second axis coordinate w.r.t. x
# OORIENTA=    -53.5801208803659 / position angle of image y axis (deg. e of n)
# OCTYPE1 = 'RA---TAN'           / the coordinate type for the first axis
# OCD1_1  =         -7.51026E-06 / partial of first axis coordinate w.r.t. x
# OCD1_2  =         -1.01748E-05 / partial of first axis coordinate w.r.t. y
# OCTYPE2 = 'DEC--TAN'           / the coordinate type for the second axis
# WCSCDATE= '17:14:45 (30/10/2008)' / Time WCS keywords were copied.
# A_0_2   = -1.7983835205246E-06
# B_0_2   = -3.3029178474517E-06
# A_1_1   = -1.8764892222447E-06
# B_1_1   = -2.1656425506094E-06
# A_2_0   = -3.7388900125047E-06
# B_2_0   = -1.9929349509544E-06
# A_0_3   = 7.60016703088866E-11
# B_0_3   = -3.6333451949562E-08
# A_1_2   = -3.5920000950922E-08
# B_1_2   = 3.06320494129238E-10
# A_2_1   = 9.49561927606829E-11
# B_2_1   = -3.6238483509424E-08
# A_3_0   = -3.5843998930359E-08
# B_3_0   = -1.6758881657366E-10
# A_ORDER =                    3
# B_ORDER =                    3
# IDCSCALE=             0.045549
# IDCV2REF=    2.553350605389487
# IDCV3REF=   -30.36976920398757
# IDCTHETA=    224.8480072021484
# OCX10   = 2.27744994246677E-07
# OCX11   =             0.045549
# OCY10   =  0.04555355565583706
# OCY11   = 5.19668521061539E-05
# D2IMERR2=  0.01497428864240646 / Maximum error of NPOL correction for axis 2
# D2IMDIS2= 'Lookup  '           / Detector to image correction type
# D2IM2   = 'EXTVER: 1' / Version number of WCSDVARR extension containing d2im loo
# D2IM2   = 'NAXES: 2' / Number of independent variables in d2im function
# D2IM2   = 'AXIS.1: 1' / Axis number of the jth independent variable in a d2im fu
# D2IM2   = 'AXIS.2: 2' / Axis number of the jth independent variable in a d2im fu
# D2IMEXT = 'u2tv1802t_c0m_d2im.fits'
# RADESYS = 'FK5     '
# WCSNAMEO= 'OPUS    '
# WCSAXESO=                    2
# CRPIX1O =                425.0
# CRPIX2O =                425.0
# CDELT1O =                  1.0
# CDELT2O =                  1.0
# CUNIT1O = 'deg     '
# CUNIT2O = 'deg     '
# CTYPE1O = 'RA---TAN-SIP'
# CTYPE2O = 'DEC--TAN-SIP'
# CRVAL1O =      137.89370837238
# CRVAL2O =      60.045086201767
# LONPOLEO=                180.0
# LATPOLEO=      60.045086201767
# RADESYSO= 'FK5     '
# EQUINOXO=               2000.0
# CD1_1O  = -7.5514365452974E-06
# CD1_2O  = -1.0161588810915E-05
# CD2_1O  =  -1.015193175391E-05
# CD2_2O  =   7.540549205487E-06
# IDCXREF =                425.0
# IDCYREF =                425.0
# IDCTAB  = 'uref$ta81040lu_idc.fits'
# WCSNAME = 'TWEAK   '
# WCSNAMEA= 'IDC_ta81040lu'
# WCSAXESA=                    2
# CRPIX1A =                425.0
# CRPIX2A =                425.0
# CDELT1A =                  1.0
# CDELT2A =                  1.0
# CUNIT1A = 'deg     '
# CUNIT2A = 'deg     '
# CTYPE1A = 'RA---TAN-SIP'
# CTYPE2A = 'DEC--TAN-SIP'
# CRVAL1A =      137.89370519565
# CRVAL2A =      60.045085936752
# LONPOLEA=                180.0
# LATPOLEA=      60.045085936752
# RADESYSA= 'FK5     '
# EQUINOXA=               2000.0
# CD1_1A  = -7.5519944817163E-06
# CD1_2A  = -1.0162339683605E-05
# CD2_1A  = -1.0152681905942E-05
# CD2_2A  =  7.5411063373574E-06
# CDELT1  =                  1.0
# CDELT2  =                  1.0
# CUNIT1  = 'deg     '
# CUNIT2  = 'deg     '
# LONPOLE =                180.0
# LATPOLE =      60.045086060968
# CRDER1  =  4.2587826101226E-06
# CRDER2  =  2.4973200396516E-07
# EQUINOX =               2000.0
# WCSNAMEB= 'TWEAK   '
# WCSAXESB=                    2
# CRPIX1B =                425.0
# CRPIX2B =                425.0
# CDELT1B =                  1.0
# CDELT2B =                  1.0
# CUNIT1B = 'deg     '
# CUNIT2B = 'deg     '
# CTYPE1B = 'RA---TAN-SIP'
# CTYPE2B = 'DEC--TAN-SIP'
# CRVAL1B =      137.89370526931
# CRVAL2B =      60.045086060968
# LONPOLEB=                180.0
# LATPOLEB=      60.045086060968
# CRDER1B =  4.2587826101226E-06
# CRDER2B =  2.4973200396516E-07
# RADESYSB= 'FK5     '
# EQUINOXB=               2000.0
# CD1_1B  =  -7.551781783184E-06
# CD1_2B  = -1.0162374504793E-05
# CD2_1B  = -1.0152717012145E-05
# CD2_2B  =  7.5408935575332E-06
# FITNAMEB= 'TWEAK   '
# NMATCHB =                   27
# RMS_RAB = 4.25878261012258E-06
# RMS_DECB= 2.49732003965164E-07

# %%
tw[1].header['WCSNAME']
# Out:
# 'TWEAK'
