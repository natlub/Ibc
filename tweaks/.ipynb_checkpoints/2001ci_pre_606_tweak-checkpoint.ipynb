# %%
# tweakreg defaults: 
# threshold = 4
# conv_width = 3.5
# use round = No --> roundlo = -1, roundhi = 1
# peakmin = //
# peakmax = //

# %%
import sys
sys.path.append("/Users/natalie/PycharmProjects/code/")
    
from Drizzle_func import *
import pandas
import matplotlib.pyplot as plt
# Out:
# The following task in the stsci.skypac package can be run with TEAL:
#                                     skymatch
# The following tasks in the drizzlepac package can be run with TEAL:
#     astrodrizzle       imagefindpars           mapreg              photeq
#      pixreplace           pixtopix            pixtosky        refimagefindpars
#      resetbits          runastrodriz          skytopix           tweakback
#       tweakreg           updatenpol

# %%
# tweak_run(path, n_up, threshold_ini, threshold_gap, conv_width_ini, conv_width_gap, 
# roundlo_val_ini, roundlo_gap, roundhi_val_ini, roundhi_gap, peakmax_val_ini, peakmax_gap):
test = tweak_run('/Users/natalie/anaconda2/envs/iraf27/iraf/sn/2001ci/2001ci_pre/tweak_547',10,1,1,3.5,0,-1,0,1,0,1000,0)
# Out:
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 17:39:52.925 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0303r_c0m.fits
#
#     u54v0304r_c0m.fits
#
# ===  Source finding for image 'u54v0303r_c0m.fits':
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 1) started at: 17:39:53.21 (12/12/2017)
#
#      Found 2621 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 2) started at: 17:39:56.499 (12/12/2017)
#
#      Found 3770 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 3) started at: 17:40:00.641 (12/12/2017)
#
#      Found 2571 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 4) started at: 17:40:03.815 (12/12/2017)
#
#      Found 2037 objects.
#
# ===  Found a TOTAL of 10999 objects in image 'u54v0303r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0304r_c0m.fits':
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 1) started at: 17:40:06.38 (12/12/2017)
#
#      Found 3663 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 2) started at: 17:40:11.378 (12/12/2017)
#
#      Found 3735 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 3) started at: 17:40:15.093 (12/12/2017)
#
#      Found 3773 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 4) started at: 17:40:18.591 (12/12/2017)
#
#      Found 1027 objects.
#
# ===  Found a TOTAL of 12198 objects in image 'u54v0304r_c0m.fits'
#
#
#
#  Catalog trimmed to 10999 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0303r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0304r_c0m.fits
#
# Matching sources from 'u54v0304r_c0m.fits' with sources from reference image 'u54v0303r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -10.9498130081 -5.9715847799
#
#     with significance of  307.164451068 and  50.0  matches
#
# Found 198 matches for u54v0304r_c0m.fits...
#
# Computed  rscale  fit for  u54v0304r_c0m.fits :
#
# XSH: -10.8741  YSH: -5.94326    ROT: 359.999    SCALE: 1.00003
#
# XRMS: 0.757399    YRMS: 0.701379
#
# RMS_RA: 8.1546e-06 (deg)   RMS_DEC: 1.22199e-05 (deg)
#
# Final solution based on  198  objects.
#
# wrote XY data to:  u54v0304r_c0m_catalog_fit.match
#
# Writing out shiftfile : 1shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -10.874103
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 17:40:20.698 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0303r_c0m.fits
#
#     u54v0304r_c0m.fits
#
# ===  Source finding for image 'u54v0303r_c0m.fits':
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 1) started at: 17:40:20.897 (12/12/2017)
#
#      Found 3893 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 2) started at: 17:40:24.06 (12/12/2017)
#
#      Found 3018 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 3) started at: 17:40:25.284 (12/12/2017)
#
#      Found 3964 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 4) started at: 17:40:28.511 (12/12/2017)
#
#      Found 3871 objects.
#
# ===  Found a TOTAL of 14746 objects in image 'u54v0303r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0304r_c0m.fits':
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 1) started at: 17:40:32.36 (12/12/2017)
#
#      Found 2191 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 2) started at: 17:40:33.151 (12/12/2017)
#
#      Found 3036 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 3) started at: 17:40:34.358 (12/12/2017)
#
#      Found 2533 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 4) started at: 17:40:35.21 (12/12/2017)
#
#      Found 3199 objects.
#
# ===  Found a TOTAL of 10959 objects in image 'u54v0304r_c0m.fits'
#
#
#
#  Catalog trimmed to 14746 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0303r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0304r_c0m.fits
#
# Matching sources from 'u54v0304r_c0m.fits' with sources from reference image 'u54v0303r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.987959872423 -0.886423466277
#
#     with significance of  779.925962906 and  55.0  matches
#
# Found 266 matches for u54v0304r_c0m.fits...
#
# Computed  rscale  fit for  u54v0304r_c0m.fits :
#
# XSH: -0.875847  YSH: -0.718322    ROT: 360    SCALE: 0.999945
#
# XRMS: 0.729111    YRMS: 0.76232
#
# RMS_RA: 6.97519e-06 (deg)   RMS_DEC: 1.2749e-05 (deg)
#
# Final solution based on  266  objects.
#
# wrote XY data to:  u54v0304r_c0m_catalog_fit.match
#
# Writing out shiftfile : 2shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.875847
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 17:40:39.867 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0303r_c0m.fits
#
#     u54v0304r_c0m.fits
#
# ===  Source finding for image 'u54v0303r_c0m.fits':
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 1) started at: 17:40:40.071 (12/12/2017)
#
#      Found 3322 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 2) started at: 17:40:41.622 (12/12/2017)
#
#      Found 681 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 3) started at: 17:40:41.996 (12/12/2017)
#
#      Found 3549 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 4) started at: 17:40:43.619 (12/12/2017)
#
#      Found 4038 objects.
#
# ===  Found a TOTAL of 11590 objects in image 'u54v0303r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0304r_c0m.fits':
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 1) started at: 17:40:46.289 (12/12/2017)
#
#      Found 470 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 2) started at: 17:40:46.820 (12/12/2017)
#
#      Found 611 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 3) started at: 17:40:47.190 (12/12/2017)
#
#      Found 591 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 4) started at: 17:40:47.56 (12/12/2017)
#
#      Found 3927 objects.
#
# ===  Found a TOTAL of 5599 objects in image 'u54v0304r_c0m.fits'
#
#
#
#  Catalog trimmed to 11590 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0303r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0304r_c0m.fits
#
# Matching sources from 'u54v0304r_c0m.fits' with sources from reference image 'u54v0303r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.884016032752 -0.867649420641
#
#     with significance of  597.813843353 and  40.0  matches
#
# Found 143 matches for u54v0304r_c0m.fits...
#
# Computed  rscale  fit for  u54v0304r_c0m.fits :
#
# XSH: -0.493319  YSH: -0.565829    ROT: 0.00669898    SCALE: 0.999883
#
# XRMS: 0.669384    YRMS: 0.708538
#
# RMS_RA: 6.31681e-06 (deg)   RMS_DEC: 1.18027e-05 (deg)
#
# Final solution based on  143  objects.
#
# wrote XY data to:  u54v0304r_c0m_catalog_fit.match
#
# Writing out shiftfile : 3shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.493319
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 17:40:51.997 (12/12/2017)
#
# Version Information
#
# --------------------
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0303r_c0m.fits
#
#     u54v0304r_c0m.fits
#
# ===  Source finding for image 'u54v0303r_c0m.fits':
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 1) started at: 17:40:52.226 (12/12/2017)
#
#      Found 1266 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 2) started at: 17:40:52.792 (12/12/2017)
#
#      Found 353 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 3) started at: 17:40:53.114 (12/12/2017)
#
#      Found 1655 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 4) started at: 17:40:53.81 (12/12/2017)
#
#      Found 2782 objects.
#
# ===  Found a TOTAL of 6056 objects in image 'u54v0303r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0304r_c0m.fits':
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 1) started at: 17:40:55.077 (12/12/2017)
#
#      Found 437 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 2) started at: 17:40:55.537 (12/12/2017)
#
#      Found 286 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 3) started at: 17:40:55.816 (12/12/2017)
#
#      Found 346 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 4) started at: 17:40:56.102 (12/12/2017)
#
#      Found 4019 objects.
#
# ===  Found a TOTAL of 5088 objects in image 'u54v0304r_c0m.fits'
#
#
#
#  Catalog trimmed to 6056 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0303r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0304r_c0m.fits
#
# Matching sources from 'u54v0304r_c0m.fits' with sources from reference image 'u54v0303r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.877417620035 -0.714400588405
#
#     with significance of  523.200864618 and  29.0  matches
#
# Found 103 matches for u54v0304r_c0m.fits...
#
# Computed  rscale  fit for  u54v0304r_c0m.fits :
#
# XSH: -0.480532  YSH: -0.394678    ROT: 0.00861267    SCALE: 0.999825
#
# XRMS: 0.629999    YRMS: 0.613215
#
# RMS_RA: 6.48362e-06 (deg)   RMS_DEC: 1.05016e-05 (deg)
#
# Final solution based on  103  objects.
#
# wrote XY data to:  u54v0304r_c0m_catalog_fit.match
#
# Writing out shiftfile : 4shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.480532
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 17:40:59.404 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0303r_c0m.fits
#
#     u54v0304r_c0m.fits
#
# ===  Source finding for image 'u54v0303r_c0m.fits':
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 1) started at: 17:40:59.619 (12/12/2017)
#
#      Found 555 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 2) started at: 17:41:00.195 (12/12/2017)
#
#      Found 317 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 3) started at: 17:41:00.515 (12/12/2017)
#
#      Found 743 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 4) started at: 17:41:00.918 (12/12/2017)
#
#      Found 1234 objects.
#
# ===  Found a TOTAL of 2849 objects in image 'u54v0303r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0304r_c0m.fits':
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 1) started at: 17:41:01.662 (12/12/2017)
#
#      Found 459 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 2) started at: 17:41:02.187 (12/12/2017)
#
#      Found 250 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 3) started at: 17:41:02.410 (12/12/2017)
#
#      Found 305 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 4) started at: 17:41:02.676 (12/12/2017)
#
#      Found 3506 objects.
#
# ===  Found a TOTAL of 4520 objects in image 'u54v0304r_c0m.fits'
#
#
#
#  Catalog trimmed to 2849 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0303r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0304r_c0m.fits
#
# Matching sources from 'u54v0304r_c0m.fits' with sources from reference image 'u54v0303r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.739498847809 -0.751037309348
#
#     with significance of  467.197293951 and  23.0  matches
#
# Found 78 matches for u54v0304r_c0m.fits...
#
# Computed  rscale  fit for  u54v0304r_c0m.fits :
#
# XSH: -0.420029  YSH: -0.476861    ROT: 0.00481104    SCALE: 0.999742
#
# XRMS: 0.53476    YRMS: 0.613172
#
# RMS_RA: 4.57318e-06 (deg)   RMS_DEC: 9.96207e-06 (deg)
#
# Final solution based on  78  objects.
#
# wrote XY data to:  u54v0304r_c0m_catalog_fit.match
#
# Writing out shiftfile : 5shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.420029
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 17:41:04.885 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0303r_c0m.fits
#
#     u54v0304r_c0m.fits
#
# ===  Source finding for image 'u54v0303r_c0m.fits':
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 1) started at: 17:41:05.159 (12/12/2017)
#
#      Found 457 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 2) started at: 17:41:05.59 (12/12/2017)
#
#      Found 310 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 3) started at: 17:41:05.883 (12/12/2017)
#
#      Found 444 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 4) started at: 17:41:06.241 (12/12/2017)
#
#      Found 588 objects.
#
# ===  Found a TOTAL of 1799 objects in image 'u54v0303r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0304r_c0m.fits':
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 1) started at: 17:41:06.800 (12/12/2017)
#
#      Found 446 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 2) started at: 17:41:07.265 (12/12/2017)
#
#      Found 223 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 3) started at: 17:41:07.529 (12/12/2017)
#
#      Found 293 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 4) started at: 17:41:07.799 (12/12/2017)
#
#      Found 2272 objects.
#
# ===  Found a TOTAL of 3234 objects in image 'u54v0304r_c0m.fits'
#
#
#
#  Catalog trimmed to 1799 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0303r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0304r_c0m.fits
#
# Matching sources from 'u54v0304r_c0m.fits' with sources from reference image 'u54v0303r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.866767387653 -0.91467157927
#
#     with significance of  427.389283909 and  21.0  matches
#
# Found 62 matches for u54v0304r_c0m.fits...
#
# Computed  rscale  fit for  u54v0304r_c0m.fits :
#
# XSH: -0.39045  YSH: -0.562416    ROT: 0.00815882    SCALE: 0.999728
#
# XRMS: 0.46115    YRMS: 0.687485
#
# RMS_RA: 2.3502e-06 (deg)   RMS_DEC: 1.0386e-05 (deg)
#
# Final solution based on  60  objects.
#
# wrote XY data to:  u54v0304r_c0m_catalog_fit.match
#
# Writing out shiftfile : 6shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.390450
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 17:41:09.149 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0303r_c0m.fits
#
#     u54v0304r_c0m.fits
#
# ===  Source finding for image 'u54v0303r_c0m.fits':
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 1) started at: 17:41:09.380 (12/12/2017)
#
#      Found 442 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 2) started at: 17:41:09.749 (12/12/2017)
#
#      Found 292 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 3) started at: 17:41:09.990 (12/12/2017)
#
#      Found 357 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 4) started at: 17:41:10.282 (12/12/2017)
#
#      Found 395 objects.
#
# ===  Found a TOTAL of 1486 objects in image 'u54v0303r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0304r_c0m.fits':
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 1) started at: 17:41:10.823 (12/12/2017)
#
#      Found 466 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 2) started at: 17:41:11.259 (12/12/2017)
#
#      Found 225 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 3) started at: 17:41:11.484 (12/12/2017)
#
#      Found 278 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 4) started at: 17:41:11.780 (12/12/2017)
#
#      Found 1190 objects.
#
# ===  Found a TOTAL of 2159 objects in image 'u54v0304r_c0m.fits'
#
#
#
#  Catalog trimmed to 1486 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0303r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0304r_c0m.fits
#
# Matching sources from 'u54v0304r_c0m.fits' with sources from reference image 'u54v0303r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.915278473589 -0.847710906022
#
#     with significance of  372.754745107 and  17.0  matches
#
# Found 53 matches for u54v0304r_c0m.fits...
#
# Computed  rscale  fit for  u54v0304r_c0m.fits :
#
# XSH: -0.545973  YSH: -0.390168    ROT: 359.996    SCALE: 0.999746
#
# XRMS: 0.61424    YRMS: 0.614408
#
# RMS_RA: 6.15544e-06 (deg)   RMS_DEC: 1.04259e-05 (deg)
#
# Final solution based on  53  objects.
#
# wrote XY data to:  u54v0304r_c0m_catalog_fit.match
#
# Writing out shiftfile : 7shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.545973
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 17:41:12.678 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0303r_c0m.fits
#
#     u54v0304r_c0m.fits
#
# ===  Source finding for image 'u54v0303r_c0m.fits':
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 1) started at: 17:41:12.880 (12/12/2017)
#
#      Found 473 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 2) started at: 17:41:13.296 (12/12/2017)
#
#      Found 285 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 3) started at: 17:41:13.530 (12/12/2017)
#
#      Found 336 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 4) started at: 17:41:13.795 (12/12/2017)
#
#      Found 351 objects.
#
# ===  Found a TOTAL of 1445 objects in image 'u54v0303r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0304r_c0m.fits':
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 1) started at: 17:41:14.226 (12/12/2017)
#
#      Found 465 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 2) started at: 17:41:14.65 (12/12/2017)
#
#      Found 224 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 3) started at: 17:41:14.880 (12/12/2017)
#
#      Found 273 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 4) started at: 17:41:15.144 (12/12/2017)
#
#      Found 659 objects.
#
# ===  Found a TOTAL of 1621 objects in image 'u54v0304r_c0m.fits'
#
#
#
#  Catalog trimmed to 1445 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0303r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0304r_c0m.fits
#
# Matching sources from 'u54v0304r_c0m.fits' with sources from reference image 'u54v0303r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.890207349834 -0.830996823518
#
#     with significance of  398.367543859 and  18.0  matches
#
# Found 48 matches for u54v0304r_c0m.fits...
#
# Computed  rscale  fit for  u54v0304r_c0m.fits :
#
# XSH: -0.385722  YSH: -0.527221    ROT: 0.00538296    SCALE: 0.999695
#
# XRMS: 0.534849    YRMS: 0.637986
#
# RMS_RA: 4.32585e-06 (deg)   RMS_DEC: 1.02432e-05 (deg)
#
# Final solution based on  48  objects.
#
# wrote XY data to:  u54v0304r_c0m_catalog_fit.match
#
# Writing out shiftfile : 8shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.385722
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 17:41:15.91 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0303r_c0m.fits
#
#     u54v0304r_c0m.fits
#
# ===  Source finding for image 'u54v0303r_c0m.fits':
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 1) started at: 17:41:16.149 (12/12/2017)
#
#      Found 489 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 2) started at: 17:41:16.591 (12/12/2017)
#
#      Found 286 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 3) started at: 17:41:16.838 (12/12/2017)
#
#      Found 328 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 4) started at: 17:41:17.136 (12/12/2017)
#
#      Found 323 objects.
#
# ===  Found a TOTAL of 1426 objects in image 'u54v0303r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0304r_c0m.fits':
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 1) started at: 17:41:17.57 (12/12/2017)
#
#      Found 466 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 2) started at: 17:41:18.008 (12/12/2017)
#
#      Found 234 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 3) started at: 17:41:18.244 (12/12/2017)
#
#      Found 261 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 4) started at: 17:41:18.492 (12/12/2017)
#
#      Found 438 objects.
#
# ===  Found a TOTAL of 1399 objects in image 'u54v0304r_c0m.fits'
#
#
#
#  Catalog trimmed to 1426 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0303r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0304r_c0m.fits
#
# Matching sources from 'u54v0304r_c0m.fits' with sources from reference image 'u54v0303r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -1.01662982494 -0.982846041157
#
#     with significance of  337.880896175 and  15.0  matches
#
# Found 39 matches for u54v0304r_c0m.fits...
#
# Computed  rscale  fit for  u54v0304r_c0m.fits :
#
# XSH: -0.52293  YSH: -0.571663    ROT: 0.0113657    SCALE: 0.999715
#
# XRMS: 0.590053    YRMS: 0.690819
#
# RMS_RA: 4.90302e-06 (deg)   RMS_DEC: 1.11533e-05 (deg)
#
# Final solution based on  39  objects.
#
# wrote XY data to:  u54v0304r_c0m_catalog_fit.match
#
# Writing out shiftfile : 9shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.522930

# %%
# change to a jupyter table
dt=test.to_pandas()
dt.to_pickle('data.pickle')
good_table=pandas.read_pickle('data.pickle')

# %%
# all table
good_table
# Out:
#          shift                file     x_rms     y_rms  threshold  conv_width  \
# 0   1shift.txt  u54v0303r_c0m.fits  0.000000  0.000000          1         3.5
# 1   1shift.txt  u54v0304r_c0m.fits  0.757399  0.701379          1         3.5
# 2   2shift.txt  u54v0303r_c0m.fits  0.000000  0.000000          2         3.5
# 3   2shift.txt  u54v0304r_c0m.fits  0.729111  0.762320          2         3.5
# 4   3shift.txt  u54v0303r_c0m.fits  0.000000  0.000000          3         3.5
# 5   3shift.txt  u54v0304r_c0m.fits  0.669384  0.708538          3         3.5
# 6   4shift.txt  u54v0303r_c0m.fits  0.000000  0.000000          4         3.5
# 7   4shift.txt  u54v0304r_c0m.fits  0.629999  0.613215          4         3.5
# 8   5shift.txt  u54v0303r_c0m.fits  0.000000  0.000000          5         3.5
# 9   5shift.txt  u54v0304r_c0m.fits  0.534760  0.613172          5         3.5
# 10  6shift.txt  u54v0303r_c0m.fits  0.000000  0.000000          6         3.5
# 11  6shift.txt  u54v0304r_c0m.fits  0.461150  0.687485          6         3.5
# 12  7shift.txt  u54v0303r_c0m.fits  0.000000  0.000000          7         3.5
# 13  7shift.txt  u54v0304r_c0m.fits  0.614240  0.614408          7         3.5
# 14  8shift.txt  u54v0303r_c0m.fits  0.000000  0.000000          8         3.5
# 15  8shift.txt  u54v0304r_c0m.fits  0.534849  0.637986          8         3.5
# 16  9shift.txt  u54v0303r_c0m.fits  0.000000  0.000000          9         3.5
# 17  9shift.txt  u54v0304r_c0m.fits  0.590053  0.690819          9         3.5
#
#     roundlo  roundhi  peakmax
# 0        -1        1     1000
# 1        -1        1     1000
# 2        -1        1     1000
# 3        -1        1     1000
# 4        -1        1     1000
# 5        -1        1     1000
# 6        -1        1     1000
# 7        -1        1     1000
# 8        -1        1     1000
# 9        -1        1     1000
# 10       -1        1     1000
# 11       -1        1     1000
# 12       -1        1     1000
# 13       -1        1     1000
# 14       -1        1     1000
# 15       -1        1     1000
# 16       -1        1     1000
# 17       -1        1     1000

# %%
# filter by column
good_table['y_rms']
# Out:
# 0     0.000000
# 1     0.613172
# 2     0.000000
# 3     0.687485
# 4     0.000000
# 5     0.614408
# 6     0.000000
# 7     0.637986
# 8     0.000000
# 9     0.690819
# 10    0.000000
# 11    0.611619
# 12    0.000000
# 13      failed
# 14    0.000000
# 15    0.692300
# 16    0.000000
# 17    0.457063
# Name: y_rms, dtype: object

# %%
# filter by value in column
good_table[good_table['y_rms']=='failed']
# Out:
# Empty DataFrame
# Columns: [shift, file, x_rms, y_rms, threshold, conv_width, roundlo, roundhi, peakmax]
# Index: []

# %%
# see unique in column
good_table['shift'].unique()
# Out:
# array(['1shift.txt', '2shift.txt', '3shift.txt', '4shift.txt',
#        '5shift.txt', '6shift.txt', '7shift.txt', '8shift.txt', '9shift.txt'], dtype=object)

# %%
good_table.shape
# Out:
# (18, 9)

# %%
# take only unfailed sessions
good = good_table[good_table['y_rms'] != 'failed']

# %%
# ????????????????????????????????????????????????????
plt.figure(figsize = (7,7))
plt.plot(good['threshold'],good['x_rms'],'.g')
plt.plot(good['threshold'],good['y_rms'],'.b')
plt.title('x,y_rms(threshold)-g,b')
plt.show()

# %%
# plot figure for choosen sub-exp
plt.figure(figsize = (7,7))
plt.plot(good[good['file'] == 'u29r1r01t_c0m.fits']['threshold'],good[good['file'] == 'u29r1r01t_c0m.fits']['y_rms'],'.b')
plt.plot(good[good['file'] == 'u29r1r02t_c0m.fits']['threshold'],good[good['file'] == 'u29r1r02t_c0m.fits']['y_rms'],'.g')
plt.title('y_rms(threshold)-two filters')
plt.show()

# %%
# find min y_rms and min x_rms
min_x = good[good['x_rms'].values.astype(float) != 0.0]['x_rms'].min()
min_y = good[good['y_rms'].values.astype(float) != 0.0]['y_rms'].min()
print(min_x)
print(min_y)
# Out:
# 0.206961
# 0.186928

# %%
# sort all values =! 0 and take lowest 5 in y_rms
good[good['x_rms'].values.astype(float) != 0.0].sort_values('x_rms',ascending=True)[:5]
# Out:
#          shift                file     x_rms     y_rms  threshold  conv_width
# 21  6shift.txt  u6ea5402m_c0m.fits  0.056897  0.037645         51           3
# 17  5shift.txt  u6ea5402m_c0m.fits  0.069021  0.038714         41           3
# 9   3shift.txt  u6ea5402m_c0m.fits  0.074321  0.078460         21           3
# 5   2shift.txt  u6ea5402m_c0m.fits  0.088635  0.088857         11           3
# 13  4shift.txt  u6ea5402m_c0m.fits  0.152657  0.101558         31           3

# %%
# sort all values =! 0 and take lowest 5 in y_rms BY FILTER??????????????????????
good['file' == 'u29r1r02t_c0m.fits'][['y_rms'].values.astype(float) != 0.0]].sort_values('y_rms',ascending=True)[:5]
#plt.plot(good[good['file'] == 'u6ea5402m_c0m.fits']['threshold'],good[good['file'] == 'u6ea5402m_c0m.fits']['y_rms'],'.b')
# Out:
#   File "<ipython-input-14-aaeb809a2179>", line 2
#     good['file' == 'u29r1r02t_c0m.fits'][['y_rms'].values.astype(float) != 0.0]].sort_values('y_rms',ascending=True)[:5]
#                                                                                ^
# SyntaxError: invalid syntax

# %%
############################################################ thresh=6?, conv_width?

# %%
# tweak_run(path, n_up, threshold_ini, threshold_gap, conv_width_ini, conv_width_gap, 
# roundlo_val_ini, roundlo_gap, roundhi_val_ini, roundhi_gap, peakmax_val_ini, peakmax_gap):
test = tweak_run('/Users/natalie/anaconda2/envs/iraf27/iraf/sn/2001ci/2001ci_pre/tweak_547',10,6,0,2.5,0.2,-1,0,1,0,1000,0)
# Out:
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 17:42:53.884 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0303r_c0m.fits
#
#     u54v0304r_c0m.fits
#
# ===  Source finding for image 'u54v0303r_c0m.fits':
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 1) started at: 17:42:54.18 (12/12/2017)
#
#      Found 366 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 2) started at: 17:42:54.614 (12/12/2017)
#
#      Found 164 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 3) started at: 17:42:54.905 (12/12/2017)
#
#      Found 234 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 4) started at: 17:42:55.268 (12/12/2017)
#
#      Found 218 objects.
#
# ===  Found a TOTAL of 982 objects in image 'u54v0303r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0304r_c0m.fits':
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 1) started at: 17:42:55.906 (12/12/2017)
#
#      Found 365 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 2) started at: 17:42:56.390 (12/12/2017)
#
#      Found 155 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 3) started at: 17:42:56.652 (12/12/2017)
#
#      Found 175 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 4) started at: 17:42:56.983 (12/12/2017)
#
#      Found 664 objects.
#
# ===  Found a TOTAL of 1359 objects in image 'u54v0304r_c0m.fits'
#
#
#
#  Catalog trimmed to 982 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0303r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0304r_c0m.fits
#
# Matching sources from 'u54v0304r_c0m.fits' with sources from reference image 'u54v0303r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.821730700464 -0.835815207506
#
#     with significance of  361.707063796 and  13.0  matches
#
# Found 43 matches for u54v0304r_c0m.fits...
#
# Computed  rscale  fit for  u54v0304r_c0m.fits :
#
# XSH: -0.680954  YSH: -0.499214    ROT: 0.00158749    SCALE: 0.999599
#
# XRMS: 0.628857    YRMS: 0.602654
#
# RMS_RA: 6.56673e-06 (deg)   RMS_DEC: 1.03757e-05 (deg)
#
# Final solution based on  43  objects.
#
# wrote XY data to:  u54v0304r_c0m_catalog_fit.match
#
# Writing out shiftfile : 1shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.680954
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 17:42:57.965 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0303r_c0m.fits
#
#     u54v0304r_c0m.fits
#
# ===  Source finding for image 'u54v0303r_c0m.fits':
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 1) started at: 17:42:58.248 (12/12/2017)
#
#      Found 363 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 2) started at: 17:42:58.638 (12/12/2017)
#
#      Found 181 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 3) started at: 17:42:58.900 (12/12/2017)
#
#      Found 244 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 4) started at: 17:42:59.250 (12/12/2017)
#
#      Found 248 objects.
#
# ===  Found a TOTAL of 1036 objects in image 'u54v0303r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0304r_c0m.fits':
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 1) started at: 17:42:59.820 (12/12/2017)
#
#      Found 372 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 2) started at: 17:43:00.285 (12/12/2017)
#
#      Found 160 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 3) started at: 17:43:00.504 (12/12/2017)
#
#      Found 182 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 4) started at: 17:43:00.882 (12/12/2017)
#
#      Found 824 objects.
#
# ===  Found a TOTAL of 1538 objects in image 'u54v0304r_c0m.fits'
#
#
#
#  Catalog trimmed to 1036 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0303r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0304r_c0m.fits
#
# Matching sources from 'u54v0304r_c0m.fits' with sources from reference image 'u54v0303r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.819718628029 -0.792507743676
#
#     with significance of  392.85176675 and  15.0  matches
#
# Found 43 matches for u54v0304r_c0m.fits...
#
# Computed  rscale  fit for  u54v0304r_c0m.fits :
#
# XSH: -0.343747  YSH: -0.226071    ROT: 359.998    SCALE: 0.999818
#
# XRMS: 0.587373    YRMS: 0.400444
#
# RMS_RA: 7.76456e-06 (deg)   RMS_DEC: 7.85374e-06 (deg)
#
# Final solution based on  41  objects.
#
# wrote XY data to:  u54v0304r_c0m_catalog_fit.match
#
# Writing out shiftfile : 2shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.343747
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 17:43:01.755 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0303r_c0m.fits
#
#     u54v0304r_c0m.fits
#
# ===  Source finding for image 'u54v0303r_c0m.fits':
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 1) started at: 17:43:01.982 (12/12/2017)
#
#      Found 360 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 2) started at: 17:43:02.34 (12/12/2017)
#
#      Found 195 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 3) started at: 17:43:02.588 (12/12/2017)
#
#      Found 273 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 4) started at: 17:43:02.834 (12/12/2017)
#
#      Found 277 objects.
#
# ===  Found a TOTAL of 1105 objects in image 'u54v0303r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0304r_c0m.fits':
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 1) started at: 17:43:03.377 (12/12/2017)
#
#      Found 393 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 2) started at: 17:43:03.760 (12/12/2017)
#
#      Found 176 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 3) started at: 17:43:03.979 (12/12/2017)
#
#      Found 204 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 4) started at: 17:43:04.229 (12/12/2017)
#
#      Found 1074 objects.
#
# ===  Found a TOTAL of 1847 objects in image 'u54v0304r_c0m.fits'
#
#
#
#  Catalog trimmed to 1105 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0303r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0304r_c0m.fits
#
# Matching sources from 'u54v0304r_c0m.fits' with sources from reference image 'u54v0303r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -1.04311268364 -0.593448254108
#
#     with significance of  386.515447931 and  14.0  matches
#
# Found 44 matches for u54v0304r_c0m.fits...
#
# Computed  rscale  fit for  u54v0304r_c0m.fits :
#
# XSH: -0.421171  YSH: -0.34045    ROT: 359.999    SCALE: 0.99979
#
# XRMS: 0.599282    YRMS: 0.574578
#
# RMS_RA: 6.25521e-06 (deg)   RMS_DEC: 9.89073e-06 (deg)
#
# Final solution based on  44  objects.
#
# wrote XY data to:  u54v0304r_c0m_catalog_fit.match
#
# Writing out shiftfile : 3shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.421171
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 17:43:05.406 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0303r_c0m.fits
#
#     u54v0304r_c0m.fits
#
# ===  Source finding for image 'u54v0303r_c0m.fits':
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 1) started at: 17:43:05.648 (12/12/2017)
#
#      Found 394 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 2) started at: 17:43:06.936 (12/12/2017)
#
#      Found 228 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 3) started at: 17:43:07.822 (12/12/2017)
#
#      Found 327 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 4) started at: 17:43:08.265 (12/12/2017)
#
#      Found 350 objects.
#
# ===  Found a TOTAL of 1299 objects in image 'u54v0303r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0304r_c0m.fits':
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 1) started at: 17:43:08.864 (12/12/2017)
#
#      Found 408 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 2) started at: 17:43:09.283 (12/12/2017)
#
#      Found 193 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 3) started at: 17:43:09.71 (12/12/2017)
#
#      Found 223 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 4) started at: 17:43:10.031 (12/12/2017)
#
#      Found 1402 objects.
#
# ===  Found a TOTAL of 2226 objects in image 'u54v0304r_c0m.fits'
#
#
#
#  Catalog trimmed to 1299 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0303r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0304r_c0m.fits
#
# Matching sources from 'u54v0304r_c0m.fits' with sources from reference image 'u54v0303r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.895008203319 -0.800413608724
#
#     with significance of  396.062635338 and  13.0  matches
#
# Found 46 matches for u54v0304r_c0m.fits...
#
# Computed  rscale  fit for  u54v0304r_c0m.fits :
#
# XSH: -0.512183  YSH: -0.357769    ROT: 359.997    SCALE: 0.999642
#
# XRMS: 0.607176    YRMS: 0.572265
#
# RMS_RA: 6.43683e-06 (deg)   RMS_DEC: 9.90924e-06 (deg)
#
# Final solution based on  46  objects.
#
# wrote XY data to:  u54v0304r_c0m_catalog_fit.match
#
# Writing out shiftfile : 4shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.512183
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 17:43:11.3 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0303r_c0m.fits
#
#     u54v0304r_c0m.fits
#
# ===  Source finding for image 'u54v0303r_c0m.fits':
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 1) started at: 17:43:11.529 (12/12/2017)
#
#      Found 414 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 2) started at: 17:43:11.916 (12/12/2017)
#
#      Found 264 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 3) started at: 17:43:12.149 (12/12/2017)
#
#      Found 396 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 4) started at: 17:43:12.419 (12/12/2017)
#
#      Found 449 objects.
#
# ===  Found a TOTAL of 1523 objects in image 'u54v0303r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0304r_c0m.fits':
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 1) started at: 17:43:13.064 (12/12/2017)
#
#      Found 411 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 2) started at: 17:43:13.513 (12/12/2017)
#
#      Found 216 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 3) started at: 17:43:13.773 (12/12/2017)
#
#      Found 247 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 4) started at: 17:43:14.031 (12/12/2017)
#
#      Found 1802 objects.
#
# ===  Found a TOTAL of 2676 objects in image 'u54v0304r_c0m.fits'
#
#
#
#  Catalog trimmed to 1523 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0303r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0304r_c0m.fits
#
# Matching sources from 'u54v0304r_c0m.fits' with sources from reference image 'u54v0303r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.778178607766 -0.763994210603
#
#     with significance of  381.817009275 and  17.0  matches
#
# Found 52 matches for u54v0304r_c0m.fits...
#
# Computed  rscale  fit for  u54v0304r_c0m.fits :
#
# XSH: -0.464989  YSH: -0.273149    ROT: 359.998    SCALE: 0.999842
#
# XRMS: 0.518888    YRMS: 0.547077
#
# RMS_RA: 4.91832e-06 (deg)   RMS_DEC: 9.12466e-06 (deg)
#
# Final solution based on  51  objects.
#
# wrote XY data to:  u54v0304r_c0m_catalog_fit.match
#
# Writing out shiftfile : 5shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.464989
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 17:43:15.178 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0303r_c0m.fits
#
#     u54v0304r_c0m.fits
#
# ===  Source finding for image 'u54v0303r_c0m.fits':
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 1) started at: 17:43:15.414 (12/12/2017)
#
#      Found 457 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 2) started at: 17:43:15.774 (12/12/2017)
#
#      Found 310 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 3) started at: 17:43:16.083 (12/12/2017)
#
#      Found 444 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 4) started at: 17:43:16.446 (12/12/2017)
#
#      Found 588 objects.
#
# ===  Found a TOTAL of 1799 objects in image 'u54v0303r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0304r_c0m.fits':
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 1) started at: 17:43:17.197 (12/12/2017)
#
#      Found 446 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 2) started at: 17:43:17.700 (12/12/2017)
#
#      Found 223 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 3) started at: 17:43:17.927 (12/12/2017)
#
#      Found 293 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 4) started at: 17:43:18.161 (12/12/2017)
#
#      Found 2272 objects.
#
# ===  Found a TOTAL of 3234 objects in image 'u54v0304r_c0m.fits'
#
#
#
#  Catalog trimmed to 1799 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0303r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0304r_c0m.fits
#
# Matching sources from 'u54v0304r_c0m.fits' with sources from reference image 'u54v0303r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.866767387653 -0.91467157927
#
#     with significance of  427.389283909 and  21.0  matches
#
# Found 62 matches for u54v0304r_c0m.fits...
#
# Computed  rscale  fit for  u54v0304r_c0m.fits :
#
# XSH: -0.39045  YSH: -0.562416    ROT: 0.00815882    SCALE: 0.999728
#
# XRMS: 0.46115    YRMS: 0.687485
#
# RMS_RA: 2.3502e-06 (deg)   RMS_DEC: 1.0386e-05 (deg)
#
# Final solution based on  60  objects.
#
# wrote XY data to:  u54v0304r_c0m_catalog_fit.match
#
# Writing out shiftfile : 6shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.390450
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 17:43:19.334 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0303r_c0m.fits
#
#     u54v0304r_c0m.fits
#
# ===  Source finding for image 'u54v0303r_c0m.fits':
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 1) started at: 17:43:19.59 (12/12/2017)
#
#      Found 335 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 2) started at: 17:43:19.959 (12/12/2017)
#
#      Found 143 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 3) started at: 17:43:20.239 (12/12/2017)
#
#      Found 228 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 4) started at: 17:43:20.554 (12/12/2017)
#
#      Found 190 objects.
#
# ===  Found a TOTAL of 896 objects in image 'u54v0303r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0304r_c0m.fits':
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 1) started at: 17:43:20.991 (12/12/2017)
#
#      Found 387 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 2) started at: 17:43:21.34 (12/12/2017)
#
#      Found 154 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 3) started at: 17:43:21.56 (12/12/2017)
#
#      Found 171 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 4) started at: 17:43:21.887 (12/12/2017)
#
#      Found 488 objects.
#
# ===  Found a TOTAL of 1200 objects in image 'u54v0304r_c0m.fits'
#
#
#
#  Catalog trimmed to 896 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0303r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0304r_c0m.fits
#
# Matching sources from 'u54v0304r_c0m.fits' with sources from reference image 'u54v0303r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.72090910422 -1.08757577089
#
#     with significance of  291.806228515 and  11.0  matches
#
# Found 28 matches for u54v0304r_c0m.fits...
#
# Computed  rscale  fit for  u54v0304r_c0m.fits :
#
# XSH: -0.496942  YSH: -0.501406    ROT: 359.993    SCALE: 0.999704
#
# XRMS: 0.558233    YRMS: 0.664896
#
# RMS_RA: 4.52485e-06 (deg)   RMS_DEC: 1.068e-05 (deg)
#
# Final solution based on  28  objects.
#
# wrote XY data to:  u54v0304r_c0m_catalog_fit.match
#
# Writing out shiftfile : 7shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.496942
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 17:43:22.826 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0303r_c0m.fits
#
#     u54v0304r_c0m.fits
#
# ===  Source finding for image 'u54v0303r_c0m.fits':
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 1) started at: 17:43:23.143 (12/12/2017)
#
#      Found 364 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 2) started at: 17:43:23.66 (12/12/2017)
#
#      Found 163 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 3) started at: 17:43:23.970 (12/12/2017)
#
#      Found 239 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 4) started at: 17:43:24.341 (12/12/2017)
#
#      Found 209 objects.
#
# ===  Found a TOTAL of 975 objects in image 'u54v0303r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0304r_c0m.fits':
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 1) started at: 17:43:24.804 (12/12/2017)
#
#      Found 393 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 2) started at: 17:43:25.439 (12/12/2017)
#
#      Found 160 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 3) started at: 17:43:25.740 (12/12/2017)
#
#      Found 202 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 4) started at: 17:43:26.10 (12/12/2017)
#
#      Found 623 objects.
#
# ===  Found a TOTAL of 1378 objects in image 'u54v0304r_c0m.fits'
#
#
#
#  Catalog trimmed to 975 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0303r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0304r_c0m.fits
#
# Matching sources from 'u54v0304r_c0m.fits' with sources from reference image 'u54v0303r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.746157860439 -1.03720263656
#
#     with significance of  342.670196598 and  15.0  matches
#
# Found 33 matches for u54v0304r_c0m.fits...
#
# Computed  rscale  fit for  u54v0304r_c0m.fits :
#
# XSH: -0.513555  YSH: -0.409076    ROT: 359.992    SCALE: 0.999671
#
# XRMS: 0.562612    YRMS: 0.480595
#
# RMS_RA: 6.46306e-06 (deg)   RMS_DEC: 8.62018e-06 (deg)
#
# Final solution based on  32  objects.
#
# wrote XY data to:  u54v0304r_c0m_catalog_fit.match
#
# Writing out shiftfile : 8shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.513555
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 17:43:27.301 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0303r_c0m.fits
#
#     u54v0304r_c0m.fits
#
# ===  Source finding for image 'u54v0303r_c0m.fits':
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 1) started at: 17:43:27.584 (12/12/2017)
#
#      Found 394 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 2) started at: 17:43:28.061 (12/12/2017)
#
#      Found 178 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 3) started at: 17:43:28.341 (12/12/2017)
#
#      Found 268 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 4) started at: 17:43:28.769 (12/12/2017)
#
#      Found 249 objects.
#
# ===  Found a TOTAL of 1089 objects in image 'u54v0303r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0304r_c0m.fits':
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 1) started at: 17:43:29.289 (12/12/2017)
#
#      Found 399 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 2) started at: 17:43:29.752 (12/12/2017)
#
#      Found 170 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 3) started at: 17:43:30.046 (12/12/2017)
#
#      Found 215 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 4) started at: 17:43:30.39 (12/12/2017)
#
#      Found 868 objects.
#
# ===  Found a TOTAL of 1652 objects in image 'u54v0304r_c0m.fits'
#
#
#
#  Catalog trimmed to 1089 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0303r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0304r_c0m.fits
#
# Matching sources from 'u54v0304r_c0m.fits' with sources from reference image 'u54v0303r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -1.04537831866 -0.854295516109
#
#     with significance of  395.469792959 and  17.0  matches
#
# Found 46 matches for u54v0304r_c0m.fits...
#
# Computed  rscale  fit for  u54v0304r_c0m.fits :
#
# XSH: -0.792481  YSH: -0.547925    ROT: 359.995    SCALE: 0.999585
#
# XRMS: 0.720557    YRMS: 0.650436
#
# RMS_RA: 7.92686e-06 (deg)   RMS_DEC: 1.14351e-05 (deg)
#
# Final solution based on  46  objects.
#
# wrote XY data to:  u54v0304r_c0m_catalog_fit.match
#
# Writing out shiftfile : 9shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.792481

# %%
# change to a jupyter table
dt=test.to_pandas()
dt.to_pickle('data.pickle')
good_table=pandas.read_pickle('data.pickle')

# %%
# take only unfailed sessions
good_conv = good_table[good_table['y_rms'] != 'failed']

# %%
good_conv
# Out:
#          shift                file     x_rms     y_rms  threshold  conv_width  \
# 0   1shift.txt  u54v0303r_c0m.fits  0.000000  0.000000          6         2.5
# 1   1shift.txt  u54v0304r_c0m.fits  0.628857  0.602654          6         2.5
# 2   2shift.txt  u54v0303r_c0m.fits  0.000000  0.000000          6         2.7
# 3   2shift.txt  u54v0304r_c0m.fits  0.587373  0.400444          6         2.7
# 4   3shift.txt  u54v0303r_c0m.fits  0.000000  0.000000          6         2.9
# 5   3shift.txt  u54v0304r_c0m.fits  0.599282  0.574578          6         2.9
# 6   4shift.txt  u54v0303r_c0m.fits  0.000000  0.000000          6         3.1
# 7   4shift.txt  u54v0304r_c0m.fits  0.607176  0.572265          6         3.1
# 8   5shift.txt  u54v0303r_c0m.fits  0.000000  0.000000          6         3.3
# 9   5shift.txt  u54v0304r_c0m.fits  0.518888  0.547077          6         3.3
# 10  6shift.txt  u54v0303r_c0m.fits  0.000000  0.000000          6         3.5
# 11  6shift.txt  u54v0304r_c0m.fits  0.461150  0.687485          6         3.5
# 12  7shift.txt  u54v0303r_c0m.fits  0.000000  0.000000          6         3.7
# 13  7shift.txt  u54v0304r_c0m.fits  0.558233  0.664896          6         3.7
# 14  8shift.txt  u54v0303r_c0m.fits  0.000000  0.000000          6         3.9
# 15  8shift.txt  u54v0304r_c0m.fits  0.562612  0.480595          6         3.9
# 16  9shift.txt  u54v0303r_c0m.fits  0.000000  0.000000          6         4.1
# 17  9shift.txt  u54v0304r_c0m.fits  0.720557  0.650436          6         4.1
#
#     roundlo  roundhi  peakmax
# 0        -1        1     1000
# 1        -1        1     1000
# 2        -1        1     1000
# 3        -1        1     1000
# 4        -1        1     1000
# 5        -1        1     1000
# 6        -1        1     1000
# 7        -1        1     1000
# 8        -1        1     1000
# 9        -1        1     1000
# 10       -1        1     1000
# 11       -1        1     1000
# 12       -1        1     1000
# 13       -1        1     1000
# 14       -1        1     1000
# 15       -1        1     1000
# 16       -1        1     1000
# 17       -1        1     1000

# %%
# plot figure for all sub-exp
plt.figure(figsize = (7,7))
plt.plot(good_conv['conv_width'],good_conv['x_rms'],'.g')
plt.plot(good_conv['conv_width'],good_conv['y_rms'],'.b')
plt.title('x,y_rms(conv_width)-g,b')
plt.show()

# %%
# plot figure for choosen sub-exp
plt.figure(figsize = (7,7))
plt.plot(good_conv[good_conv['file'] == 'u6ea5402m_c0m.fits']['conv_width'],good_conv[good_conv['file'] == 'u6ea5402m_c0m.fits']['y_rms'],'.b')
plt.plot(good_conv[good_conv['file'] == 'u6ea5403m_c0m.fits']['conv_width'],good_conv[good_conv['file'] == 'u6ea5403m_c0m.fits']['y_rms'],'.g')
plt.title('y_rms(conv)-two filters')
plt.show()

# %%
#############################################thresh = 6?, conv = 3.3?, roundlo?

# %%
# tweak_run(path, n_up, threshold_ini, threshold_gap, conv_width_ini, conv_width_gap, 
# roundlo_val_ini, roundlo_gap, roundhi_val_ini, roundhi_gap, peakmax_val_ini, peakmax_gap):
test = tweak_run('/Users/natalie/anaconda2/envs/iraf27/iraf/sn/2001ci/2001ci_pre/tweak_547',10,6,0,3.3,0,-0.5,0.1,1,0,1000,0)
# Out:
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 17:47:24.942 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0303r_c0m.fits
#
#     u54v0304r_c0m.fits
#
# ===  Source finding for image 'u54v0303r_c0m.fits':
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 1) started at: 17:47:25.26 (12/12/2017)
#
#      Found 293 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 2) started at: 17:47:25.795 (12/12/2017)
#
#      Found 234 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 3) started at: 17:47:26.132 (12/12/2017)
#
#      Found 330 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 4) started at: 17:47:26.492 (12/12/2017)
#
#      Found 343 objects.
#
# ===  Found a TOTAL of 1200 objects in image 'u54v0303r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0304r_c0m.fits':
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 1) started at: 17:47:27.023 (12/12/2017)
#
#      Found 290 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 2) started at: 17:47:27.457 (12/12/2017)
#
#      Found 183 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 3) started at: 17:47:27.758 (12/12/2017)
#
#      Found 208 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 4) started at: 17:47:28.216 (12/12/2017)
#
#      Found 1273 objects.
#
# ===  Found a TOTAL of 1954 objects in image 'u54v0304r_c0m.fits'
#
#
#
#  Catalog trimmed to 1200 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0303r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0304r_c0m.fits
#
# Matching sources from 'u54v0304r_c0m.fits' with sources from reference image 'u54v0303r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.925990405033 -0.425990405033
#
#     with significance of  359.558774326 and  12.0  matches
#
# Found 37 matches for u54v0304r_c0m.fits...
#
# Computed  rscale  fit for  u54v0304r_c0m.fits :
#
# XSH: -0.136812  YSH: -0.207592    ROT: 0.00695063    SCALE: 0.999883
#
# XRMS: 0.293693    YRMS: 0.521202
#
# RMS_RA: 6.59817e-07 (deg)   RMS_DEC: 7.55743e-06 (deg)
#
# Final solution based on  34  objects.
#
# wrote XY data to:  u54v0304r_c0m_catalog_fit.match
#
# Writing out shiftfile : 1shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.136812
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 17:47:29.649 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0303r_c0m.fits
#
#     u54v0304r_c0m.fits
#
# ===  Source finding for image 'u54v0303r_c0m.fits':
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 1) started at: 17:47:29.904 (12/12/2017)
#
#      Found 259 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 2) started at: 17:47:30.301 (12/12/2017)
#
#      Found 207 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 3) started at: 17:47:30.58 (12/12/2017)
#
#      Found 307 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 4) started at: 17:47:30.887 (12/12/2017)
#
#      Found 313 objects.
#
# ===  Found a TOTAL of 1086 objects in image 'u54v0303r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0304r_c0m.fits':
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 1) started at: 17:47:31.387 (12/12/2017)
#
#      Found 265 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 2) started at: 17:47:31.797 (12/12/2017)
#
#      Found 168 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 3) started at: 17:47:32.058 (12/12/2017)
#
#      Found 196 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 4) started at: 17:47:32.306 (12/12/2017)
#
#      Found 1134 objects.
#
# ===  Found a TOTAL of 1763 objects in image 'u54v0304r_c0m.fits'
#
#
#
#  Catalog trimmed to 1086 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0303r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0304r_c0m.fits
#
# Matching sources from 'u54v0304r_c0m.fits' with sources from reference image 'u54v0303r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.977501144021 -0.484963830588
#
#     with significance of  322.661346969 and  11.0  matches
#
# Found 32 matches for u54v0304r_c0m.fits...
#
# Computed  rscale  fit for  u54v0304r_c0m.fits :
#
# XSH: -0.0523634  YSH: -0.1034    ROT: 0.00518483    SCALE: 0.999951
#
# XRMS: 0.202495    YRMS: 0.305162
#
# RMS_RA: 9.99041e-07 (deg)   RMS_DEC: 4.59769e-06 (deg)
#
# Final solution based on  29  objects.
#
# wrote XY data to:  u54v0304r_c0m_catalog_fit.match
#
# Writing out shiftfile : 2shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.052363
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 17:47:33.331 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0303r_c0m.fits
#
#     u54v0304r_c0m.fits
#
# ===  Source finding for image 'u54v0303r_c0m.fits':
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 1) started at: 17:47:33.579 (12/12/2017)
#
#      Found 229 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 2) started at: 17:47:33.944 (12/12/2017)
#
#      Found 182 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 3) started at: 17:47:34.245 (12/12/2017)
#
#      Found 269 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 4) started at: 17:47:34.698 (12/12/2017)
#
#      Found 273 objects.
#
# ===  Found a TOTAL of 953 objects in image 'u54v0303r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0304r_c0m.fits':
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 1) started at: 17:47:35.18 (12/12/2017)
#
#      Found 229 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 2) started at: 17:47:35.611 (12/12/2017)
#
#      Found 144 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 3) started at: 17:47:35.846 (12/12/2017)
#
#      Found 171 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 4) started at: 17:47:36.083 (12/12/2017)
#
#      Found 974 objects.
#
# ===  Found a TOTAL of 1518 objects in image 'u54v0304r_c0m.fits'
#
#
#
#  Catalog trimmed to 953 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0303r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0304r_c0m.fits
#
# Matching sources from 'u54v0304r_c0m.fits' with sources from reference image 'u54v0303r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.962575770886 -0.629242437553
#
#     with significance of  309.307128919 and  9.0  matches
#
# Found 24 matches for u54v0304r_c0m.fits...
#
# Computed  rscale  fit for  u54v0304r_c0m.fits :
#
# XSH: -0.0127051  YSH: -0.0818334    ROT: 0.00930023    SCALE: 0.999956
#
# XRMS: 0.197283    YRMS: 0.246071
#
# RMS_RA: 1.48775e-06 (deg)   RMS_DEC: 3.89983e-06 (deg)
#
# Final solution based on  21  objects.
#
# wrote XY data to:  u54v0304r_c0m_catalog_fit.match
#
# Writing out shiftfile : 3shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.012705
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 17:47:37.164 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0303r_c0m.fits
#
#     u54v0304r_c0m.fits
#
# ===  Source finding for image 'u54v0303r_c0m.fits':
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 1) started at: 17:47:37.461 (12/12/2017)
#
#      Found 179 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 2) started at: 17:47:37.88 (12/12/2017)
#
#      Found 150 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 3) started at: 17:47:38.166 (12/12/2017)
#
#      Found 214 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 4) started at: 17:47:38.524 (12/12/2017)
#
#      Found 225 objects.
#
# ===  Found a TOTAL of 768 objects in image 'u54v0303r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0304r_c0m.fits':
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 1) started at: 17:47:38.959 (12/12/2017)
#
#      Found 190 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 2) started at: 17:47:39.376 (12/12/2017)
#
#      Found 118 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 3) started at: 17:47:39.649 (12/12/2017)
#
#      Found 147 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 4) started at: 17:47:39.897 (12/12/2017)
#
#      Found 806 objects.
#
# ===  Found a TOTAL of 1261 objects in image 'u54v0304r_c0m.fits'
#
#
#
#  Catalog trimmed to 768 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0303r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0304r_c0m.fits
#
# Matching sources from 'u54v0304r_c0m.fits' with sources from reference image 'u54v0303r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -1.12924243755 -0.712575770886
#
#     with significance of  252.855690068 and  7.0  matches
#
# Found 18 matches for u54v0304r_c0m.fits...
#
# Computed  rscale  fit for  u54v0304r_c0m.fits :
#
# XSH: -0.47867  YSH: -0.3475    ROT: 359.999    SCALE: 0.999751
#
# XRMS: 0.706935    YRMS: 0.584206
#
# RMS_RA: 8.3185e-06 (deg)   RMS_DEC: 1.06089e-05 (deg)
#
# Final solution based on  18  objects.
#
# wrote XY data to:  u54v0304r_c0m_catalog_fit.match
#
# Writing out shiftfile : 4shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.478670
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 17:47:41.021 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0303r_c0m.fits
#
#     u54v0304r_c0m.fits
#
# ===  Source finding for image 'u54v0303r_c0m.fits':
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 1) started at: 17:47:41.251 (12/12/2017)
#
#      Found 151 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 2) started at: 17:47:41.717 (12/12/2017)
#
#      Found 116 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 3) started at: 17:47:41.979 (12/12/2017)
#
#      Found 181 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 4) started at: 17:47:42.257 (12/12/2017)
#
#      Found 181 objects.
#
# ===  Found a TOTAL of 629 objects in image 'u54v0303r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0304r_c0m.fits':
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 1) started at: 17:47:42.715 (12/12/2017)
#
#      Found 154 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 2) started at: 17:47:43.193 (12/12/2017)
#
#      Found 91 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 3) started at: 17:47:43.439 (12/12/2017)
#
#      Found 123 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 4) started at: 17:47:43.726 (12/12/2017)
#
#      Found 660 objects.
#
# ===  Found a TOTAL of 1028 objects in image 'u54v0304r_c0m.fits'
#
#
#
#  Catalog trimmed to 629 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0303r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0304r_c0m.fits
#
# Matching sources from 'u54v0304r_c0m.fits' with sources from reference image 'u54v0303r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -1.32621213452 -0.962575770886
#
#     with significance of  184.298670641 and  4.0  matches
#
# ##############################################################################
# #                                                                            #
# # WARNING:                                                                   #
# # Not enough matches (< 15) found for input image: u54v0304r_c0m.fits        #
# #                                                                            #
# ##############################################################################
#
#
# Unable to match the following images:
#
# -------------------------------------
#
# u54v0304r_c0m.fits
#
#
# Writing out shiftfile : 5shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# nan
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 17:47:44.724 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0303r_c0m.fits
#
#     u54v0304r_c0m.fits
#
# ===  Source finding for image 'u54v0303r_c0m.fits':
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 1) started at: 17:47:45.015 (12/12/2017)
#
#      Found 120 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 2) started at: 17:47:45.442 (12/12/2017)
#
#      Found 91 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 3) started at: 17:47:45.709 (12/12/2017)
#
#      Found 136 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 4) started at: 17:47:46.111 (12/12/2017)
#
#      Found 133 objects.
#
# ===  Found a TOTAL of 480 objects in image 'u54v0303r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0304r_c0m.fits':
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 1) started at: 17:47:46.611 (12/12/2017)
#
#      Found 122 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 2) started at: 17:47:47.06 (12/12/2017)
#
#      Found 64 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 3) started at: 17:47:47.310 (12/12/2017)
#
#      Found 91 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 4) started at: 17:47:47.583 (12/12/2017)
#
#      Found 537 objects.
#
# ===  Found a TOTAL of 814 objects in image 'u54v0304r_c0m.fits'
#
#
#
#  Catalog trimmed to 480 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0303r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0304r_c0m.fits
#
# Matching sources from 'u54v0304r_c0m.fits' with sources from reference image 'u54v0303r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -1.29590910422 -1.09590910422
#
#     with significance of  196.46304302 and  4.0  matches
#
# ##############################################################################
# #                                                                            #
# # WARNING:                                                                   #
# # Not enough matches (< 15) found for input image: u54v0304r_c0m.fits        #
# #                                                                            #
# ##############################################################################
#
#
# Unable to match the following images:
#
# -------------------------------------
#
# u54v0304r_c0m.fits
#
#
# Writing out shiftfile : 6shift.txt
#
# Trailer file written to:  tweakreg.log
# 0.000000
# nan
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 17:47:48.571 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0303r_c0m.fits
#
#     u54v0304r_c0m.fits
#
# ===  Source finding for image 'u54v0303r_c0m.fits':
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 1) started at: 17:47:48.919 (12/12/2017)
#
#      Found 90 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 2) started at: 17:47:49.296 (12/12/2017)
#
#      Found 70 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 3) started at: 17:47:49.569 (12/12/2017)
#
#      Found 93 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 4) started at: 17:47:49.922 (12/12/2017)
#
#      Found 98 objects.
#
# ===  Found a TOTAL of 351 objects in image 'u54v0303r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0304r_c0m.fits':
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 1) started at: 17:47:50.442 (12/12/2017)
#
#      Found 89 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 2) started at: 17:47:50.88 (12/12/2017)
#
#      Found 48 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 3) started at: 17:47:51.165 (12/12/2017)
#
#      Found 64 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 4) started at: 17:47:51.416 (12/12/2017)
#
#      Found 403 objects.
#
# ===  Found a TOTAL of 604 objects in image 'u54v0304r_c0m.fits'
#
#
#
#  Catalog trimmed to 351 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0303r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0304r_c0m.fits
#
# Matching sources from 'u54v0304r_c0m.fits' with sources from reference image 'u54v0303r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  1.37075756245 -15.9625757709
#
#     with significance of  130.318839774 and  2.0  matches
#
# ##############################################################################
# #                                                                            #
# # WARNING:                                                                   #
# # Not enough matches (< 15) found for input image: u54v0304r_c0m.fits        #
# #                                                                            #
# ##############################################################################
#
#
# Unable to match the following images:
#
# -------------------------------------
#
# u54v0304r_c0m.fits
#
#
# Writing out shiftfile : 7shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# nan
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 17:47:52.410 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0303r_c0m.fits
#
#     u54v0304r_c0m.fits
#
# ===  Source finding for image 'u54v0303r_c0m.fits':
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 1) started at: 17:47:52.650 (12/12/2017)
#
#      Found 64 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 2) started at: 17:47:53.069 (12/12/2017)
#
#      Found 47 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 3) started at: 17:47:53.349 (12/12/2017)
#
#      Found 61 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 4) started at: 17:47:53.61 (12/12/2017)
#
#      Found 63 objects.
#
# ===  Found a TOTAL of 235 objects in image 'u54v0303r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0304r_c0m.fits':
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 1) started at: 17:47:54.103 (12/12/2017)
#
#      Found 56 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 2) started at: 17:47:54.589 (12/12/2017)
#
#      Found 28 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 3) started at: 17:47:54.859 (12/12/2017)
#
#      Found 42 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 4) started at: 17:47:55.141 (12/12/2017)
#
#      Found 270 objects.
#
# ===  Found a TOTAL of 396 objects in image 'u54v0304r_c0m.fits'
#
#
#
#  Catalog trimmed to 235 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0303r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0304r_c0m.fits
#
# Matching sources from 'u54v0304r_c0m.fits' with sources from reference image 'u54v0303r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  0.787424229114 -15.9625757709
#
#     with significance of  122.865780427 and  2.0  matches
#
# ##############################################################################
# #                                                                            #
# # WARNING:                                                                   #
# # Not enough matches (< 15) found for input image: u54v0304r_c0m.fits        #
# #                                                                            #
# ##############################################################################
#
#
# Unable to match the following images:
#
# -------------------------------------
#
# u54v0304r_c0m.fits
#
#
# Writing out shiftfile : 8shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# nan
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 17:47:55.971 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0303r_c0m.fits
#
#     u54v0304r_c0m.fits
#
# ===  Source finding for image 'u54v0303r_c0m.fits':
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 1) started at: 17:47:56.188 (12/12/2017)
#
#      Found 35 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 2) started at: 17:47:56.540 (12/12/2017)
#
#      Found 15 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 3) started at: 17:47:56.775 (12/12/2017)
#
#      Found 41 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 4) started at: 17:47:57.113 (12/12/2017)
#
#      Found 40 objects.
#
# ===  Found a TOTAL of 131 objects in image 'u54v0303r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0304r_c0m.fits':
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 1) started at: 17:47:57.542 (12/12/2017)
#
#      Found 30 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 2) started at: 17:47:57.935 (12/12/2017)
#
#      Found 14 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 3) started at: 17:47:58.214 (12/12/2017)
#
#      Found 22 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 4) started at: 17:47:58.486 (12/12/2017)
#
#      Found 179 objects.
#
# ===  Found a TOTAL of 245 objects in image 'u54v0304r_c0m.fits'
#
#
#
#  Catalog trimmed to 131 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0303r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0304r_c0m.fits
#
# Matching sources from 'u54v0304r_c0m.fits' with sources from reference image 'u54v0303r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -8.96257577089 -20.9625757709
#
#     with significance of  43.6004587132 and  1.0  matches
#
# ##############################################################################
# #                                                                            #
# # WARNING:                                                                   #
# # Not enough matches (< 15) found for input image: u54v0304r_c0m.fits        #
# #                                                                            #
# ##############################################################################
#
#
# Unable to match the following images:
#
# -------------------------------------
#
# u54v0304r_c0m.fits
#
#
# Writing out shiftfile : 9shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# nan

# %%
# change to a jupyter table
dt=test.to_pandas()
dt.to_pickle('data.pickle')
good_table=pandas.read_pickle('data.pickle')

# %%
# take only unfailed sessions
good_roundlo = good_table[good_table['y_rms'] != 'failed']

# %%
good_roundlo
# Out:
#          shift                file     x_rms     y_rms  threshold  conv_width  \
# 0   1shift.txt  u54v0303r_c0m.fits  0.000000  0.000000          6         3.3
# 1   1shift.txt  u54v0304r_c0m.fits  0.293693  0.521202          6         3.3
# 2   2shift.txt  u54v0303r_c0m.fits  0.000000  0.000000          6         3.3
# 3   2shift.txt  u54v0304r_c0m.fits  0.202495  0.305162          6         3.3
# 4   3shift.txt  u54v0303r_c0m.fits  0.000000  0.000000          6         3.3
# 5   3shift.txt  u54v0304r_c0m.fits  0.197283  0.246071          6         3.3
# 6   4shift.txt  u54v0303r_c0m.fits  0.000000  0.000000          6         3.3
# 7   4shift.txt  u54v0304r_c0m.fits  0.706935  0.584206          6         3.3
# 8   5shift.txt  u54v0303r_c0m.fits  0.000000  0.000000          6         3.3
# 10  6shift.txt  u54v0303r_c0m.fits  0.000000  0.000000          6         3.3
# 12  7shift.txt  u54v0303r_c0m.fits  0.000000  0.000000          6         3.3
# 14  8shift.txt  u54v0303r_c0m.fits  0.000000  0.000000          6         3.3
# 16  9shift.txt  u54v0303r_c0m.fits  0.000000  0.000000          6         3.3
#
#     roundlo  roundhi  peakmax
# 0      -0.5        1     1000
# 1      -0.5        1     1000
# 2      -0.4        1     1000
# 3      -0.4        1     1000
# 4      -0.3        1     1000
# 5      -0.3        1     1000
# 6      -0.2        1     1000
# 7      -0.2        1     1000
# 8      -0.1        1     1000
# 10      0.0        1     1000
# 12      0.1        1     1000
# 14      0.2        1     1000
# 16      0.3        1     1000

# %%
# plot figure for all sub-exp
plt.figure(figsize = (7,7))
plt.plot(good_roundlo['roundlo'],good_roundlo['x_rms'],'.g')
plt.plot(good_roundlo['roundlo'],good_roundlo['y_rms'],'.b')
plt.title('x,y_rms(roundlo)-g,b')
plt.show()

# %%
# plot figure for choosen sub-exp
plt.figure(figsize = (7,7))
plt.plot(good_round[good_round['file'] == 'u6ea5402m_c0m.fits']['roundlo'],good_round[good_round['file'] == 'u6ea5402m_c0m.fits']['y_rms'],'.b')
plt.plot(good_round[good_round['file'] == 'u6ea5403m_c0m.fits']['roundlo'],good_round[good_round['file'] == 'u6ea5403m_c0m.fits']['y_rms'],'.g')
plt.title('y_rms(roundlo)-two filters')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-1b5e9d62f47a> in <module>()
#       1 # plot figure for choosen sub-exp
#       2 plt.figure(figsize = (7,7))
# ----> 3 plt.plot(good_round[good_round['file'] == 'u6ea5402m_c0m.fits']['roundlo'],good_round[good_round['file'] == 'u6ea5402m_c0m.fits']['y_rms'],'.b')
#       4 plt.plot(good_round[good_round['file'] == 'u6ea5403m_c0m.fits']['roundlo'],good_round[good_round['file'] == 'u6ea5403m_c0m.fits']['y_rms'],'.g')
#       5 plt.title('y_rms(roundlo)-two filters')
#
# NameError: name 'good_round' is not defined

# %%
#############################################thresh = 6, conv = 3.3, roundlo = -0.3, roundhi?

# %%
# tweak_run(path, n_up, threshold_ini, threshold_gap, conv_width_ini, conv_width_gap, 
# roundlo_val_ini, roundlo_gap, roundhi_val_ini, roundhi_gap, peakmax_val_ini, peakmax_gap):
test = tweak_run('/Users/natalie/anaconda2/envs/iraf27/iraf/sn/2001ci/2001ci_pre/tweak_547',10,6,0,3.3,0,-0.3,0,0.5,0.2,1000,0)
# Out:
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 17:49:02.757 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0303r_c0m.fits
#
#     u54v0304r_c0m.fits
#
# ===  Source finding for image 'u54v0303r_c0m.fits':
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 1) started at: 17:49:03.134 (12/12/2017)
#
#      Found 156 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 2) started at: 17:49:03.54 (12/12/2017)
#
#      Found 148 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 3) started at: 17:49:03.815 (12/12/2017)
#
#      Found 198 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 4) started at: 17:49:04.137 (12/12/2017)
#
#      Found 193 objects.
#
# ===  Found a TOTAL of 695 objects in image 'u54v0303r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0304r_c0m.fits':
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 1) started at: 17:49:04.676 (12/12/2017)
#
#      Found 147 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 2) started at: 17:49:05.084 (12/12/2017)
#
#      Found 122 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 3) started at: 17:49:05.332 (12/12/2017)
#
#      Found 136 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 4) started at: 17:49:05.656 (12/12/2017)
#
#      Found 553 objects.
#
# ===  Found a TOTAL of 958 objects in image 'u54v0304r_c0m.fits'
#
#
#
#  Catalog trimmed to 695 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0303r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0304r_c0m.fits
#
# Matching sources from 'u54v0304r_c0m.fits' with sources from reference image 'u54v0303r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -1.14114719946 -0.676861485172
#
#     with significance of  233.525801572 and  7.0  matches
#
# Found 17 matches for u54v0304r_c0m.fits...
#
# Computed  rscale  fit for  u54v0304r_c0m.fits :
#
# XSH: -0.0224204  YSH: -0.107706    ROT: 0.00978897    SCALE: 0.999977
#
# XRMS: 0.205866    YRMS: 0.239315
#
# RMS_RA: 1.72777e-06 (deg)   RMS_DEC: 3.872e-06 (deg)
#
# Final solution based on  16  objects.
#
# wrote XY data to:  u54v0304r_c0m_catalog_fit.match
#
# Writing out shiftfile : 1shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.022420
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 17:49:06.953 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0303r_c0m.fits
#
#     u54v0304r_c0m.fits
#
# ===  Source finding for image 'u54v0303r_c0m.fits':
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 1) started at: 17:49:07.247 (12/12/2017)
#
#      Found 189 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 2) started at: 17:49:07.666 (12/12/2017)
#
#      Found 163 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 3) started at: 17:49:07.92 (12/12/2017)
#
#      Found 230 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 4) started at: 17:49:08.278 (12/12/2017)
#
#      Found 232 objects.
#
# ===  Found a TOTAL of 814 objects in image 'u54v0303r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0304r_c0m.fits':
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 1) started at: 17:49:08.809 (12/12/2017)
#
#      Found 186 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 2) started at: 17:49:09.279 (12/12/2017)
#
#      Found 133 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 3) started at: 17:49:09.498 (12/12/2017)
#
#      Found 151 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 4) started at: 17:49:09.79 (12/12/2017)
#
#      Found 732 objects.
#
# ===  Found a TOTAL of 1202 objects in image 'u54v0304r_c0m.fits'
#
#
#
#  Catalog trimmed to 814 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0303r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0304r_c0m.fits
#
# Matching sources from 'u54v0304r_c0m.fits' with sources from reference image 'u54v0303r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.935548743859 -0.611224419535
#
#     with significance of  271.497582862 and  9.0  matches
#
# Found 22 matches for u54v0304r_c0m.fits...
#
# Computed  rscale  fit for  u54v0304r_c0m.fits :
#
# XSH: -0.0127051  YSH: -0.0818334    ROT: 0.00930023    SCALE: 0.999956
#
# XRMS: 0.197283    YRMS: 0.246071
#
# RMS_RA: 1.48775e-06 (deg)   RMS_DEC: 3.89983e-06 (deg)
#
# Final solution based on  21  objects.
#
# wrote XY data to:  u54v0304r_c0m_catalog_fit.match
#
# Writing out shiftfile : 2shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.012705
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 17:49:10.930 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0303r_c0m.fits
#
#     u54v0304r_c0m.fits
#
# ===  Source finding for image 'u54v0303r_c0m.fits':
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 1) started at: 17:49:11.209 (12/12/2017)
#
#      Found 218 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 2) started at: 17:49:11.695 (12/12/2017)
#
#      Found 179 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 3) started at: 17:49:11.972 (12/12/2017)
#
#      Found 261 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 4) started at: 17:49:12.303 (12/12/2017)
#
#      Found 263 objects.
#
# ===  Found a TOTAL of 921 objects in image 'u54v0303r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0304r_c0m.fits':
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 1) started at: 17:49:12.814 (12/12/2017)
#
#      Found 216 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 2) started at: 17:49:13.272 (12/12/2017)
#
#      Found 143 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 3) started at: 17:49:13.534 (12/12/2017)
#
#      Found 163 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 4) started at: 17:49:13.802 (12/12/2017)
#
#      Found 908 objects.
#
# ===  Found a TOTAL of 1430 objects in image 'u54v0304r_c0m.fits'
#
#
#
#  Catalog trimmed to 921 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0303r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0304r_c0m.fits
#
# Matching sources from 'u54v0304r_c0m.fits' with sources from reference image 'u54v0303r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.918131326442 -0.518131326442
#
#     with significance of  289.849136171 and  9.0  matches
#
# Found 25 matches for u54v0304r_c0m.fits...
#
# Computed  rscale  fit for  u54v0304r_c0m.fits :
#
# XSH: -0.00693294  YSH: -0.0506201    ROT: 0.00963356    SCALE: 0.99997
#
# XRMS: 0.196748    YRMS: 0.266731
#
# RMS_RA: 1.26959e-06 (deg)   RMS_DEC: 4.13049e-06 (deg)
#
# Final solution based on  22  objects.
#
# wrote XY data to:  u54v0304r_c0m_catalog_fit.match
#
# Writing out shiftfile : 3shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.006933
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 17:49:15.05 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0303r_c0m.fits
#
#     u54v0304r_c0m.fits
#
# ===  Source finding for image 'u54v0303r_c0m.fits':
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 1) started at: 17:49:15.285 (12/12/2017)
#
#      Found 241 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 2) started at: 17:49:15.717 (12/12/2017)
#
#      Found 190 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 3) started at: 17:49:16.010 (12/12/2017)
#
#      Found 275 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 4) started at: 17:49:16.276 (12/12/2017)
#
#      Found 283 objects.
#
# ===  Found a TOTAL of 989 objects in image 'u54v0303r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0304r_c0m.fits':
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 1) started at: 17:49:16.861 (12/12/2017)
#
#      Found 243 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 2) started at: 17:49:17.310 (12/12/2017)
#
#      Found 147 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 3) started at: 17:49:17.576 (12/12/2017)
#
#      Found 174 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 4) started at: 17:49:17.841 (12/12/2017)
#
#      Found 1037 objects.
#
# ===  Found a TOTAL of 1601 objects in image 'u54v0304r_c0m.fits'
#
#
#
#  Catalog trimmed to 989 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0303r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0304r_c0m.fits
#
# Matching sources from 'u54v0304r_c0m.fits' with sources from reference image 'u54v0303r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.980757589068 -0.526212134523
#
#     with significance of  325.160240217 and  10.0  matches
#
# Found 26 matches for u54v0304r_c0m.fits...
#
# Computed  rscale  fit for  u54v0304r_c0m.fits :
#
# XSH: -0.0170024  YSH: -0.031205    ROT: 0.00904295    SCALE: 0.999974
#
# XRMS: 0.195101    YRMS: 0.270131
#
# RMS_RA: 1.20239e-06 (deg)   RMS_DEC: 4.15962e-06 (deg)
#
# Final solution based on  23  objects.
#
# wrote XY data to:  u54v0304r_c0m_catalog_fit.match
#
# Writing out shiftfile : 4shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.017002
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 17:49:19.018 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0303r_c0m.fits
#
#     u54v0304r_c0m.fits
#
# ===  Source finding for image 'u54v0303r_c0m.fits':
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 1) started at: 17:49:19.283 (12/12/2017)
#
#      Found 263 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 2) started at: 17:49:19.676 (12/12/2017)
#
#      Found 196 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 3) started at: 17:49:19.936 (12/12/2017)
#
#      Found 288 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 4) started at: 17:49:20.214 (12/12/2017)
#
#      Found 291 objects.
#
# ===  Found a TOTAL of 1038 objects in image 'u54v0303r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0304r_c0m.fits':
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 1) started at: 17:49:20.778 (12/12/2017)
#
#      Found 256 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 2) started at: 17:49:21.266 (12/12/2017)
#
#      Found 155 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 3) started at: 17:49:21.516 (12/12/2017)
#
#      Found 177 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 4) started at: 17:49:21.82 (12/12/2017)
#
#      Found 1099 objects.
#
# ===  Found a TOTAL of 1687 objects in image 'u54v0304r_c0m.fits'
#
#
#
#  Catalog trimmed to 1038 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0303r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0304r_c0m.fits
#
# Matching sources from 'u54v0304r_c0m.fits' with sources from reference image 'u54v0303r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.879242437553 -0.579242437553
#
#     with significance of  298.906921676 and  10.0  matches
#
# Found 28 matches for u54v0304r_c0m.fits...
#
# Computed  rscale  fit for  u54v0304r_c0m.fits :
#
# XSH: 0.0228712  YSH: -0.111494    ROT: 0.0115057    SCALE: 1.00004
#
# XRMS: 0.217771    YRMS: 0.440821
#
# RMS_RA: 5.64538e-08 (deg)   RMS_DEC: 6.21855e-06 (deg)
#
# Final solution based on  25  objects.
#
# wrote XY data to:  u54v0304r_c0m_catalog_fit.match
#
# Writing out shiftfile : 5shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 0.022871
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 17:49:22.978 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0303r_c0m.fits
#
#     u54v0304r_c0m.fits
#
# ===  Source finding for image 'u54v0303r_c0m.fits':
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 1) started at: 17:49:23.186 (12/12/2017)
#
#      Found 278 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 2) started at: 17:49:23.568 (12/12/2017)
#
#      Found 200 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 3) started at: 17:49:23.85 (12/12/2017)
#
#      Found 292 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 4) started at: 17:49:24.148 (12/12/2017)
#
#      Found 296 objects.
#
# ===  Found a TOTAL of 1066 objects in image 'u54v0303r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0304r_c0m.fits':
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 1) started at: 17:49:24.710 (12/12/2017)
#
#      Found 273 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 2) started at: 17:49:25.176 (12/12/2017)
#
#      Found 162 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 3) started at: 17:49:25.436 (12/12/2017)
#
#      Found 184 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 4) started at: 17:49:25.691 (12/12/2017)
#
#      Found 1148 objects.
#
# ===  Found a TOTAL of 1767 objects in image 'u54v0304r_c0m.fits'
#
#
#
#  Catalog trimmed to 1066 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0303r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0304r_c0m.fits
#
# Matching sources from 'u54v0304r_c0m.fits' with sources from reference image 'u54v0303r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.947191155502 -0.501037309348
#
#     with significance of  306.691526306 and  10.0  matches
#
# Found 27 matches for u54v0304r_c0m.fits...
#
# Computed  rscale  fit for  u54v0304r_c0m.fits :
#
# XSH: -0.00478969  YSH: -0.0697055    ROT: 0.0105745    SCALE: 0.999964
#
# XRMS: 0.192304    YRMS: 0.296821
#
# RMS_RA: 8.78306e-07 (deg)   RMS_DEC: 4.44567e-06 (deg)
#
# Final solution based on  24  objects.
#
# wrote XY data to:  u54v0304r_c0m_catalog_fit.match
#
# Writing out shiftfile : 6shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.004790
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 17:49:26.9 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0303r_c0m.fits
#
#     u54v0304r_c0m.fits
#
# ===  Source finding for image 'u54v0303r_c0m.fits':
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 1) started at: 17:49:27.204 (12/12/2017)
#
#      Found 291 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 2) started at: 17:49:27.637 (12/12/2017)
#
#      Found 205 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 3) started at: 17:49:27.906 (12/12/2017)
#
#      Found 297 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 4) started at: 17:49:28.216 (12/12/2017)
#
#      Found 298 objects.
#
# ===  Found a TOTAL of 1091 objects in image 'u54v0303r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0304r_c0m.fits':
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 1) started at: 17:49:28.777 (12/12/2017)
#
#      Found 286 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 2) started at: 17:49:29.196 (12/12/2017)
#
#      Found 168 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 3) started at: 17:49:29.474 (12/12/2017)
#
#      Found 187 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 4) started at: 17:49:29.784 (12/12/2017)
#
#      Found 1195 objects.
#
# ===  Found a TOTAL of 1836 objects in image 'u54v0304r_c0m.fits'
#
#
#
#  Catalog trimmed to 1091 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0303r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0304r_c0m.fits
#
# Matching sources from 'u54v0304r_c0m.fits' with sources from reference image 'u54v0303r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.962575770886 -0.407020215331
#
#     with significance of  333.037034978 and  10.0  matches
#
# Found 27 matches for u54v0304r_c0m.fits...
#
# Computed  rscale  fit for  u54v0304r_c0m.fits :
#
# XSH: -0.00478969  YSH: -0.0697055    ROT: 0.0105745    SCALE: 0.999964
#
# XRMS: 0.192304    YRMS: 0.296821
#
# RMS_RA: 8.78306e-07 (deg)   RMS_DEC: 4.44567e-06 (deg)
#
# Final solution based on  24  objects.
#
# wrote XY data to:  u54v0304r_c0m_catalog_fit.match
#
# Writing out shiftfile : 7shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.004790
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 17:49:30.888 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0303r_c0m.fits
#
#     u54v0304r_c0m.fits
#
# ===  Source finding for image 'u54v0303r_c0m.fits':
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 1) started at: 17:49:31.126 (12/12/2017)
#
#      Found 304 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 2) started at: 17:49:31.519 (12/12/2017)
#
#      Found 206 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 3) started at: 17:49:31.887 (12/12/2017)
#
#      Found 299 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 4) started at: 17:49:32.335 (12/12/2017)
#
#      Found 301 objects.
#
# ===  Found a TOTAL of 1110 objects in image 'u54v0303r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0304r_c0m.fits':
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 1) started at: 17:49:33.1 (12/12/2017)
#
#      Found 294 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 2) started at: 17:49:33.702 (12/12/2017)
#
#      Found 169 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 3) started at: 17:49:33.962 (12/12/2017)
#
#      Found 190 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 4) started at: 17:49:34.308 (12/12/2017)
#
#      Found 1214 objects.
#
# ===  Found a TOTAL of 1867 objects in image 'u54v0304r_c0m.fits'
#
#
#
#  Catalog trimmed to 1110 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0303r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0304r_c0m.fits
#
# Matching sources from 'u54v0304r_c0m.fits' with sources from reference image 'u54v0303r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.98997303116 -0.387233305133
#
#     with significance of  333.037034978 and  10.0  matches
#
# Found 27 matches for u54v0304r_c0m.fits...
#
# Computed  rscale  fit for  u54v0304r_c0m.fits :
#
# XSH: -0.00478969  YSH: -0.0697055    ROT: 0.0105745    SCALE: 0.999964
#
# XRMS: 0.192304    YRMS: 0.296821
#
# RMS_RA: 8.78306e-07 (deg)   RMS_DEC: 4.44567e-06 (deg)
#
# Final solution based on  24  objects.
#
# wrote XY data to:  u54v0304r_c0m_catalog_fit.match
#
# Writing out shiftfile : 8shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.004790
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 17:49:35.599 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0303r_c0m.fits
#
#     u54v0304r_c0m.fits
#
# ===  Source finding for image 'u54v0303r_c0m.fits':
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 1) started at: 17:49:35.864 (12/12/2017)
#
#      Found 307 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 2) started at: 17:49:36.288 (12/12/2017)
#
#      Found 206 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 3) started at: 17:49:36.559 (12/12/2017)
#
#      Found 299 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 4) started at: 17:49:36.860 (12/12/2017)
#
#      Found 303 objects.
#
# ===  Found a TOTAL of 1115 objects in image 'u54v0303r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0304r_c0m.fits':
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 1) started at: 17:49:37.412 (12/12/2017)
#
#      Found 300 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 2) started at: 17:49:37.822 (12/12/2017)
#
#      Found 169 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 3) started at: 17:49:38.086 (12/12/2017)
#
#      Found 190 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 4) started at: 17:49:38.368 (12/12/2017)
#
#      Found 1218 objects.
#
# ===  Found a TOTAL of 1877 objects in image 'u54v0304r_c0m.fits'
#
#
#
#  Catalog trimmed to 1115 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0303r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0304r_c0m.fits
#
# Matching sources from 'u54v0304r_c0m.fits' with sources from reference image 'u54v0303r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.97590910422 -0.37590910422
#
#     with significance of  340.839348577 and  10.0  matches
#
# Found 27 matches for u54v0304r_c0m.fits...
#
# Computed  rscale  fit for  u54v0304r_c0m.fits :
#
# XSH: -0.00478969  YSH: -0.0697055    ROT: 0.0105745    SCALE: 0.999964
#
# XRMS: 0.192304    YRMS: 0.296821
#
# RMS_RA: 8.78306e-07 (deg)   RMS_DEC: 4.44567e-06 (deg)
#
# Final solution based on  24  objects.
#
# wrote XY data to:  u54v0304r_c0m_catalog_fit.match
#
# Writing out shiftfile : 9shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.004790

# %%
# change to a jupyter table
dt=test.to_pandas()
dt.to_pickle('data.pickle')
good_table=pandas.read_pickle('data.pickle')

# %%
# take only unfailed sessions
good_roundhi = good_table[good_table['y_rms'] != 'failed']

# %%
good_roundhi
# Out:
#          shift                file     x_rms     y_rms  threshold  conv_width  \
# 0   1shift.txt  u54v0303r_c0m.fits  0.000000  0.000000          6         3.3
# 1   1shift.txt  u54v0304r_c0m.fits  0.205866  0.239315          6         3.3
# 2   2shift.txt  u54v0303r_c0m.fits  0.000000  0.000000          6         3.3
# 3   2shift.txt  u54v0304r_c0m.fits  0.197283  0.246071          6         3.3
# 4   3shift.txt  u54v0303r_c0m.fits  0.000000  0.000000          6         3.3
# 5   3shift.txt  u54v0304r_c0m.fits  0.196748  0.266731          6         3.3
# 6   4shift.txt  u54v0303r_c0m.fits  0.000000  0.000000          6         3.3
# 7   4shift.txt  u54v0304r_c0m.fits  0.195101  0.270131          6         3.3
# 8   5shift.txt  u54v0303r_c0m.fits  0.000000  0.000000          6         3.3
# 9   5shift.txt  u54v0304r_c0m.fits  0.217771  0.440821          6         3.3
# 10  6shift.txt  u54v0303r_c0m.fits  0.000000  0.000000          6         3.3
# 11  6shift.txt  u54v0304r_c0m.fits  0.192304  0.296821          6         3.3
# 12  7shift.txt  u54v0303r_c0m.fits  0.000000  0.000000          6         3.3
# 13  7shift.txt  u54v0304r_c0m.fits  0.192304  0.296821          6         3.3
# 14  8shift.txt  u54v0303r_c0m.fits  0.000000  0.000000          6         3.3
# 15  8shift.txt  u54v0304r_c0m.fits  0.192304  0.296821          6         3.3
# 16  9shift.txt  u54v0303r_c0m.fits  0.000000  0.000000          6         3.3
# 17  9shift.txt  u54v0304r_c0m.fits  0.192304  0.296821          6         3.3
#
#     roundlo  roundhi  peakmax
# 0      -0.3      0.5     1000
# 1      -0.3      0.5     1000
# 2      -0.3      0.7     1000
# 3      -0.3      0.7     1000
# 4      -0.3      0.9     1000
# 5      -0.3      0.9     1000
# 6      -0.3      1.1     1000
# 7      -0.3      1.1     1000
# 8      -0.3      1.3     1000
# 9      -0.3      1.3     1000
# 10     -0.3      1.5     1000
# 11     -0.3      1.5     1000
# 12     -0.3      1.7     1000
# 13     -0.3      1.7     1000
# 14     -0.3      1.9     1000
# 15     -0.3      1.9     1000
# 16     -0.3      2.1     1000
# 17     -0.3      2.1     1000

# %%
# plot figure for all sub-exp 
plt.figure(figsize = (7,7))
plt.plot(good_roundhi['roundhi'],good_roundhi['x_rms'],'.g')
plt.plot(good_roundhi['roundhi'],good_roundhi['y_rms'],'.b')
plt.title('x,y_rms(roundhi)-g,b')
plt.show()

# %%
# plot figure for choosen sub-exp
plt.figure(figsize = (7,7))
plt.plot(good_round[good_round['file'] == 'u6ea5402m_c0m.fits']['roundhi'],good_round[good_round['file'] == 'u6ea5402m_c0m.fits']['y_rms'],'.b')
plt.plot(good_round[good_round['file'] == 'u6ea5403m_c0m.fits']['roundhi'],good_round[good_round['file'] == 'u6ea5403m_c0m.fits']['y_rms'],'.g')
plt.title('y_rms(roundhi)-two filters')
plt.show()

# %%
#############################################thresh = 6, conv = 3.3 roundnlo = -0.3, rounfhi = 0.7, peakmax?

# %%
# tweak_run(path, n_up, threshold_ini, threshold_gap, conv_width_ini, conv_width_gap, 
# roundlo_val_ini, roundlo_gap, roundhi_val_ini, roundhi_gap, peakmax_val_ini, peakmax_gap):
test = tweak_run('/Users/natalie/anaconda2/envs/iraf27/iraf/sn/2001ci/2001ci_pre/tweak_547',10,6,0,3.3,0,-0.3,0,0.7,0,500,500)
# Out:
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 17:50:53.625 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0303r_c0m.fits
#
#     u54v0304r_c0m.fits
#
# ===  Source finding for image 'u54v0303r_c0m.fits':
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 1) started at: 17:50:53.949 (12/12/2017)
#
#      Found 180 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 2) started at: 17:50:54.334 (12/12/2017)
#
#      Found 154 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 3) started at: 17:50:54.607 (12/12/2017)
#
#      Found 221 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 4) started at: 17:50:54.953 (12/12/2017)
#
#      Found 229 objects.
#
# ===  Found a TOTAL of 784 objects in image 'u54v0303r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0304r_c0m.fits':
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 1) started at: 17:50:55.682 (12/12/2017)
#
#      Found 173 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 2) started at: 17:50:56.120 (12/12/2017)
#
#      Found 130 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 3) started at: 17:50:56.375 (12/12/2017)
#
#      Found 146 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 4) started at: 17:50:56.684 (12/12/2017)
#
#      Found 727 objects.
#
# ===  Found a TOTAL of 1176 objects in image 'u54v0304r_c0m.fits'
#
#
#
#  Catalog trimmed to 784 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0303r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0304r_c0m.fits
#
# Matching sources from 'u54v0304r_c0m.fits' with sources from reference image 'u54v0303r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.935548743859 -0.611224419535
#
#     with significance of  271.497582862 and  9.0  matches
#
# Found 22 matches for u54v0304r_c0m.fits...
#
# Computed  rscale  fit for  u54v0304r_c0m.fits :
#
# XSH: -0.0127051  YSH: -0.0818334    ROT: 0.00930023    SCALE: 0.999956
#
# XRMS: 0.197283    YRMS: 0.246071
#
# RMS_RA: 1.48775e-06 (deg)   RMS_DEC: 3.89983e-06 (deg)
#
# Final solution based on  21  objects.
#
# wrote XY data to:  u54v0304r_c0m_catalog_fit.match
#
# Writing out shiftfile : 1shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.012705
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 17:50:57.906 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0303r_c0m.fits
#
#     u54v0304r_c0m.fits
#
# ===  Source finding for image 'u54v0303r_c0m.fits':
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 1) started at: 17:50:58.167 (12/12/2017)
#
#      Found 189 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 2) started at: 17:50:58.547 (12/12/2017)
#
#      Found 163 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 3) started at: 17:50:58.81 (12/12/2017)
#
#      Found 230 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 4) started at: 17:50:59.096 (12/12/2017)
#
#      Found 232 objects.
#
# ===  Found a TOTAL of 814 objects in image 'u54v0303r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0304r_c0m.fits':
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 1) started at: 17:50:59.648 (12/12/2017)
#
#      Found 186 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 2) started at: 17:51:00.106 (12/12/2017)
#
#      Found 133 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 3) started at: 17:51:00.370 (12/12/2017)
#
#      Found 151 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 4) started at: 17:51:00.628 (12/12/2017)
#
#      Found 732 objects.
#
# ===  Found a TOTAL of 1202 objects in image 'u54v0304r_c0m.fits'
#
#
#
#  Catalog trimmed to 814 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0303r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0304r_c0m.fits
#
# Matching sources from 'u54v0304r_c0m.fits' with sources from reference image 'u54v0303r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.935548743859 -0.611224419535
#
#     with significance of  271.497582862 and  9.0  matches
#
# Found 22 matches for u54v0304r_c0m.fits...
#
# Computed  rscale  fit for  u54v0304r_c0m.fits :
#
# XSH: -0.0127051  YSH: -0.0818334    ROT: 0.00930023    SCALE: 0.999956
#
# XRMS: 0.197283    YRMS: 0.246071
#
# RMS_RA: 1.48775e-06 (deg)   RMS_DEC: 3.89983e-06 (deg)
#
# Final solution based on  21  objects.
#
# wrote XY data to:  u54v0304r_c0m_catalog_fit.match
#
# Writing out shiftfile : 2shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.012705
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 17:51:01.715 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0303r_c0m.fits
#
#     u54v0304r_c0m.fits
#
# ===  Source finding for image 'u54v0303r_c0m.fits':
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 1) started at: 17:51:01.976 (12/12/2017)
#
#      Found 190 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 2) started at: 17:51:02.354 (12/12/2017)
#
#      Found 165 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 3) started at: 17:51:02.666 (12/12/2017)
#
#      Found 233 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 4) started at: 17:51:02.957 (12/12/2017)
#
#      Found 235 objects.
#
# ===  Found a TOTAL of 823 objects in image 'u54v0303r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0304r_c0m.fits':
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 1) started at: 17:51:03.491 (12/12/2017)
#
#      Found 190 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 2) started at: 17:51:03.906 (12/12/2017)
#
#      Found 134 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 3) started at: 17:51:04.143 (12/12/2017)
#
#      Found 153 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 4) started at: 17:51:04.430 (12/12/2017)
#
#      Found 732 objects.
#
# ===  Found a TOTAL of 1209 objects in image 'u54v0304r_c0m.fits'
#
#
#
#  Catalog trimmed to 823 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0303r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0304r_c0m.fits
#
# Matching sources from 'u54v0304r_c0m.fits' with sources from reference image 'u54v0303r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.935548743859 -0.611224419535
#
#     with significance of  271.497582862 and  9.0  matches
#
# Found 22 matches for u54v0304r_c0m.fits...
#
# Computed  rscale  fit for  u54v0304r_c0m.fits :
#
# XSH: -0.0127051  YSH: -0.0818334    ROT: 0.00930023    SCALE: 0.999956
#
# XRMS: 0.197283    YRMS: 0.246071
#
# RMS_RA: 1.48775e-06 (deg)   RMS_DEC: 3.89983e-06 (deg)
#
# Final solution based on  21  objects.
#
# wrote XY data to:  u54v0304r_c0m_catalog_fit.match
#
# Writing out shiftfile : 3shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.012705
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 17:51:05.537 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0303r_c0m.fits
#
#     u54v0304r_c0m.fits
#
# ===  Source finding for image 'u54v0303r_c0m.fits':
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 1) started at: 17:51:05.787 (12/12/2017)
#
#      Found 191 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 2) started at: 17:51:06.162 (12/12/2017)
#
#      Found 167 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 3) started at: 17:51:06.422 (12/12/2017)
#
#      Found 233 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 4) started at: 17:51:06.698 (12/12/2017)
#
#      Found 236 objects.
#
# ===  Found a TOTAL of 827 objects in image 'u54v0303r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0304r_c0m.fits':
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 1) started at: 17:51:07.242 (12/12/2017)
#
#      Found 190 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 2) started at: 17:51:07.64 (12/12/2017)
#
#      Found 134 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 3) started at: 17:51:07.888 (12/12/2017)
#
#      Found 155 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 4) started at: 17:51:08.219 (12/12/2017)
#
#      Found 733 objects.
#
# ===  Found a TOTAL of 1212 objects in image 'u54v0304r_c0m.fits'
#
#
#
#  Catalog trimmed to 827 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0303r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0304r_c0m.fits
#
# Matching sources from 'u54v0304r_c0m.fits' with sources from reference image 'u54v0303r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.935548743859 -0.611224419535
#
#     with significance of  271.497582862 and  9.0  matches
#
# Found 22 matches for u54v0304r_c0m.fits...
#
# Computed  rscale  fit for  u54v0304r_c0m.fits :
#
# XSH: -0.0127051  YSH: -0.0818334    ROT: 0.00930023    SCALE: 0.999956
#
# XRMS: 0.197283    YRMS: 0.246071
#
# RMS_RA: 1.48775e-06 (deg)   RMS_DEC: 3.89983e-06 (deg)
#
# Final solution based on  21  objects.
#
# wrote XY data to:  u54v0304r_c0m_catalog_fit.match
#
# Writing out shiftfile : 4shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.012705
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 17:51:09.292 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0303r_c0m.fits
#
#     u54v0304r_c0m.fits
#
# ===  Source finding for image 'u54v0303r_c0m.fits':
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 1) started at: 17:51:09.571 (12/12/2017)
#
#      Found 192 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 2) started at: 17:51:09.947 (12/12/2017)
#
#      Found 167 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 3) started at: 17:51:10.216 (12/12/2017)
#
#      Found 233 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 4) started at: 17:51:10.490 (12/12/2017)
#
#      Found 236 objects.
#
# ===  Found a TOTAL of 828 objects in image 'u54v0303r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0304r_c0m.fits':
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 1) started at: 17:51:11.084 (12/12/2017)
#
#      Found 191 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 2) started at: 17:51:11.481 (12/12/2017)
#
#      Found 134 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 3) started at: 17:51:11.715 (12/12/2017)
#
#      Found 155 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 4) started at: 17:51:11.987 (12/12/2017)
#
#      Found 733 objects.
#
# ===  Found a TOTAL of 1213 objects in image 'u54v0304r_c0m.fits'
#
#
#
#  Catalog trimmed to 828 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0303r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0304r_c0m.fits
#
# Matching sources from 'u54v0304r_c0m.fits' with sources from reference image 'u54v0303r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.935548743859 -0.611224419535
#
#     with significance of  271.497582862 and  9.0  matches
#
# Found 22 matches for u54v0304r_c0m.fits...
#
# Computed  rscale  fit for  u54v0304r_c0m.fits :
#
# XSH: -0.0127051  YSH: -0.0818334    ROT: 0.00930023    SCALE: 0.999956
#
# XRMS: 0.197283    YRMS: 0.246071
#
# RMS_RA: 1.48775e-06 (deg)   RMS_DEC: 3.89983e-06 (deg)
#
# Final solution based on  21  objects.
#
# wrote XY data to:  u54v0304r_c0m_catalog_fit.match
#
# Writing out shiftfile : 5shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.012705
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 17:51:13.044 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0303r_c0m.fits
#
#     u54v0304r_c0m.fits
#
# ===  Source finding for image 'u54v0303r_c0m.fits':
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 1) started at: 17:51:13.301 (12/12/2017)
#
#      Found 193 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 2) started at: 17:51:13.725 (12/12/2017)
#
#      Found 168 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 3) started at: 17:51:13.989 (12/12/2017)
#
#      Found 233 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 4) started at: 17:51:14.322 (12/12/2017)
#
#      Found 236 objects.
#
# ===  Found a TOTAL of 830 objects in image 'u54v0303r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0304r_c0m.fits':
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 1) started at: 17:51:14.825 (12/12/2017)
#
#      Found 192 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 2) started at: 17:51:15.229 (12/12/2017)
#
#      Found 135 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 3) started at: 17:51:15.472 (12/12/2017)
#
#      Found 155 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 4) started at: 17:51:15.723 (12/12/2017)
#
#      Found 733 objects.
#
# ===  Found a TOTAL of 1215 objects in image 'u54v0304r_c0m.fits'
#
#
#
#  Catalog trimmed to 830 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0303r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0304r_c0m.fits
#
# Matching sources from 'u54v0304r_c0m.fits' with sources from reference image 'u54v0303r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.935548743859 -0.611224419535
#
#     with significance of  271.497582862 and  9.0  matches
#
# Found 22 matches for u54v0304r_c0m.fits...
#
# Computed  rscale  fit for  u54v0304r_c0m.fits :
#
# XSH: -0.0127051  YSH: -0.0818334    ROT: 0.00930023    SCALE: 0.999956
#
# XRMS: 0.197283    YRMS: 0.246071
#
# RMS_RA: 1.48775e-06 (deg)   RMS_DEC: 3.89983e-06 (deg)
#
# Final solution based on  21  objects.
#
# wrote XY data to:  u54v0304r_c0m_catalog_fit.match
#
# Writing out shiftfile : 6shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.012705
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 17:51:16.861 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0303r_c0m.fits
#
#     u54v0304r_c0m.fits
#
# ===  Source finding for image 'u54v0303r_c0m.fits':
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 1) started at: 17:51:17.138 (12/12/2017)
#
#      Found 193 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 2) started at: 17:51:17.520 (12/12/2017)
#
#      Found 168 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 3) started at: 17:51:17.783 (12/12/2017)
#
#      Found 233 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 4) started at: 17:51:18.067 (12/12/2017)
#
#      Found 236 objects.
#
# ===  Found a TOTAL of 830 objects in image 'u54v0303r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0304r_c0m.fits':
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 1) started at: 17:51:18.640 (12/12/2017)
#
#      Found 193 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 2) started at: 17:51:19.048 (12/12/2017)
#
#      Found 135 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 3) started at: 17:51:19.293 (12/12/2017)
#
#      Found 155 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 4) started at: 17:51:19.565 (12/12/2017)
#
#      Found 733 objects.
#
# ===  Found a TOTAL of 1216 objects in image 'u54v0304r_c0m.fits'
#
#
#
#  Catalog trimmed to 830 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0303r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0304r_c0m.fits
#
# Matching sources from 'u54v0304r_c0m.fits' with sources from reference image 'u54v0303r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.935548743859 -0.611224419535
#
#     with significance of  271.497582862 and  9.0  matches
#
# Found 22 matches for u54v0304r_c0m.fits...
#
# Computed  rscale  fit for  u54v0304r_c0m.fits :
#
# XSH: -0.0127051  YSH: -0.0818334    ROT: 0.00930023    SCALE: 0.999956
#
# XRMS: 0.197283    YRMS: 0.246071
#
# RMS_RA: 1.48775e-06 (deg)   RMS_DEC: 3.89983e-06 (deg)
#
# Final solution based on  21  objects.
#
# wrote XY data to:  u54v0304r_c0m_catalog_fit.match
#
# Writing out shiftfile : 7shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.012705
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 17:51:20.714 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0303r_c0m.fits
#
#     u54v0304r_c0m.fits
#
# ===  Source finding for image 'u54v0303r_c0m.fits':
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 1) started at: 17:51:20.97 (12/12/2017)
#
#      Found 193 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 2) started at: 17:51:21.349 (12/12/2017)
#
#      Found 169 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 3) started at: 17:51:21.621 (12/12/2017)
#
#      Found 233 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 4) started at: 17:51:21.909 (12/12/2017)
#
#      Found 236 objects.
#
# ===  Found a TOTAL of 831 objects in image 'u54v0303r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0304r_c0m.fits':
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 1) started at: 17:51:22.474 (12/12/2017)
#
#      Found 194 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 2) started at: 17:51:22.926 (12/12/2017)
#
#      Found 136 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 3) started at: 17:51:23.176 (12/12/2017)
#
#      Found 156 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 4) started at: 17:51:23.444 (12/12/2017)
#
#      Found 733 objects.
#
# ===  Found a TOTAL of 1219 objects in image 'u54v0304r_c0m.fits'
#
#
#
#  Catalog trimmed to 831 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0303r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0304r_c0m.fits
#
# Matching sources from 'u54v0304r_c0m.fits' with sources from reference image 'u54v0303r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.935548743859 -0.611224419535
#
#     with significance of  271.497582862 and  9.0  matches
#
# Found 22 matches for u54v0304r_c0m.fits...
#
# Computed  rscale  fit for  u54v0304r_c0m.fits :
#
# XSH: -0.0127051  YSH: -0.0818334    ROT: 0.00930023    SCALE: 0.999956
#
# XRMS: 0.197283    YRMS: 0.246071
#
# RMS_RA: 1.48775e-06 (deg)   RMS_DEC: 3.89983e-06 (deg)
#
# Final solution based on  21  objects.
#
# wrote XY data to:  u54v0304r_c0m_catalog_fit.match
#
# Writing out shiftfile : 8shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.012705
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 17:51:24.520 (12/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0303r_c0m.fits
#
#     u54v0304r_c0m.fits
#
# ===  Source finding for image 'u54v0303r_c0m.fits':
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 1) started at: 17:51:24.785 (12/12/2017)
#
#      Found 193 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 2) started at: 17:51:25.230 (12/12/2017)
#
#      Found 171 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 3) started at: 17:51:25.58 (12/12/2017)
#
#      Found 233 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 4) started at: 17:51:25.967 (12/12/2017)
#
#      Found 236 objects.
#
# ===  Found a TOTAL of 833 objects in image 'u54v0303r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0304r_c0m.fits':
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 1) started at: 17:51:26.469 (12/12/2017)
#
#      Found 194 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 2) started at: 17:51:26.860 (12/12/2017)
#
#      Found 137 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 3) started at: 17:51:27.104 (12/12/2017)
#
#      Found 156 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 4) started at: 17:51:27.385 (12/12/2017)
#
#      Found 733 objects.
#
# ===  Found a TOTAL of 1220 objects in image 'u54v0304r_c0m.fits'
#
#
#
#  Catalog trimmed to 833 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0303r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0304r_c0m.fits
#
# Matching sources from 'u54v0304r_c0m.fits' with sources from reference image 'u54v0303r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.936259981413 -0.620470507729
#
#     with significance of  273.926997574 and  9.0  matches
#
# Found 23 matches for u54v0304r_c0m.fits...
#
# Computed  rscale  fit for  u54v0304r_c0m.fits :
#
# XSH: -0.0213266  YSH: -0.0838277    ROT: 0.00869836    SCALE: 0.999957
#
# XRMS: 0.193371    YRMS: 0.242211
#
# RMS_RA: 1.44801e-06 (deg)   RMS_DEC: 3.83403e-06 (deg)
#
# Final solution based on  22  objects.
#
# wrote XY data to:  u54v0304r_c0m_catalog_fit.match
#
# Writing out shiftfile : 9shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.021327

# %%
# change to a jupyter table
dt=test.to_pandas()
dt.to_pickle('data.pickle')
good_table=pandas.read_pickle('data.pickle')

# %%
# take only unfailed sessions
good_peakmax = good_table[good_table['y_rms'] != 'failed']

# %%
good_peakmax
# Out:
#          shift                file     x_rms     y_rms  threshold  conv_width  \
# 0   1shift.txt  u54v0303r_c0m.fits  0.000000  0.000000          6         3.3
# 1   1shift.txt  u54v0304r_c0m.fits  0.197283  0.246071          6         3.3
# 2   2shift.txt  u54v0303r_c0m.fits  0.000000  0.000000          6         3.3
# 3   2shift.txt  u54v0304r_c0m.fits  0.197283  0.246071          6         3.3
# 4   3shift.txt  u54v0303r_c0m.fits  0.000000  0.000000          6         3.3
# 5   3shift.txt  u54v0304r_c0m.fits  0.197283  0.246071          6         3.3
# 6   4shift.txt  u54v0303r_c0m.fits  0.000000  0.000000          6         3.3
# 7   4shift.txt  u54v0304r_c0m.fits  0.197283  0.246071          6         3.3
# 8   5shift.txt  u54v0303r_c0m.fits  0.000000  0.000000          6         3.3
# 9   5shift.txt  u54v0304r_c0m.fits  0.197283  0.246071          6         3.3
# 10  6shift.txt  u54v0303r_c0m.fits  0.000000  0.000000          6         3.3
# 11  6shift.txt  u54v0304r_c0m.fits  0.197283  0.246071          6         3.3
# 12  7shift.txt  u54v0303r_c0m.fits  0.000000  0.000000          6         3.3
# 13  7shift.txt  u54v0304r_c0m.fits  0.197283  0.246071          6         3.3
# 14  8shift.txt  u54v0303r_c0m.fits  0.000000  0.000000          6         3.3
# 15  8shift.txt  u54v0304r_c0m.fits  0.197283  0.246071          6         3.3
# 16  9shift.txt  u54v0303r_c0m.fits  0.000000  0.000000          6         3.3
# 17  9shift.txt  u54v0304r_c0m.fits  0.193371  0.242211          6         3.3
#
#     roundlo  roundhi  peakmax
# 0      -0.3      0.7      500
# 1      -0.3      0.7      500
# 2      -0.3      0.7     1000
# 3      -0.3      0.7     1000
# 4      -0.3      0.7     1500
# 5      -0.3      0.7     1500
# 6      -0.3      0.7     2000
# 7      -0.3      0.7     2000
# 8      -0.3      0.7     2500
# 9      -0.3      0.7     2500
# 10     -0.3      0.7     3000
# 11     -0.3      0.7     3000
# 12     -0.3      0.7     3500
# 13     -0.3      0.7     3500
# 14     -0.3      0.7     4000
# 15     -0.3      0.7     4000
# 16     -0.3      0.7     4500
# 17     -0.3      0.7     4500

# %%
# plot figure for all sub-exp ??????????????????????????????????????????
plt.figure(figsize = (7,7))
plt.plot(good_peakmax['peakmax'],good_peakmax['x_rms'],'.g')
plt.plot(good_peakmax['peakmax'],good_peakmax['y_rms'],'.b')
plt.title('x,y_rms(peakmax)-g,b')
plt.show()

# %%
################################## tweakreg run for good parameters without headers, see figures- 
# thresh = 6, conv = 3.3 roundnlo = -0.3, rounfhi = 0.7, peakmax = 1000

# %%
# final parameters to see plots
import os
from drizzlepac import tweakreg
os.chdir('/Users/natalie/anaconda2/envs/iraf27/iraf/sn/2001ci/2001ci_pre/tweak_547')
tweakreg.TweakReg('*c0m.fits', exclusions='WFPC2_exclude.txt', updatehdr=False, shiftfile=True, outshifts='shift_final', residplot='both', see2dplot='Yes', use_sharp_round='Yes', threshold=6, conv_width=3.3, roundlo=-0.3, roundhi=0.7, sharphi=2, peakmax=6000)
# Out:
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 10:45:42.956 (13/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0303r_c0m.fits
#
#     u54v0304r_c0m.fits
#
# ===  Source finding for image 'u54v0303r_c0m.fits':
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 1) started at: 10:45:43.286 (13/12/2017)
#
#      Found 381 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 2) started at: 10:45:43.702 (13/12/2017)
#
#      Found 439 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 3) started at: 10:45:43.971 (13/12/2017)
#
#      Found 438 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 4) started at: 10:45:44.251 (13/12/2017)
#
#      Found 410 objects.
#
# ===  Found a TOTAL of 1668 objects in image 'u54v0303r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0304r_c0m.fits':
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 1) started at: 10:45:44.87 (13/12/2017)
#
#      Found 358 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 2) started at: 10:45:45.480 (13/12/2017)
#
#      Found 291 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 3) started at: 10:45:45.804 (13/12/2017)
#
#      Found 376 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 4) started at: 10:45:46.230 (13/12/2017)
#
#      Found 922 objects.
#
# ===  Found a TOTAL of 1947 objects in image 'u54v0304r_c0m.fits'
#
#
#
#  Catalog trimmed to 1668 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0303r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0304r_c0m.fits
#
# Matching sources from 'u54v0304r_c0m.fits' with sources from reference image 'u54v0303r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -1.02507577089 -0.937575770886
#
#     with significance of  410.465763319 and  22.0  matches
#
# Found 46 matches for u54v0304r_c0m.fits...
#
# Computed  rscale  fit for  u54v0304r_c0m.fits :
#
# XSH: -0.076361  YSH: -0.0955731    ROT: 0.00287407    SCALE: 0.999984
#
# XRMS: 0.162584    YRMS: 0.217692
#
# RMS_RA: 1.07646e-06 (deg)   RMS_DEC: 3.38246e-06 (deg)
#
# Final solution based on  41  objects.
#
# wrote XY data to:  u54v0304r_c0m_catalog_fit.match
#
# Total # points:  41
#
# # of points after clipping:  41
#
# Total # points:  41
#
# # of points after clipping:  41
#
# Press ENTER for next image,
#       'n' to continue without updating header or
#       'q' to quit immediately...
#
# Writing out shiftfile : shift_final
#
# Trailer file written to:  tweakreg.log

# %%
# final run with hdr update
import os
from drizzlepac import tweakreg
os.chdir('/Users/natalie/anaconda2/envs/iraf27/iraf/sn/2001ci/2001ci_pre/tweak_547')
tweakreg.TweakReg('*c0m.fits', exclusions='WFPC2_exclude.txt', updatehdr=True, shiftfile=True, outshifts='shift_final', residplot='both', see2dplot='Yes', use_sharp_round='Yes', threshold=6, conv_width=3.3, roundlo=-0.3, roundhi=0.7, sharphi=2, peakmax=6000)
# Out:
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 10:59:50.615 (13/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0303r_c0m.fits
#
#     u54v0304r_c0m.fits
#
# ===  Source finding for image 'u54v0303r_c0m.fits':
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 1) started at: 10:59:51.058 (13/12/2017)
#
#      Found 381 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 2) started at: 10:59:51.447 (13/12/2017)
#
#      Found 439 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 3) started at: 10:59:51.739 (13/12/2017)
#
#      Found 438 objects.
#
#   #  Source finding for 'u54v0303r_c0m.fits', EXT=('SCI', 4) started at: 10:59:52.061 (13/12/2017)
#
#      Found 410 objects.
#
# ===  Found a TOTAL of 1668 objects in image 'u54v0303r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0304r_c0m.fits':
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 1) started at: 10:59:52.735 (13/12/2017)
#
#      Found 358 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 2) started at: 10:59:53.336 (13/12/2017)
#
#      Found 291 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 3) started at: 10:59:53.616 (13/12/2017)
#
#      Found 376 objects.
#
#   #  Source finding for 'u54v0304r_c0m.fits', EXT=('SCI', 4) started at: 10:59:53.922 (13/12/2017)
#
#      Found 922 objects.
#
# ===  Found a TOTAL of 1947 objects in image 'u54v0304r_c0m.fits'
#
#
#
#  Catalog trimmed to 1668 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0303r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0304r_c0m.fits
#
# Matching sources from 'u54v0304r_c0m.fits' with sources from reference image 'u54v0303r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -1.02507577089 -0.937575770886
#
#     with significance of  410.465763319 and  22.0  matches
#
# Found 46 matches for u54v0304r_c0m.fits...
#
# Computed  rscale  fit for  u54v0304r_c0m.fits :
#
# XSH: -0.076361  YSH: -0.0955731    ROT: 0.00287407    SCALE: 0.999984
#
# XRMS: 0.162584    YRMS: 0.217692
#
# RMS_RA: 1.07646e-06 (deg)   RMS_DEC: 3.38246e-06 (deg)
#
# Final solution based on  41  objects.
#
# wrote XY data to:  u54v0304r_c0m_catalog_fit.match
#
# Total # points:  41
#
# # of points after clipping:  41
#
# Total # points:  41
#
# # of points after clipping:  41
#
# Press ENTER for next image,
#       'n' to continue without updating header or
#       'q' to quit immediately...
#
#
# ....Updating header for u54v0304r_c0m.fits...
#
#
# Processing u54v0304r_c0m.fits['SCI',1]
#
# Updating header for u54v0304r_c0m.fits[1]
#
# WCSNAME  :  TWEAK
#
#
# Processing u54v0304r_c0m.fits['SCI',2]
#
# Updating header for u54v0304r_c0m.fits[2]
#
# WCSNAME  :  TWEAK
#
#
# Processing u54v0304r_c0m.fits['SCI',3]
#
# Updating header for u54v0304r_c0m.fits[3]
#
# WCSNAME  :  TWEAK
#
#
# Processing u54v0304r_c0m.fits['SCI',4]
#
# Updating header for u54v0304r_c0m.fits[4]
#
# WCSNAME  :  TWEAK
#
# Writing out shiftfile : shift_final
#
# Trailer file written to:  tweakreg.log

# %%
# tweaked checks
from astropy.io import fits
tw=fits.open('/Users/natalie/anaconda2/envs/iraf27/iraf/sn/2001ci/2001ci_pre/tweak_547/u54v0304r_c0m.fits')

# %%
tw[1].header['WCSNAME']
# Out:
# 'TWEAK'

# %%
tw[1].header
