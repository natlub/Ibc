# %%
# tweakreg defaults: 
# threshold = 4
# conv_width = 3.5
# use round = No --> roundlo = -1, roundhi = 1
# peakmin = //
# peakmax = //

# %%
import sys
sys.path.append("/Users/natalie/PycharmProjects/code/")
    
from Drizzle_func import *
import pandas
import matplotlib.pyplot as plt
# Out:
# The following task in the stsci.skypac package can be run with TEAL:
#                                     skymatch
# The following tasks in the drizzlepac package can be run with TEAL:
#     astrodrizzle       imagefindpars           mapreg              photeq
#      pixreplace           pixtopix            pixtosky        refimagefindpars
#      resetbits          runastrodriz          skytopix           tweakback
#       tweakreg           updatenpol

# %%
# tweak_run(path, n_up, threshold_ini, threshold_gap, conv_width_ini, conv_width_gap, 
# roundlo_val_ini, roundlo_gap, roundhi_val_ini, roundhi_gap, peakmax_val_ini, peakmax_gap):
test = tweak_run('/Users/natalie/anaconda2/envs/iraf27/iraf/sn/2001ci/2001ci_pre/tweak_658',10,23,1,3.5,0,-1,0,1,0,1000,0)
# Out:
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 08:20:18.638 (14/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0306r_c0m.fits
#
#     u54v0307r_c0m.fits
#
# ===  Source finding for image 'u54v0306r_c0m.fits':
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 1) started at: 08:20:18.933 (14/12/2017)
#
#      Found 613 objects.
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 2) started at: 08:20:19.323 (14/12/2017)
#
#      Found 492 objects.
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 3) started at: 08:20:19.656 (14/12/2017)
#
#      Found 493 objects.
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 4) started at: 08:20:20.055 (14/12/2017)
#
#      Found 4054 objects.
#
# ===  Found a TOTAL of 5652 objects in image 'u54v0306r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0307r_c0m.fits':
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 1) started at: 08:20:22.919 (14/12/2017)
#
#      Found 658 objects.
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 2) started at: 08:20:23.331 (14/12/2017)
#
#      Found 531 objects.
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 3) started at: 08:20:23.646 (14/12/2017)
#
#      Found 585 objects.
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 4) started at: 08:20:24.038 (14/12/2017)
#
#      Found 532 objects.
#
# ===  Found a TOTAL of 2306 objects in image 'u54v0307r_c0m.fits'
#
#
#
#  Catalog trimmed to 5652 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0306r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0307r_c0m.fits
#
# Matching sources from 'u54v0307r_c0m.fits' with sources from reference image 'u54v0306r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -2.04460718144 -1.77466853114
#
#     with significance of  279.116719057 and  10.0  matches
#
# Found 29 matches for u54v0307r_c0m.fits...
#
# Computed  rscale  fit for  u54v0307r_c0m.fits :
#
# XSH: -1.75595  YSH: -1.61316    ROT: 0.00265081    SCALE: 0.9998
#
# XRMS: 0.618096    YRMS: 0.695155
#
# RMS_RA: 5.42308e-06 (deg)   RMS_DEC: 1.1363e-05 (deg)
#
# Final solution based on  29  objects.
#
# wrote XY data to:  u54v0307r_c0m_catalog_fit.match
#
# Writing out shiftfile : 1shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -1.755949
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 08:20:25.073 (14/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0306r_c0m.fits
#
#     u54v0307r_c0m.fits
#
# ===  Source finding for image 'u54v0306r_c0m.fits':
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 1) started at: 08:20:25.332 (14/12/2017)
#
#      Found 603 objects.
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 2) started at: 08:20:25.693 (14/12/2017)
#
#      Found 495 objects.
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 3) started at: 08:20:26.068 (14/12/2017)
#
#      Found 503 objects.
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 4) started at: 08:20:26.443 (14/12/2017)
#
#      Found 4065 objects.
#
# ===  Found a TOTAL of 5666 objects in image 'u54v0306r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0307r_c0m.fits':
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 1) started at: 08:20:29.209 (14/12/2017)
#
#      Found 663 objects.
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 2) started at: 08:20:29.594 (14/12/2017)
#
#      Found 527 objects.
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 3) started at: 08:20:29.894 (14/12/2017)
#
#      Found 585 objects.
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 4) started at: 08:20:30.231 (14/12/2017)
#
#      Found 527 objects.
#
# ===  Found a TOTAL of 2302 objects in image 'u54v0307r_c0m.fits'
#
#
#
#  Catalog trimmed to 5666 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0306r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0307r_c0m.fits
#
# Matching sources from 'u54v0307r_c0m.fits' with sources from reference image 'u54v0306r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -1.06336877368 1.81453820306
#
#     with significance of  301.480513466 and  10.0  matches
#
# Found 32 matches for u54v0307r_c0m.fits...
#
# Computed  rscale  fit for  u54v0307r_c0m.fits :
#
# XSH: -0.94674  YSH: 2.0683    ROT: 0.00827488    SCALE: 1.00021
#
# XRMS: 0.662819    YRMS: 0.80731
#
# RMS_RA: 5.19433e-06 (deg)   RMS_DEC: 1.2885e-05 (deg)
#
# Final solution based on  32  objects.
#
# wrote XY data to:  u54v0307r_c0m_catalog_fit.match
#
# Writing out shiftfile : 2shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.946740
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 08:20:31.134 (14/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0306r_c0m.fits
#
#     u54v0307r_c0m.fits
#
# ===  Source finding for image 'u54v0306r_c0m.fits':
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 1) started at: 08:20:31.379 (14/12/2017)
#
#      Found 580 objects.
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 2) started at: 08:20:31.710 (14/12/2017)
#
#      Found 494 objects.
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 3) started at: 08:20:32.04 (14/12/2017)
#
#      Found 503 objects.
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 4) started at: 08:20:32.341 (14/12/2017)
#
#      Found 4022 objects.
#
# ===  Found a TOTAL of 5599 objects in image 'u54v0306r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0307r_c0m.fits':
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 1) started at: 08:20:35.270 (14/12/2017)
#
#      Found 657 objects.
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 2) started at: 08:20:35.763 (14/12/2017)
#
#      Found 531 objects.
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 3) started at: 08:20:36.085 (14/12/2017)
#
#      Found 593 objects.
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 4) started at: 08:20:36.51 (14/12/2017)
#
#      Found 526 objects.
#
# ===  Found a TOTAL of 2307 objects in image 'u54v0307r_c0m.fits'
#
#
#
#  Catalog trimmed to 5599 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0306r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0307r_c0m.fits
#
# Matching sources from 'u54v0307r_c0m.fits' with sources from reference image 'u54v0306r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  18.6194073891 6.00221988911
#
#     with significance of  312.532055499 and  12.0  matches
#
# Found 25 matches for u54v0307r_c0m.fits...
#
# Computed  rscale  fit for  u54v0307r_c0m.fits :
#
# XSH: 18.9036  YSH: 6.17004    ROT: 0.00858504    SCALE: 0.999883
#
# XRMS: 0.847224    YRMS: 0.706225
#
# RMS_RA: 9.90991e-06 (deg)   RMS_DEC: 1.27853e-05 (deg)
#
# Final solution based on  25  objects.
#
# wrote XY data to:  u54v0307r_c0m_catalog_fit.match
#
# Writing out shiftfile : 3shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 18.903553
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 08:20:37.612 (14/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0306r_c0m.fits
#
#     u54v0307r_c0m.fits
#
# ===  Source finding for image 'u54v0306r_c0m.fits':
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 1) started at: 08:20:38.053 (14/12/2017)
#
#      Found 583 objects.
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 2) started at: 08:20:38.556 (14/12/2017)
#
#      Found 500 objects.
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 3) started at: 08:20:38.882 (14/12/2017)
#
#      Found 498 objects.
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 4) started at: 08:20:39.23 (14/12/2017)
#
#      Found 3922 objects.
#
# ===  Found a TOTAL of 5503 objects in image 'u54v0306r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0307r_c0m.fits':
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 1) started at: 08:20:41.994 (14/12/2017)
#
#      Found 664 objects.
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 2) started at: 08:20:42.355 (14/12/2017)
#
#      Found 533 objects.
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 3) started at: 08:20:42.6 (14/12/2017)
#
#      Found 592 objects.
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 4) started at: 08:20:43.015 (14/12/2017)
#
#      Found 520 objects.
#
# ===  Found a TOTAL of 2309 objects in image 'u54v0307r_c0m.fits'
#
#
#
#  Catalog trimmed to 5503 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0306r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0307r_c0m.fits
#
# Matching sources from 'u54v0307r_c0m.fits' with sources from reference image 'u54v0306r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  18.5616075924 6.04941247041
#
#     with significance of  144.33987668 and  11.0  matches
#
# Found 23 matches for u54v0307r_c0m.fits...
#
# Computed  rscale  fit for  u54v0307r_c0m.fits :
#
# XSH: 18.8531  YSH: 6.2009    ROT: 0.00413299    SCALE: 0.999892
#
# XRMS: 0.870353    YRMS: 0.663161
#
# RMS_RA: 1.08065e-05 (deg)   RMS_DEC: 1.24291e-05 (deg)
#
# Final solution based on  23  objects.
#
# wrote XY data to:  u54v0307r_c0m_catalog_fit.match
#
# Writing out shiftfile : 4shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 18.853083
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 08:20:44.316 (14/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0306r_c0m.fits
#
#     u54v0307r_c0m.fits
#
# ===  Source finding for image 'u54v0306r_c0m.fits':
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 1) started at: 08:20:44.619 (14/12/2017)
#
#      Found 563 objects.
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 2) started at: 08:20:44.950 (14/12/2017)
#
#      Found 497 objects.
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 3) started at: 08:20:45.273 (14/12/2017)
#
#      Found 503 objects.
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 4) started at: 08:20:45.584 (14/12/2017)
#
#      Found 3829 objects.
#
# ===  Found a TOTAL of 5392 objects in image 'u54v0306r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0307r_c0m.fits':
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 1) started at: 08:20:47.99 (14/12/2017)
#
#      Found 663 objects.
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 2) started at: 08:20:48.350 (14/12/2017)
#
#      Found 531 objects.
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 3) started at: 08:20:48.647 (14/12/2017)
#
#      Found 588 objects.
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 4) started at: 08:20:48.981 (14/12/2017)
#
#      Found 523 objects.
#
# ===  Found a TOTAL of 2305 objects in image 'u54v0307r_c0m.fits'
#
#
#
#  Catalog trimmed to 5392 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0306r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0307r_c0m.fits
#
# Matching sources from 'u54v0307r_c0m.fits' with sources from reference image 'u54v0306r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -9.83371761089 -4.94309261089
#
#     with significance of  137.368118572 and  10.0  matches
#
# Found 22 matches for u54v0307r_c0m.fits...
#
# Computed  rscale  fit for  u54v0307r_c0m.fits :
#
# XSH: -9.93757  YSH: -4.9513    ROT: 359.987    SCALE: 1.00014
#
# XRMS: 0.712386    YRMS: 0.544932
#
# RMS_RA: 8.82371e-06 (deg)   RMS_DEC: 1.01973e-05 (deg)
#
# Final solution based on  22  objects.
#
# wrote XY data to:  u54v0307r_c0m_catalog_fit.match
#
# Writing out shiftfile : 5shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -9.937565
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 08:20:49.827 (14/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0306r_c0m.fits
#
#     u54v0307r_c0m.fits
#
# ===  Source finding for image 'u54v0306r_c0m.fits':
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 1) started at: 08:20:50.081 (14/12/2017)
#
#      Found 553 objects.
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 2) started at: 08:20:50.419 (14/12/2017)
#
#      Found 502 objects.
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 3) started at: 08:20:50.733 (14/12/2017)
#
#      Found 506 objects.
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 4) started at: 08:20:51.056 (14/12/2017)
#
#      Found 3655 objects.
#
# ===  Found a TOTAL of 5216 objects in image 'u54v0306r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0307r_c0m.fits':
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 1) started at: 08:20:52.859 (14/12/2017)
#
#      Found 648 objects.
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 2) started at: 08:20:53.218 (14/12/2017)
#
#      Found 528 objects.
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 3) started at: 08:20:53.581 (14/12/2017)
#
#      Found 594 objects.
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 4) started at: 08:20:53.944 (14/12/2017)
#
#      Found 526 objects.
#
# ===  Found a TOTAL of 2296 objects in image 'u54v0307r_c0m.fits'
#
#
#
#  Catalog trimmed to 5216 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0306r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0307r_c0m.fits
#
# Matching sources from 'u54v0307r_c0m.fits' with sources from reference image 'u54v0306r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -4.82664213919 -14.7700383656
#
#     with significance of  130.318839774 and  9.0  matches
#
# Found 16 matches for u54v0307r_c0m.fits...
#
# Computed  rscale  fit for  u54v0307r_c0m.fits :
#
# XSH: -4.47038  YSH: -14.2826    ROT: 0.00454328    SCALE: 0.999904
#
# XRMS: 0.487608    YRMS: 0.495743
#
# RMS_RA: 4.80694e-06 (deg)   RMS_DEC: 8.36847e-06 (deg)
#
# Final solution based on  16  objects.
#
# wrote XY data to:  u54v0307r_c0m_catalog_fit.match
#
# Writing out shiftfile : 6shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -4.470381
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 08:20:54.810 (14/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0306r_c0m.fits
#
#     u54v0307r_c0m.fits
#
# ===  Source finding for image 'u54v0306r_c0m.fits':
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 1) started at: 08:20:55.054 (14/12/2017)
#
#      Found 548 objects.
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 2) started at: 08:20:55.366 (14/12/2017)
#
#      Found 498 objects.
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 3) started at: 08:20:55.652 (14/12/2017)
#
#      Found 503 objects.
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 4) started at: 08:20:55.950 (14/12/2017)
#
#      Found 3437 objects.
#
# ===  Found a TOTAL of 4986 objects in image 'u54v0306r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0307r_c0m.fits':
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 1) started at: 08:20:57.605 (14/12/2017)
#
#      Found 647 objects.
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 2) started at: 08:20:57.95 (14/12/2017)
#
#      Found 525 objects.
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 3) started at: 08:20:58.296 (14/12/2017)
#
#      Found 599 objects.
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 4) started at: 08:20:58.669 (14/12/2017)
#
#      Found 528 objects.
#
# ===  Found a TOTAL of 2299 objects in image 'u54v0307r_c0m.fits'
#
#
#
#  Catalog trimmed to 4986 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0306r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0307r_c0m.fits
#
# Matching sources from 'u54v0307r_c0m.fits' with sources from reference image 'u54v0306r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -4.84107055207 -14.8998940815
#
#     with significance of  130.318839774 and  9.0  matches
#
# ##############################################################################
# #                                                                            #
# # WARNING:                                                                   #
# # Not enough matches (< 15) found for input image: u54v0307r_c0m.fits        #
# #                                                                            #
# ##############################################################################
#
#
# Unable to match the following images:
#
# -------------------------------------
#
# u54v0307r_c0m.fits
#
#
# Writing out shiftfile : 7shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# nan
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 08:20:59.398 (14/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0306r_c0m.fits
#
#     u54v0307r_c0m.fits
#
# ===  Source finding for image 'u54v0306r_c0m.fits':
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 1) started at: 08:20:59.643 (14/12/2017)
#
#      Found 540 objects.
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 2) started at: 08:20:59.936 (14/12/2017)
#
#      Found 500 objects.
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 3) started at: 08:21:00.22 (14/12/2017)
#
#      Found 502 objects.
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 4) started at: 08:21:00.531 (14/12/2017)
#
#      Found 3211 objects.
#
# ===  Found a TOTAL of 4753 objects in image 'u54v0306r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0307r_c0m.fits':
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 1) started at: 08:21:02.269 (14/12/2017)
#
#      Found 626 objects.
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 2) started at: 08:21:02.618 (14/12/2017)
#
#      Found 522 objects.
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 3) started at: 08:21:02.916 (14/12/2017)
#
#      Found 603 objects.
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 4) started at: 08:21:03.360 (14/12/2017)
#
#      Found 531 objects.
#
# ===  Found a TOTAL of 2282 objects in image 'u54v0307r_c0m.fits'
#
#
#
#  Catalog trimmed to 4753 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0306r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0307r_c0m.fits
#
# Matching sources from 'u54v0307r_c0m.fits' with sources from reference image 'u54v0306r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  9.04928238911 -1.77471761089
#
#     with significance of  130.318839774 and  9.0  matches
#
# Found 19 matches for u54v0307r_c0m.fits...
#
# Computed  rscale  fit for  u54v0307r_c0m.fits :
#
# XSH: 9.35412  YSH: -1.68172    ROT: 359.994    SCALE: 0.999932
#
# XRMS: 0.592892    YRMS: 0.586881
#
# RMS_RA: 6.00455e-06 (deg)   RMS_DEC: 9.99548e-06 (deg)
#
# Final solution based on  19  objects.
#
# wrote XY data to:  u54v0307r_c0m_catalog_fit.match
#
# Writing out shiftfile : 8shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 9.354125
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 08:21:04.355 (14/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0306r_c0m.fits
#
#     u54v0307r_c0m.fits
#
# ===  Source finding for image 'u54v0306r_c0m.fits':
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 1) started at: 08:21:04.593 (14/12/2017)
#
#      Found 529 objects.
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 2) started at: 08:21:05.012 (14/12/2017)
#
#      Found 503 objects.
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 3) started at: 08:21:05.338 (14/12/2017)
#
#      Found 498 objects.
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 4) started at: 08:21:05.680 (14/12/2017)
#
#      Found 2997 objects.
#
# ===  Found a TOTAL of 4527 objects in image 'u54v0306r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0307r_c0m.fits':
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 1) started at: 08:21:07.037 (14/12/2017)
#
#      Found 631 objects.
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 2) started at: 08:21:07.384 (14/12/2017)
#
#      Found 520 objects.
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 3) started at: 08:21:07.67 (14/12/2017)
#
#      Found 599 objects.
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 4) started at: 08:21:08.025 (14/12/2017)
#
#      Found 525 objects.
#
# ===  Found a TOTAL of 2275 objects in image 'u54v0307r_c0m.fits'
#
#
#
#  Catalog trimmed to 4527 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0306r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0307r_c0m.fits
#
# Matching sources from 'u54v0307r_c0m.fits' with sources from reference image 'u54v0306r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -8.0175411403 3.93203869163
#
#     with significance of  130.318839774 and  9.0  matches
#
# Found 25 matches for u54v0307r_c0m.fits...
#
# Computed  rscale  fit for  u54v0307r_c0m.fits :
#
# XSH: -7.9338  YSH: 4.15726    ROT: 0.0178271    SCALE: 1.00032
#
# XRMS: 0.62611    YRMS: 0.750983
#
# RMS_RA: 5.0233e-06 (deg)   RMS_DEC: 1.204e-05 (deg)
#
# Final solution based on  25  objects.
#
# wrote XY data to:  u54v0307r_c0m_catalog_fit.match
#
# Writing out shiftfile : 9shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -7.933796

# %%
# change to a jupyter table
dt=test.to_pandas()
dt.to_pickle('data.pickle')
good_table=pandas.read_pickle('data.pickle')

# %%
# all table
good_table
# Out:
#          shift                file     x_rms     y_rms  threshold  conv_width  \
# 0   1shift.txt  u54v0306r_c0m.fits  0.000000  0.000000         23         3.5
# 1   1shift.txt  u54v0307r_c0m.fits  0.618096  0.695155         23         3.5
# 2   2shift.txt  u54v0306r_c0m.fits  0.000000  0.000000         24         3.5
# 3   2shift.txt  u54v0307r_c0m.fits  0.662819  0.807310         24         3.5
# 4   3shift.txt  u54v0306r_c0m.fits  0.000000  0.000000         25         3.5
# 5   3shift.txt  u54v0307r_c0m.fits  0.847224  0.706225         25         3.5
# 6   4shift.txt  u54v0306r_c0m.fits  0.000000  0.000000         26         3.5
# 7   4shift.txt  u54v0307r_c0m.fits  0.870353  0.663161         26         3.5
# 8   5shift.txt  u54v0306r_c0m.fits  0.000000  0.000000         27         3.5
# 9   5shift.txt  u54v0307r_c0m.fits  0.712386  0.544932         27         3.5
# 10  6shift.txt  u54v0306r_c0m.fits  0.000000  0.000000         28         3.5
# 11  6shift.txt  u54v0307r_c0m.fits  0.487608  0.495743         28         3.5
# 12  7shift.txt  u54v0306r_c0m.fits  0.000000  0.000000         29         3.5
# 13  7shift.txt  u54v0307r_c0m.fits    failed    failed         29         3.5
# 14  8shift.txt  u54v0306r_c0m.fits  0.000000  0.000000         30         3.5
# 15  8shift.txt  u54v0307r_c0m.fits  0.592892  0.586881         30         3.5
# 16  9shift.txt  u54v0306r_c0m.fits  0.000000  0.000000         31         3.5
# 17  9shift.txt  u54v0307r_c0m.fits  0.626110  0.750983         31         3.5
#
#     roundlo  roundhi  peakmax
# 0        -1        1     1000
# 1        -1        1     1000
# 2        -1        1     1000
# 3        -1        1     1000
# 4        -1        1     1000
# 5        -1        1     1000
# 6        -1        1     1000
# 7        -1        1     1000
# 8        -1        1     1000
# 9        -1        1     1000
# 10       -1        1     1000
# 11       -1        1     1000
# 12       -1        1     1000
# 13       -1        1     1000
# 14       -1        1     1000
# 15       -1        1     1000
# 16       -1        1     1000
# 17       -1        1     1000

# %%
# filter by column
# good_table['y_rms']

# %%
# filter by value in column
# good_table[good_table['y_rms']=='failed']

# %%
# see unique in column
# good_table['shift'].unique()

# %%
# good_table.shape

# %%
# take only unfailed sessions
good = good_table[good_table['y_rms'] != 'failed']

# %%
# ????????????????????????????????????????????????????
plt.figure(figsize = (7,7))
plt.plot(good['threshold'],good['x_rms'],'.g')
plt.plot(good['threshold'],good['y_rms'],'.b')
plt.title('x,y_rms(threshold)-g,b')
plt.show()

# %%
# plot figure for choosen sub-exp
plt.figure(figsize = (7,7))
plt.plot(good[good['file'] == 'u29r1r01t_c0m.fits']['threshold'],good[good['file'] == 'u29r1r01t_c0m.fits']['y_rms'],'.b')
plt.plot(good[good['file'] == 'u29r1r02t_c0m.fits']['threshold'],good[good['file'] == 'u29r1r02t_c0m.fits']['y_rms'],'.g')
plt.title('y_rms(threshold)-two filters')
plt.show()

# %%
# find min y_rms and min x_rms
min_x = good[good['x_rms'].values.astype(float) != 0.0]['x_rms'].min()
min_y = good[good['y_rms'].values.astype(float) != 0.0]['y_rms'].min()
print(min_x)
print(min_y)
# Out:
# 0.206961
# 0.186928

# %%
# sort all values =! 0 and take lowest 5 in y_rms
good[good['x_rms'].values.astype(float) != 0.0].sort_values('x_rms',ascending=True)[:5]
# Out:
#          shift                file     x_rms     y_rms  threshold  conv_width
# 21  6shift.txt  u6ea5402m_c0m.fits  0.056897  0.037645         51           3
# 17  5shift.txt  u6ea5402m_c0m.fits  0.069021  0.038714         41           3
# 9   3shift.txt  u6ea5402m_c0m.fits  0.074321  0.078460         21           3
# 5   2shift.txt  u6ea5402m_c0m.fits  0.088635  0.088857         11           3
# 13  4shift.txt  u6ea5402m_c0m.fits  0.152657  0.101558         31           3

# %%
# sort all values =! 0 and take lowest 5 in y_rms BY FILTER??????????????????????
good['file' == 'u29r1r02t_c0m.fits'][['y_rms'].values.astype(float) != 0.0]].sort_values('y_rms',ascending=True)[:5]
#plt.plot(good[good['file'] == 'u6ea5402m_c0m.fits']['threshold'],good[good['file'] == 'u6ea5402m_c0m.fits']['y_rms'],'.b')
# Out:
#   File "<ipython-input-14-aaeb809a2179>", line 2
#     good['file' == 'u29r1r02t_c0m.fits'][['y_rms'].values.astype(float) != 0.0]].sort_values('y_rms',ascending=True)[:5]
#                                                                                ^
# SyntaxError: invalid syntax

# %%
############################################################ thresh=28, conv_width?

# %%
# tweak_run(path, n_up, threshold_ini, threshold_gap, conv_width_ini, conv_width_gap, 
# roundlo_val_ini, roundlo_gap, roundhi_val_ini, roundhi_gap, peakmax_val_ini, peakmax_gap):
test = tweak_run('/Users/natalie/anaconda2/envs/iraf27/iraf/sn/2001ci/2001ci_pre/tweak_658',10,28,0,2.0,0.2,-1.5,0,1,0,1000,0)
# Out:
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 08:23:42.664 (14/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0306r_c0m.fits
#
#     u54v0307r_c0m.fits
#
# ===  Source finding for image 'u54v0306r_c0m.fits':
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 1) started at: 08:23:42.954 (14/12/2017)
#
#      Found 360 objects.
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 2) started at: 08:23:43.29 (14/12/2017)
#
#      Found 316 objects.
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 3) started at: 08:23:43.607 (14/12/2017)
#
#      Found 312 objects.
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 4) started at: 08:23:43.945 (14/12/2017)
#
#      Found 1354 objects.
#
# ===  Found a TOTAL of 2342 objects in image 'u54v0306r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0307r_c0m.fits':
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 1) started at: 08:23:44.86 (14/12/2017)
#
#      Found 427 objects.
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 2) started at: 08:23:45.275 (14/12/2017)
#
#      Found 349 objects.
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 3) started at: 08:23:45.616 (14/12/2017)
#
#      Found 421 objects.
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 4) started at: 08:23:46.137 (14/12/2017)
#
#      Found 307 objects.
#
# ===  Found a TOTAL of 1504 objects in image 'u54v0307r_c0m.fits'
#
#
#
#  Catalog trimmed to 2342 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0306r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0307r_c0m.fits
#
# Matching sources from 'u54v0307r_c0m.fits' with sources from reference image 'u54v0306r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  1.07128238911 0.161282389108
#
#     with significance of  252.548213219 and  8.0  matches
#
# Found 18 matches for u54v0307r_c0m.fits...
#
# Computed  rscale  fit for  u54v0307r_c0m.fits :
#
# XSH: 1.17195  YSH: 0.377206    ROT: 0.00103642    SCALE: 1.00018
#
# XRMS: 0.631648    YRMS: 0.633942
#
# RMS_RA: 6.30972e-06 (deg)   RMS_DEC: 1.07473e-05 (deg)
#
# Final solution based on  18  objects.
#
# wrote XY data to:  u54v0307r_c0m_catalog_fit.match
#
# Writing out shiftfile : 1shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 1.171949
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 08:23:47.360 (14/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0306r_c0m.fits
#
#     u54v0307r_c0m.fits
#
# ===  Source finding for image 'u54v0306r_c0m.fits':
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 1) started at: 08:23:47.614 (14/12/2017)
#
#      Found 323 objects.
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 2) started at: 08:23:47.894 (14/12/2017)
#
#      Found 290 objects.
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 3) started at: 08:23:48.257 (14/12/2017)
#
#      Found 284 objects.
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 4) started at: 08:23:48.723 (14/12/2017)
#
#      Found 1450 objects.
#
# ===  Found a TOTAL of 2347 objects in image 'u54v0306r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0307r_c0m.fits':
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 1) started at: 08:23:49.506 (14/12/2017)
#
#      Found 398 objects.
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 2) started at: 08:23:49.814 (14/12/2017)
#
#      Found 296 objects.
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 3) started at: 08:23:50.134 (14/12/2017)
#
#      Found 367 objects.
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 4) started at: 08:23:50.540 (14/12/2017)
#
#      Found 289 objects.
#
# ===  Found a TOTAL of 1350 objects in image 'u54v0307r_c0m.fits'
#
#
#
#  Catalog trimmed to 2347 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0306r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0307r_c0m.fits
#
# Matching sources from 'u54v0307r_c0m.fits' with sources from reference image 'u54v0306r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -15.4666541188 -2.32379697597
#
#     with significance of  114.930413729 and  7.0  matches
#
# Found 20 matches for u54v0307r_c0m.fits...
#
# Computed  rscale  fit for  u54v0307r_c0m.fits :
#
# XSH: -15.3524  YSH: -2.26004    ROT: 359.999    SCALE: 1.00028
#
# XRMS: 0.854528    YRMS: 0.736708
#
# RMS_RA: 9.75039e-06 (deg)   RMS_DEC: 1.31715e-05 (deg)
#
# Final solution based on  20  objects.
#
# wrote XY data to:  u54v0307r_c0m_catalog_fit.match
#
# Writing out shiftfile : 2shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -15.352369
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 08:23:51.97 (14/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0306r_c0m.fits
#
#     u54v0307r_c0m.fits
#
# ===  Source finding for image 'u54v0306r_c0m.fits':
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 1) started at: 08:23:52.35 (14/12/2017)
#
#      Found 322 objects.
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 2) started at: 08:23:52.760 (14/12/2017)
#
#      Found 292 objects.
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 3) started at: 08:23:53.22 (14/12/2017)
#
#      Found 288 objects.
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 4) started at: 08:23:53.866 (14/12/2017)
#
#      Found 1665 objects.
#
# ===  Found a TOTAL of 2567 objects in image 'u54v0306r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0307r_c0m.fits':
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 1) started at: 08:23:55.228 (14/12/2017)
#
#      Found 403 objects.
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 2) started at: 08:23:55.870 (14/12/2017)
#
#      Found 288 objects.
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 3) started at: 08:23:56.192 (14/12/2017)
#
#      Found 364 objects.
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 4) started at: 08:23:56.726 (14/12/2017)
#
#      Found 288 objects.
#
# ===  Found a TOTAL of 1343 objects in image 'u54v0307r_c0m.fits'
#
#
#
#  Catalog trimmed to 2567 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0306r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0307r_c0m.fits
#
# Matching sources from 'u54v0307r_c0m.fits' with sources from reference image 'u54v0306r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  4.95507549256 -16.6138900247
#
#     with significance of  213.694641954 and  6.0  matches
#
# ##############################################################################
# #                                                                            #
# # WARNING:                                                                   #
# # Not enough matches (< 15) found for input image: u54v0307r_c0m.fits        #
# #                                                                            #
# ##############################################################################
#
#
# Unable to match the following images:
#
# -------------------------------------
#
# u54v0307r_c0m.fits
#
#
# Writing out shiftfile : 3shift.txt
#
# Trailer file written to:  tweakreg.log
# 0.000000
# nan
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 08:23:57. (14/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0306r_c0m.fits
#
#     u54v0307r_c0m.fits
#
# ===  Source finding for image 'u54v0306r_c0m.fits':
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 1) started at: 08:23:57.846 (14/12/2017)
#
#      Found 360 objects.
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 2) started at: 08:23:58.241 (14/12/2017)
#
#      Found 308 objects.
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 3) started at: 08:23:58.756 (14/12/2017)
#
#      Found 296 objects.
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 4) started at: 08:23:59.304 (14/12/2017)
#
#      Found 2017 objects.
#
# ===  Found a TOTAL of 2981 objects in image 'u54v0306r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0307r_c0m.fits':
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 1) started at: 08:24:00.354 (14/12/2017)
#
#      Found 446 objects.
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 2) started at: 08:24:00.904 (14/12/2017)
#
#      Found 300 objects.
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 3) started at: 08:24:01.434 (14/12/2017)
#
#      Found 386 objects.
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 4) started at: 08:24:02.033 (14/12/2017)
#
#      Found 311 objects.
#
# ===  Found a TOTAL of 1443 objects in image 'u54v0307r_c0m.fits'
#
#
#
#  Catalog trimmed to 2981 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0306r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0307r_c0m.fits
#
# Matching sources from 'u54v0307r_c0m.fits' with sources from reference image 'u54v0306r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  18.1425482119 -6.07264166152
#
#     with significance of  230.543922063 and  7.0  matches
#
# ##############################################################################
# #                                                                            #
# # WARNING:                                                                   #
# # Not enough matches (< 15) found for input image: u54v0307r_c0m.fits        #
# #                                                                            #
# ##############################################################################
#
#
# Unable to match the following images:
#
# -------------------------------------
#
# u54v0307r_c0m.fits
#
#
# Writing out shiftfile : 4shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# nan
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 08:24:03.402 (14/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0306r_c0m.fits
#
#     u54v0307r_c0m.fits
#
# ===  Source finding for image 'u54v0306r_c0m.fits':
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 1) started at: 08:24:03.797 (14/12/2017)
#
#      Found 394 objects.
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 2) started at: 08:24:04.135 (14/12/2017)
#
#      Found 333 objects.
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 3) started at: 08:24:04.639 (14/12/2017)
#
#      Found 323 objects.
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 4) started at: 08:24:05.2 (14/12/2017)
#
#      Found 2500 objects.
#
# ===  Found a TOTAL of 3550 objects in image 'u54v0306r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0307r_c0m.fits':
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 1) started at: 08:24:06.828 (14/12/2017)
#
#      Found 486 objects.
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 2) started at: 08:24:07.38 (14/12/2017)
#
#      Found 336 objects.
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 3) started at: 08:24:07.952 (14/12/2017)
#
#      Found 409 objects.
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 4) started at: 08:24:08.438 (14/12/2017)
#
#      Found 336 objects.
#
# ===  Found a TOTAL of 1567 objects in image 'u54v0307r_c0m.fits'
#
#
#
#  Catalog trimmed to 3550 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0306r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0307r_c0m.fits
#
# Matching sources from 'u54v0307r_c0m.fits' with sources from reference image 'u54v0306r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -6.78728903946 -11.9587176109
#
#     with significance of  271.974998851 and  9.0  matches
#
# Found 16 matches for u54v0307r_c0m.fits...
#
# Computed  rscale  fit for  u54v0307r_c0m.fits :
#
# XSH: -6.81273  YSH: -11.7199    ROT: 359.981    SCALE: 0.999824
#
# XRMS: 0.631577    YRMS: 0.57262
#
# RMS_RA: 6.92405e-06 (deg)   RMS_DEC: 1.00531e-05 (deg)
#
# Final solution based on  16  objects.
#
# wrote XY data to:  u54v0307r_c0m_catalog_fit.match
#
# Writing out shiftfile : 5shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -6.812729
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 08:24:09.291 (14/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0306r_c0m.fits
#
#     u54v0307r_c0m.fits
#
# ===  Source finding for image 'u54v0306r_c0m.fits':
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 1) started at: 08:24:09.719 (14/12/2017)
#
#      Found 447 objects.
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 2) started at: 08:24:10.235 (14/12/2017)
#
#      Found 363 objects.
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 3) started at: 08:24:10.533 (14/12/2017)
#
#      Found 367 objects.
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 4) started at: 08:24:10.99 (14/12/2017)
#
#      Found 2977 objects.
#
# ===  Found a TOTAL of 4154 objects in image 'u54v0306r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0307r_c0m.fits':
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 1) started at: 08:24:12.544 (14/12/2017)
#
#      Found 551 objects.
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 2) started at: 08:24:13.1e (14/12/2017)
#
#      Found 405 objects.
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 3) started at: 08:24:13.451 (14/12/2017)
#
#      Found 471 objects.
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 4) started at: 08:24:13.84 (14/12/2017)
#
#      Found 394 objects.
#
# ===  Found a TOTAL of 1821 objects in image 'u54v0307r_c0m.fits'
#
#
#
#  Catalog trimmed to 4154 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0306r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0307r_c0m.fits
#
# Matching sources from 'u54v0307r_c0m.fits' with sources from reference image 'u54v0306r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -15.151700067 -1.03766497931
#
#     with significance of  137.368118572 and  10.0  matches
#
# Found 23 matches for u54v0307r_c0m.fits...
#
# Computed  rscale  fit for  u54v0307r_c0m.fits :
#
# XSH: -14.8384  YSH: -1.28008    ROT: 359.974    SCALE: 1.00013
#
# XRMS: 0.5674    YRMS: 0.675316
#
# RMS_RA: 4.60495e-06 (deg)   RMS_DEC: 1.08516e-05 (deg)
#
# Final solution based on  23  objects.
#
# wrote XY data to:  u54v0307r_c0m_catalog_fit.match
#
# Writing out shiftfile : 6shift.txt
#
# Trailer file written to:  tweakreg.log
# 0.000000
# -14.838376
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 08:24:14.666 (14/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0306r_c0m.fits
#
#     u54v0307r_c0m.fits
#
# ===  Source finding for image 'u54v0306r_c0m.fits':
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 1) started at: 08:24:14.910 (14/12/2017)
#
#      Found 517 objects.
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 2) started at: 08:24:15.214 (14/12/2017)
#
#      Found 425 objects.
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 3) started at: 08:24:15.499 (14/12/2017)
#
#      Found 435 objects.
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 4) started at: 08:24:15.79 (14/12/2017)
#
#      Found 3478 objects.
#
# ===  Found a TOTAL of 4855 objects in image 'u54v0306r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0307r_c0m.fits':
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 1) started at: 08:24:17.200 (14/12/2017)
#
#      Found 591 objects.
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 2) started at: 08:24:17.538 (14/12/2017)
#
#      Found 456 objects.
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 3) started at: 08:24:17.839 (14/12/2017)
#
#      Found 515 objects.
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 4) started at: 08:24:18.289 (14/12/2017)
#
#      Found 437 objects.
#
# ===  Found a TOTAL of 1999 objects in image 'u54v0307r_c0m.fits'
#
#
#
#  Catalog trimmed to 4855 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0306r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0307r_c0m.fits
#
# Matching sources from 'u54v0307r_c0m.fits' with sources from reference image 'u54v0306r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  5.75262259529 -14.6700578171
#
#     with significance of  262.698088524 and  9.0  matches
#
# Found 23 matches for u54v0307r_c0m.fits...
#
# Computed  rscale  fit for  u54v0307r_c0m.fits :
#
# XSH: 6.27117  YSH: -14.4464    ROT: 0.013865    SCALE: 0.999809
#
# XRMS: 0.684835    YRMS: 0.591019
#
# RMS_RA: 7.80805e-06 (deg)   RMS_DEC: 1.05628e-05 (deg)
#
# Final solution based on  23  objects.
#
# wrote XY data to:  u54v0307r_c0m_catalog_fit.match
#
# Writing out shiftfile : 7shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 6.271167
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 08:24:19.125 (14/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0306r_c0m.fits
#
#     u54v0307r_c0m.fits
#
# ===  Source finding for image 'u54v0306r_c0m.fits':
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 1) started at: 08:24:19.373 (14/12/2017)
#
#      Found 569 objects.
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 2) started at: 08:24:19.677 (14/12/2017)
#
#      Found 488 objects.
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 3) started at: 08:24:19.96 (14/12/2017)
#
#      Found 498 objects.
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 4) started at: 08:24:20.259 (14/12/2017)
#
#      Found 3987 objects.
#
# ===  Found a TOTAL of 5542 objects in image 'u54v0306r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0307r_c0m.fits':
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 1) started at: 08:24:21.88 (14/12/2017)
#
#      Found 663 objects.
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 2) started at: 08:24:22.232 (14/12/2017)
#
#      Found 517 objects.
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 3) started at: 08:24:22.515 (14/12/2017)
#
#      Found 607 objects.
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 4) started at: 08:24:22.899 (14/12/2017)
#
#      Found 516 objects.
#
# ===  Found a TOTAL of 2303 objects in image 'u54v0307r_c0m.fits'
#
#
#
#  Catalog trimmed to 5542 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0306r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0307r_c0m.fits
#
# Matching sources from 'u54v0307r_c0m.fits' with sources from reference image 'u54v0306r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  7.91490876273 2.99183183966
#
#     with significance of  282.357486177 and  10.0  matches
#
# Found 36 matches for u54v0307r_c0m.fits...
#
# Computed  rscale  fit for  u54v0307r_c0m.fits :
#
# XSH: 8.08224  YSH: 3.28235    ROT: 0.00347349    SCALE: 0.999691
#
# XRMS: 0.67638    YRMS: 0.726844
#
# RMS_RA: 6.27449e-06 (deg)   RMS_DEC: 1.20514e-05 (deg)
#
# Final solution based on  36  objects.
#
# wrote XY data to:  u54v0307r_c0m_catalog_fit.match
#
# Writing out shiftfile : 8shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 8.082242
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 08:24:23.789 (14/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0306r_c0m.fits
#
#     u54v0307r_c0m.fits
#
# ===  Source finding for image 'u54v0306r_c0m.fits':
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 1) started at: 08:24:24.033 (14/12/2017)
#
#      Found 245 objects.
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 2) started at: 08:24:24.28 (14/12/2017)
#
#      Found 201 objects.
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 3) started at: 08:24:24.589 (14/12/2017)
#
#      Found 224 objects.
#
#   #  Source finding for 'u54v0306r_c0m.fits', EXT=('SCI', 4) started at: 08:24:24.910 (14/12/2017)
#
#      Found 1171 objects.
#
# ===  Found a TOTAL of 1841 objects in image 'u54v0306r_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0307r_c0m.fits':
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 1) started at: 08:24:25.709 (14/12/2017)
#
#      Found 309 objects.
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 2) started at: 08:24:26.105 (14/12/2017)
#
#      Found 214 objects.
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 3) started at: 08:24:26.535 (14/12/2017)
#
#      Found 296 objects.
#
#   #  Source finding for 'u54v0307r_c0m.fits', EXT=('SCI', 4) started at: 08:24:27.172 (14/12/2017)
#
#      Found 207 objects.
#
# ===  Found a TOTAL of 1026 objects in image 'u54v0307r_c0m.fits'
#
#
#
#  Catalog trimmed to 1841 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0306r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0307r_c0m.fits
#
# Matching sources from 'u54v0307r_c0m.fits' with sources from reference image 'u54v0306r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -1.90316205534 7.055171278
#
#     with significance of  215.015115748 and  6.0  matches
#
# ##############################################################################
# #                                                                            #
# # WARNING:                                                                   #
# # Not enough matches (< 15) found for input image: u54v0307r_c0m.fits        #
# #                                                                            #
# ##############################################################################
#
#
# Unable to match the following images:
#
# -------------------------------------
#
# u54v0307r_c0m.fits
#
#
# Writing out shiftfile : 9shift.txt
# Trailer file written to:  tweakreg.log
#
# 0.000000
# nan

# %%
# change to a jupyter table
dt=test.to_pandas()
dt.to_pickle('data.pickle')
good_table=pandas.read_pickle('data.pickle')

# %%
# take only unfailed sessions
good_conv = good_table[good_table['y_rms'] != 'failed']

# %%
good_conv
# Out:
#          shift                file     x_rms     y_rms  threshold  conv_width  \
# 0   1shift.txt  u54v0306r_c0m.fits  0.000000  0.000000         28         2.0
# 1   1shift.txt  u54v0307r_c0m.fits  0.631648  0.633942         28         2.0
# 2   2shift.txt  u54v0306r_c0m.fits  0.000000  0.000000         28         2.2
# 3   2shift.txt  u54v0307r_c0m.fits  0.854528  0.736708         28         2.2
# 4   3shift.txt  u54v0306r_c0m.fits  0.000000  0.000000         28         2.4
# 6   4shift.txt  u54v0306r_c0m.fits  0.000000  0.000000         28         2.6
# 8   5shift.txt  u54v0306r_c0m.fits  0.000000  0.000000         28         2.8
# 9   5shift.txt  u54v0307r_c0m.fits  0.631577  0.572620         28         2.8
# 10  6shift.txt  u54v0306r_c0m.fits  0.000000  0.000000         28         3.0
# 11  6shift.txt  u54v0307r_c0m.fits  0.567400  0.675316         28         3.0
# 12  7shift.txt  u54v0306r_c0m.fits  0.000000  0.000000         28         3.2
# 13  7shift.txt  u54v0307r_c0m.fits  0.684835  0.591019         28         3.2
# 14  8shift.txt  u54v0306r_c0m.fits  0.000000  0.000000         28         3.4
# 15  8shift.txt  u54v0307r_c0m.fits  0.676380  0.726844         28         3.4
# 16  9shift.txt  u54v0306r_c0m.fits  0.000000  0.000000         28         3.6
#
#     roundlo  roundhi  peakmax
# 0      -1.5        1     1000
# 1      -1.5        1     1000
# 2      -1.5        1     1000
# 3      -1.5        1     1000
# 4      -1.5        1     1000
# 6      -1.5        1     1000
# 8      -1.5        1     1000
# 9      -1.5        1     1000
# 10     -1.5        1     1000
# 11     -1.5        1     1000
# 12     -1.5        1     1000
# 13     -1.5        1     1000
# 14     -1.5        1     1000
# 15     -1.5        1     1000
# 16     -1.5        1     1000

# %%
# plot figure for all sub-exp
plt.figure(figsize = (7,7))
plt.plot(good_conv['conv_width'],good_conv['x_rms'],'.g')
plt.plot(good_conv['conv_width'],good_conv['y_rms'],'.b')
plt.title('x,y_rms(conv_width)-g,b')
plt.show()

# %%
# plot figure for choosen sub-exp
plt.figure(figsize = (7,7))
plt.plot(good_conv[good_conv['file'] == 'u6ea5402m_c0m.fits']['conv_width'],good_conv[good_conv['file'] == 'u6ea5402m_c0m.fits']['y_rms'],'.b')
plt.plot(good_conv[good_conv['file'] == 'u6ea5403m_c0m.fits']['conv_width'],good_conv[good_conv['file'] == 'u6ea5403m_c0m.fits']['y_rms'],'.g')
plt.title('y_rms(conv)-two filters')
plt.show()

# %%
#############################################thresh = 9, conv = 2.9, roundlo?

# %%
# tweak_run(path, n_up, threshold_ini, threshold_gap, conv_width_ini, conv_width_gap, 
# roundlo_val_ini, roundlo_gap, roundhi_val_ini, roundhi_gap, peakmax_val_ini, peakmax_gap):
test = tweak_run('/Users/natalie/anaconda2/envs/iraf27/iraf/sn/2001ci/2001ci_pre/tweak_814',10,9,0,2.8,0,-2,0.1,1,0,1000,0)
# Out:
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 19:21:25.39 (13/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0301m_c0m.fits
#
#     u54v0302r_c0m.fits
#
# ===  Source finding for image 'u54v0301m_c0m.fits':
#
#   #  Source finding for 'u54v0301m_c0m.fits', EXT=('SCI', 1) started at: 19:21:25.680 (13/12/2017)
#
#      Found 482 objects.
#
#   #  Source finding for 'u54v0301m_c0m.fits', EXT=('SCI', 2) started at: 19:21:26.081 (13/12/2017)
#
#      Found 422 objects.
#
#   #  Source finding for 'u54v0301m_c0m.fits', EXT=('SCI', 3) started at: 19:21:26.363 (13/12/2017)
#
#      Found 191 objects.
#
#   #  Source finding for 'u54v0301m_c0m.fits', EXT=('SCI', 4) started at: 19:21:26.633 (13/12/2017)
#
#      Found 194 objects.
#
# ===  Found a TOTAL of 1289 objects in image 'u54v0301m_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0302r_c0m.fits':
#
#   #  Source finding for 'u54v0302r_c0m.fits', EXT=('SCI', 1) started at: 19:21:27.101 (13/12/2017)
#
#      Found 533 objects.
#
#   #  Source finding for 'u54v0302r_c0m.fits', EXT=('SCI', 2) started at: 19:21:27.555 (13/12/2017)
#
#      Found 195 objects.
#
#   #  Source finding for 'u54v0302r_c0m.fits', EXT=('SCI', 3) started at: 19:21:27.787 (13/12/2017)
#
#      Found 206 objects.
#
#   #  Source finding for 'u54v0302r_c0m.fits', EXT=('SCI', 4) started at: 19:21:28.034 (13/12/2017)
#
#      Found 223 objects.
#
# ===  Found a TOTAL of 1157 objects in image 'u54v0302r_c0m.fits'
#
#
#
#  Catalog trimmed to 1289 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0301m_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0302r_c0m.fits
#
# Matching sources from 'u54v0302r_c0m.fits' with sources from reference image 'u54v0301m_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  7.93956059309 0.0102676637946
#
#     with significance of  289.59742172 and  11.0  matches
#
# Found 41 matches for u54v0302r_c0m.fits...
#
# Computed  rscale  fit for  u54v0302r_c0m.fits :
#
# XSH: 8.06935  YSH: 0.271043    ROT: 0.00383936    SCALE: 0.99947
#
# XRMS: 0.731297    YRMS: 0.751771
#
# RMS_RA: 7.12762e-06 (deg)   RMS_DEC: 1.26468e-05 (deg)
#
# Final solution based on  41  objects.
#
# wrote XY data to:  u54v0302r_c0m_catalog_fit.match
#
# Writing out shiftfile : 1shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 8.069348
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 19:21:28.867 (13/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0301m_c0m.fits
#
#     u54v0302r_c0m.fits
#
# ===  Source finding for image 'u54v0301m_c0m.fits':
#
#   #  Source finding for 'u54v0301m_c0m.fits', EXT=('SCI', 1) started at: 19:21:29.127 (13/12/2017)
#
#      Found 479 objects.
#
#   #  Source finding for 'u54v0301m_c0m.fits', EXT=('SCI', 2) started at: 19:21:29.553 (13/12/2017)
#
#      Found 420 objects.
#
#   #  Source finding for 'u54v0301m_c0m.fits', EXT=('SCI', 3) started at: 19:21:29.831 (13/12/2017)
#
#      Found 189 objects.
#
#   #  Source finding for 'u54v0301m_c0m.fits', EXT=('SCI', 4) started at: 19:21:30.081 (13/12/2017)
#
#      Found 194 objects.
#
# ===  Found a TOTAL of 1282 objects in image 'u54v0301m_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0302r_c0m.fits':
#
#   #  Source finding for 'u54v0302r_c0m.fits', EXT=('SCI', 1) started at: 19:21:30.56 (13/12/2017)
#
#      Found 528 objects.
#
#   #  Source finding for 'u54v0302r_c0m.fits', EXT=('SCI', 2) started at: 19:21:31.010 (13/12/2017)
#
#      Found 194 objects.
#
#   #  Source finding for 'u54v0302r_c0m.fits', EXT=('SCI', 3) started at: 19:21:31.251 (13/12/2017)
#
#      Found 203 objects.
#
#   #  Source finding for 'u54v0302r_c0m.fits', EXT=('SCI', 4) started at: 19:21:31.510 (13/12/2017)
#
#      Found 220 objects.
#
# ===  Found a TOTAL of 1145 objects in image 'u54v0302r_c0m.fits'
#
#
#
#  Catalog trimmed to 1282 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0301m_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0302r_c0m.fits
#
# Matching sources from 'u54v0302r_c0m.fits' with sources from reference image 'u54v0301m_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  7.92254427607 0.0251083786353
#
#     with significance of  144.072898215 and  11.0  matches
#
# Found 40 matches for u54v0302r_c0m.fits...
#
# Computed  rscale  fit for  u54v0302r_c0m.fits :
#
# XSH: 8.07402  YSH: 0.316329    ROT: 0.00619314    SCALE: 0.999439
#
# XRMS: 0.736295    YRMS: 0.732539
#
# RMS_RA: 7.4211e-06 (deg)   RMS_DEC: 1.24575e-05 (deg)
#
# Final solution based on  40  objects.
#
# wrote XY data to:  u54v0302r_c0m_catalog_fit.match
#
# Writing out shiftfile : 2shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 8.074024
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 19:21:32.216 (13/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0301m_c0m.fits
#
#     u54v0302r_c0m.fits
#
# ===  Source finding for image 'u54v0301m_c0m.fits':
#
#   #  Source finding for 'u54v0301m_c0m.fits', EXT=('SCI', 1) started at: 19:21:32.493 (13/12/2017)
#
#      Found 473 objects.
#
#   #  Source finding for 'u54v0301m_c0m.fits', EXT=('SCI', 2) started at: 19:21:32.877 (13/12/2017)
#
#      Found 414 objects.
#
#   #  Source finding for 'u54v0301m_c0m.fits', EXT=('SCI', 3) started at: 19:21:33.141 (13/12/2017)
#
#      Found 187 objects.
#
#   #  Source finding for 'u54v0301m_c0m.fits', EXT=('SCI', 4) started at: 19:21:33.414 (13/12/2017)
#
#      Found 194 objects.
#
# ===  Found a TOTAL of 1268 objects in image 'u54v0301m_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0302r_c0m.fits':
#
#   #  Source finding for 'u54v0302r_c0m.fits', EXT=('SCI', 1) started at: 19:21:33.92 (13/12/2017)
#
#      Found 526 objects.
#
#   #  Source finding for 'u54v0302r_c0m.fits', EXT=('SCI', 2) started at: 19:21:34.305 (13/12/2017)
#
#      Found 193 objects.
#
#   #  Source finding for 'u54v0302r_c0m.fits', EXT=('SCI', 3) started at: 19:21:34.531 (13/12/2017)
#
#      Found 199 objects.
#
#   #  Source finding for 'u54v0302r_c0m.fits', EXT=('SCI', 4) started at: 19:21:34.770 (13/12/2017)
#
#      Found 218 objects.
#
# ===  Found a TOTAL of 1136 objects in image 'u54v0302r_c0m.fits'
#
#
#
#  Catalog trimmed to 1268 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0301m_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0302r_c0m.fits
#
# Matching sources from 'u54v0302r_c0m.fits' with sources from reference image 'u54v0301m_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -16.6686645151 -19.4662835628
#
#     with significance of  137.622672551 and  10.0  matches
#
# Found 19 matches for u54v0302r_c0m.fits...
#
# Computed  rscale  fit for  u54v0302r_c0m.fits :
#
# XSH: -16.5729  YSH: -19.6077    ROT: 0.0218051    SCALE: 1.00005
#
# XRMS: 0.509263    YRMS: 0.534584
#
# RMS_RA: 4.85245e-06 (deg)   RMS_DEC: 8.93221e-06 (deg)
#
# Final solution based on  19  objects.
#
# wrote XY data to:  u54v0302r_c0m_catalog_fit.match
#
# Writing out shiftfile : 3shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -16.572877
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 19:21:35.494 (13/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0301m_c0m.fits
#
#     u54v0302r_c0m.fits
#
# ===  Source finding for image 'u54v0301m_c0m.fits':
#
#   #  Source finding for 'u54v0301m_c0m.fits', EXT=('SCI', 1) started at: 19:21:35.743 (13/12/2017)
#
#      Found 469 objects.
#
#   #  Source finding for 'u54v0301m_c0m.fits', EXT=('SCI', 2) started at: 19:21:36.171 (13/12/2017)
#
#      Found 410 objects.
#
#   #  Source finding for 'u54v0301m_c0m.fits', EXT=('SCI', 3) started at: 19:21:36.44 (13/12/2017)
#
#      Found 186 objects.
#
#   #  Source finding for 'u54v0301m_c0m.fits', EXT=('SCI', 4) started at: 19:21:36.685 (13/12/2017)
#
#      Found 192 objects.
#
# ===  Found a TOTAL of 1257 objects in image 'u54v0301m_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0302r_c0m.fits':
#
#   #  Source finding for 'u54v0302r_c0m.fits', EXT=('SCI', 1) started at: 19:21:37.160 (13/12/2017)
#
#      Found 514 objects.
#
#   #  Source finding for 'u54v0302r_c0m.fits', EXT=('SCI', 2) started at: 19:21:37.539 (13/12/2017)
#
#      Found 191 objects.
#
#   #  Source finding for 'u54v0302r_c0m.fits', EXT=('SCI', 3) started at: 19:21:37.770 (13/12/2017)
#
#      Found 198 objects.
#
#   #  Source finding for 'u54v0302r_c0m.fits', EXT=('SCI', 4) started at: 19:21:38.038 (13/12/2017)
#
#      Found 215 objects.
#
# ===  Found a TOTAL of 1118 objects in image 'u54v0302r_c0m.fits'
#
#
#
#  Catalog trimmed to 1257 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0301m_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0302r_c0m.fits
#
# Matching sources from 'u54v0302r_c0m.fits' with sources from reference image 'u54v0301m_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -16.6686645151 -19.4662835628
#
#     with significance of  137.622672551 and  10.0  matches
#
# Found 19 matches for u54v0302r_c0m.fits...
#
# Computed  rscale  fit for  u54v0302r_c0m.fits :
#
# XSH: -16.5729  YSH: -19.6077    ROT: 0.0218051    SCALE: 1.00005
#
# XRMS: 0.509263    YRMS: 0.534584
#
# RMS_RA: 4.85245e-06 (deg)   RMS_DEC: 8.93221e-06 (deg)
#
# Final solution based on  19  objects.
#
# wrote XY data to:  u54v0302r_c0m_catalog_fit.match
#
# Writing out shiftfile : 4shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -16.572877
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 19:21:38.773 (13/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0301m_c0m.fits
#
#     u54v0302r_c0m.fits
#
# ===  Source finding for image 'u54v0301m_c0m.fits':
#
#   #  Source finding for 'u54v0301m_c0m.fits', EXT=('SCI', 1) started at: 19:21:39.111 (13/12/2017)
#
#      Found 462 objects.
#
#   #  Source finding for 'u54v0301m_c0m.fits', EXT=('SCI', 2) started at: 19:21:39.523 (13/12/2017)
#
#      Found 406 objects.
#
#   #  Source finding for 'u54v0301m_c0m.fits', EXT=('SCI', 3) started at: 19:21:39.807 (13/12/2017)
#
#      Found 184 objects.
#
#   #  Source finding for 'u54v0301m_c0m.fits', EXT=('SCI', 4) started at: 19:21:40.101 (13/12/2017)
#
#      Found 192 objects.
#
# ===  Found a TOTAL of 1244 objects in image 'u54v0301m_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0302r_c0m.fits':
#
#   #  Source finding for 'u54v0302r_c0m.fits', EXT=('SCI', 1) started at: 19:21:40.695 (13/12/2017)
#
#      Found 510 objects.
#
#   #  Source finding for 'u54v0302r_c0m.fits', EXT=('SCI', 2) started at: 19:21:41.112 (13/12/2017)
#
#      Found 190 objects.
#
#   #  Source finding for 'u54v0302r_c0m.fits', EXT=('SCI', 3) started at: 19:21:41.346 (13/12/2017)
#
#      Found 197 objects.
#
#   #  Source finding for 'u54v0302r_c0m.fits', EXT=('SCI', 4) started at: 19:21:41.673 (13/12/2017)
#
#      Found 212 objects.
#
# ===  Found a TOTAL of 1109 objects in image 'u54v0302r_c0m.fits'
#
#
#
#  Catalog trimmed to 1244 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0301m_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0302r_c0m.fits
#
# Matching sources from 'u54v0302r_c0m.fits' with sources from reference image 'u54v0301m_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -16.6860861179 -19.4665739228
#
#     with significance of  137.622672551 and  10.0  matches
#
# Found 19 matches for u54v0302r_c0m.fits...
#
# Computed  rscale  fit for  u54v0302r_c0m.fits :
#
# XSH: -16.5729  YSH: -19.6077    ROT: 0.0218051    SCALE: 1.00005
#
# XRMS: 0.509263    YRMS: 0.534584
#
# RMS_RA: 4.85245e-06 (deg)   RMS_DEC: 8.93221e-06 (deg)
#
# Final solution based on  19  objects.
#
# wrote XY data to:  u54v0302r_c0m_catalog_fit.match
#
# Writing out shiftfile : 5shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -16.572877
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 19:21:42.429 (13/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0301m_c0m.fits
#
#     u54v0302r_c0m.fits
#
# ===  Source finding for image 'u54v0301m_c0m.fits':
#
#   #  Source finding for 'u54v0301m_c0m.fits', EXT=('SCI', 1) started at: 19:21:42.699 (13/12/2017)
#
#      Found 450 objects.
#
#   #  Source finding for 'u54v0301m_c0m.fits', EXT=('SCI', 2) started at: 19:21:43.101 (13/12/2017)
#
#      Found 401 objects.
#
#   #  Source finding for 'u54v0301m_c0m.fits', EXT=('SCI', 3) started at: 19:21:43.379 (13/12/2017)
#
#      Found 184 objects.
#
#   #  Source finding for 'u54v0301m_c0m.fits', EXT=('SCI', 4) started at: 19:21:43.672 (13/12/2017)
#
#      Found 189 objects.
#
# ===  Found a TOTAL of 1224 objects in image 'u54v0301m_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0302r_c0m.fits':
#
#   #  Source finding for 'u54v0302r_c0m.fits', EXT=('SCI', 1) started at: 19:21:44.133 (13/12/2017)
#
#      Found 504 objects.
#
#   #  Source finding for 'u54v0302r_c0m.fits', EXT=('SCI', 2) started at: 19:21:44.579 (13/12/2017)
#
#      Found 187 objects.
#
#   #  Source finding for 'u54v0302r_c0m.fits', EXT=('SCI', 3) started at: 19:21:44.819 (13/12/2017)
#
#      Found 194 objects.
#
#   #  Source finding for 'u54v0302r_c0m.fits', EXT=('SCI', 4) started at: 19:21:45.064 (13/12/2017)
#
#      Found 210 objects.
#
# ===  Found a TOTAL of 1095 objects in image 'u54v0302r_c0m.fits'
#
#
#
#  Catalog trimmed to 1224 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0301m_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0302r_c0m.fits
#
# Matching sources from 'u54v0302r_c0m.fits' with sources from reference image 'u54v0301m_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -16.6704281836 -19.4605516404
#
#     with significance of  137.622672551 and  10.0  matches
#
# Found 17 matches for u54v0302r_c0m.fits...
#
# Computed  rscale  fit for  u54v0302r_c0m.fits :
#
# XSH: -16.5458  YSH: -19.4911    ROT: 0.0341723    SCALE: 0.999914
#
# XRMS: 0.361084    YRMS: 0.470072
#
# RMS_RA: 2.52622e-06 (deg)   RMS_DEC: 7.36328e-06 (deg)
#
# Final solution based on  17  objects.
#
# wrote XY data to:  u54v0302r_c0m_catalog_fit.match
#
# Writing out shiftfile : 6shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -16.545819
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 19:21:45.811 (13/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0301m_c0m.fits
#
#     u54v0302r_c0m.fits
#
# ===  Source finding for image 'u54v0301m_c0m.fits':
#
#   #  Source finding for 'u54v0301m_c0m.fits', EXT=('SCI', 1) started at: 19:21:46.065 (13/12/2017)
#
#      Found 438 objects.
#
#   #  Source finding for 'u54v0301m_c0m.fits', EXT=('SCI', 2) started at: 19:21:46.453 (13/12/2017)
#
#      Found 395 objects.
#
#   #  Source finding for 'u54v0301m_c0m.fits', EXT=('SCI', 3) started at: 19:21:46.724 (13/12/2017)
#
#      Found 180 objects.
#
#   #  Source finding for 'u54v0301m_c0m.fits', EXT=('SCI', 4) started at: 19:21:46.972 (13/12/2017)
#
#      Found 186 objects.
#
# ===  Found a TOTAL of 1199 objects in image 'u54v0301m_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0302r_c0m.fits':
#
#   #  Source finding for 'u54v0302r_c0m.fits', EXT=('SCI', 1) started at: 19:21:47.450 (13/12/2017)
#
#      Found 492 objects.
#
#   #  Source finding for 'u54v0302r_c0m.fits', EXT=('SCI', 2) started at: 19:21:47.845 (13/12/2017)
#
#      Found 186 objects.
#
#   #  Source finding for 'u54v0302r_c0m.fits', EXT=('SCI', 3) started at: 19:21:48.075 (13/12/2017)
#
#      Found 194 objects.
#
#   #  Source finding for 'u54v0302r_c0m.fits', EXT=('SCI', 4) started at: 19:21:48.361 (13/12/2017)
#
#      Found 205 objects.
#
# ===  Found a TOTAL of 1077 objects in image 'u54v0302r_c0m.fits'
#
#
#
#  Catalog trimmed to 1199 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0301m_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0302r_c0m.fits
#
# Matching sources from 'u54v0302r_c0m.fits' with sources from reference image 'u54v0301m_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -16.6780630114 -19.5596419587
#
#     with significance of  137.622672551 and  10.0  matches
#
# Found 18 matches for u54v0302r_c0m.fits...
#
# Computed  rscale  fit for  u54v0302r_c0m.fits :
#
# XSH: -16.5703  YSH: -19.6945    ROT: 0.0311533    SCALE: 1.00013
#
# XRMS: 0.341883    YRMS: 0.636562
#
# RMS_RA: 4.68679e-07 (deg)   RMS_DEC: 9.13839e-06 (deg)
#
# Final solution based on  18  objects.
#
# wrote XY data to:  u54v0302r_c0m_catalog_fit.match
#
# Writing out shiftfile : 7shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -16.570264
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 19:21:49.13 (13/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0301m_c0m.fits
#
#     u54v0302r_c0m.fits
#
# ===  Source finding for image 'u54v0301m_c0m.fits':
#
#   #  Source finding for 'u54v0301m_c0m.fits', EXT=('SCI', 1) started at: 19:21:49.375 (13/12/2017)
#
#      Found 429 objects.
#
#   #  Source finding for 'u54v0301m_c0m.fits', EXT=('SCI', 2) started at: 19:21:49.776 (13/12/2017)
#
#      Found 388 objects.
#
#   #  Source finding for 'u54v0301m_c0m.fits', EXT=('SCI', 3) started at: 19:21:50.047 (13/12/2017)
#
#      Found 175 objects.
#
#   #  Source finding for 'u54v0301m_c0m.fits', EXT=('SCI', 4) started at: 19:21:50.330 (13/12/2017)
#
#      Found 181 objects.
#
# ===  Found a TOTAL of 1173 objects in image 'u54v0301m_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0302r_c0m.fits':
#
#   #  Source finding for 'u54v0302r_c0m.fits', EXT=('SCI', 1) started at: 19:21:50.776 (13/12/2017)
#
#      Found 481 objects.
#
#   #  Source finding for 'u54v0302r_c0m.fits', EXT=('SCI', 2) started at: 19:21:51.227 (13/12/2017)
#
#      Found 185 objects.
#
#   #  Source finding for 'u54v0302r_c0m.fits', EXT=('SCI', 3) started at: 19:21:51.46 (13/12/2017)
#
#      Found 191 objects.
#
#   #  Source finding for 'u54v0302r_c0m.fits', EXT=('SCI', 4) started at: 19:21:51.731 (13/12/2017)
#
#      Found 204 objects.
#
# ===  Found a TOTAL of 1061 objects in image 'u54v0302r_c0m.fits'
#
#
#
#  Catalog trimmed to 1173 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0301m_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0302r_c0m.fits
#
# Matching sources from 'u54v0302r_c0m.fits' with sources from reference image 'u54v0301m_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -16.6570815036 -19.5489733954
#
#     with significance of  137.622672551 and  10.0  matches
#
# Found 18 matches for u54v0302r_c0m.fits...
#
# Computed  rscale  fit for  u54v0302r_c0m.fits :
#
# XSH: -16.5703  YSH: -19.6945    ROT: 0.0311533    SCALE: 1.00013
#
# XRMS: 0.341883    YRMS: 0.636562
#
# RMS_RA: 4.68679e-07 (deg)   RMS_DEC: 9.13839e-06 (deg)
#
# Final solution based on  18  objects.
#
# wrote XY data to:  u54v0302r_c0m_catalog_fit.match
#
# Writing out shiftfile : 8shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -16.570264
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 19:21:52.445 (13/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0301m_c0m.fits
#
#     u54v0302r_c0m.fits
#
# ===  Source finding for image 'u54v0301m_c0m.fits':
#
#   #  Source finding for 'u54v0301m_c0m.fits', EXT=('SCI', 1) started at: 19:21:52.705 (13/12/2017)
#
#      Found 422 objects.
#
#   #  Source finding for 'u54v0301m_c0m.fits', EXT=('SCI', 2) started at: 19:21:53.093 (13/12/2017)
#
#      Found 374 objects.
#
#   #  Source finding for 'u54v0301m_c0m.fits', EXT=('SCI', 3) started at: 19:21:53.369 (13/12/2017)
#
#      Found 171 objects.
#
#   #  Source finding for 'u54v0301m_c0m.fits', EXT=('SCI', 4) started at: 19:21:53.619 (13/12/2017)
#
#      Found 179 objects.
#
# ===  Found a TOTAL of 1146 objects in image 'u54v0301m_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0302r_c0m.fits':
#
#   #  Source finding for 'u54v0302r_c0m.fits', EXT=('SCI', 1) started at: 19:21:54.166 (13/12/2017)
#
#      Found 464 objects.
#
#   #  Source finding for 'u54v0302r_c0m.fits', EXT=('SCI', 2) started at: 19:21:54.547 (13/12/2017)
#
#      Found 183 objects.
#
#   #  Source finding for 'u54v0302r_c0m.fits', EXT=('SCI', 3) started at: 19:21:54.780 (13/12/2017)
#
#      Found 188 objects.
#
#   #  Source finding for 'u54v0302r_c0m.fits', EXT=('SCI', 4) started at: 19:21:55.042 (13/12/2017)
#
#      Found 198 objects.
#
# ===  Found a TOTAL of 1033 objects in image 'u54v0302r_c0m.fits'
#
#
#
#  Catalog trimmed to 1146 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0301m_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0302r_c0m.fits
#
# Matching sources from 'u54v0302r_c0m.fits' with sources from reference image 'u54v0301m_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -16.658604153 -19.5740971107
#
#     with significance of  130.560330882 and  9.0  matches
#
# Found 17 matches for u54v0302r_c0m.fits...
#
# Computed  rscale  fit for  u54v0302r_c0m.fits :
#
# XSH: -16.5677  YSH: -19.6913    ROT: 0.0311387    SCALE: 1.00013
#
# XRMS: 0.351512    YRMS: 0.654967
#
# RMS_RA: 4.771e-07 (deg)   RMS_DEC: 9.40116e-06 (deg)
#
# Final solution based on  17  objects.
#
# wrote XY data to:  u54v0302r_c0m_catalog_fit.match
#
# Writing out shiftfile : 9shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -16.567664

# %%
# change to a jupyter table
dt=test.to_pandas()
dt.to_pickle('data.pickle')
good_table=pandas.read_pickle('data.pickle')

# %%
# take only unfailed sessions
good_roundlo = good_table[good_table['y_rms'] != 'failed']

# %%
good_roundlo
# Out:
#          shift                file     x_rms     y_rms  threshold  conv_width  \
# 0   1shift.txt  u54v0301m_c0m.fits  0.000000  0.000000          9         2.8
# 1   1shift.txt  u54v0302r_c0m.fits  0.731297  0.751771          9         2.8
# 2   2shift.txt  u54v0301m_c0m.fits  0.000000  0.000000          9         2.8
# 3   2shift.txt  u54v0302r_c0m.fits  0.736295  0.732539          9         2.8
# 4   3shift.txt  u54v0301m_c0m.fits  0.000000  0.000000          9         2.8
# 5   3shift.txt  u54v0302r_c0m.fits  0.509263  0.534584          9         2.8
# 6   4shift.txt  u54v0301m_c0m.fits  0.000000  0.000000          9         2.8
# 7   4shift.txt  u54v0302r_c0m.fits  0.509263  0.534584          9         2.8
# 8   5shift.txt  u54v0301m_c0m.fits  0.000000  0.000000          9         2.8
# 9   5shift.txt  u54v0302r_c0m.fits  0.509263  0.534584          9         2.8
# 10  6shift.txt  u54v0301m_c0m.fits  0.000000  0.000000          9         2.8
# 11  6shift.txt  u54v0302r_c0m.fits  0.361084  0.470072          9         2.8
# 12  7shift.txt  u54v0301m_c0m.fits  0.000000  0.000000          9         2.8
# 13  7shift.txt  u54v0302r_c0m.fits  0.341883  0.636562          9         2.8
# 14  8shift.txt  u54v0301m_c0m.fits  0.000000  0.000000          9         2.8
# 15  8shift.txt  u54v0302r_c0m.fits  0.341883  0.636562          9         2.8
# 16  9shift.txt  u54v0301m_c0m.fits  0.000000  0.000000          9         2.8
# 17  9shift.txt  u54v0302r_c0m.fits  0.351512  0.654967          9         2.8
#
#     roundlo  roundhi  peakmax
# 0      -2.0        1     1000
# 1      -2.0        1     1000
# 2      -1.9        1     1000
# 3      -1.9        1     1000
# 4      -1.8        1     1000
# 5      -1.8        1     1000
# 6      -1.7        1     1000
# 7      -1.7        1     1000
# 8      -1.6        1     1000
# 9      -1.6        1     1000
# 10     -1.5        1     1000
# 11     -1.5        1     1000
# 12     -1.4        1     1000
# 13     -1.4        1     1000
# 14     -1.3        1     1000
# 15     -1.3        1     1000
# 16     -1.2        1     1000
# 17     -1.2        1     1000

# %%
# plot figure for all sub-exp
plt.figure(figsize = (7,7))
plt.plot(good_roundlo['roundlo'],good_roundlo['x_rms'],'.g')
plt.plot(good_roundlo['roundlo'],good_roundlo['y_rms'],'.b')
plt.title('x,y_rms(roundlo)-g,b')
plt.show()

# %%
# plot figure for choosen sub-exp
plt.figure(figsize = (7,7))
plt.plot(good_round[good_round['file'] == 'u6ea5402m_c0m.fits']['roundlo'],good_round[good_round['file'] == 'u6ea5402m_c0m.fits']['y_rms'],'.b')
plt.plot(good_round[good_round['file'] == 'u6ea5403m_c0m.fits']['roundlo'],good_round[good_round['file'] == 'u6ea5403m_c0m.fits']['y_rms'],'.g')
plt.title('y_rms(roundlo)-two filters')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-1b5e9d62f47a> in <module>()
#       1 # plot figure for choosen sub-exp
#       2 plt.figure(figsize = (7,7))
# ----> 3 plt.plot(good_round[good_round['file'] == 'u6ea5402m_c0m.fits']['roundlo'],good_round[good_round['file'] == 'u6ea5402m_c0m.fits']['y_rms'],'.b')
#       4 plt.plot(good_round[good_round['file'] == 'u6ea5403m_c0m.fits']['roundlo'],good_round[good_round['file'] == 'u6ea5403m_c0m.fits']['y_rms'],'.g')
#       5 plt.title('y_rms(roundlo)-two filters')
#
# NameError: name 'good_round' is not defined

# %%
#############################################thresh = 9, conv = 2.8, roundlo = -1.5, roundhi?

# %%
# tweak_run(path, n_up, threshold_ini, threshold_gap, conv_width_ini, conv_width_gap, 
# roundlo_val_ini, roundlo_gap, roundhi_val_ini, roundhi_gap, peakmax_val_ini, peakmax_gap):
test = tweak_run('/Users/natalie/anaconda2/envs/iraf27/iraf/sn/2001ci/2001ci_pre/tweak_814',2,9,0,2.9,0,-1.5,0,1,0.1,1000,0)
# Out:
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 19:25:12.606 (13/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0301m_c0m.fits
#
#     u54v0302r_c0m.fits
#
# ===  Source finding for image 'u54v0301m_c0m.fits':
#
#   #  Source finding for 'u54v0301m_c0m.fits', EXT=('SCI', 1) started at: 19:25:12.930 (13/12/2017)
#
#      Found 476 objects.
#
#   #  Source finding for 'u54v0301m_c0m.fits', EXT=('SCI', 2) started at: 19:25:13.327 (13/12/2017)
#
#      Found 452 objects.
#
#   #  Source finding for 'u54v0301m_c0m.fits', EXT=('SCI', 3) started at: 19:25:13.63 (13/12/2017)
#
#      Found 186 objects.
#
#   #  Source finding for 'u54v0301m_c0m.fits', EXT=('SCI', 4) started at: 19:25:13.949 (13/12/2017)
#
#      Found 201 objects.
#
# ===  Found a TOTAL of 1315 objects in image 'u54v0301m_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0302r_c0m.fits':
#
#   #  Source finding for 'u54v0302r_c0m.fits', EXT=('SCI', 1) started at: 19:25:14.436 (13/12/2017)
#
#      Found 507 objects.
#
#   #  Source finding for 'u54v0302r_c0m.fits', EXT=('SCI', 2) started at: 19:25:14.836 (13/12/2017)
#
#      Found 198 objects.
#
#   #  Source finding for 'u54v0302r_c0m.fits', EXT=('SCI', 3) started at: 19:25:15.095 (13/12/2017)
#
#      Found 208 objects.
#
#   #  Source finding for 'u54v0302r_c0m.fits', EXT=('SCI', 4) started at: 19:25:15.359 (13/12/2017)
#
#      Found 226 objects.
#
# ===  Found a TOTAL of 1139 objects in image 'u54v0302r_c0m.fits'
#
#
#
#  Catalog trimmed to 1315 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0301m_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0302r_c0m.fits
#
# Matching sources from 'u54v0302r_c0m.fits' with sources from reference image 'u54v0301m_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  9.15471210824 -12.7968030433
#
#     with significance of  291.806228515 and  11.0  matches
#
# Found 23 matches for u54v0302r_c0m.fits...
#
# Computed  rscale  fit for  u54v0302r_c0m.fits :
#
# XSH: 9.37313  YSH: -12.6699    ROT: 359.994    SCALE: 1.00004
#
# XRMS: 0.596069    YRMS: 0.69216
#
# RMS_RA: 5.01211e-06 (deg)   RMS_DEC: 1.12067e-05 (deg)
#
# Final solution based on  23  objects.
#
# wrote XY data to:  u54v0302r_c0m_catalog_fit.match
#
# Writing out shiftfile : 1shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# 9.373126

# %%
# change to a jupyter table
dt=test.to_pandas()
dt.to_pickle('data.pickle')
good_table=pandas.read_pickle('data.pickle')

# %%
# take only unfailed sessions
good_roundhi = good_table[good_table['y_rms'] != 'failed']

# %%
good_roundhi
# Out:
#         shift                file     x_rms     y_rms  threshold  conv_width  \
# 0  1shift.txt  u54v0301m_c0m.fits  0.000000  0.000000          9         2.9
# 1  1shift.txt  u54v0302r_c0m.fits  0.596069  0.692160          9         2.9
#
#    roundlo  roundhi  peakmax
# 0     -1.5      1.0     1000
# 1     -1.5      1.0     1000

# %%
# plot figure for all sub-exp 
plt.figure(figsize = (7,7))
plt.plot(good_roundhi['roundhi'],good_roundhi['x_rms'],'.g')
plt.plot(good_roundhi['roundhi'],good_roundhi['y_rms'],'.b')
plt.title('x,y_rms(roundhi)-g,b')
plt.show()

# %%
# plot figure for choosen sub-exp
plt.figure(figsize = (7,7))
plt.plot(good_round[good_round['file'] == 'u6ea5402m_c0m.fits']['roundhi'],good_round[good_round['file'] == 'u6ea5402m_c0m.fits']['y_rms'],'.b')
plt.plot(good_round[good_round['file'] == 'u6ea5403m_c0m.fits']['roundhi'],good_round[good_round['file'] == 'u6ea5403m_c0m.fits']['y_rms'],'.g')
plt.title('y_rms(roundhi)-two filters')
plt.show()

# %%
#############################################thresh = 9, conv = 2.8 roundnlo = -1.5, rounfhi = 1, peakmax?

# %%
# tweak_run(path, n_up, threshold_ini, threshold_gap, conv_width_ini, conv_width_gap, 
# roundlo_val_ini, roundlo_gap, roundhi_val_ini, roundhi_gap, peakmax_val_ini, peakmax_gap):
test = tweak_run('/Users/natalie/anaconda2/envs/iraf27/iraf/sn/2001ci/2001ci_pre/tweak_814',2,9,0,2.8,0,-1.5,0,1,0,500,0)
# Out:
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 19:37:35.874 (13/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0301m_c0m.fits
#
#     u54v0302r_c0m.fits
#
# ===  Source finding for image 'u54v0301m_c0m.fits':
#
#   #  Source finding for 'u54v0301m_c0m.fits', EXT=('SCI', 1) started at: 19:37:36.19 (13/12/2017)
#
#      Found 441 objects.
#
#   #  Source finding for 'u54v0301m_c0m.fits', EXT=('SCI', 2) started at: 19:37:36.59 (13/12/2017)
#
#      Found 397 objects.
#
#   #  Source finding for 'u54v0301m_c0m.fits', EXT=('SCI', 3) started at: 19:37:36.916 (13/12/2017)
#
#      Found 180 objects.
#
#   #  Source finding for 'u54v0301m_c0m.fits', EXT=('SCI', 4) started at: 19:37:37.227 (13/12/2017)
#
#      Found 181 objects.
#
# ===  Found a TOTAL of 1199 objects in image 'u54v0301m_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0302r_c0m.fits':
#
#   #  Source finding for 'u54v0302r_c0m.fits', EXT=('SCI', 1) started at: 19:37:37.676 (13/12/2017)
#
#      Found 502 objects.
#
#   #  Source finding for 'u54v0302r_c0m.fits', EXT=('SCI', 2) started at: 19:37:38.123 (13/12/2017)
#
#      Found 180 objects.
#
#   #  Source finding for 'u54v0302r_c0m.fits', EXT=('SCI', 3) started at: 19:37:38.365 (13/12/2017)
#
#      Found 192 objects.
#
#   #  Source finding for 'u54v0302r_c0m.fits', EXT=('SCI', 4) started at: 19:37:38.614 (13/12/2017)
#
#      Found 207 objects.
#
# ===  Found a TOTAL of 1081 objects in image 'u54v0302r_c0m.fits'
#
#
#
#  Catalog trimmed to 1199 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0301m_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0302r_c0m.fits
#
# Matching sources from 'u54v0302r_c0m.fits' with sources from reference image 'u54v0301m_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -16.6704281836 -19.4605516404
#
#     with significance of  137.622672551 and  10.0  matches
#
# Found 17 matches for u54v0302r_c0m.fits...
#
# Computed  rscale  fit for  u54v0302r_c0m.fits :
#
# XSH: -16.5458  YSH: -19.4911    ROT: 0.0341723    SCALE: 0.999914
#
# XRMS: 0.361084    YRMS: 0.470072
#
# RMS_RA: 2.52622e-06 (deg)   RMS_DEC: 7.36328e-06 (deg)
#
# Final solution based on  17  objects.
#
# wrote XY data to:  u54v0302r_c0m_catalog_fit.match
#
# Writing out shiftfile : 1shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -16.545819

# %%
# change to a jupyter table
dt=test.to_pandas()
dt.to_pickle('data.pickle')
good_table=pandas.read_pickle('data.pickle')

# %%
# take only unfailed sessions
good_peakmax = good_table[good_table['y_rms'] != 'failed']

# %%
good_peakmax
# Out:
#         shift                file     x_rms     y_rms  threshold  conv_width  \
# 0  1shift.txt  u54v0301m_c0m.fits  0.000000  0.000000          9         2.8
# 1  1shift.txt  u54v0302r_c0m.fits  0.361084  0.470072          9         2.8
#
#    roundlo  roundhi  peakmax
# 0     -1.5        1      500
# 1     -1.5        1      500

# %%
# plot figure for all sub-exp ??????????????????????????????????????????
plt.figure(figsize = (7,7))
plt.plot(good_peakmax['peakmax'],good_peakmax['x_rms'],'.g')
plt.plot(good_peakmax['peakmax'],good_peakmax['y_rms'],'.b')
plt.title('x,y_rms(peakmax)-g,b')
plt.show()

# %%
################################## tweakreg run for good parameters without headers, see figures- 
# thresh = 9, conv = 2.8, roundnlo = -1.5, rounfhi = 1.0, peakmax = 500

# %%
# final parameters to see plots
import os
from drizzlepac import tweakreg
os.chdir('/Users/natalie/anaconda2/envs/iraf27/iraf/sn/2001ci/2001ci_pre/tweak_814')
tweakreg.TweakReg('*c0m.fits', exclusions='WFPC2_exclude.txt', updatehdr=False, shiftfile=True, outshifts='shift_final', residplot='both', see2dplot='Yes', use_sharp_round='Yes', threshold=1, conv_width=3.4, roundlo=-1, roundhi=1, peakmin=2, peakmax=4000)
# Out:
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 08:09:56.154 (14/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u54v0301m_c0m.fits
#
#     u54v0302r_c0m.fits
#
# ===  Source finding for image 'u54v0301m_c0m.fits':
#
#   #  Source finding for 'u54v0301m_c0m.fits', EXT=('SCI', 1) started at: 08:09:56.556 (14/12/2017)
#
#      Found 2927 objects.
#
#   #  Source finding for 'u54v0301m_c0m.fits', EXT=('SCI', 2) started at: 08:09:59.765 (14/12/2017)
#
#      Found 557 objects.
#
#   #  Source finding for 'u54v0301m_c0m.fits', EXT=('SCI', 3) started at: 08:10:00.898 (14/12/2017)
#
#      Found 3483 objects.
#
#   #  Source finding for 'u54v0301m_c0m.fits', EXT=('SCI', 4) started at: 08:10:04.626 (14/12/2017)
#
#      Found 1945 objects.
#
# ===  Found a TOTAL of 8912 objects in image 'u54v0301m_c0m.fits'
#
#
#
# ===  Source finding for image 'u54v0302r_c0m.fits':
#
#   #  Source finding for 'u54v0302r_c0m.fits', EXT=('SCI', 1) started at: 08:10:07.540 (14/12/2017)
#
#      Found 3014 objects.
#
#   #  Source finding for 'u54v0302r_c0m.fits', EXT=('SCI', 2) started at: 08:10:10.634 (14/12/2017)
#
#      Found 1912 objects.
#
#   #  Source finding for 'u54v0302r_c0m.fits', EXT=('SCI', 3) started at: 08:10:13.506 (14/12/2017)
#
#      Found 3156 objects.
#
#   #  Source finding for 'u54v0302r_c0m.fits', EXT=('SCI', 4) started at: 08:10:16.838 (14/12/2017)
#
#      Found 1958 objects.
#
# ===  Found a TOTAL of 10040 objects in image 'u54v0302r_c0m.fits'
#
#
#
#  Catalog trimmed to 8912 objects
#
#
# ====================
# Aligning all input images to WCS defined by u54v0301m_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u54v0302r_c0m.fits
#
# Matching sources from 'u54v0302r_c0m.fits' with sources from reference image 'u54v0301m_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  6.1120484882 -1.85384020121
#
#     with significance of  281.520869564 and  42.0  matches
#
# Found 174 matches for u54v0302r_c0m.fits...
#
# Computed  rscale  fit for  u54v0302r_c0m.fits :
#
# XSH: 6.16243  YSH: -1.84598    ROT: 359.999    SCALE: 1.00001
#
# XRMS: 0.71541    YRMS: 0.767085
#
# RMS_RA: 6.65495e-06 (deg)   RMS_DEC: 1.27301e-05 (deg)
#
# Final solution based on  174  objects.
#
# wrote XY data to:  u54v0302r_c0m_catalog_fit.match
#
# Total # points:  174
#
# # of points after clipping:  174
#
# Total # points:  174
#
# # of points after clipping:  174
#
# Press ENTER for next image,
#       'n' to continue without updating header or
#       'q' to quit immediately...
#
# Writing out shiftfile : shift_final
#
# Trailer file written to:  tweakreg.log

# %%
# final run with hdr update
import os
from drizzlepac import tweakreg
os.chdir('/Users/natalie/anaconda2/envs/iraf27/iraf/sn/2001ci/2001ci_pre/tweak_606')
tweakreg.TweakReg('*c0m.fits', exclusions='WFPC2_exclude.txt', updatehdr=True, shiftfile=True, outshifts='shift_final', residplot='both', see2dplot='Yes', use_sharp_round='Yes', threshold=8, conv_width=4.6, roundlo=-0.5, roundhi=0.8, peakmax=4000)
# Out:
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 13:12:34.64 (13/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u67n2601r_c0m.fits
#
#     u67n2602r_c0m.fits
#
# ===  Source finding for image 'u67n2601r_c0m.fits':
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 1) started at: 13:12:35.125 (13/12/2017)
#
#      Found 184 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 2) started at: 13:12:35.529 (13/12/2017)
#
#      Found 162 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 3) started at: 13:12:35.840 (13/12/2017)
#
#      Found 101 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 4) started at: 13:12:36.134 (13/12/2017)
#
#      Found 108 objects.
#
# ===  Found a TOTAL of 555 objects in image 'u67n2601r_c0m.fits'
#
#
#
# ===  Source finding for image 'u67n2602r_c0m.fits':
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 1) started at: 13:12:36.681 (13/12/2017)
#
#      Found 179 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 2) started at: 13:12:37.033 (13/12/2017)
#
#      Found 290 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 3) started at: 13:12:37.415 (13/12/2017)
#
#      Found 159 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 4) started at: 13:12:37.81 (13/12/2017)
#
#      Found 153 objects.
#
# ===  Found a TOTAL of 781 objects in image 'u67n2602r_c0m.fits'
#
#
#
#  Catalog trimmed to 555 objects
#
#
# ====================
# Aligning all input images to WCS defined by u67n2601r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u67n2602r_c0m.fits
#
# Matching sources from 'u67n2602r_c0m.fits' with sources from reference image 'u67n2601r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.809131369918 -0.718222279009
#
#     with significance of  486.360611139 and  27.0  matches
#
# Found 74 matches for u67n2602r_c0m.fits...
#
# Computed  rscale  fit for  u67n2602r_c0m.fits :
#
# XSH: -0.0232849  YSH: 0.0184867    ROT: 0.000565629    SCALE: 0.999969
#
# XRMS: 0.135195    YRMS: 0.159836
#
# RMS_RA: 3.31349e-06 (deg)   RMS_DEC: 1.87682e-06 (deg)
#
# Final solution based on  70  objects.
#
# wrote XY data to:  u67n2602r_c0m_catalog_fit.match
#
# Total # points:  70
#
# # of points after clipping:  70
#
# Total # points:  70
#
# # of points after clipping:  70
#
# Press ENTER for next image,
#       'n' to continue without updating header or
#       'q' to quit immediately...
#
#
# ....Updating header for u67n2602r_c0m.fits...
#
#
# Processing u67n2602r_c0m.fits['SCI',1]
#
# Updating header for u67n2602r_c0m.fits[1]
#
# WCSNAME  :  TWEAK
#
#
# Processing u67n2602r_c0m.fits['SCI',2]
#
# Updating header for u67n2602r_c0m.fits[2]
#
# WCSNAME  :  TWEAK
#
#
# Processing u67n2602r_c0m.fits['SCI',3]
#
# Updating header for u67n2602r_c0m.fits[3]
#
# WCSNAME  :  TWEAK
#
#
# Processing u67n2602r_c0m.fits['SCI',4]
#
# Updating header for u67n2602r_c0m.fits[4]
#
# WCSNAME  :  TWEAK
#
# Writing out shiftfile : shift_final
#
# Trailer file written to:  tweakreg.log

# %%
# tweaked checks
from astropy.io import fits
tw=fits.open('/Users/natalie/anaconda2/envs/iraf27/iraf/sn/2001ci/2001ci_pre/tweak_547/u54v0304r_c0m.fits')

# %%
tw[1].header['WCSNAME']
# Out:
# 'TWEAK'

# %%
tw[1].header
