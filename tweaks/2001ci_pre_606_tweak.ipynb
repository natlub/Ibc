# %%
# tweakreg defaults: 
# threshold = 4
# conv_width = 3.5
# use round = No --> roundlo = -1, roundhi = 1
# peakmin = //
# peakmax = //

# %%
import sys
sys.path.append("/Users/natalie/PycharmProjects/code/")
    
from Drizzle_func import *
import pandas
import matplotlib.pyplot as plt
# Out:
# The following task in the stsci.skypac package can be run with TEAL:
#                                     skymatch
# The following tasks in the drizzlepac package can be run with TEAL:
#     astrodrizzle       imagefindpars           mapreg              photeq
#      pixreplace           pixtopix            pixtosky        refimagefindpars
#      resetbits          runastrodriz          skytopix           tweakback
#       tweakreg           updatenpol

# %%
# tweak_run(path, n_up, threshold_ini, threshold_gap, conv_width_ini, conv_width_gap, 
# roundlo_val_ini, roundlo_gap, roundhi_val_ini, roundhi_gap, peakmax_val_ini, peakmax_gap):
test = tweak_run('/Users/natalie/anaconda2/envs/iraf27/iraf/sn/2001ci/2001ci_pre/tweak_606',10,1,1,3.5,0,-1,0,1,0,1000,0)
# Out:
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 11:02:35.986 (13/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u67n2601r_c0m.fits
#
#     u67n2602r_c0m.fits
#
# ===  Source finding for image 'u67n2601r_c0m.fits':
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 1) started at: 11:02:36.432 (13/12/2017)
#
#      Found 3723 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 2) started at: 11:02:40.12 (13/12/2017)
#
#      Found 3751 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 3) started at: 11:02:43.301 (13/12/2017)
#
#      Found 3912 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 4) started at: 11:02:46.615 (13/12/2017)
#
#      Found 3845 objects.
#
# ===  Found a TOTAL of 15231 objects in image 'u67n2601r_c0m.fits'
#
#
#
# ===  Source finding for image 'u67n2602r_c0m.fits':
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 1) started at: 11:02:50.480 (13/12/2017)
#
#      Found 4076 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 2) started at: 11:02:52.914 (13/12/2017)
#
#      Found 3791 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 3) started at: 11:02:55.512 (13/12/2017)
#
#      Found 4158 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 4) started at: 11:02:57.919 (13/12/2017)
#
#      Found 3969 objects.
#
# ===  Found a TOTAL of 15994 objects in image 'u67n2602r_c0m.fits'
#
#
#
#  Catalog trimmed to 15231 objects
#
#
# ====================
# Aligning all input images to WCS defined by u67n2601r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u67n2602r_c0m.fits
#
# Matching sources from 'u67n2602r_c0m.fits' with sources from reference image 'u67n2601r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.874677340574 -0.879949035627
#
#     with significance of  1077.84215241 and  122.0  matches
#
# Found 501 matches for u67n2602r_c0m.fits...
#
# Computed  rscale  fit for  u67n2602r_c0m.fits :
#
# XSH: -0.558114  YSH: -0.604569    ROT: 0.000606805    SCALE: 1.00001
#
# XRMS: 0.699315    YRMS: 0.75097
#
# RMS_RA: 1.54449e-05 (deg)   RMS_DEC: 9.62603e-06 (deg)
#
# Final solution based on  501  objects.
#
# wrote XY data to:  u67n2602r_c0m_catalog_fit.match
#
# Writing out shiftfile : 1shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.558114
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 11:03:01.500 (13/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u67n2601r_c0m.fits
#
#     u67n2602r_c0m.fits
#
# ===  Source finding for image 'u67n2601r_c0m.fits':
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 1) started at: 11:03:01.794 (13/12/2017)
#
#      Found 2839 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 2) started at: 11:03:02.954 (13/12/2017)
#
#      Found 2595 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 3) started at: 11:03:04.12 (13/12/2017)
#
#      Found 1775 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 4) started at: 11:03:04.790 (13/12/2017)
#
#      Found 2505 objects.
#
# ===  Found a TOTAL of 9714 objects in image 'u67n2601r_c0m.fits'
#
#
#
# ===  Source finding for image 'u67n2602r_c0m.fits':
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 1) started at: 11:03:06.076 (13/12/2017)
#
#      Found 1687 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 2) started at: 11:03:06.770 (13/12/2017)
#
#      Found 2640 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 3) started at: 11:03:07.94 (13/12/2017)
#
#      Found 844 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 4) started at: 11:03:08.330 (13/12/2017)
#
#      Found 1060 objects.
#
# ===  Found a TOTAL of 6231 objects in image 'u67n2602r_c0m.fits'
#
#
#
#  Catalog trimmed to 9714 objects
#
#
# ====================
# Aligning all input images to WCS defined by u67n2601r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u67n2602r_c0m.fits
#
# Matching sources from 'u67n2602r_c0m.fits' with sources from reference image 'u67n2601r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.810683097878 -0.720705043745
#
#     with significance of  1294.33856013 and  141.0  matches
#
# Found 532 matches for u67n2602r_c0m.fits...
#
# Computed  rscale  fit for  u67n2602r_c0m.fits :
#
# XSH: -0.234469  YSH: -0.158439    ROT: 0.00117275    SCALE: 0.99996
#
# XRMS: 0.491432    YRMS: 0.473178
#
# RMS_RA: 9.63413e-06 (deg)   RMS_DEC: 6.70549e-06 (deg)
#
# Final solution based on  497  objects.
#
# wrote XY data to:  u67n2602r_c0m_catalog_fit.match
#
# Writing out shiftfile : 2shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.234469
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 11:03:09.557 (13/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u67n2601r_c0m.fits
#
#     u67n2602r_c0m.fits
#
# ===  Source finding for image 'u67n2601r_c0m.fits':
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 1) started at: 11:03:09.816 (13/12/2017)
#
#      Found 917 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 2) started at: 11:03:10.31 (13/12/2017)
#
#      Found 1284 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 3) started at: 11:03:10.891 (13/12/2017)
#
#      Found 328 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 4) started at: 11:03:11.187 (13/12/2017)
#
#      Found 567 objects.
#
# ===  Found a TOTAL of 3096 objects in image 'u67n2601r_c0m.fits'
#
#
#
# ===  Source finding for image 'u67n2602r_c0m.fits':
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 1) started at: 11:03:11.768 (13/12/2017)
#
#      Found 912 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 2) started at: 11:03:12.279 (13/12/2017)
#
#      Found 1829 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 3) started at: 11:03:12.980 (13/12/2017)
#
#      Found 478 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 4) started at: 11:03:13.293 (13/12/2017)
#
#      Found 556 objects.
#
# ===  Found a TOTAL of 3775 objects in image 'u67n2602r_c0m.fits'
#
#
#
#  Catalog trimmed to 3096 objects
#
#
# ====================
# Aligning all input images to WCS defined by u67n2601r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u67n2602r_c0m.fits
#
# Matching sources from 'u67n2602r_c0m.fits' with sources from reference image 'u67n2601r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.675465948582 -0.579575537623
#
#     with significance of  1217.92157383 and  153.0  matches
#
# Found 488 matches for u67n2602r_c0m.fits...
#
# Computed  rscale  fit for  u67n2602r_c0m.fits :
#
# XSH: -0.131014  YSH: -0.0217287    ROT: 359.999    SCALE: 0.999938
#
# XRMS: 0.405843    YRMS: 0.391577
#
# RMS_RA: 7.97432e-06 (deg)   RMS_DEC: 5.53852e-06 (deg)
#
# Final solution based on  467  objects.
#
# wrote XY data to:  u67n2602r_c0m_catalog_fit.match
#
# Writing out shiftfile : 3shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.131014
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 11:03:14.185 (13/12/2017)
#
# Version Information
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u67n2601r_c0m.fits
#
#     u67n2602r_c0m.fits
#
# ===  Source finding for image 'u67n2601r_c0m.fits':
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 1) started at: 11:03:14.443 (13/12/2017)
#
#      Found 557 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 2) started at: 11:03:14.879 (13/12/2017)
#
#      Found 769 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 3) started at: 11:03:15.223 (13/12/2017)
#
#      Found 251 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 4) started at: 11:03:15.474 (13/12/2017)
#
#      Found 281 objects.
#
# ===  Found a TOTAL of 1858 objects in image 'u67n2601r_c0m.fits'
#
#
#
# ===  Source finding for image 'u67n2602r_c0m.fits':
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 1) started at: 11:03:16.044 (13/12/2017)
#
#      Found 784 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 2) started at: 11:03:16.491 (13/12/2017)
#
#      Found 1264 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 3) started at: 11:03:16.955 (13/12/2017)
#
#      Found 439 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 4) started at: 11:03:17.290 (13/12/2017)
#
#      Found 462 objects.
#
# ===  Found a TOTAL of 2949 objects in image 'u67n2602r_c0m.fits'
#
#
#
#  Catalog trimmed to 1858 objects
#
#
# ====================
# Aligning all input images to WCS defined by u67n2601r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u67n2602r_c0m.fits
#
# Matching sources from 'u67n2602r_c0m.fits' with sources from reference image 'u67n2601r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.679912576479 -0.632206154461
#
#     with significance of  1072.41545231 and  139.0  matches
#
# Found 373 matches for u67n2602r_c0m.fits...
#
# Computed  rscale  fit for  u67n2602r_c0m.fits :
#
# XSH: -0.0666845  YSH: -0.0115838    ROT: 360    SCALE: 0.999952
#
# XRMS: 0.286051    YRMS: 0.29743
#
# RMS_RA: 6.0997e-06 (deg)   RMS_DEC: 3.92692e-06 (deg)
#
# Final solution based on  348  objects.
#
# wrote XY data to:  u67n2602r_c0m_catalog_fit.match
#
# Writing out shiftfile : 4shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.066684
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 11:03:18.143 (13/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u67n2601r_c0m.fits
#
#     u67n2602r_c0m.fits
#
# ===  Source finding for image 'u67n2601r_c0m.fits':
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 1) started at: 11:03:18.442 (13/12/2017)
#
#      Found 530 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 2) started at: 11:03:18.848 (13/12/2017)
#
#      Found 531 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 3) started at: 11:03:19.139 (13/12/2017)
#
#      Found 232 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 4) started at: 11:03:19.404 (13/12/2017)
#
#      Found 253 objects.
#
# ===  Found a TOTAL of 1546 objects in image 'u67n2601r_c0m.fits'
#
#
#
# ===  Source finding for image 'u67n2602r_c0m.fits':
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 1) started at: 11:03:19.902 (13/12/2017)
#
#      Found 716 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 2) started at: 11:03:20.334 (13/12/2017)
#
#      Found 984 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 3) started at: 11:03:20.739 (13/12/2017)
#
#      Found 412 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 4) started at: 11:03:21.077 (13/12/2017)
#
#      Found 454 objects.
#
# ===  Found a TOTAL of 2566 objects in image 'u67n2602r_c0m.fits'
#
#
#
#  Catalog trimmed to 1546 objects
#
#
# ====================
# Aligning all input images to WCS defined by u67n2601r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u67n2602r_c0m.fits
#
# Matching sources from 'u67n2602r_c0m.fits' with sources from reference image 'u67n2601r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.785126890949 -0.63732088633
#
#     with significance of  938.753524847 and  107.0  matches
#
# Found 286 matches for u67n2602r_c0m.fits...
#
# Computed  rscale  fit for  u67n2602r_c0m.fits :
#
# XSH: -0.0795927  YSH: 0.00908292    ROT: 0.000400733    SCALE: 0.999945
#
# XRMS: 0.249105    YRMS: 0.247092
#
# RMS_RA: 5.04536e-06 (deg)   RMS_DEC: 3.40681e-06 (deg)
#
# Final solution based on  262  objects.
#
# wrote XY data to:  u67n2602r_c0m_catalog_fit.match
#
# Writing out shiftfile : 5shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.079593
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 11:03:21.8 (13/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u67n2601r_c0m.fits
#
#     u67n2602r_c0m.fits
#
# ===  Source finding for image 'u67n2601r_c0m.fits':
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 1) started at: 11:03:22.131 (13/12/2017)
#
#      Found 493 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 2) started at: 11:03:22.53 (13/12/2017)
#
#      Found 427 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 3) started at: 11:03:22.809 (13/12/2017)
#
#      Found 243 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 4) started at: 11:03:23.051 (13/12/2017)
#
#      Found 250 objects.
#
# ===  Found a TOTAL of 1413 objects in image 'u67n2601r_c0m.fits'
#
#
#
# ===  Source finding for image 'u67n2602r_c0m.fits':
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 1) started at: 11:03:23.595 (13/12/2017)
#
#      Found 666 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 2) started at: 11:03:23.983 (13/12/2017)
#
#      Found 844 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 3) started at: 11:03:24.337 (13/12/2017)
#
#      Found 401 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 4) started at: 11:03:24.630 (13/12/2017)
#
#      Found 452 objects.
#
# ===  Found a TOTAL of 2363 objects in image 'u67n2602r_c0m.fits'
#
#
#
#  Catalog trimmed to 1413 objects
#
#
# ====================
# Aligning all input images to WCS defined by u67n2601r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u67n2602r_c0m.fits
#
# Matching sources from 'u67n2602r_c0m.fits' with sources from reference image 'u67n2601r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.791745717144 -0.663059390066
#
#     with significance of  853.599908504 and  89.0  matches
#
# Found 229 matches for u67n2602r_c0m.fits...
#
# Computed  rscale  fit for  u67n2602r_c0m.fits :
#
# XSH: -0.0674879  YSH: 0.00629956    ROT: 0.000304444    SCALE: 0.999959
#
# XRMS: 0.220811    YRMS: 0.231314
#
# RMS_RA: 4.74697e-06 (deg)   RMS_DEC: 3.03317e-06 (deg)
#
# Final solution based on  213  objects.
#
# wrote XY data to:  u67n2602r_c0m_catalog_fit.match
#
# Writing out shiftfile : 6shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.067488
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 11:03:25.419 (13/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u67n2601r_c0m.fits
#
#     u67n2602r_c0m.fits
#
# ===  Source finding for image 'u67n2601r_c0m.fits':
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 1) started at: 11:03:25.675 (13/12/2017)
#
#      Found 482 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 2) started at: 11:03:26.13 (13/12/2017)
#
#      Found 353 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 3) started at: 11:03:26.399 (13/12/2017)
#
#      Found 250 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 4) started at: 11:03:26.650 (13/12/2017)
#
#      Found 239 objects.
#
# ===  Found a TOTAL of 1324 objects in image 'u67n2601r_c0m.fits'
#
#
#
# ===  Source finding for image 'u67n2602r_c0m.fits':
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 1) started at: 11:03:27.140 (13/12/2017)
#
#      Found 634 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 2) started at: 11:03:27.502 (13/12/2017)
#
#      Found 750 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 3) started at: 11:03:27.838 (13/12/2017)
#
#      Found 397 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 4) started at: 11:03:28.161 (13/12/2017)
#
#      Found 441 objects.
#
# ===  Found a TOTAL of 2222 objects in image 'u67n2602r_c0m.fits'
#
#
#
#  Catalog trimmed to 1324 objects
#
#
# ====================
# Aligning all input images to WCS defined by u67n2601r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u67n2602r_c0m.fits
#
# Matching sources from 'u67n2602r_c0m.fits' with sources from reference image 'u67n2601r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.750682108622 -0.707977482288
#
#     with significance of  731.806118392 and  65.0  matches
#
# Found 182 matches for u67n2602r_c0m.fits...
#
# Computed  rscale  fit for  u67n2602r_c0m.fits :
#
# XSH: -0.064992  YSH: 0.0053585    ROT: 0.000813872    SCALE: 0.999965
#
# XRMS: 0.189695    YRMS: 0.218955
#
# RMS_RA: 4.53042e-06 (deg)   RMS_DEC: 2.62765e-06 (deg)
#
# Final solution based on  166  objects.
#
# wrote XY data to:  u67n2602r_c0m_catalog_fit.match
#
# Writing out shiftfile : 7shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.064992
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 11:03:29.00 (13/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u67n2601r_c0m.fits
#
#     u67n2602r_c0m.fits
#
# ===  Source finding for image 'u67n2601r_c0m.fits':
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 1) started at: 11:03:29.255 (13/12/2017)
#
#      Found 452 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 2) started at: 11:03:29.640 (13/12/2017)
#
#      Found 332 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 3) started at: 11:03:29.893 (13/12/2017)
#
#      Found 247 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 4) started at: 11:03:30.145 (13/12/2017)
#
#      Found 228 objects.
#
# ===  Found a TOTAL of 1259 objects in image 'u67n2601r_c0m.fits'
#
#
#
# ===  Source finding for image 'u67n2602r_c0m.fits':
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 1) started at: 11:03:30.624 (13/12/2017)
#
#      Found 608 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 2) started at: 11:03:30.989 (13/12/2017)
#
#      Found 676 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 3) started at: 11:03:31.325 (13/12/2017)
#
#      Found 387 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 4) started at: 11:03:31.678 (13/12/2017)
#
#      Found 428 objects.
#
# ===  Found a TOTAL of 2099 objects in image 'u67n2602r_c0m.fits'
#
#
#
#  Catalog trimmed to 1259 objects
#
#
# ====================
# Aligning all input images to WCS defined by u67n2601r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u67n2602r_c0m.fits
#
# Matching sources from 'u67n2602r_c0m.fits' with sources from reference image 'u67n2601r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.813979854767 -0.662868743656
#
#     with significance of  648.608642733 and  48.0  matches
#
# Found 143 matches for u67n2602r_c0m.fits...
#
# Computed  rscale  fit for  u67n2602r_c0m.fits :
#
# XSH: -0.0251017  YSH: 0.0134427    ROT: 0.00112318    SCALE: 0.999981
#
# XRMS: 0.181679    YRMS: 0.201271
#
# RMS_RA: 4.1505e-06 (deg)   RMS_DEC: 2.50749e-06 (deg)
#
# Final solution based on  132  objects.
#
# wrote XY data to:  u67n2602r_c0m_catalog_fit.match
#
# Writing out shiftfile : 8shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.025102
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 11:03:32.509 (13/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u67n2601r_c0m.fits
#
#     u67n2602r_c0m.fits
#
# ===  Source finding for image 'u67n2601r_c0m.fits':
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 1) started at: 11:03:32.764 (13/12/2017)
#
#      Found 458 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 2) started at: 11:03:33.140 (13/12/2017)
#
#      Found 305 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 3) started at: 11:03:33.396 (13/12/2017)
#
#      Found 255 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 4) started at: 11:03:33.655 (13/12/2017)
#
#      Found 234 objects.
#
# ===  Found a TOTAL of 1252 objects in image 'u67n2601r_c0m.fits'
#
#
#
# ===  Source finding for image 'u67n2602r_c0m.fits':
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 1) started at: 11:03:34.163 (13/12/2017)
#
#      Found 558 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 2) started at: 11:03:34.470 (13/12/2017)
#
#      Found 630 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 3) started at: 11:03:34.850 (13/12/2017)
#
#      Found 397 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 4) started at: 11:03:35.261 (13/12/2017)
#
#      Found 422 objects.
#
# ===  Found a TOTAL of 2007 objects in image 'u67n2602r_c0m.fits'
#
#
#
#  Catalog trimmed to 1252 objects
#
#
# ====================
# Aligning all input images to WCS defined by u67n2601r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u67n2602r_c0m.fits
#
# Matching sources from 'u67n2602r_c0m.fits' with sources from reference image 'u67n2601r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.666528874375 -0.650486093626
#
#     with significance of  570.855231317 and  37.0  matches
#
# Found 122 matches for u67n2602r_c0m.fits...
#
# Computed  rscale  fit for  u67n2602r_c0m.fits :
#
# XSH: -0.012872  YSH: 0.00617001    ROT: 0.00170791    SCALE: 0.999971
#
# XRMS: 0.186909    YRMS: 0.215371
#
# RMS_RA: 4.45566e-06 (deg)   RMS_DEC: 2.58865e-06 (deg)
#
# Final solution based on  111  objects.
#
# wrote XY data to:  u67n2602r_c0m_catalog_fit.match
#
# Writing out shiftfile : 9shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.012872

# %%
# change to a jupyter table
dt=test.to_pandas()
dt.to_pickle('data.pickle')
good_table=pandas.read_pickle('data.pickle')

# %%
# all table
good_table
# Out:
#          shift                file     x_rms     y_rms  threshold  conv_width  \
# 0   1shift.txt  u67n2601r_c0m.fits  0.000000  0.000000          1         3.5
# 1   1shift.txt  u67n2602r_c0m.fits  0.699315  0.750970          1         3.5
# 2   2shift.txt  u67n2601r_c0m.fits  0.000000  0.000000          2         3.5
# 3   2shift.txt  u67n2602r_c0m.fits  0.491432  0.473178          2         3.5
# 4   3shift.txt  u67n2601r_c0m.fits  0.000000  0.000000          3         3.5
# 5   3shift.txt  u67n2602r_c0m.fits  0.405843  0.391577          3         3.5
# 6   4shift.txt  u67n2601r_c0m.fits  0.000000  0.000000          4         3.5
# 7   4shift.txt  u67n2602r_c0m.fits  0.286051  0.297430          4         3.5
# 8   5shift.txt  u67n2601r_c0m.fits  0.000000  0.000000          5         3.5
# 9   5shift.txt  u67n2602r_c0m.fits  0.249105  0.247092          5         3.5
# 10  6shift.txt  u67n2601r_c0m.fits  0.000000  0.000000          6         3.5
# 11  6shift.txt  u67n2602r_c0m.fits  0.220811  0.231314          6         3.5
# 12  7shift.txt  u67n2601r_c0m.fits  0.000000  0.000000          7         3.5
# 13  7shift.txt  u67n2602r_c0m.fits  0.189695  0.218955          7         3.5
# 14  8shift.txt  u67n2601r_c0m.fits  0.000000  0.000000          8         3.5
# 15  8shift.txt  u67n2602r_c0m.fits  0.181679  0.201271          8         3.5
# 16  9shift.txt  u67n2601r_c0m.fits  0.000000  0.000000          9         3.5
# 17  9shift.txt  u67n2602r_c0m.fits  0.186909  0.215371          9         3.5
#
#     roundlo  roundhi  peakmax
# 0        -1        1     1000
# 1        -1        1     1000
# 2        -1        1     1000
# 3        -1        1     1000
# 4        -1        1     1000
# 5        -1        1     1000
# 6        -1        1     1000
# 7        -1        1     1000
# 8        -1        1     1000
# 9        -1        1     1000
# 10       -1        1     1000
# 11       -1        1     1000
# 12       -1        1     1000
# 13       -1        1     1000
# 14       -1        1     1000
# 15       -1        1     1000
# 16       -1        1     1000
# 17       -1        1     1000

# %%
# filter by column
good_table['y_rms']
# Out:
# 0     0.000000
# 1     0.750970
# 2     0.000000
# 3     0.473178
# 4     0.000000
# 5     0.391577
# 6     0.000000
# 7     0.297430
# 8     0.000000
# 9     0.247092
# 10    0.000000
# 11    0.231314
# 12    0.000000
# 13    0.218955
# 14    0.000000
# 15    0.201271
# 16    0.000000
# 17    0.215371
# Name: y_rms, dtype: object

# %%
# filter by value in column
# good_table[good_table['y_rms']=='failed']
# Out:
# Empty DataFrame
# Columns: [shift, file, x_rms, y_rms, threshold, conv_width, roundlo, roundhi, peakmax]
# Index: []

# %%
# see unique in column
# good_table['shift'].unique()
# Out:
# array(['1shift.txt', '2shift.txt', '3shift.txt', '4shift.txt',
#        '5shift.txt', '6shift.txt', '7shift.txt', '8shift.txt', '9shift.txt'], dtype=object)

# %%
# good_table.shape
# Out:
# (18, 9)

# %%
# take only unfailed sessions
good = good_table[good_table['y_rms'] != 'failed']

# %%
# ????????????????????????????????????????????????????
plt.figure(figsize = (7,7))
plt.plot(good['threshold'],good['x_rms'],'.g')
plt.plot(good['threshold'],good['y_rms'],'.b')
plt.title('x,y_rms(threshold)-g,b')
plt.show()

# %%
# plot figure for choosen sub-exp
plt.figure(figsize = (7,7))
plt.plot(good[good['file'] == 'u29r1r01t_c0m.fits']['threshold'],good[good['file'] == 'u29r1r01t_c0m.fits']['y_rms'],'.b')
plt.plot(good[good['file'] == 'u29r1r02t_c0m.fits']['threshold'],good[good['file'] == 'u29r1r02t_c0m.fits']['y_rms'],'.g')
plt.title('y_rms(threshold)-two filters')
plt.show()

# %%
# find min y_rms and min x_rms
min_x = good[good['x_rms'].values.astype(float) != 0.0]['x_rms'].min()
min_y = good[good['y_rms'].values.astype(float) != 0.0]['y_rms'].min()
print(min_x)
print(min_y)
# Out:
# 0.206961
# 0.186928

# %%
# sort all values =! 0 and take lowest 5 in y_rms
good[good['x_rms'].values.astype(float) != 0.0].sort_values('x_rms',ascending=True)[:5]
# Out:
#          shift                file     x_rms     y_rms  threshold  conv_width
# 21  6shift.txt  u6ea5402m_c0m.fits  0.056897  0.037645         51           3
# 17  5shift.txt  u6ea5402m_c0m.fits  0.069021  0.038714         41           3
# 9   3shift.txt  u6ea5402m_c0m.fits  0.074321  0.078460         21           3
# 5   2shift.txt  u6ea5402m_c0m.fits  0.088635  0.088857         11           3
# 13  4shift.txt  u6ea5402m_c0m.fits  0.152657  0.101558         31           3

# %%
# sort all values =! 0 and take lowest 5 in y_rms BY FILTER??????????????????????
good['file' == 'u29r1r02t_c0m.fits'][['y_rms'].values.astype(float) != 0.0]].sort_values('y_rms',ascending=True)[:5]
#plt.plot(good[good['file'] == 'u6ea5402m_c0m.fits']['threshold'],good[good['file'] == 'u6ea5402m_c0m.fits']['y_rms'],'.b')
# Out:
#   File "<ipython-input-14-aaeb809a2179>", line 2
#     good['file' == 'u29r1r02t_c0m.fits'][['y_rms'].values.astype(float) != 0.0]].sort_values('y_rms',ascending=True)[:5]
#                                                                                ^
# SyntaxError: invalid syntax

# %%
############################################################ thresh=8, conv_width?

# %%
# tweak_run(path, n_up, threshold_ini, threshold_gap, conv_width_ini, conv_width_gap, 
# roundlo_val_ini, roundlo_gap, roundhi_val_ini, roundhi_gap, peakmax_val_ini, peakmax_gap):
test = tweak_run('/Users/natalie/anaconda2/envs/iraf27/iraf/sn/2001ci/2001ci_pre/tweak_606',10,8,0,4.4,0.1,-1,0,1,0,1000,0)
# Out:
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 13:01:39.099 (13/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u67n2601r_c0m.fits
#
#     u67n2602r_c0m.fits
#
# ===  Source finding for image 'u67n2601r_c0m.fits':
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 1) started at: 13:01:39.496 (13/12/2017)
#
#      Found 379 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 2) started at: 13:01:39.86 (13/12/2017)
#
#      Found 326 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 3) started at: 13:01:40.171 (13/12/2017)
#
#      Found 202 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 4) started at: 13:01:40.468 (13/12/2017)
#
#      Found 208 objects.
#
# ===  Found a TOTAL of 1115 objects in image 'u67n2601r_c0m.fits'
#
#
#
# ===  Source finding for image 'u67n2602r_c0m.fits':
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 1) started at: 13:01:40.977 (13/12/2017)
#
#      Found 458 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 2) started at: 13:01:41.339 (13/12/2017)
#
#      Found 577 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 3) started at: 13:01:41.761 (13/12/2017)
#
#      Found 314 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 4) started at: 13:01:42.133 (13/12/2017)
#
#      Found 315 objects.
#
# ===  Found a TOTAL of 1664 objects in image 'u67n2602r_c0m.fits'
#
#
#
#  Catalog trimmed to 1115 objects
#
#
# ====================
# Aligning all input images to WCS defined by u67n2601r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u67n2602r_c0m.fits
#
# Matching sources from 'u67n2602r_c0m.fits' with sources from reference image 'u67n2601r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.844766693107 -0.651633645897
#
#     with significance of  660.436640077 and  50.0  matches
#
# Found 144 matches for u67n2602r_c0m.fits...
#
# Computed  rscale  fit for  u67n2602r_c0m.fits :
#
# XSH: -0.0311717  YSH: 0.00926492    ROT: 0.000671027    SCALE: 0.999966
#
# XRMS: 0.163575    YRMS: 0.192415
#
# RMS_RA: 3.98729e-06 (deg)   RMS_DEC: 2.26975e-06 (deg)
#
# Final solution based on  125  objects.
#
# wrote XY data to:  u67n2602r_c0m_catalog_fit.match
#
# Writing out shiftfile : 1shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.031172
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 13:01:43.194 (13/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u67n2601r_c0m.fits
#
#     u67n2602r_c0m.fits
#
# ===  Source finding for image 'u67n2601r_c0m.fits':
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 1) started at: 13:01:43.437 (13/12/2017)
#
#      Found 307 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 2) started at: 13:01:43.732 (13/12/2017)
#
#      Found 231 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 3) started at: 13:01:44.042 (13/12/2017)
#
#      Found 147 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 4) started at: 13:01:44.345 (13/12/2017)
#
#      Found 171 objects.
#
# ===  Found a TOTAL of 856 objects in image 'u67n2601r_c0m.fits'
#
#
#
# ===  Source finding for image 'u67n2602r_c0m.fits':
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 1) started at: 13:01:44.906 (13/12/2017)
#
#      Found 223 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 2) started at: 13:01:45.22 (13/12/2017)
#
#      Found 383 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 3) started at: 13:01:45.634 (13/12/2017)
#
#      Found 240 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 4) started at: 13:01:46.024 (13/12/2017)
#
#      Found 204 objects.
#
# ===  Found a TOTAL of 1050 objects in image 'u67n2602r_c0m.fits'
#
#
#
#  Catalog trimmed to 856 objects
#
#
# ====================
# Aligning all input images to WCS defined by u67n2601r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u67n2602r_c0m.fits
#
# Matching sources from 'u67n2602r_c0m.fits' with sources from reference image 'u67n2601r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.781542043822 -0.65467637218
#
#     with significance of  499.555552466 and  28.0  matches
#
# Found 79 matches for u67n2602r_c0m.fits...
#
# Computed  rscale  fit for  u67n2602r_c0m.fits :
#
# XSH: -0.0255153  YSH: 0.0180429    ROT: 0.000514495    SCALE: 0.999979
#
# XRMS: 0.149373    YRMS: 0.180013
#
# RMS_RA: 3.73732e-06 (deg)   RMS_DEC: 2.07733e-06 (deg)
#
# Final solution based on  71  objects.
#
# wrote XY data to:  u67n2602r_c0m_catalog_fit.match
#
# Writing out shiftfile : 2shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.025515
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 13:01:46.836 (13/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u67n2601r_c0m.fits
#
#     u67n2602r_c0m.fits
#
# ===  Source finding for image 'u67n2601r_c0m.fits':
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 1) started at: 13:01:47.081 (13/12/2017)
#
#      Found 312 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 2) started at: 13:01:47.398 (13/12/2017)
#
#      Found 235 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 3) started at: 13:01:47.66 (13/12/2017)
#
#      Found 148 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 4) started at: 13:01:47.98 (13/12/2017)
#
#      Found 170 objects.
#
# ===  Found a TOTAL of 865 objects in image 'u67n2601r_c0m.fits'
#
#
#
# ===  Source finding for image 'u67n2602r_c0m.fits':
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 1) started at: 13:01:48.4 (13/12/2017)
#
#      Found 238 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 2) started at: 13:01:48.726 (13/12/2017)
#
#      Found 396 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 3) started at: 13:01:49.105 (13/12/2017)
#
#      Found 245 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 4) started at: 13:01:49.46 (13/12/2017)
#
#      Found 220 objects.
#
# ===  Found a TOTAL of 1099 objects in image 'u67n2602r_c0m.fits'
#
#
#
#  Catalog trimmed to 865 objects
#
#
# ====================
# Aligning all input images to WCS defined by u67n2601r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u67n2602r_c0m.fits
#
# Matching sources from 'u67n2602r_c0m.fits' with sources from reference image 'u67n2601r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.817789378576 -0.688537677896
#
#     with significance of  526.286738166 and  29.0  matches
#
# Found 85 matches for u67n2602r_c0m.fits...
#
# Computed  rscale  fit for  u67n2602r_c0m.fits :
#
# XSH: -0.034242  YSH: 0.0182199    ROT: 0.000415048    SCALE: 0.999975
#
# XRMS: 0.151034    YRMS: 0.171138
#
# RMS_RA: 3.53573e-06 (deg)   RMS_DEC: 2.08866e-06 (deg)
#
# Final solution based on  76  objects.
#
# wrote XY data to:  u67n2602r_c0m_catalog_fit.match
#
# Writing out shiftfile : 3shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.034242
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 13:01:50.249 (13/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u67n2601r_c0m.fits
#
#     u67n2602r_c0m.fits
#
# ===  Source finding for image 'u67n2601r_c0m.fits':
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 1) started at: 13:01:50.482 (13/12/2017)
#
#      Found 313 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 2) started at: 13:01:50.787 (13/12/2017)
#
#      Found 241 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 3) started at: 13:01:51.059 (13/12/2017)
#
#      Found 152 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 4) started at: 13:01:51.334 (13/12/2017)
#
#      Found 174 objects.
#
# ===  Found a TOTAL of 880 objects in image 'u67n2601r_c0m.fits'
#
#
#
# ===  Source finding for image 'u67n2602r_c0m.fits':
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 1) started at: 13:01:51.887 (13/12/2017)
#
#      Found 248 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 2) started at: 13:01:52.144 (13/12/2017)
#
#      Found 405 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 3) started at: 13:01:52.483 (13/12/2017)
#
#      Found 253 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 4) started at: 13:01:52.811 (13/12/2017)
#
#      Found 235 objects.
#
# ===  Found a TOTAL of 1141 objects in image 'u67n2602r_c0m.fits'
#
#
#
#  Catalog trimmed to 880 objects
#
#
# ====================
# Aligning all input images to WCS defined by u67n2601r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u67n2602r_c0m.fits
#
# Matching sources from 'u67n2602r_c0m.fits' with sources from reference image 'u67n2601r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.778828339615 -0.551555612343
#
#     with significance of  554.051411574 and  31.0  matches
#
# Found 95 matches for u67n2602r_c0m.fits...
#
# Computed  rscale  fit for  u67n2602r_c0m.fits :
#
# XSH: -0.0236059  YSH: 0.0483765    ROT: 0.000684385    SCALE: 0.999986
#
# XRMS: 0.182835    YRMS: 0.20306
#
# RMS_RA: 4.18829e-06 (deg)   RMS_DEC: 2.52399e-06 (deg)
#
# Final solution based on  83  objects.
#
# wrote XY data to:  u67n2602r_c0m_catalog_fit.match
#
# Writing out shiftfile : 4shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.023606
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 13:01:53.599 (13/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u67n2601r_c0m.fits
#
#     u67n2602r_c0m.fits
#
# ===  Source finding for image 'u67n2601r_c0m.fits':
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 1) started at: 13:01:53.851 (13/12/2017)
#
#      Found 163 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 2) started at: 13:01:54.122 (13/12/2017)
#
#      Found 133 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 3) started at: 13:01:54.372 (13/12/2017)
#
#      Found 84 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 4) started at: 13:01:54.643 (13/12/2017)
#
#      Found 94 objects.
#
# ===  Found a TOTAL of 474 objects in image 'u67n2601r_c0m.fits'
#
#
#
# ===  Source finding for image 'u67n2602r_c0m.fits':
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 1) started at: 13:01:55.164 (13/12/2017)
#
#      Found 137 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 2) started at: 13:01:55.4 (13/12/2017)
#
#      Found 240 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 3) started at: 13:01:55.707 (13/12/2017)
#
#      Found 126 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 4) started at: 13:01:56.041 (13/12/2017)
#
#      Found 87 objects.
#
# ===  Found a TOTAL of 590 objects in image 'u67n2602r_c0m.fits'
#
#
#
#  Catalog trimmed to 474 objects
#
#
# ====================
# Aligning all input images to WCS defined by u67n2601r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u67n2602r_c0m.fits
#
# Matching sources from 'u67n2602r_c0m.fits' with sources from reference image 'u67n2601r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.706678267465 -0.516202076989
#
#     with significance of  402.290939495 and  20.0  matches
#
# Found 56 matches for u67n2602r_c0m.fits...
#
# Computed  rscale  fit for  u67n2602r_c0m.fits :
#
# XSH: -0.0499495  YSH: 0.0339675    ROT: 0.00151431    SCALE: 0.999987
#
# XRMS: 0.217021    YRMS: 0.193398
#
# RMS_RA: 3.90665e-06 (deg)   RMS_DEC: 2.94436e-06 (deg)
#
# Final solution based on  53  objects.
#
# wrote XY data to:  u67n2602r_c0m_catalog_fit.match
#
# Writing out shiftfile : 5shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.049950
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 13:01:56.796 (13/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u67n2601r_c0m.fits
#
#     u67n2602r_c0m.fits
#
# ===  Source finding for image 'u67n2601r_c0m.fits':
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 1) started at: 13:01:57.032 (13/12/2017)
#
#      Found 173 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 2) started at: 13:01:57.313 (13/12/2017)
#
#      Found 139 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 3) started at: 13:01:57.615 (13/12/2017)
#
#      Found 80 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 4) started at: 13:01:57.873 (13/12/2017)
#
#      Found 93 objects.
#
# ===  Found a TOTAL of 485 objects in image 'u67n2601r_c0m.fits'
#
#
#
# ===  Source finding for image 'u67n2602r_c0m.fits':
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 1) started at: 13:01:58.335 (13/12/2017)
#
#      Found 143 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 2) started at: 13:01:58.566 (13/12/2017)
#
#      Found 240 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 3) started at: 13:01:58.86 (13/12/2017)
#
#      Found 127 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 4) started at: 13:01:59.195 (13/12/2017)
#
#      Found 90 objects.
#
# ===  Found a TOTAL of 600 objects in image 'u67n2602r_c0m.fits'
#
#
#
#  Catalog trimmed to 485 objects
#
#
# ====================
# Aligning all input images to WCS defined by u67n2601r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u67n2602r_c0m.fits
#
# Matching sources from 'u67n2602r_c0m.fits' with sources from reference image 'u67n2601r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.791632436927 -0.664871873546
#
#     with significance of  420.615924684 and  21.0  matches
#
# Found 59 matches for u67n2602r_c0m.fits...
#
# Computed  rscale  fit for  u67n2602r_c0m.fits :
#
# XSH: -0.0384012  YSH: 0.0254075    ROT: 0.00102926    SCALE: 0.999971
#
# XRMS: 0.212192    YRMS: 0.188181
#
# RMS_RA: 3.79929e-06 (deg)   RMS_DEC: 2.87785e-06 (deg)
#
# Final solution based on  56  objects.
#
# wrote XY data to:  u67n2602r_c0m_catalog_fit.match
#
# Writing out shiftfile : 6shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.038401
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 13:01:59.926 (13/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u67n2601r_c0m.fits
#
#     u67n2602r_c0m.fits
#
# ===  Source finding for image 'u67n2601r_c0m.fits':
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 1) started at: 13:02:00.228 (13/12/2017)
#
#      Found 119 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 2) started at: 13:02:00.45 (13/12/2017)
#
#      Found 91 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 3) started at: 13:02:00.687 (13/12/2017)
#
#      Found 65 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 4) started at: 13:02:00.9 (13/12/2017)
#
#      Found 68 objects.
#
# ===  Found a TOTAL of 343 objects in image 'u67n2601r_c0m.fits'
#
#
#
# ===  Source finding for image 'u67n2602r_c0m.fits':
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 1) started at: 13:02:01.393 (13/12/2017)
#
#      Found 92 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 2) started at: 13:02:01.603 (13/12/2017)
#
#      Found 187 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 3) started at: 13:02:01.909 (13/12/2017)
#
#      Found 88 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 4) started at: 13:02:02.202 (13/12/2017)
#
#      Found 84 objects.
#
# ===  Found a TOTAL of 451 objects in image 'u67n2602r_c0m.fits'
#
#
#
#  Catalog trimmed to 343 objects
#
#
# ====================
# Aligning all input images to WCS defined by u67n2601r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u67n2602r_c0m.fits
#
# Matching sources from 'u67n2602r_c0m.fits' with sources from reference image 'u67n2601r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.747880563987 -0.598944393774
#
#     with significance of  350.142114005 and  13.0  matches
#
# Found 39 matches for u67n2602r_c0m.fits...
#
# Computed  rscale  fit for  u67n2602r_c0m.fits :
#
# XSH: -0.0461932  YSH: 0.0885834    ROT: 359.998    SCALE: 0.999979
#
# XRMS: 0.2603    YRMS: 0.224706
#
# RMS_RA: 4.52342e-06 (deg)   RMS_DEC: 3.52367e-06 (deg)
#
# Final solution based on  39  objects.
#
# wrote XY data to:  u67n2602r_c0m_catalog_fit.match
#
# Writing out shiftfile : 7shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.046193
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 13:02:02.958 (13/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u67n2601r_c0m.fits
#
#     u67n2602r_c0m.fits
#
# ===  Source finding for image 'u67n2601r_c0m.fits':
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 1) started at: 13:02:03.196 (13/12/2017)
#
#      Found 123 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 2) started at: 13:02:03.418 (13/12/2017)
#
#      Found 101 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 3) started at: 13:02:03.652 (13/12/2017)
#
#      Found 66 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 4) started at: 13:02:03.90 (13/12/2017)
#
#      Found 64 objects.
#
# ===  Found a TOTAL of 354 objects in image 'u67n2601r_c0m.fits'
#
#
#
# ===  Source finding for image 'u67n2602r_c0m.fits':
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 1) started at: 13:02:04.344 (13/12/2017)
#
#      Found 95 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 2) started at: 13:02:04.56 (13/12/2017)
#
#      Found 186 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 3) started at: 13:02:04.900 (13/12/2017)
#
#      Found 92 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 4) started at: 13:02:05.207 (13/12/2017)
#
#      Found 87 objects.
#
# ===  Found a TOTAL of 460 objects in image 'u67n2602r_c0m.fits'
#
#
#
#  Catalog trimmed to 354 objects
#
#
# ====================
# Aligning all input images to WCS defined by u67n2601r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u67n2602r_c0m.fits
#
# Matching sources from 'u67n2602r_c0m.fits' with sources from reference image 'u67n2601r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.760646521434 -0.651555612343
#
#     with significance of  366.693288379 and  16.0  matches
#
# Found 45 matches for u67n2602r_c0m.fits...
#
# Computed  rscale  fit for  u67n2602r_c0m.fits :
#
# XSH: -0.0544935  YSH: 0.0553489    ROT: 359.998    SCALE: 0.99996
#
# XRMS: 0.231927    YRMS: 0.265461
#
# RMS_RA: 5.48897e-06 (deg)   RMS_DEC: 3.21022e-06 (deg)
#
# Final solution based on  45  objects.
#
# wrote XY data to:  u67n2602r_c0m_catalog_fit.match
#
# Writing out shiftfile : 8shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.054494
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 13:02:05.924 (13/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u67n2601r_c0m.fits
#
#     u67n2602r_c0m.fits
#
# ===  Source finding for image 'u67n2601r_c0m.fits':
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 1) started at: 13:02:06.172 (13/12/2017)
#
#      Found 120 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 2) started at: 13:02:06.415 (13/12/2017)
#
#      Found 105 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 3) started at: 13:02:06.652 (13/12/2017)
#
#      Found 68 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 4) started at: 13:02:06.90 (13/12/2017)
#
#      Found 71 objects.
#
# ===  Found a TOTAL of 364 objects in image 'u67n2601r_c0m.fits'
#
#
#
# ===  Source finding for image 'u67n2602r_c0m.fits':
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 1) started at: 13:02:07.366 (13/12/2017)
#
#      Found 102 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 2) started at: 13:02:07.630 (13/12/2017)
#
#      Found 189 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 3) started at: 13:02:07.914 (13/12/2017)
#
#      Found 89 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 4) started at: 13:02:08.228 (13/12/2017)
#
#      Found 88 objects.
#
# ===  Found a TOTAL of 468 objects in image 'u67n2602r_c0m.fits'
#
#
#
#  Catalog trimmed to 364 objects
#
#
# ====================
# Aligning all input images to WCS defined by u67n2601r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u67n2602r_c0m.fits
#
# Matching sources from 'u67n2602r_c0m.fits' with sources from reference image 'u67n2601r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.662400907398 -0.609769328451
#
#     with significance of  390.099242956 and  19.0  matches
#
# Found 49 matches for u67n2602r_c0m.fits...
#
# Computed  rscale  fit for  u67n2602r_c0m.fits :
#
# XSH: -0.0596176  YSH: 0.0626958    ROT: 0.000381503    SCALE: 0.999977
#
# XRMS: 0.226289    YRMS: 0.230463
#
# RMS_RA: 4.71744e-06 (deg)   RMS_DEC: 3.10128e-06 (deg)
#
# Final solution based on  49  objects.
#
# wrote XY data to:  u67n2602r_c0m_catalog_fit.match
#
# Writing out shiftfile : 9shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.059618

# %%
# change to a jupyter table
dt=test.to_pandas()
dt.to_pickle('data.pickle')
good_table=pandas.read_pickle('data.pickle')

# %%
# take only unfailed sessions
good_conv = good_table[good_table['y_rms'] != 'failed']

# %%
good_conv
# Out:
#          shift                file     x_rms     y_rms  threshold  conv_width  \
# 0   1shift.txt  u67n2601r_c0m.fits  0.000000  0.000000          8         4.4
# 1   1shift.txt  u67n2602r_c0m.fits  0.163575  0.192415          8         4.4
# 2   2shift.txt  u67n2601r_c0m.fits  0.000000  0.000000          8         4.5
# 3   2shift.txt  u67n2602r_c0m.fits  0.149373  0.180013          8         4.5
# 4   3shift.txt  u67n2601r_c0m.fits  0.000000  0.000000          8         4.6
# 5   3shift.txt  u67n2602r_c0m.fits  0.151034  0.171138          8         4.6
# 6   4shift.txt  u67n2601r_c0m.fits  0.000000  0.000000          8         4.7
# 7   4shift.txt  u67n2602r_c0m.fits  0.182835  0.203060          8         4.7
# 8   5shift.txt  u67n2601r_c0m.fits  0.000000  0.000000          8         4.8
# 9   5shift.txt  u67n2602r_c0m.fits  0.217021  0.193398          8         4.8
# 10  6shift.txt  u67n2601r_c0m.fits  0.000000  0.000000          8         4.9
# 11  6shift.txt  u67n2602r_c0m.fits  0.212192  0.188181          8         4.9
# 12  7shift.txt  u67n2601r_c0m.fits  0.000000  0.000000          8         5.0
# 13  7shift.txt  u67n2602r_c0m.fits  0.260300  0.224706          8         5.0
# 14  8shift.txt  u67n2601r_c0m.fits  0.000000  0.000000          8         5.1
# 15  8shift.txt  u67n2602r_c0m.fits  0.231927  0.265461          8         5.1
# 16  9shift.txt  u67n2601r_c0m.fits  0.000000  0.000000          8         5.2
# 17  9shift.txt  u67n2602r_c0m.fits  0.226289  0.230463          8         5.2
#
#     roundlo  roundhi  peakmax
# 0        -1        1     1000
# 1        -1        1     1000
# 2        -1        1     1000
# 3        -1        1     1000
# 4        -1        1     1000
# 5        -1        1     1000
# 6        -1        1     1000
# 7        -1        1     1000
# 8        -1        1     1000
# 9        -1        1     1000
# 10       -1        1     1000
# 11       -1        1     1000
# 12       -1        1     1000
# 13       -1        1     1000
# 14       -1        1     1000
# 15       -1        1     1000
# 16       -1        1     1000
# 17       -1        1     1000

# %%
# plot figure for all sub-exp
plt.figure(figsize = (7,7))
plt.plot(good_conv['conv_width'],good_conv['x_rms'],'.g')
plt.plot(good_conv['conv_width'],good_conv['y_rms'],'.b')
plt.title('x,y_rms(conv_width)-g,b')
plt.show()

# %%
# plot figure for choosen sub-exp
plt.figure(figsize = (7,7))
plt.plot(good_conv[good_conv['file'] == 'u6ea5402m_c0m.fits']['conv_width'],good_conv[good_conv['file'] == 'u6ea5402m_c0m.fits']['y_rms'],'.b')
plt.plot(good_conv[good_conv['file'] == 'u6ea5403m_c0m.fits']['conv_width'],good_conv[good_conv['file'] == 'u6ea5403m_c0m.fits']['y_rms'],'.g')
plt.title('y_rms(conv)-two filters')
plt.show()

# %%
#############################################thresh = 8, conv = 4.6, roundlo?

# %%
# tweak_run(path, n_up, threshold_ini, threshold_gap, conv_width_ini, conv_width_gap, 
# roundlo_val_ini, roundlo_gap, roundhi_val_ini, roundhi_gap, peakmax_val_ini, peakmax_gap):
test = tweak_run('/Users/natalie/anaconda2/envs/iraf27/iraf/sn/2001ci/2001ci_pre/tweak_606',5,8,0,4.6,0,-0.7,0.1,1,0,1000,0)
# Out:
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 13:04:46.607 (13/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u67n2601r_c0m.fits
#
#     u67n2602r_c0m.fits
#
# ===  Source finding for image 'u67n2601r_c0m.fits':
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 1) started at: 13:04:46.931 (13/12/2017)
#
#      Found 268 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 2) started at: 13:04:47.238 (13/12/2017)
#
#      Found 212 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 3) started at: 13:04:47.565 (13/12/2017)
#
#      Found 129 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 4) started at: 13:04:47.853 (13/12/2017)
#
#      Found 146 objects.
#
# ===  Found a TOTAL of 755 objects in image 'u67n2601r_c0m.fits'
#
#
#
# ===  Source finding for image 'u67n2602r_c0m.fits':
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 1) started at: 13:04:48.36 (13/12/2017)
#
#      Found 214 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 2) started at: 13:04:48.647 (13/12/2017)
#
#      Found 353 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 3) started at: 13:04:49.048 (13/12/2017)
#
#      Found 205 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 4) started at: 13:04:49.433 (13/12/2017)
#
#      Found 194 objects.
#
# ===  Found a TOTAL of 966 objects in image 'u67n2602r_c0m.fits'
#
#
#
#  Catalog trimmed to 755 objects
#
#
# ====================
# Aligning all input images to WCS defined by u67n2601r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u67n2602r_c0m.fits
#
# Matching sources from 'u67n2602r_c0m.fits' with sources from reference image 'u67n2601r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.78604334683 -0.714614775402
#
#     with significance of  496.515276054 and  28.0  matches
#
# Found 79 matches for u67n2602r_c0m.fits...
#
# Computed  rscale  fit for  u67n2602r_c0m.fits :
#
# XSH: -0.0377306  YSH: 0.0105234    ROT: 0.000653255    SCALE: 0.999973
#
# XRMS: 0.151195    YRMS: 0.16525
#
# RMS_RA: 3.40379e-06 (deg)   RMS_DEC: 2.08432e-06 (deg)
#
# Final solution based on  73  objects.
#
# wrote XY data to:  u67n2602r_c0m_catalog_fit.match
#
# Writing out shiftfile : 1shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.037731
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 13:04:50.262 (13/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u67n2601r_c0m.fits
#
#     u67n2602r_c0m.fits
#
# ===  Source finding for image 'u67n2601r_c0m.fits':
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 1) started at: 13:04:50.504 (13/12/2017)
#
#      Found 247 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 2) started at: 13:04:50.855 (13/12/2017)
#
#      Found 200 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 3) started at: 13:04:51.185 (13/12/2017)
#
#      Found 121 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 4) started at: 13:04:51.51 (13/12/2017)
#
#      Found 136 objects.
#
# ===  Found a TOTAL of 704 objects in image 'u67n2601r_c0m.fits'
#
#
#
# ===  Source finding for image 'u67n2602r_c0m.fits':
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 1) started at: 13:04:52.073 (13/12/2017)
#
#      Found 200 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 2) started at: 13:04:52.328 (13/12/2017)
#
#      Found 337 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 3) started at: 13:04:52.653 (13/12/2017)
#
#      Found 187 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 4) started at: 13:04:52.998 (13/12/2017)
#
#      Found 181 objects.
#
# ===  Found a TOTAL of 905 objects in image 'u67n2602r_c0m.fits'
#
#
#
#  Catalog trimmed to 704 objects
#
#
# ====================
# Aligning all input images to WCS defined by u67n2601r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u67n2602r_c0m.fits
#
# Matching sources from 'u67n2602r_c0m.fits' with sources from reference image 'u67n2601r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.842002453637 -0.748782114654
#
#     with significance of  493.506636227 and  28.0  matches
#
# Found 76 matches for u67n2602r_c0m.fits...
#
# Computed  rscale  fit for  u67n2602r_c0m.fits :
#
# XSH: -0.0377853  YSH: 0.010176    ROT: 0.000598647    SCALE: 0.999973
#
# XRMS: 0.152163    YRMS: 0.166308
#
# RMS_RA: 3.4256e-06 (deg)   RMS_DEC: 2.09766e-06 (deg)
#
# Final solution based on  72  objects.
#
# wrote XY data to:  u67n2602r_c0m_catalog_fit.match
#
# Writing out shiftfile : 2shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.037785
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 13:04:53.83 (13/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u67n2601r_c0m.fits
#
#     u67n2602r_c0m.fits
#
# ===  Source finding for image 'u67n2601r_c0m.fits':
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 1) started at: 13:04:54.082 (13/12/2017)
#
#      Found 223 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 2) started at: 13:04:54.369 (13/12/2017)
#
#      Found 175 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 3) started at: 13:04:54.633 (13/12/2017)
#
#      Found 117 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 4) started at: 13:04:54.937 (13/12/2017)
#
#      Found 121 objects.
#
# ===  Found a TOTAL of 636 objects in image 'u67n2601r_c0m.fits'
#
#
#
# ===  Source finding for image 'u67n2602r_c0m.fits':
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 1) started at: 13:04:55.453 (13/12/2017)
#
#      Found 189 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 2) started at: 13:04:55.698 (13/12/2017)
#
#      Found 314 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 3) started at: 13:04:56.096 (13/12/2017)
#
#      Found 173 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 4) started at: 13:04:56.440 (13/12/2017)
#
#      Found 166 objects.
#
# ===  Found a TOTAL of 842 objects in image 'u67n2602r_c0m.fits'
#
#
#
#  Catalog trimmed to 636 objects
#
#
# ====================
# Aligning all input images to WCS defined by u67n2601r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u67n2602r_c0m.fits
#
# Matching sources from 'u67n2602r_c0m.fits' with sources from reference image 'u67n2601r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.820459605546 -0.717655867228
#
#     with significance of  495.697922902 and  27.0  matches
#
# Found 74 matches for u67n2602r_c0m.fits...
#
# Computed  rscale  fit for  u67n2602r_c0m.fits :
#
# XSH: -0.0345054  YSH: 0.0143701    ROT: 0.000736841    SCALE: 0.999972
#
# XRMS: 0.147855    YRMS: 0.162546
#
# RMS_RA: 3.34976e-06 (deg)   RMS_DEC: 2.03929e-06 (deg)
#
# Final solution based on  71  objects.
#
# wrote XY data to:  u67n2602r_c0m_catalog_fit.match
#
# Writing out shiftfile : 3shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.034505
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 13:04:57.22 (13/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u67n2601r_c0m.fits
#
#     u67n2602r_c0m.fits
#
# ===  Source finding for image 'u67n2601r_c0m.fits':
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 1) started at: 13:04:57.463 (13/12/2017)
#
#      Found 200 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 2) started at: 13:04:57.755 (13/12/2017)
#
#      Found 164 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 3) started at: 13:04:58.019 (13/12/2017)
#
#      Found 109 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 4) started at: 13:04:58.289 (13/12/2017)
#
#      Found 108 objects.
#
# ===  Found a TOTAL of 581 objects in image 'u67n2601r_c0m.fits'
#
#
#
# ===  Source finding for image 'u67n2602r_c0m.fits':
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 1) started at: 13:04:58.831 (13/12/2017)
#
#      Found 171 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 2) started at: 13:04:59.079 (13/12/2017)
#
#      Found 293 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 3) started at: 13:04:59.412 (13/12/2017)
#
#      Found 157 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 4) started at: 13:04:59.738 (13/12/2017)
#
#      Found 153 objects.
#
# ===  Found a TOTAL of 774 objects in image 'u67n2602r_c0m.fits'
#
#
#
#  Catalog trimmed to 581 objects
#
#
# ====================
# Aligning all input images to WCS defined by u67n2601r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u67n2602r_c0m.fits
#
# Matching sources from 'u67n2602r_c0m.fits' with sources from reference image 'u67n2601r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.721516086651 -0.699776956216
#
#     with significance of  465.417402436 and  25.0  matches
#
# Found 70 matches for u67n2602r_c0m.fits...
#
# Computed  rscale  fit for  u67n2602r_c0m.fits :
#
# XSH: -0.0243044  YSH: 0.0320372    ROT: 0.000527148    SCALE: 0.999976
#
# XRMS: 0.149134    YRMS: 0.171626
#
# RMS_RA: 3.55028e-06 (deg)   RMS_DEC: 2.06524e-06 (deg)
#
# Final solution based on  69  objects.
#
# wrote XY data to:  u67n2602r_c0m_catalog_fit.match
#
# Writing out shiftfile : 4shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.024304

# %%
# change to a jupyter table
dt=test.to_pandas()
dt.to_pickle('data.pickle')
good_table=pandas.read_pickle('data.pickle')

# %%
# take only unfailed sessions
good_roundlo = good_table[good_table['y_rms'] != 'failed']

# %%
good_roundlo
# Out:
#         shift                file     x_rms     y_rms  threshold  conv_width  \
# 0  1shift.txt  u67n2601r_c0m.fits  0.000000  0.000000          8         4.6
# 1  1shift.txt  u67n2602r_c0m.fits  0.151195  0.165250          8         4.6
# 2  2shift.txt  u67n2601r_c0m.fits  0.000000  0.000000          8         4.6
# 3  2shift.txt  u67n2602r_c0m.fits  0.152163  0.166308          8         4.6
# 4  3shift.txt  u67n2601r_c0m.fits  0.000000  0.000000          8         4.6
# 5  3shift.txt  u67n2602r_c0m.fits  0.147855  0.162546          8         4.6
# 6  4shift.txt  u67n2601r_c0m.fits  0.000000  0.000000          8         4.6
# 7  4shift.txt  u67n2602r_c0m.fits  0.149134  0.171626          8         4.6
#
#    roundlo  roundhi  peakmax
# 0     -0.7        1     1000
# 1     -0.7        1     1000
# 2     -0.6        1     1000
# 3     -0.6        1     1000
# 4     -0.5        1     1000
# 5     -0.5        1     1000
# 6     -0.4        1     1000
# 7     -0.4        1     1000

# %%
# plot figure for all sub-exp
plt.figure(figsize = (7,7))
plt.plot(good_roundlo['roundlo'],good_roundlo['x_rms'],'.g')
plt.plot(good_roundlo['roundlo'],good_roundlo['y_rms'],'.b')
plt.title('x,y_rms(roundlo)-g,b')
plt.show()

# %%
# plot figure for choosen sub-exp
plt.figure(figsize = (7,7))
plt.plot(good_round[good_round['file'] == 'u6ea5402m_c0m.fits']['roundlo'],good_round[good_round['file'] == 'u6ea5402m_c0m.fits']['y_rms'],'.b')
plt.plot(good_round[good_round['file'] == 'u6ea5403m_c0m.fits']['roundlo'],good_round[good_round['file'] == 'u6ea5403m_c0m.fits']['y_rms'],'.g')
plt.title('y_rms(roundlo)-two filters')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-1b5e9d62f47a> in <module>()
#       1 # plot figure for choosen sub-exp
#       2 plt.figure(figsize = (7,7))
# ----> 3 plt.plot(good_round[good_round['file'] == 'u6ea5402m_c0m.fits']['roundlo'],good_round[good_round['file'] == 'u6ea5402m_c0m.fits']['y_rms'],'.b')
#       4 plt.plot(good_round[good_round['file'] == 'u6ea5403m_c0m.fits']['roundlo'],good_round[good_round['file'] == 'u6ea5403m_c0m.fits']['y_rms'],'.g')
#       5 plt.title('y_rms(roundlo)-two filters')
#
# NameError: name 'good_round' is not defined

# %%
#############################################thresh = 8, conv = 4.6, roundlo = -0.5, roundhi?

# %%
# tweak_run(path, n_up, threshold_ini, threshold_gap, conv_width_ini, conv_width_gap, 
# roundlo_val_ini, roundlo_gap, roundhi_val_ini, roundhi_gap, peakmax_val_ini, peakmax_gap):
test = tweak_run('/Users/natalie/anaconda2/envs/iraf27/iraf/sn/2001ci/2001ci_pre/tweak_606',5,8,0,4.6,0,-0.5,0,0.7,0.1,1000,0)
# Out:
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 13:07:16.671 (13/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u67n2601r_c0m.fits
#
#     u67n2602r_c0m.fits
#
# ===  Source finding for image 'u67n2601r_c0m.fits':
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 1) started at: 13:07:17.021 (13/12/2017)
#
#      Found 163 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 2) started at: 13:07:17.327 (13/12/2017)
#
#      Found 153 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 3) started at: 13:07:17.594 (13/12/2017)
#
#      Found 88 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 4) started at: 13:07:17.938 (13/12/2017)
#
#      Found 90 objects.
#
# ===  Found a TOTAL of 494 objects in image 'u67n2601r_c0m.fits'
#
#
#
# ===  Source finding for image 'u67n2602r_c0m.fits':
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 1) started at: 13:07:18.418 (13/12/2017)
#
#      Found 165 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 2) started at: 13:07:18.693 (13/12/2017)
#
#      Found 277 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 3) started at: 13:07:19.09 (13/12/2017)
#
#      Found 144 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 4) started at: 13:07:19.465 (13/12/2017)
#
#      Found 134 objects.
#
# ===  Found a TOTAL of 720 objects in image 'u67n2602r_c0m.fits'
#
#
#
#  Catalog trimmed to 494 objects
#
#
# ====================
# Aligning all input images to WCS defined by u67n2601r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u67n2602r_c0m.fits
#
# Matching sources from 'u67n2602r_c0m.fits' with sources from reference image 'u67n2601r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.734840069821 -0.691829317133
#
#     with significance of  475.998724488 and  26.0  matches
#
# Found 72 matches for u67n2602r_c0m.fits...
#
# Computed  rscale  fit for  u67n2602r_c0m.fits :
#
# XSH: -0.0232601  YSH: 0.0273531    ROT: 0.000694159    SCALE: 0.999973
#
# XRMS: 0.148725    YRMS: 0.171503
#
# RMS_RA: 3.54833e-06 (deg)   RMS_DEC: 2.05996e-06 (deg)
#
# Final solution based on  71  objects.
#
# wrote XY data to:  u67n2602r_c0m_catalog_fit.match
#
# Writing out shiftfile : 1shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.023260
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 13:07:20.412 (13/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u67n2601r_c0m.fits
#
#     u67n2602r_c0m.fits
#
# ===  Source finding for image 'u67n2601r_c0m.fits':
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 1) started at: 13:07:20.706 (13/12/2017)
#
#      Found 183 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 2) started at: 13:07:21.083 (13/12/2017)
#
#      Found 160 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 3) started at: 13:07:21.378 (13/12/2017)
#
#      Found 99 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 4) started at: 13:07:21.68 (13/12/2017)
#
#      Found 103 objects.
#
# ===  Found a TOTAL of 545 objects in image 'u67n2601r_c0m.fits'
#
#
#
# ===  Source finding for image 'u67n2602r_c0m.fits':
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 1) started at: 13:07:22.18 (13/12/2017)
#
#      Found 176 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 2) started at: 13:07:22.434 (13/12/2017)
#
#      Found 288 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 3) started at: 13:07:22.757 (13/12/2017)
#
#      Found 159 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 4) started at: 13:07:23.109 (13/12/2017)
#
#      Found 144 objects.
#
# ===  Found a TOTAL of 767 objects in image 'u67n2602r_c0m.fits'
#
#
#
#  Catalog trimmed to 545 objects
#
#
# ====================
# Aligning all input images to WCS defined by u67n2601r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u67n2602r_c0m.fits
#
# Matching sources from 'u67n2602r_c0m.fits' with sources from reference image 'u67n2601r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.806007346176 -0.723533119372
#
#     with significance of  479.127655583 and  26.0  matches
#
# Found 72 matches for u67n2602r_c0m.fits...
#
# Computed  rscale  fit for  u67n2602r_c0m.fits :
#
# XSH: -0.0301411  YSH: 0.0157155    ROT: 0.000757608    SCALE: 0.999972
#
# XRMS: 0.146132    YRMS: 0.159712
#
# RMS_RA: 3.28972e-06 (deg)   RMS_DEC: 2.01452e-06 (deg)
#
# Final solution based on  69  objects.
#
# wrote XY data to:  u67n2602r_c0m_catalog_fit.match
#
# Writing out shiftfile : 2shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.030141
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 13:07:23.94 (13/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u67n2601r_c0m.fits
#
#     u67n2602r_c0m.fits
#
# ===  Source finding for image 'u67n2601r_c0m.fits':
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 1) started at: 13:07:24.188 (13/12/2017)
#
#      Found 198 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 2) started at: 13:07:24.469 (13/12/2017)
#
#      Found 169 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 3) started at: 13:07:24.736 (13/12/2017)
#
#      Found 102 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 4) started at: 13:07:25.019 (13/12/2017)
#
#      Found 112 objects.
#
# ===  Found a TOTAL of 581 objects in image 'u67n2601r_c0m.fits'
#
#
#
# ===  Source finding for image 'u67n2602r_c0m.fits':
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 1) started at: 13:07:25.521 (13/12/2017)
#
#      Found 184 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 2) started at: 13:07:25.753 (13/12/2017)
#
#      Found 305 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 3) started at: 13:07:26.131 (13/12/2017)
#
#      Found 165 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 4) started at: 13:07:26.475 (13/12/2017)
#
#      Found 160 objects.
#
# ===  Found a TOTAL of 814 objects in image 'u67n2602r_c0m.fits'
#
#
#
#  Catalog trimmed to 581 objects
#
#
# ====================
# Aligning all input images to WCS defined by u67n2601r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u67n2602r_c0m.fits
#
# Matching sources from 'u67n2602r_c0m.fits' with sources from reference image 'u67n2601r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.831933650146 -0.69331978876
#
#     with significance of  485.481603253 and  26.0  matches
#
# Found 73 matches for u67n2602r_c0m.fits...
#
# Computed  rscale  fit for  u67n2602r_c0m.fits :
#
# XSH: -0.0337704  YSH: 0.018519    ROT: 0.000705444    SCALE: 0.999972
#
# XRMS: 0.148868    YRMS: 0.15992
#
# RMS_RA: 3.28912e-06 (deg)   RMS_DEC: 2.04922e-06 (deg)
#
# Final solution based on  70  objects.
#
# wrote XY data to:  u67n2602r_c0m_catalog_fit.match
#
# Writing out shiftfile : 3shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.033770
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 13:07:27.237 (13/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u67n2601r_c0m.fits
#
#     u67n2602r_c0m.fits
#
# ===  Source finding for image 'u67n2601r_c0m.fits':
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 1) started at: 13:07:27.490 (13/12/2017)
#
#      Found 223 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 2) started at: 13:07:27.780 (13/12/2017)
#
#      Found 175 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 3) started at: 13:07:28.04 (13/12/2017)
#
#      Found 117 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 4) started at: 13:07:28.34 (13/12/2017)
#
#      Found 121 objects.
#
# ===  Found a TOTAL of 636 objects in image 'u67n2601r_c0m.fits'
#
#
#
# ===  Source finding for image 'u67n2602r_c0m.fits':
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 1) started at: 13:07:28.805 (13/12/2017)
#
#      Found 189 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 2) started at: 13:07:29.046 (13/12/2017)
#
#      Found 314 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 3) started at: 13:07:29.413 (13/12/2017)
#
#      Found 173 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 4) started at: 13:07:29.760 (13/12/2017)
#
#      Found 166 objects.
#
# ===  Found a TOTAL of 842 objects in image 'u67n2602r_c0m.fits'
#
#
#
#  Catalog trimmed to 636 objects
#
#
# ====================
# Aligning all input images to WCS defined by u67n2601r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u67n2602r_c0m.fits
#
# Matching sources from 'u67n2602r_c0m.fits' with sources from reference image 'u67n2601r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.820459605546 -0.717655867228
#
#     with significance of  495.697922902 and  27.0  matches
#
# Found 74 matches for u67n2602r_c0m.fits...
#
# Computed  rscale  fit for  u67n2602r_c0m.fits :
#
# XSH: -0.0345054  YSH: 0.0143701    ROT: 0.000736841    SCALE: 0.999972
#
# XRMS: 0.147855    YRMS: 0.162546
#
# RMS_RA: 3.34976e-06 (deg)   RMS_DEC: 2.03929e-06 (deg)
#
# Final solution based on  71  objects.
#
# wrote XY data to:  u67n2602r_c0m_catalog_fit.match
#
# Writing out shiftfile : 4shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.034505

# %%
# change to a jupyter table
dt=test.to_pandas()
dt.to_pickle('data.pickle')
good_table=pandas.read_pickle('data.pickle')

# %%
# take only unfailed sessions
good_roundhi = good_table[good_table['y_rms'] != 'failed']

# %%
good_roundhi
# Out:
#         shift                file     x_rms     y_rms  threshold  conv_width  \
# 0  1shift.txt  u67n2601r_c0m.fits  0.000000  0.000000          8         4.6
# 1  1shift.txt  u67n2602r_c0m.fits  0.148725  0.171503          8         4.6
# 2  2shift.txt  u67n2601r_c0m.fits  0.000000  0.000000          8         4.6
# 3  2shift.txt  u67n2602r_c0m.fits  0.146132  0.159712          8         4.6
# 4  3shift.txt  u67n2601r_c0m.fits  0.000000  0.000000          8         4.6
# 5  3shift.txt  u67n2602r_c0m.fits  0.148868  0.159920          8         4.6
# 6  4shift.txt  u67n2601r_c0m.fits  0.000000  0.000000          8         4.6
# 7  4shift.txt  u67n2602r_c0m.fits  0.147855  0.162546          8         4.6
#
#    roundlo  roundhi  peakmax
# 0     -0.5      0.7     1000
# 1     -0.5      0.7     1000
# 2     -0.5      0.8     1000
# 3     -0.5      0.8     1000
# 4     -0.5      0.9     1000
# 5     -0.5      0.9     1000
# 6     -0.5      1.0     1000
# 7     -0.5      1.0     1000

# %%
# plot figure for all sub-exp 
plt.figure(figsize = (7,7))
plt.plot(good_roundhi['roundhi'],good_roundhi['x_rms'],'.g')
plt.plot(good_roundhi['roundhi'],good_roundhi['y_rms'],'.b')
plt.title('x,y_rms(roundhi)-g,b')
plt.show()

# %%
# plot figure for choosen sub-exp
plt.figure(figsize = (7,7))
plt.plot(good_round[good_round['file'] == 'u6ea5402m_c0m.fits']['roundhi'],good_round[good_round['file'] == 'u6ea5402m_c0m.fits']['y_rms'],'.b')
plt.plot(good_round[good_round['file'] == 'u6ea5403m_c0m.fits']['roundhi'],good_round[good_round['file'] == 'u6ea5403m_c0m.fits']['y_rms'],'.g')
plt.title('y_rms(roundhi)-two filters')
plt.show()

# %%
#############################################thresh = 8, conv = 4.6 roundnlo = -0.5, rounfhi = 0.8, peakmax?

# %%
# tweak_run(path, n_up, threshold_ini, threshold_gap, conv_width_ini, conv_width_gap, 
# roundlo_val_ini, roundlo_gap, roundhi_val_ini, roundhi_gap, peakmax_val_ini, peakmax_gap):
test = tweak_run('/Users/natalie/anaconda2/envs/iraf27/iraf/sn/2001ci/2001ci_pre/tweak_606',10,8,0,4.6,0,-0.5,0,0.8,0,4000,500)
# Out:
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 13:09:04.200 (13/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u67n2601r_c0m.fits
#
#     u67n2602r_c0m.fits
#
# ===  Source finding for image 'u67n2601r_c0m.fits':
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 1) started at: 13:09:04.619 (13/12/2017)
#
#      Found 184 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 2) started at: 13:09:04.934 (13/12/2017)
#
#      Found 162 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 3) started at: 13:09:05.204 (13/12/2017)
#
#      Found 101 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 4) started at: 13:09:05.499 (13/12/2017)
#
#      Found 108 objects.
#
# ===  Found a TOTAL of 555 objects in image 'u67n2601r_c0m.fits'
#
#
#
# ===  Source finding for image 'u67n2602r_c0m.fits':
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 1) started at: 13:09:06.011 (13/12/2017)
#
#      Found 179 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 2) started at: 13:09:06.26 (13/12/2017)
#
#      Found 290 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 3) started at: 13:09:06.616 (13/12/2017)
#
#      Found 159 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 4) started at: 13:09:07.021 (13/12/2017)
#
#      Found 153 objects.
#
# ===  Found a TOTAL of 781 objects in image 'u67n2602r_c0m.fits'
#
#
#
#  Catalog trimmed to 555 objects
#
#
# ====================
# Aligning all input images to WCS defined by u67n2601r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u67n2602r_c0m.fits
#
# Matching sources from 'u67n2602r_c0m.fits' with sources from reference image 'u67n2601r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.809131369918 -0.718222279009
#
#     with significance of  486.360611139 and  27.0  matches
#
# Found 74 matches for u67n2602r_c0m.fits...
#
# Computed  rscale  fit for  u67n2602r_c0m.fits :
#
# XSH: -0.0232849  YSH: 0.0184867    ROT: 0.000565629    SCALE: 0.999969
#
# XRMS: 0.135195    YRMS: 0.159836
#
# RMS_RA: 3.31349e-06 (deg)   RMS_DEC: 1.87682e-06 (deg)
#
# Final solution based on  70  objects.
#
# wrote XY data to:  u67n2602r_c0m_catalog_fit.match
#
# Writing out shiftfile : 1shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.023285
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 13:09:07.997 (13/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u67n2601r_c0m.fits
#
#     u67n2602r_c0m.fits
#
# ===  Source finding for image 'u67n2601r_c0m.fits':
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 1) started at: 13:09:08.286 (13/12/2017)
#
#      Found 184 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 2) started at: 13:09:08.643 (13/12/2017)
#
#      Found 162 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 3) started at: 13:09:08.921 (13/12/2017)
#
#      Found 101 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 4) started at: 13:09:09.263 (13/12/2017)
#
#      Found 108 objects.
#
# ===  Found a TOTAL of 555 objects in image 'u67n2601r_c0m.fits'
#
#
#
# ===  Source finding for image 'u67n2602r_c0m.fits':
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 1) started at: 13:09:09.772 (13/12/2017)
#
#      Found 179 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 2) started at: 13:09:10.030 (13/12/2017)
#
#      Found 290 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 3) started at: 13:09:10.371 (13/12/2017)
#
#      Found 161 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 4) started at: 13:09:10.776 (13/12/2017)
#
#      Found 155 objects.
#
# ===  Found a TOTAL of 785 objects in image 'u67n2602r_c0m.fits'
#
#
#
#  Catalog trimmed to 555 objects
#
#
# ====================
# Aligning all input images to WCS defined by u67n2601r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u67n2602r_c0m.fits
#
# Matching sources from 'u67n2602r_c0m.fits' with sources from reference image 'u67n2601r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.809131369918 -0.718222279009
#
#     with significance of  486.360611139 and  27.0  matches
#
# Found 74 matches for u67n2602r_c0m.fits...
#
# Computed  rscale  fit for  u67n2602r_c0m.fits :
#
# XSH: -0.0232849  YSH: 0.0184867    ROT: 0.000565629    SCALE: 0.999969
#
# XRMS: 0.135195    YRMS: 0.159836
#
# RMS_RA: 3.31349e-06 (deg)   RMS_DEC: 1.87682e-06 (deg)
#
# Final solution based on  70  objects.
#
# wrote XY data to:  u67n2602r_c0m_catalog_fit.match
#
# Writing out shiftfile : 2shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.023285
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 13:09:11.797 (13/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u67n2601r_c0m.fits
#
#     u67n2602r_c0m.fits
#
# ===  Source finding for image 'u67n2601r_c0m.fits':
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 1) started at: 13:09:12.053 (13/12/2017)
#
#      Found 184 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 2) started at: 13:09:12.432 (13/12/2017)
#
#      Found 162 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 3) started at: 13:09:12.743 (13/12/2017)
#
#      Found 102 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 4) started at: 13:09:13.035 (13/12/2017)
#
#      Found 108 objects.
#
# ===  Found a TOTAL of 556 objects in image 'u67n2601r_c0m.fits'
#
#
#
# ===  Source finding for image 'u67n2602r_c0m.fits':
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 1) started at: 13:09:13.587 (13/12/2017)
#
#      Found 180 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 2) started at: 13:09:13.920 (13/12/2017)
#
#      Found 290 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 3) started at: 13:09:14.410 (13/12/2017)
#
#      Found 163 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 4) started at: 13:09:14.763 (13/12/2017)
#
#      Found 155 objects.
#
# ===  Found a TOTAL of 788 objects in image 'u67n2602r_c0m.fits'
#
#
#
#  Catalog trimmed to 556 objects
#
#
# ====================
# Aligning all input images to WCS defined by u67n2601r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u67n2602r_c0m.fits
#
# Matching sources from 'u67n2602r_c0m.fits' with sources from reference image 'u67n2601r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.809131369918 -0.718222279009
#
#     with significance of  486.360611139 and  27.0  matches
#
# Found 74 matches for u67n2602r_c0m.fits...
#
# Computed  rscale  fit for  u67n2602r_c0m.fits :
#
# XSH: -0.0232849  YSH: 0.0184867    ROT: 0.000565629    SCALE: 0.999969
#
# XRMS: 0.135195    YRMS: 0.159836
#
# RMS_RA: 3.31349e-06 (deg)   RMS_DEC: 1.87682e-06 (deg)
#
# Final solution based on  70  objects.
#
# wrote XY data to:  u67n2602r_c0m_catalog_fit.match
#
# Writing out shiftfile : 3shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.023285
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 13:09:15.585 (13/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u67n2601r_c0m.fits
#
#     u67n2602r_c0m.fits
#
# ===  Source finding for image 'u67n2601r_c0m.fits':
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 1) started at: 13:09:15.833 (13/12/2017)
#
#      Found 184 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 2) started at: 13:09:16.137 (13/12/2017)
#
#      Found 164 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 3) started at: 13:09:16.417 (13/12/2017)
#
#      Found 102 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 4) started at: 13:09:16.830 (13/12/2017)
#
#      Found 108 objects.
#
# ===  Found a TOTAL of 558 objects in image 'u67n2601r_c0m.fits'
#
#
#
# ===  Source finding for image 'u67n2602r_c0m.fits':
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 1) started at: 13:09:17.309 (13/12/2017)
#
#      Found 180 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 2) started at: 13:09:17.565 (13/12/2017)
#
#      Found 290 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 3) started at: 13:09:17.964 (13/12/2017)
#
#      Found 164 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 4) started at: 13:09:18.318 (13/12/2017)
#
#      Found 155 objects.
#
# ===  Found a TOTAL of 789 objects in image 'u67n2602r_c0m.fits'
#
#
#
#  Catalog trimmed to 558 objects
#
#
# ====================
# Aligning all input images to WCS defined by u67n2601r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u67n2602r_c0m.fits
#
# Matching sources from 'u67n2602r_c0m.fits' with sources from reference image 'u67n2601r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.809131369918 -0.718222279009
#
#     with significance of  486.360611139 and  27.0  matches
#
# Found 74 matches for u67n2602r_c0m.fits...
#
# Computed  rscale  fit for  u67n2602r_c0m.fits :
#
# XSH: -0.0232849  YSH: 0.0184867    ROT: 0.000565629    SCALE: 0.999969
#
# XRMS: 0.135195    YRMS: 0.159836
#
# RMS_RA: 3.31349e-06 (deg)   RMS_DEC: 1.87682e-06 (deg)
#
# Final solution based on  70  objects.
#
# wrote XY data to:  u67n2602r_c0m_catalog_fit.match
#
# Writing out shiftfile : 4shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.023285
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 13:09:19.100 (13/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u67n2601r_c0m.fits
#
#     u67n2602r_c0m.fits
#
# ===  Source finding for image 'u67n2601r_c0m.fits':
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 1) started at: 13:09:19.344 (13/12/2017)
#
#      Found 184 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 2) started at: 13:09:19.633 (13/12/2017)
#
#      Found 165 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 3) started at: 13:09:19.896 (13/12/2017)
#
#      Found 102 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 4) started at: 13:09:20.174 (13/12/2017)
#
#      Found 108 objects.
#
# ===  Found a TOTAL of 559 objects in image 'u67n2601r_c0m.fits'
#
#
#
# ===  Source finding for image 'u67n2602r_c0m.fits':
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 1) started at: 13:09:20.721 (13/12/2017)
#
#      Found 180 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 2) started at: 13:09:20.975 (13/12/2017)
#
#      Found 290 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 3) started at: 13:09:21.331 (13/12/2017)
#
#      Found 164 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 4) started at: 13:09:21.695 (13/12/2017)
#
#      Found 155 objects.
#
# ===  Found a TOTAL of 789 objects in image 'u67n2602r_c0m.fits'
#
#
#
#  Catalog trimmed to 559 objects
#
#
# ====================
# Aligning all input images to WCS defined by u67n2601r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u67n2602r_c0m.fits
#
# Matching sources from 'u67n2602r_c0m.fits' with sources from reference image 'u67n2601r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.809131369918 -0.718222279009
#
#     with significance of  486.360611139 and  27.0  matches
#
# Found 74 matches for u67n2602r_c0m.fits...
#
# Computed  rscale  fit for  u67n2602r_c0m.fits :
#
# XSH: -0.0232849  YSH: 0.0184867    ROT: 0.000565629    SCALE: 0.999969
#
# XRMS: 0.135195    YRMS: 0.159836
#
# RMS_RA: 3.31349e-06 (deg)   RMS_DEC: 1.87682e-06 (deg)
#
# Final solution based on  70  objects.
#
# wrote XY data to:  u67n2602r_c0m_catalog_fit.match
#
# Writing out shiftfile : 5shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.023285
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 13:09:22.491 (13/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u67n2601r_c0m.fits
#
#     u67n2602r_c0m.fits
#
# ===  Source finding for image 'u67n2601r_c0m.fits':
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 1) started at: 13:09:22.739 (13/12/2017)
#
#      Found 184 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 2) started at: 13:09:23.047 (13/12/2017)
#
#      Found 165 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 3) started at: 13:09:23.315 (13/12/2017)
#
#      Found 102 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 4) started at: 13:09:23.702 (13/12/2017)
#
#      Found 108 objects.
#
# ===  Found a TOTAL of 559 objects in image 'u67n2601r_c0m.fits'
#
#
#
# ===  Source finding for image 'u67n2602r_c0m.fits':
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 1) started at: 13:09:24.146 (13/12/2017)
#
#      Found 180 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 2) started at: 13:09:24.397 (13/12/2017)
#
#      Found 290 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 3) started at: 13:09:24.71 (13/12/2017)
#
#      Found 164 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 4) started at: 13:09:25.06 (13/12/2017)
#
#      Found 156 objects.
#
# ===  Found a TOTAL of 790 objects in image 'u67n2602r_c0m.fits'
#
#
#
#  Catalog trimmed to 559 objects
#
#
# ====================
# Aligning all input images to WCS defined by u67n2601r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u67n2602r_c0m.fits
#
# Matching sources from 'u67n2602r_c0m.fits' with sources from reference image 'u67n2601r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.809131369918 -0.718222279009
#
#     with significance of  486.360611139 and  27.0  matches
#
# Found 74 matches for u67n2602r_c0m.fits...
#
# Computed  rscale  fit for  u67n2602r_c0m.fits :
#
# XSH: -0.0232849  YSH: 0.0184867    ROT: 0.000565629    SCALE: 0.999969
#
# XRMS: 0.135195    YRMS: 0.159836
#
# RMS_RA: 3.31349e-06 (deg)   RMS_DEC: 1.87682e-06 (deg)
#
# Final solution based on  70  objects.
#
# wrote XY data to:  u67n2602r_c0m_catalog_fit.match
#
# Writing out shiftfile : 6shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.023285
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 13:09:25.898 (13/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u67n2601r_c0m.fits
#
#     u67n2602r_c0m.fits
#
# ===  Source finding for image 'u67n2601r_c0m.fits':
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 1) started at: 13:09:26.151 (13/12/2017)
#
#      Found 184 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 2) started at: 13:09:26.506 (13/12/2017)
#
#      Found 165 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 3) started at: 13:09:26.795 (13/12/2017)
#
#      Found 102 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 4) started at: 13:09:27.081 (13/12/2017)
#
#      Found 108 objects.
#
# ===  Found a TOTAL of 559 objects in image 'u67n2601r_c0m.fits'
#
#
#
# ===  Source finding for image 'u67n2602r_c0m.fits':
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 1) started at: 13:09:27.576 (13/12/2017)
#
#      Found 180 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 2) started at: 13:09:27.829 (13/12/2017)
#
#      Found 291 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 3) started at: 13:09:28.166 (13/12/2017)
#
#      Found 164 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 4) started at: 13:09:28.516 (13/12/2017)
#
#      Found 156 objects.
#
# ===  Found a TOTAL of 791 objects in image 'u67n2602r_c0m.fits'
#
#
#
#  Catalog trimmed to 559 objects
#
#
# ====================
# Aligning all input images to WCS defined by u67n2601r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u67n2602r_c0m.fits
#
# Matching sources from 'u67n2602r_c0m.fits' with sources from reference image 'u67n2601r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.809131369918 -0.718222279009
#
#     with significance of  486.360611139 and  27.0  matches
#
# Found 74 matches for u67n2602r_c0m.fits...
#
# Computed  rscale  fit for  u67n2602r_c0m.fits :
#
# XSH: -0.0232849  YSH: 0.0184867    ROT: 0.000565629    SCALE: 0.999969
#
# XRMS: 0.135195    YRMS: 0.159836
#
# RMS_RA: 3.31349e-06 (deg)   RMS_DEC: 1.87682e-06 (deg)
#
# Final solution based on  70  objects.
#
# wrote XY data to:  u67n2602r_c0m_catalog_fit.match
#
# Writing out shiftfile : 7shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.023285
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 13:09:29.351 (13/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u67n2601r_c0m.fits
#
#     u67n2602r_c0m.fits
#
# ===  Source finding for image 'u67n2601r_c0m.fits':
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 1) started at: 13:09:29.594 (13/12/2017)
#
#      Found 184 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 2) started at: 13:09:29.916 (13/12/2017)
#
#      Found 165 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 3) started at: 13:09:30.187 (13/12/2017)
#
#      Found 102 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 4) started at: 13:09:30.527 (13/12/2017)
#
#      Found 108 objects.
#
# ===  Found a TOTAL of 559 objects in image 'u67n2601r_c0m.fits'
#
#
#
# ===  Source finding for image 'u67n2602r_c0m.fits':
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 1) started at: 13:09:30.992 (13/12/2017)
#
#      Found 180 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 2) started at: 13:09:31.239 (13/12/2017)
#
#      Found 291 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 3) started at: 13:09:31.576 (13/12/2017)
#
#      Found 164 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 4) started at: 13:09:31.932 (13/12/2017)
#
#      Found 156 objects.
#
# ===  Found a TOTAL of 791 objects in image 'u67n2602r_c0m.fits'
#
#
#
#  Catalog trimmed to 559 objects
#
#
# ====================
# Aligning all input images to WCS defined by u67n2601r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u67n2602r_c0m.fits
#
# Matching sources from 'u67n2602r_c0m.fits' with sources from reference image 'u67n2601r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.809131369918 -0.718222279009
#
#     with significance of  486.360611139 and  27.0  matches
#
# Found 74 matches for u67n2602r_c0m.fits...
#
# Computed  rscale  fit for  u67n2602r_c0m.fits :
#
# XSH: -0.0232849  YSH: 0.0184867    ROT: 0.000565629    SCALE: 0.999969
#
# XRMS: 0.135195    YRMS: 0.159836
#
# RMS_RA: 3.31349e-06 (deg)   RMS_DEC: 1.87682e-06 (deg)
#
# Final solution based on  70  objects.
#
# wrote XY data to:  u67n2602r_c0m_catalog_fit.match
#
# Writing out shiftfile : 8shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.023285
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 13:09:32.773 (13/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u67n2601r_c0m.fits
#
#     u67n2602r_c0m.fits
#
# ===  Source finding for image 'u67n2601r_c0m.fits':
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 1) started at: 13:09:33.032 (13/12/2017)
#
#      Found 184 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 2) started at: 13:09:33.324 (13/12/2017)
#
#      Found 165 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 3) started at: 13:09:33.591 (13/12/2017)
#
#      Found 102 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 4) started at: 13:09:33.864 (13/12/2017)
#
#      Found 108 objects.
#
# ===  Found a TOTAL of 559 objects in image 'u67n2601r_c0m.fits'
#
#
#
# ===  Source finding for image 'u67n2602r_c0m.fits':
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 1) started at: 13:09:34.379 (13/12/2017)
#
#      Found 180 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 2) started at: 13:09:34.629 (13/12/2017)
#
#      Found 291 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 3) started at: 13:09:35.012 (13/12/2017)
#
#      Found 164 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 4) started at: 13:09:35.368 (13/12/2017)
#
#      Found 156 objects.
#
# ===  Found a TOTAL of 791 objects in image 'u67n2602r_c0m.fits'
#
#
#
#  Catalog trimmed to 559 objects
#
#
# ====================
# Aligning all input images to WCS defined by u67n2601r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u67n2602r_c0m.fits
#
# Matching sources from 'u67n2602r_c0m.fits' with sources from reference image 'u67n2601r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.809131369918 -0.718222279009
#
#     with significance of  486.360611139 and  27.0  matches
#
# Found 74 matches for u67n2602r_c0m.fits...
#
# Computed  rscale  fit for  u67n2602r_c0m.fits :
#
# XSH: -0.0232849  YSH: 0.0184867    ROT: 0.000565629    SCALE: 0.999969
#
# XRMS: 0.135195    YRMS: 0.159836
#
# RMS_RA: 3.31349e-06 (deg)   RMS_DEC: 1.87682e-06 (deg)
#
# Final solution based on  70  objects.
#
# wrote XY data to:  u67n2602r_c0m_catalog_fit.match
#
# Writing out shiftfile : 9shift.txt
#
# Trailer file written to:  tweakreg.log
#
# 0.000000
# -0.023285

# %%
# change to a jupyter table
dt=test.to_pandas()
dt.to_pickle('data.pickle')
good_table=pandas.read_pickle('data.pickle')

# %%
# take only unfailed sessions
good_peakmax = good_table[good_table['y_rms'] != 'failed']

# %%
good_peakmax
# Out:
#          shift                file     x_rms     y_rms  threshold  conv_width  \
# 0   1shift.txt  u67n2601r_c0m.fits  0.000000  0.000000          8         4.6
# 1   1shift.txt  u67n2602r_c0m.fits  0.135195  0.159836          8         4.6
# 2   2shift.txt  u67n2601r_c0m.fits  0.000000  0.000000          8         4.6
# 3   2shift.txt  u67n2602r_c0m.fits  0.135195  0.159836          8         4.6
# 4   3shift.txt  u67n2601r_c0m.fits  0.000000  0.000000          8         4.6
# 5   3shift.txt  u67n2602r_c0m.fits  0.135195  0.159836          8         4.6
# 6   4shift.txt  u67n2601r_c0m.fits  0.000000  0.000000          8         4.6
# 7   4shift.txt  u67n2602r_c0m.fits  0.135195  0.159836          8         4.6
# 8   5shift.txt  u67n2601r_c0m.fits  0.000000  0.000000          8         4.6
# 9   5shift.txt  u67n2602r_c0m.fits  0.135195  0.159836          8         4.6
# 10  6shift.txt  u67n2601r_c0m.fits  0.000000  0.000000          8         4.6
# 11  6shift.txt  u67n2602r_c0m.fits  0.135195  0.159836          8         4.6
# 12  7shift.txt  u67n2601r_c0m.fits  0.000000  0.000000          8         4.6
# 13  7shift.txt  u67n2602r_c0m.fits  0.135195  0.159836          8         4.6
# 14  8shift.txt  u67n2601r_c0m.fits  0.000000  0.000000          8         4.6
# 15  8shift.txt  u67n2602r_c0m.fits  0.135195  0.159836          8         4.6
# 16  9shift.txt  u67n2601r_c0m.fits  0.000000  0.000000          8         4.6
# 17  9shift.txt  u67n2602r_c0m.fits  0.135195  0.159836          8         4.6
#
#     roundlo  roundhi  peakmax
# 0      -0.5      0.8     4000
# 1      -0.5      0.8     4000
# 2      -0.5      0.8     4500
# 3      -0.5      0.8     4500
# 4      -0.5      0.8     5000
# 5      -0.5      0.8     5000
# 6      -0.5      0.8     5500
# 7      -0.5      0.8     5500
# 8      -0.5      0.8     6000
# 9      -0.5      0.8     6000
# 10     -0.5      0.8     6500
# 11     -0.5      0.8     6500
# 12     -0.5      0.8     7000
# 13     -0.5      0.8     7000
# 14     -0.5      0.8     7500
# 15     -0.5      0.8     7500
# 16     -0.5      0.8     8000
# 17     -0.5      0.8     8000

# %%
# plot figure for all sub-exp ??????????????????????????????????????????
plt.figure(figsize = (7,7))
plt.plot(good_peakmax['peakmax'],good_peakmax['x_rms'],'.g')
plt.plot(good_peakmax['peakmax'],good_peakmax['y_rms'],'.b')
plt.title('x,y_rms(peakmax)-g,b')
plt.show()

# %%
################################## tweakreg run for good parameters without headers, see figures- 
# thresh = 5, conv = 4.6 roundnlo = -0.5, rounfhi = 0.8, peakmax = 4000

# %%
# final parameters to see plots
import os
from drizzlepac import tweakreg
os.chdir('/Users/natalie/anaconda2/envs/iraf27/iraf/sn/2001ci/2001ci_pre/tweak_606')
tweakreg.TweakReg('*c0m.fits', exclusions='WFPC2_exclude.txt', updatehdr=False, shiftfile=True, outshifts='shift_final', residplot='both', see2dplot='Yes', use_sharp_round='Yes', threshold=8, conv_width=4.6, roundlo=-0.5, roundhi=0.8, peakmax=4000)
# Out:
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 13:11:23.052 (13/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u67n2601r_c0m.fits
#
#     u67n2602r_c0m.fits
#
# ===  Source finding for image 'u67n2601r_c0m.fits':
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 1) started at: 13:11:23.35 (13/12/2017)
#
#      Found 184 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 2) started at: 13:11:23.668 (13/12/2017)
#
#      Found 162 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 3) started at: 13:11:24.005 (13/12/2017)
#
#      Found 101 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 4) started at: 13:11:24.284 (13/12/2017)
#
#      Found 108 objects.
#
# ===  Found a TOTAL of 555 objects in image 'u67n2601r_c0m.fits'
#
#
#
# ===  Source finding for image 'u67n2602r_c0m.fits':
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 1) started at: 13:11:24.783 (13/12/2017)
#
#      Found 179 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 2) started at: 13:11:25.037 (13/12/2017)
#
#      Found 290 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 3) started at: 13:11:25.376 (13/12/2017)
#
#      Found 159 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 4) started at: 13:11:25.723 (13/12/2017)
#
#      Found 153 objects.
#
# ===  Found a TOTAL of 781 objects in image 'u67n2602r_c0m.fits'
#
#
#
#  Catalog trimmed to 555 objects
#
#
# ====================
# Aligning all input images to WCS defined by u67n2601r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u67n2602r_c0m.fits
#
# Matching sources from 'u67n2602r_c0m.fits' with sources from reference image 'u67n2601r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.809131369918 -0.718222279009
#
#     with significance of  486.360611139 and  27.0  matches
#
# Found 74 matches for u67n2602r_c0m.fits...
#
# Computed  rscale  fit for  u67n2602r_c0m.fits :
#
# XSH: -0.0232849  YSH: 0.0184867    ROT: 0.000565629    SCALE: 0.999969
#
# XRMS: 0.135195    YRMS: 0.159836
#
# RMS_RA: 3.31349e-06 (deg)   RMS_DEC: 1.87682e-06 (deg)
#
# Final solution based on  70  objects.
#
# wrote XY data to:  u67n2602r_c0m_catalog_fit.match
#
# Total # points:  70
#
# # of points after clipping:  70
#
# Total # points:  70
#
# # of points after clipping:  70
#
# Press ENTER for next image,
#       'n' to continue without updating header or
#       'q' to quit immediately...
#
# Writing out shiftfile : shift_final
#
# Trailer file written to:  tweakreg.log

# %%
# final run with hdr update
import os
from drizzlepac import tweakreg
os.chdir('/Users/natalie/anaconda2/envs/iraf27/iraf/sn/2001ci/2001ci_pre/tweak_606')
tweakreg.TweakReg('*c0m.fits', exclusions='WFPC2_exclude.txt', updatehdr=True, shiftfile=True, outshifts='shift_final', residplot='both', see2dplot='Yes', use_sharp_round='Yes', threshold=8, conv_width=4.6, roundlo=-0.5, roundhi=0.8, peakmax=4000)
# Out:
# Setting up logfile :  tweakreg.log
#
# TweakReg Version 1.4.3(01-Jul-2016) started at: 13:12:34.64 (13/12/2017)
#
# Version Information
#
# --------------------
#
# Python Version 2.7.13 |Continuum Analytics, Inc.| (default, Dec 20 2016, 23:05:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
#
# numpy Version -> 1.13.1
#
# astropy Version -> 2.0.2
#
# stwcs Version -> 1.3.2
#
# u6ea5403m_c0m.fits
#
# u6ea5402m_c0m.fits
#
# u6ea5404m_c0m.fits
#
# u6ea5401m_c0m.fits
#
#
# Finding shifts for:
#
#     u67n2601r_c0m.fits
#
#     u67n2602r_c0m.fits
#
# ===  Source finding for image 'u67n2601r_c0m.fits':
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 1) started at: 13:12:35.125 (13/12/2017)
#
#      Found 184 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 2) started at: 13:12:35.529 (13/12/2017)
#
#      Found 162 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 3) started at: 13:12:35.840 (13/12/2017)
#
#      Found 101 objects.
#
#   #  Source finding for 'u67n2601r_c0m.fits', EXT=('SCI', 4) started at: 13:12:36.134 (13/12/2017)
#
#      Found 108 objects.
#
# ===  Found a TOTAL of 555 objects in image 'u67n2601r_c0m.fits'
#
#
#
# ===  Source finding for image 'u67n2602r_c0m.fits':
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 1) started at: 13:12:36.681 (13/12/2017)
#
#      Found 179 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 2) started at: 13:12:37.033 (13/12/2017)
#
#      Found 290 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 3) started at: 13:12:37.415 (13/12/2017)
#
#      Found 159 objects.
#
#   #  Source finding for 'u67n2602r_c0m.fits', EXT=('SCI', 4) started at: 13:12:37.81 (13/12/2017)
#
#      Found 153 objects.
#
# ===  Found a TOTAL of 781 objects in image 'u67n2602r_c0m.fits'
#
#
#
#  Catalog trimmed to 555 objects
#
#
# ====================
# Aligning all input images to WCS defined by u67n2601r_c0m.fits
# ====================
#
#
# ====================
#
# Performing fit for: u67n2602r_c0m.fits
#
# Matching sources from 'u67n2602r_c0m.fits' with sources from reference image 'u67n2601r_c0m.fits'
#
# Computing initial guess for X and Y shifts...
#
# Found initial X and Y shifts of  -0.809131369918 -0.718222279009
#
#     with significance of  486.360611139 and  27.0  matches
#
# Found 74 matches for u67n2602r_c0m.fits...
#
# Computed  rscale  fit for  u67n2602r_c0m.fits :
#
# XSH: -0.0232849  YSH: 0.0184867    ROT: 0.000565629    SCALE: 0.999969
#
# XRMS: 0.135195    YRMS: 0.159836
#
# RMS_RA: 3.31349e-06 (deg)   RMS_DEC: 1.87682e-06 (deg)
#
# Final solution based on  70  objects.
#
# wrote XY data to:  u67n2602r_c0m_catalog_fit.match
#
# Total # points:  70
#
# # of points after clipping:  70
#
# Total # points:  70
#
# # of points after clipping:  70
#
# Press ENTER for next image,
#       'n' to continue without updating header or
#       'q' to quit immediately...
#
#
# ....Updating header for u67n2602r_c0m.fits...
#
#
# Processing u67n2602r_c0m.fits['SCI',1]
#
# Updating header for u67n2602r_c0m.fits[1]
#
# WCSNAME  :  TWEAK
#
#
# Processing u67n2602r_c0m.fits['SCI',2]
#
# Updating header for u67n2602r_c0m.fits[2]
#
# WCSNAME  :  TWEAK
#
#
# Processing u67n2602r_c0m.fits['SCI',3]
#
# Updating header for u67n2602r_c0m.fits[3]
#
# WCSNAME  :  TWEAK
#
#
# Processing u67n2602r_c0m.fits['SCI',4]
#
# Updating header for u67n2602r_c0m.fits[4]
#
# WCSNAME  :  TWEAK
#
# Writing out shiftfile : shift_final
#
# Trailer file written to:  tweakreg.log

# %%
# tweaked checks
from astropy.io import fits
tw=fits.open('/Users/natalie/anaconda2/envs/iraf27/iraf/sn/2001ci/2001ci_pre/tweak_547/u54v0304r_c0m.fits')

# %%
tw[1].header['WCSNAME']
# Out:
# 'TWEAK'

# %%
tw[1].header
